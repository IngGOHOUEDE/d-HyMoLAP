# %% [markdown]
# > **This notebook implements d-HyMoLAP (a dimensionally consistent reformulation of the HyMoLAP rainfall–runoff model) over CAMELS-FR catchments with less than 10% missing discharge data and stores the resulting calibrated parameters and performance metrics in `dHyMoLAP_Simulation_Data_CAMELS_FR.csv`.**
#
# **Author:** Lionel Cedric Gohouede

# %% [markdown]
# # IMPORT LIBRARIES

# %%
# Import libraries
import numpy as np
import pandas as pd
from numba import njit
import math
import xarray as xr
import matplotlib.pyplot as plt
from google.colab import drive
from matplotlib.dates import DateFormatter
from scipy.optimize import minimize

# %% [markdown]
# ##USE DATA FROM PYTHON

# %%
pip install aqua-fetch
# Out:
# Collecting aqua-fetch
#   Downloading aqua_fetch-1.0.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas<=2.3.3,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from aqua-fetch) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from aqua-fetch) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.3.3,>=0.25.0->aqua-fetch) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.3.3,>=0.25.0->aqua-fetch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.3.3,>=0.25.0->aqua-fetch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.3.3,>=0.25.0->aqua-fetch) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->aqua-fetch) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->aqua-fetch) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->aqua-fetch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->aqua-fetch) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<=2.3.3,>=0.25.0->aqua-fetch) (1.17.0)
# Downloading aqua_fetch-1.0.1-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.1/289.1 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: aqua-fetch
# Successfully installed aqua-fetch-1.0.1

# %%
from aqua_fetch import RainfallRunoff

rr = RainfallRunoff("CAMELS_FR")
# Out:
# /usr/local/lib/python3.12/dist-packages/aqua_fetch/rr/utils.py:127: UserWarning: netCDF4 module is not installed. Please install it to save data in netcdf format
#   warnings.warn(msg, UserWarning)
# downloading 6 files to /usr/local/lib/python3.12/dist-packages/aqua_fetch/data/CAMELS/CAMELS_FR
# downloading ADDITIONAL_LICENSES.zip
# 0% of 0.07 MB downloaded
# 100% of 0.07 MB downloaded
# downloading CAMELS_FR_attributes.zip
# 0% of 9.88 MB downloaded
# 100% of 9.88 MB downloaded
# downloading CAMELS_FR_geography.zip
# 0% of 1.45 MB downloaded
# 100% of 1.45 MB downloaded
# downloading CAMELS_FR_time_series.zip
# 0% of 361.39 MB downloaded
# 20% of 361.39 MB downloaded
# 40% of 361.39 MB downloaded
# 60% of 361.39 MB downloaded
# 80% of 361.39 MB downloaded
# 100% of 361.39 MB downloaded
# downloading README.md
# 0% of 0.01 MB downloaded
# 100% of 0.01 MB downloaded
# downloading CAMELS-FR_description.ods
# 0% of 0.05 MB downloaded
# 100% of 0.05 MB downloaded
# unzipping files in /usr/local/lib/python3.12/dist-packages/aqua_fetch/data/CAMELS/CAMELS_FR
# unzipping ADDITIONAL_LICENSES.zip to ADDITIONAL_LICENSES
# unzipping CAMELS_FR_time_series.zip to CAMELS_FR_time_series
# unzipping CAMELS_FR_geography.zip to CAMELS_FR_geography
# unzipping CAMELS_FR_attributes.zip to CAMELS_FR_attributes
# P392252001  not found in site_general_attributes.csv
# P613402001  not found in site_general_attributes.csv

# %%
meta, ds = rr.fetch()
# Out:
# Read 654 stations for 22 dyn features in 52.94 seconds with 2 cpus.

# %%
print(ds.head())
# Out:
# <xarray.Dataset> Size: 131kB
# Dimensions:           (time: 5, dynamic_features: 5)
# Coordinates:
#   * time              (time) datetime64[ns] 40B 1970-01-01 ... 1970-01-05
#   * dynamic_features  (dynamic_features) object 40B 'q_cms_obs' ... 'tsd_val_m'
# Data variables: (12/654)
#     A105003001        (time, dynamic_features) float64 200B 1.65e+03 ... 10.0
#     A107020001        (time, dynamic_features) float64 200B nan nan ... nan nan
#     A112020001        (time, dynamic_features) float64 200B 1.04e+03 ... 10.0
#     A116003002        (time, dynamic_features) float64 200B nan nan ... nan nan
#     A140202001        (time, dynamic_features) float64 200B nan nan ... nan nan
#     A202030001        (time, dynamic_features) float64 200B nan nan ... nan nan
#     ...                ...
#     Y661401001        (time, dynamic_features) float64 200B 860.0 0.441 ... 10.0
#     Y781000101        (time, dynamic_features) float64 200B nan nan ... nan nan
#     Y862000101        (time, dynamic_features) float64 200B 1.54e+04 ... 10.0
#     Y881000102        (time, dynamic_features) float64 200B 7.4e+03 ... 10.0
#     Y902000101        (time, dynamic_features) float64 200B 6.86e+03 ... 10.0
#     Y960000102        (time, dynamic_features) float64 200B nan nan ... nan nan

# %%
print(ds.dynamic_features.values)
# Out:
# ['q_cms_obs' 'q_mm_obs' 'tsd_val_s' 'tsd_val_q' 'tsd_val_m' 'tsd_val_c'
#  'tsd_val_i' 'pcp_mm' 'pcp_mm_solfrac' 'airtemp_C_mean' 'pet_mm_ou'
#  'pet_mm_pe' 'pet_mm_pm' 'windspeed_mps' 'spechum_gkg' 'lwdownrad_wm2'
#  'solrad_wm2' 'tsd_swi_gr' 'tsd_swi_isba' 'tsd_swe_isba' 'airtemp_C_min'
#  'airtemp_C_max']

# %%
# Full period
print(ds["time"].values[0], ds["time"].values[-1])
# Out:
# 1970-01-01T00:00:00.000000000 2021-12-31T00:00:00.000000000

# %% [markdown]
# ## **Main Code**

# %%
import math
import numpy as np
import pandas as pd
from numba import njit
from scipy.optimize import minimize

# ============================================
# 1. dHyMoLAP MODEL
# ============================================
@njit
def dHyMoLAP_Model(params, Q0, q):
    mu, lambda_, Qs, qs = params
    N = len(q)

    k = np.zeros(N)
    x = np.zeros(N)
    r = np.zeros(N)

    if qs > 0.0:
        for t in range(N):
            r[t] = q[t] / qs

    if Qs > 0.0:
        k[0] = Q0 / Qs
    else:
        k[0] = 0.0

    if lambda_ == 0.0:
        return np.zeros(N)

    mu_over_lambda = mu / lambda_
    one_minus_mu_over_lambda = 1.0 - mu_over_lambda
    one_over_lambda = 1.0 / lambda_
    power_term = 2.0 * mu - 1.0

    for t in range(1, N):

        if math.isnan(r[t]):
            k[t] = k[t-1]
            x[t] = x[t-1]
            continue

        if r[t] > 0.0:
            x[t] = x[t-1] + mu_over_lambda * r[t]
        else:
            x[t] = one_minus_mu_over_lambda * x[t-1]

        k_prev = k[t-1]
        if k_prev <= 0.0:
            decay = 0.0
        else:
            decay = mu_over_lambda * (k_prev ** power_term)

        k[t] = max(0.0, k_prev - decay + one_over_lambda * x[t] * r[t])

    return k * Qs

# ============================================
# 2. STANDARDIZED HYDROLOGICAL METRICS
# ============================================
def NSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs = obs[mask]
    valid_sim = sim[mask]

    if valid_obs.size == 0 or np.var(valid_obs) == 0.0:
        return np.nan

    numerator = np.sum((valid_sim - valid_obs) ** 2)
    denominator = np.sum((valid_obs - np.mean(valid_obs)) ** 2)
    return 1.0 - (numerator / denominator)

def RMSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs = obs[mask]
    valid_sim = sim[mask]

    if valid_obs.size == 0:
        return np.nan

    return np.sqrt(np.mean((valid_sim - valid_obs) ** 2))

def NNSE(obs, sim):
    nse = NSE(obs, sim)
    if not np.isfinite(nse):
        return np.nan
    return 1.0 / (2.0 - nse)

def PBIAS(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs = obs[mask]
    valid_sim = sim[mask]

    if valid_obs.size == 0:
        return np.nan

    sum_obs = np.sum(valid_obs)
    if sum_obs == 0.0:
        return np.nan

    return 100.0 * (np.sum(valid_sim - valid_obs) / sum_obs)

def KGE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    o = obs[mask]
    s = sim[mask]

    if o.size == 0:
        return np.nan

    obs_mean = np.mean(o)
    sim_mean = np.mean(s)
    sigma_obs = np.std(o)
    sigma_sim = np.std(s)

    if sigma_obs == 0.0 or sigma_sim == 0.0 or obs_mean == 0.0:
        return np.nan

    r = np.corrcoef(o, s)[0, 1]
    if not np.isfinite(r):
        return np.nan

    alpha = sigma_sim / sigma_obs
    beta = sim_mean / obs_mean

    return 1.0 - np.sqrt((r - 1.0) ** 2 + (alpha - 1.0) ** 2 + (beta - 1.0) ** 2)

def FHV(obs, sim):
    """
    Top-2% high flows (FHV) - Yilmaz et al. (2008)
    """
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    o = obs[mask]
    s = sim[mask]
    L = o.size

    if L == 0:
        return np.nan

    o_sorted = np.sort(o)[::-1]
    s_sorted = np.sort(s)[::-1]

    n_hv = max(1, int(round(0.02 * L)))
    sum_obs_hv = np.sum(o_sorted[:n_hv])
    sum_sim_hv = np.sum(s_sorted[:n_hv])

    if sum_obs_hv == 0.0:
        return np.nan

    return 100.0 * ((sum_sim_hv - sum_obs_hv) / sum_obs_hv)

def FLV(obs, sim):
    """
    Bottom-30% low flows (FLV) - Yilmaz et al. (2008) Logarithmic Formulation
    """
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    o = obs[mask]
    s = sim[mask]
    L = o.size

    if L == 0:
        return np.nan

    o_sorted = np.sort(o)
    s_sorted = np.sort(s)

    n_lv = max(1, int(round(0.30 * L)))

    eps = 1e-5
    log_o = np.log10(o_sorted[:n_lv] + eps)
    log_s = np.log10(s_sorted[:n_lv] + eps)

    min_o = log_o[0]
    min_s = log_s[0]

    num_s = np.sum(log_s - min_s)
    num_o = np.sum(log_o - min_o)

    if num_o == 0.0:
        return np.nan

    return -100.0 * ((num_s - num_o) / num_o)

def compute_pte(obs, sim, dates):
    """
    Computes Mean Absolute Annual Peak Timing Error (PTE) in days.
    """
    df = pd.DataFrame({'obs': obs, 'sim': sim}, index=pd.DatetimeIndex(dates))
    df = df.dropna()

    if df.empty:
        return np.nan

    pte_list = []
    for year, group in df.groupby(df.index.year):
        days_in_year = pd.Timestamp(year, 12, 31).dayofyear
        if len(group) < 0.8 * days_in_year:
            continue

        idx_obs_peak = group['obs'].idxmax()
        idx_sim_peak = group['sim'].idxmax()

        diff_days = abs((idx_sim_peak - idx_obs_peak).days)
        pte_list.append(diff_days)

    return np.mean(pte_list) if pte_list else np.nan

# ============================================
# 3. OPTIMIZATION OBJECTIVE
# ============================================
def objective(params, Q0, q_train, Q_obs_train):
    Q_sim = dHyMoLAP_Model(params, Q0, q_train)
    nse = NSE(Q_obs_train, Q_sim)
    return 1.0 - nse if np.isfinite(nse) else 1e9

# ============================================
# 4. ROBUST EXECUTION LOOP
# ============================================
ds_recent = ds.sel(time=slice("2000-01-01", "2021-12-31")).load()
times = ds_recent.time.to_numpy()

all_stations = list(ds_recent.keys())

b1_ratio = 0.7
max_missing_ratio = 0.1
results = {}

for i, station_id in enumerate(all_stations, 1):
    print(f"\n=== Station {station_id} ===, Number = {i}")

    Q_obs_raw = ds_recent[station_id].sel(dynamic_features="q_cms_obs").to_numpy()
    Q_obs = Q_obs_raw / 1000.0

    P   = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET = ds_recent[station_id].sel(dynamic_features="pet_mm_pm").to_numpy()

    q = np.maximum(0.0, P - PET)
    N = len(Q_obs)

    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station ignored (no valid data).")
        continue

    missing_count = np.sum(np.isnan(Q_obs))
    missing_ratio = missing_count / N

    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    b1 = int(N * b1_ratio)

    valid_Q_idx = np.where(~np.isnan(Q_obs))[0]
    Q0 = Q_obs[valid_Q_idx[0]] if len(valid_Q_idx) > 0 else 0.0

    q_train = q[:b1]
    Q_obs_train = Q_obs[:b1]

    Qs_upper = 2.0 * np.nanmax(Q_obs_train) if np.any(~np.isnan(Q_obs_train)) else np.nan
    qs_upper = 2.0 * np.nanmax(q_train) if np.any(~np.isnan(q_train)) else np.nan

    if not np.isfinite(Qs_upper) or not np.isfinite(qs_upper) or Qs_upper <= 1e-3 or qs_upper <= 1e-3:
        print("⚠️ Station skipped (invalid Qs/qs bounds from training data).")
        continue

    param_bounds = [(0.5, 5.0), (1e-3, 200.0), (1e-3, Qs_upper), (1e-3, qs_upper)]

    initial_guesses = [
        [1.1, 20.0, np.nanmean(Q_obs_train), np.nanmean(q_train)]
    ]

    best_res = None
    best_val = float("inf")

    for guess in initial_guesses:
        res = minimize(
            objective,
            np.array(guess, dtype=np.float64),
            args=(Q0, q_train, Q_obs_train),
            method="Nelder-Mead",
            bounds=param_bounds,
            options={'maxiter': 2500, 'disp': False}
        )
        if res.fun < best_val:
            best_val = res.fun
            best_res = res

    MU, LAMBDA, Qs_best, qs_best = best_res.x

    # Comprehensive Evaluation Run
    Qsim = dHyMoLAP_Model(np.array([MU, LAMBDA, Qs_best, qs_best]), Q0, q)

    # Core Metric Assignment
    NSE_train   = NSE(Q_obs_train, Qsim[:b1])
    NSE_val     = NSE(Q_obs[b1:], Qsim[b1:])
    NNSE_train  = NNSE(Q_obs_train, Qsim[:b1])
    NNSE_val    = NNSE(Q_obs[b1:], Qsim[b1:])
    RMSE_train  = RMSE(Q_obs_train, Qsim[:b1])
    RMSE_val    = RMSE(Q_obs[b1:], Qsim[b1:])
    PBIAS_train = PBIAS(Q_obs_train, Qsim[:b1])
    PBIAS_val   = PBIAS(Q_obs[b1:], Qsim[b1:])
    FHV_train   = FHV(Q_obs_train, Qsim[:b1])
    FHV_val     = FHV(Q_obs[b1:], Qsim[b1:])
    FLV_train   = FLV(Q_obs_train, Qsim[:b1])
    FLV_val     = FLV(Q_obs[b1:], Qsim[b1:])
    KGE_train   = KGE(Q_obs_train, Qsim[:b1])
    KGE_val     = KGE(Q_obs[b1:], Qsim[b1:])

    # Peak Timing Error Assignment
    PTE_train = compute_pte(Q_obs_train, Qsim[:b1], times[:b1])
    PTE_val   = compute_pte(Q_obs[b1:], Qsim[b1:], times[b1:])

    # Dynamic Seasonal Sub-Looping
    months = pd.DatetimeIndex(times).month
    seasons_dict = {"DJF": [12, 1, 2], "MAM": [3, 4, 5], "JJA": [6, 7, 8], "SON": [9, 10, 11]}
    seasonal_metrics = {}

    for season, m_list in seasons_dict.items():
        mask_season = np.isin(months, m_list)
        mask_s_train = mask_season[:b1]
        mask_s_val   = mask_season[b1:]

        Q_obs_s_train, Q_sim_s_train = Q_obs_train[mask_s_train], Qsim[:b1][mask_s_train]
        Q_obs_s_val,   Q_sim_s_val   = Q_obs[b1:][mask_s_val],   Qsim[b1:][mask_s_val]

        seasonal_metrics[f"NSE_{season}_train"]   = NSE(Q_obs_s_train, Q_sim_s_train)
        seasonal_metrics[f"NSE_{season}_val"]     = NSE(Q_obs_s_val, Q_sim_s_val)
        seasonal_metrics[f"KGE_{season}_train"]   = KGE(Q_obs_s_train, Q_sim_s_train)
        seasonal_metrics[f"KGE_{season}_val"]     = KGE(Q_obs_s_val, Q_sim_s_val)
        seasonal_metrics[f"RMSE_{season}_train"]  = RMSE(Q_obs_s_train, Q_sim_s_train)
        seasonal_metrics[f"RMSE_{season}_val"]    = RMSE(Q_obs_s_val, Q_sim_s_val)
        seasonal_metrics[f"PBIAS_{season}_train"] = PBIAS(Q_obs_s_train, Q_sim_s_train)
        seasonal_metrics[f"PBIAS_{season}_val"]   = PBIAS(Q_obs_s_val, Q_sim_s_val)

    print(f"✅ Train NSE: {NSE_train:.3f}, Val NSE: {NSE_val:.3f}")
    print(f"   Train KGE: {KGE_train:.3f}, Val KGE: {KGE_val:.3f}")
    print(f"   Train RMSE: {RMSE_train:.3f}, Val RMSE: {RMSE_val:.3f}")
    print(f"   Train PBIAS: {PBIAS_train:.3f}%, Val PBIAS: {PBIAS_val:.3f}%")
    print(f"   Train FLV: {FLV_train:.3f}%, Val FLV: {FLV_val:.3f}%")
    print(f"   Train PTE: {PTE_train:.1f} days, Val PTE: {PTE_val:.1f} days")
    print(f"   Params: mu={MU:.3f}, lambda={LAMBDA:.3f}, Qs={Qs_best:.3f}, qs={qs_best:.3f}")

    results[station_id] = {
        "param_names": ["mu", "lambda", "Qs", "qs"],
        "params": [MU, LAMBDA, Qs_best, qs_best],
        "NSE_train": NSE_train,     "NSE_val": NSE_val,
        "NNSE_train": NNSE_train,   "NNSE_val": NNSE_val,
        "RMSE_train": RMSE_train,   "RMSE_val": RMSE_val,
        "PBIAS_train": PBIAS_train, "PBIAS_val": PBIAS_val,
        "FHV_train": FHV_train,     "FHV_val": FHV_val,
        "FLV_train": FLV_train,     "FLV_val": FLV_val,
        "KGE_train": KGE_train,     "KGE_val": KGE_val,
        "PTE_train": PTE_train,     "PTE_val": PTE_val,
        **seasonal_metrics,
        "Qsim": Qsim,
        "missing_ratio": missing_ratio,
        "missing_count": missing_count,
    }

print(f"\n✅ Simulation complete for {len(results)} valid basins.")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# === Station A605102001 ===, Number = 35
# ✅ Train NSE: 0.686, Val NSE: 0.767
#    Train KGE: 0.763, Val KGE: 0.796
#    Train RMSE: 4.182, Val RMSE: 3.811
#    Train PBIAS: -0.911%, Val PBIAS: 2.057%
#    Train FLV: 23.630%, Val FLV: -29.645%
#    Train PTE: 47.6 days, Val PTE: 69.2 days
#    Params: mu=1.224, lambda=18.731, Qs=3.218, qs=2.849
#
# === Station A615103001 ===, Number = 36
# ✅ Train NSE: 0.709, Val NSE: 0.830
#    Train KGE: 0.778, Val KGE: 0.868
#    Train RMSE: 7.185, Val RMSE: 5.716
#    Train PBIAS: -0.347%, Val PBIAS: 3.085%
#    Train FLV: 5.262%, Val FLV: -47.574%
#    Train PTE: 61.5 days, Val PTE: 69.0 days
#    Params: mu=1.203, lambda=23.571, Qs=3.931, qs=1.958
#
# === Station A662121202 ===, Number = 37
# ⚠️ Too many missing values (55.7%)
#
# === Station A673122001 ===, Number = 38
# ✅ Train NSE: 0.610, Val NSE: 0.651
#    Train KGE: 0.709, Val KGE: 0.756
#    Train RMSE: 4.264, Val RMSE: 3.791
#    Train PBIAS: -3.900%, Val PBIAS: 7.090%
#    Train FLV: -260.531%, Val FLV: -213.267%
#    Train PTE: 78.1 days, Val PTE: 138.8 days
#    Params: mu=1.108, lambda=24.287, Qs=0.019, qs=0.116
#
# === Station A712201001 ===, Number = 39
# ✅ Train NSE: 0.547, Val NSE: 0.782
#    Train KGE: 0.575, Val KGE: 0.721
#    Train RMSE: 1.396, Val RMSE: 0.921
#    Train PBIAS: 9.024%, Val PBIAS: 18.184%
#    Train FLV: -6.890%, Val FLV: -43.061%
#    Train PTE: 124.0 days, Val PTE: 6.7 days
#    Params: mu=1.045, lambda=26.733, Qs=0.001, qs=0.046
#
# === Station A764201001 ===, Number = 40
# ⚠️ Too many missing values (48.3%)
#
# === Station A788101001 ===, Number = 41
# ⚠️ Too many missing values (29.1%)
#
# === Station A807101001 ===, Number = 42
# ✅ Train NSE: 0.530, Val NSE: 0.545
#    Train KGE: 0.564, Val KGE: 0.399
#    Train RMSE: 4.629, Val RMSE: 4.756
#    Train PBIAS: 12.368%, Val PBIAS: -25.769%
#    Train FLV: -6.794%, Val FLV: -45.604%
#    Train PTE: 81.1 days, Val PTE: 46.0 days
#    Params: mu=1.071, lambda=23.726, Qs=0.001, qs=0.024
#
# === Station A843101001 ===, Number = 43
# ✅ Train NSE: 0.654, Val NSE: 0.725
#    Train KGE: 0.707, Val KGE: 0.699
#    Train RMSE: 9.531, Val RMSE: 9.273
#    Train PBIAS: 4.123%, Val PBIAS: -2.521%
#    Train FLV: -40.985%, Val FLV: -336.293%
#    Train PTE: 149.4 days, Val PTE: 45.3 days
#    Params: mu=1.060, lambda=27.843, Qs=0.001, qs=0.013
#
# === Station A850061001 ===, Number = 44
# ✅ Train NSE: 0.725, Val NSE: 0.832
#    Train KGE: 0.789, Val KGE: 0.866
#    Train RMSE: 76.090, Val RMSE: 62.318
#    Train PBIAS: -0.065%, Val PBIAS: 2.434%
#    Train FLV: -49.559%, Val FLV: -72.879%
#    Train PTE: 90.1 days, Val PTE: 55.7 days
#    Params: mu=1.087, lambda=27.683, Qs=0.676, qs=0.135
#
# === Station A901305050 ===, Number = 45
# ✅ Train NSE: 0.656, Val NSE: 0.798
#    Train KGE: 0.743, Val KGE: 0.825
#    Train RMSE: 0.553, Val RMSE: 0.484
#    Train PBIAS: -0.790%, Val PBIAS: 11.401%
#    Train FLV: -132.953%, Val FLV: -106.667%
#    Train PTE: 60.1 days, Val PTE: 123.5 days
#    Params: mu=1.225, lambda=31.853, Qs=1.085, qs=2.860
#
# === Station A907105050 ===, Number = 46
# ✅ Train NSE: 0.595, Val NSE: 0.735
#    Train KGE: 0.657, Val KGE: 0.763
#    Train RMSE: 6.281, Val RMSE: 5.256
#    Train PBIAS: 3.585%, Val PBIAS: 11.049%
#    Train FLV: -103.416%, Val FLV: -71.421%
#    Train PTE: 104.9 days, Val PTE: 54.8 days
#    Params: mu=1.091, lambda=36.509, Qs=0.001, qs=0.014
#
# === Station A926000101 ===, Number = 47
# ✅ Train NSE: 0.541, Val NSE: 0.661
#    Train KGE: 0.625, Val KGE: 0.679
#    Train RMSE: 2.962, Val RMSE: 2.124
#    Train PBIAS: 0.098%, Val PBIAS: 27.652%
#    Train FLV: -6.261%, Val FLV: -167.349%
#    Train PTE: 26.9 days, Val PTE: 48.8 days
#    Params: mu=1.092, lambda=28.241, Qs=0.001, qs=0.023
#
# === Station A931108050 ===, Number = 48
# ✅ Train NSE: 0.620, Val NSE: 0.743
#    Train KGE: 0.696, Val KGE: 0.782
#    Train RMSE: 15.202, Val RMSE: 12.335
#    Train PBIAS: 0.649%, Val PBIAS: 17.902%
#    Train FLV: -292.815%, Val FLV: -312.124%
#    Train PTE: 101.2 days, Val PTE: 64.8 days
#    Params: mu=1.067, lambda=26.850, Qs=0.001, qs=0.010
#
# === Station A932215050 ===, Number = 49
# ✅ Train NSE: 0.548, Val NSE: 0.683
#    Train KGE: 0.676, Val KGE: 0.803
#    Train RMSE: 0.315, Val RMSE: 0.225
#    Train PBIAS: -2.209%, Val PBIAS: -0.885%
#    Train FLV: -109.939%, Val FLV: -112.092%
#    Train PTE: 35.5 days, Val PTE: 19.3 days
#    Params: mu=1.356, lambda=72.447, Qs=0.159, qs=0.595
#
# === Station A975201001 ===, Number = 50
# ✅ Train NSE: 0.587, Val NSE: 0.620
#    Train KGE: 0.609, Val KGE: 0.674
#    Train RMSE: 3.922, Val RMSE: 3.866
#    Train PBIAS: 12.359%, Val PBIAS: 18.188%
#    Train FLV: -197.500%, Val FLV: -307.479%
#    Train PTE: 106.1 days, Val PTE: 7.8 days
#    Params: mu=1.066, lambda=23.987, Qs=0.001, qs=0.020
#
# === Station A983201001 ===, Number = 51
# ✅ Train NSE: 0.662, Val NSE: 0.770
#    Train KGE: 0.664, Val KGE: 0.772
#    Train RMSE: 1.556, Val RMSE: 1.324
#    Train PBIAS: 12.709%, Val PBIAS: 17.633%
#    Train FLV: -58.196%, Val FLV: -56.072%
#    Train PTE: 148.0 days, Val PTE: 1.5 days
#    Params: mu=1.061, lambda=22.045, Qs=0.001, qs=0.037
#
# === Station A986201001 ===, Number = 52
# ✅ Train NSE: 0.669, Val NSE: 0.783
#    Train KGE: 0.701, Val KGE: 0.820
#    Train RMSE: 2.853, Val RMSE: 2.297
#    Train PBIAS: 8.086%, Val PBIAS: 13.461%
#    Train FLV: -70.480%, Val FLV: -138.889%
#    Train PTE: 101.3 days, Val PTE: 6.3 days
#    Params: mu=1.064, lambda=21.438, Qs=0.001, qs=0.026
#
# === Station A994202002 ===, Number = 53
# ⚠️ Too many missing values (72.6%)
#
# === Station B022001001 ===, Number = 54
# ✅ Train NSE: 0.580, Val NSE: 0.586
#    Train KGE: 0.620, Val KGE: 0.667
#    Train RMSE: 4.791, Val RMSE: 4.281
#    Train PBIAS: 10.324%, Val PBIAS: 22.146%
#    Train FLV: -11.999%, Val FLV: -72.085%
#    Train PTE: 60.9 days, Val PTE: 161.2 days
#    Params: mu=1.065, lambda=17.226, Qs=0.001, qs=0.028
#
# === Station B109201001 ===, Number = 55
# ✅ Train NSE: 0.572, Val NSE: 0.624
#    Train KGE: 0.631, Val KGE: 0.685
#    Train RMSE: 5.512, Val RMSE: 4.657
#    Train PBIAS: 6.793%, Val PBIAS: 0.987%
#    Train FLV: -31.177%, Val FLV: -127.644%
#    Train PTE: 44.6 days, Val PTE: 79.8 days
#    Params: mu=1.058, lambda=14.803, Qs=0.001, qs=0.030
#
# === Station B115001001 ===, Number = 56
# ✅ Train NSE: 0.585, Val NSE: 0.660
#    Train KGE: 0.654, Val KGE: 0.734
#    Train RMSE: 12.688, Val RMSE: 10.744
#    Train PBIAS: 3.105%, Val PBIAS: 0.113%
#    Train FLV: -88.363%, Val FLV: -358.852%
#    Train PTE: 43.7 days, Val PTE: 126.0 days
#    Params: mu=1.052, lambda=18.178, Qs=0.001, qs=0.018
#
# === Station B128201001 ===, Number = 57
# ✅ Train NSE: 0.564, Val NSE: 0.675
#    Train KGE: 0.618, Val KGE: 0.681
#    Train RMSE: 5.881, Val RMSE: 4.696
#    Train PBIAS: 7.062%, Val PBIAS: 1.550%
#    Train FLV: -52.359%, Val FLV: -284.392%
#    Train PTE: 39.9 days, Val PTE: 79.8 days
#    Params: mu=1.065, lambda=21.006, Qs=0.001, qs=0.024
#
# === Station B134001001 ===, Number = 58
# ✅ Train NSE: 0.577, Val NSE: 0.674
#    Train KGE: 0.633, Val KGE: 0.691
#    Train RMSE: 18.726, Val RMSE: 16.660
#    Train PBIAS: 5.140%, Val PBIAS: -0.578%
#    Train FLV: -81.583%, Val FLV: -238.677%
#    Train PTE: 45.1 days, Val PTE: 80.2 days
#    Params: mu=1.050, lambda=23.061, Qs=0.001, qs=0.013
#
# === Station B222001001 ===, Number = 59
# ✅ Train NSE: 0.657, Val NSE: 0.745
#    Train KGE: 0.708, Val KGE: 0.806
#    Train RMSE: 21.657, Val RMSE: 18.813
#    Train PBIAS: 3.815%, Val PBIAS: 6.528%
#    Train FLV: -116.116%, Val FLV: -294.371%
#    Train PTE: 62.2 days, Val PTE: 5.0 days
#    Params: mu=1.029, lambda=24.386, Qs=0.001, qs=0.013
#
# === Station B315002001 ===, Number = 60
# ✅ Train NSE: 0.747, Val NSE: 0.818
#    Train KGE: 0.789, Val KGE: 0.853
#    Train RMSE: 23.765, Val RMSE: 22.347
#    Train PBIAS: 2.122%, Val PBIAS: 5.789%
#    Train FLV: -119.142%, Val FLV: -166.130%
#    Train PTE: 78.8 days, Val PTE: 4.0 days
#    Params: mu=1.065, lambda=25.205, Qs=21.028, qs=1.849
#
# === Station B403101001 ===, Number = 61
# ✅ Train NSE: 0.595, Val NSE: 0.772
#    Train KGE: 0.691, Val KGE: 0.823
#    Train RMSE: 2.907, Val RMSE: 2.446
#    Train PBIAS: -1.899%, Val PBIAS: -2.258%
#    Train FLV: -128.491%, Val FLV: -403.452%
#    Train PTE: 108.3 days, Val PTE: 68.0 days
#    Params: mu=1.213, lambda=30.795, Qs=0.463, qs=0.494
#
# === Station B413201001 ===, Number = 62
# ✅ Train NSE: 0.687, Val NSE: 0.824
#    Train KGE: 0.743, Val KGE: 0.749
#    Train RMSE: 1.065, Val RMSE: 0.979
#    Train PBIAS: 1.002%, Val PBIAS: -5.490%
#    Train FLV: -42.674%, Val FLV: -244.163%
#    Train PTE: 83.1 days, Val PTE: 37.2 days
#    Params: mu=1.194, lambda=31.671, Qs=1.243, qs=1.610
#
# === Station B422431001 ===, Number = 63
# ✅ Train NSE: 0.592, Val NSE: 0.703
#    Train KGE: 0.696, Val KGE: 0.797
#    Train RMSE: 2.130, Val RMSE: 1.972
#    Train PBIAS: -1.518%, Val PBIAS: -1.605%
#    Train FLV: -170.111%, Val FLV: -299.966%
#    Train PTE: 79.9 days, Val PTE: 51.2 days
#    Params: mu=1.400, lambda=41.776, Qs=2.033, qs=1.112
#
# === Station B457201001 ===, Number = 64
# ✅ Train NSE: 0.571, Val NSE: 0.569
#    Train KGE: 0.635, Val KGE: 0.412
#    Train RMSE: 4.119, Val RMSE: 4.310
#    Train PBIAS: 4.737%, Val PBIAS: -31.469%
#    Train FLV: -163.552%, Val FLV: -138.454%
#    Train PTE: 97.3 days, Val PTE: 35.5 days
#    Params: mu=1.072, lambda=23.208, Qs=0.001, qs=0.024
#
# === Station B460101001 ===, Number = 65
# ✅ Train NSE: 0.696, Val NSE: 0.773
#    Train KGE: 0.769, Val KGE: 0.756
#    Train RMSE: 11.778, Val RMSE: 11.225
#    Train PBIAS: -0.518%, Val PBIAS: -9.450%
#    Train FLV: -229.649%, Val FLV: -411.633%
#    Train PTE: 107.7 days, Val PTE: 7.8 days
#    Params: mu=1.158, lambda=31.919, Qs=2.217, qs=0.554
#
# === Station B463101001 ===, Number = 66
# ✅ Train NSE: 0.731, Val NSE: 0.785
#    Train KGE: 0.798, Val KGE: 0.751
#    Train RMSE: 11.604, Val RMSE: 12.135
#    Train PBIAS: -0.445%, Val PBIAS: -9.797%
#    Train FLV: -208.977%, Val FLV: -473.293%
#    Train PTE: 83.6 days, Val PTE: 10.8 days
#    Params: mu=1.169, lambda=33.454, Qs=5.230, qs=0.875
#
# === Station B532201001 ===, Number = 67
# ✅ Train NSE: 0.634, Val NSE: 0.673
#    Train KGE: 0.726, Val KGE: 0.810
#    Train RMSE: 1.586, Val RMSE: 1.375
#    Train PBIAS: -2.597%, Val PBIAS: 10.614%
#    Train FLV: -396.546%, Val FLV: -934.421%
#    Train PTE: 124.9 days, Val PTE: 134.0 days
#    Params: mu=1.128, lambda=28.925, Qs=0.021, qs=0.162
#
# === Station B611101001 ===, Number = 68
# ✅ Train NSE: 0.660, Val NSE: 0.715
#    Train KGE: 0.730, Val KGE: 0.806
#    Train RMSE: 18.618, Val RMSE: 17.766
#    Train PBIAS: 0.564%, Val PBIAS: 6.818%
#    Train FLV: -29.164%, Val FLV: -48.708%
#    Train PTE: 95.3 days, Val PTE: 89.3 days
#    Params: mu=1.173, lambda=11.553, Qs=47.910, qs=5.353
#
# === Station B720000002 ===, Number = 69
# ✅ Train NSE: 0.780, Val NSE: 0.866
#    Train KGE: 0.820, Val KGE: 0.903
#    Train RMSE: 67.451, Val RMSE: 55.415
#    Train PBIAS: 1.077%, Val PBIAS: 3.609%
#    Train FLV: -67.481%, Val FLV: -185.854%
#    Train PTE: 110.7 days, Val PTE: 54.3 days
#    Params: mu=1.142, lambda=24.526, Qs=63.029, qs=1.666
#
# === Station D020601001 ===, Number = 70
# ✅ Train NSE: 0.614, Val NSE: 0.471
#    Train KGE: 0.706, Val KGE: 0.563
#    Train RMSE: 0.894, Val RMSE: 0.906
#    Train PBIAS: -1.460%, Val PBIAS: 37.871%
#    Train FLV: -311.137%, Val FLV: -152.272%
#    Train PTE: 82.2 days, Val PTE: 53.5 days
#    Params: mu=1.191, lambda=36.796, Qs=0.092, qs=0.333
#
# === Station E172751001 ===, Number = 71
# ✅ Train NSE: 0.374, Val NSE: 0.281
#    Train KGE: 0.466, Val KGE: 0.529
#    Train RMSE: 0.454, Val RMSE: 0.466
#    Train PBIAS: -0.407%, Val PBIAS: 20.902%
#    Train FLV: -67.399%, Val FLV: 4.527%
#    Train PTE: 95.4 days, Val PTE: 52.2 days
#    Params: mu=1.620, lambda=98.513, Qs=0.701, qs=0.881
#
# === Station E334602001 ===, Number = 72
# ✅ Train NSE: 0.565, Val NSE: 0.545
#    Train KGE: 0.641, Val KGE: 0.570
#    Train RMSE: 0.213, Val RMSE: 0.185
#    Train PBIAS: 1.340%, Val PBIAS: 38.423%
#    Train FLV: -39.171%, Val FLV: 30.352%
#    Train PTE: 35.3 days, Val PTE: 58.4 days
#    Params: mu=1.133, lambda=35.825, Qs=0.001, qs=0.058
#
# === Station E403571001 ===, Number = 73
# ✅ Train NSE: 0.709, Val NSE: 0.710
#    Train KGE: 0.758, Val KGE: 0.815
#    Train RMSE: 1.922, Val RMSE: 1.607
#    Train PBIAS: 0.245%, Val PBIAS: 9.850%
#    Train FLV: -17.918%, Val FLV: -42.674%
#    Train PTE: 44.7 days, Val PTE: 63.6 days
#    Params: mu=1.243, lambda=44.579, Qs=26.609, qs=9.008
#
# === Station E430601001 ===, Number = 74
# ✅ Train NSE: 0.642, Val NSE: 0.707
#    Train KGE: 0.706, Val KGE: 0.741
#    Train RMSE: 0.985, Val RMSE: 0.864
#    Train PBIAS: 0.984%, Val PBIAS: 7.373%
#    Train FLV: 66.536%, Val FLV: -77.462%
#    Train PTE: 84.5 days, Val PTE: 103.0 days
#    Params: mu=1.283, lambda=36.667, Qs=0.803, qs=1.552
#
# === Station E520571001 ===, Number = 75
# ✅ Train NSE: 0.553, Val NSE: 0.655
#    Train KGE: 0.642, Val KGE: 0.674
#    Train RMSE: 1.278, Val RMSE: 1.026
#    Train PBIAS: -1.871%, Val PBIAS: -6.143%
#    Train FLV: -49.565%, Val FLV: -104.000%
#    Train PTE: 46.1 days, Val PTE: 101.2 days
#    Params: mu=1.145, lambda=15.401, Qs=0.024, qs=0.292
#
# === Station E530021001 ===, Number = 76
# ✅ Train NSE: 0.619, Val NSE: 0.652
#    Train KGE: 0.708, Val KGE: 0.750
#    Train RMSE: 1.466, Val RMSE: 1.277
#    Train PBIAS: -1.964%, Val PBIAS: 7.782%
#    Train FLV: -130.705%, Val FLV: 2.528%
#    Train PTE: 94.0 days, Val PTE: 117.2 days
#    Params: mu=1.280, lambda=27.912, Qs=0.250, qs=0.583
#
# === Station E540031001 ===, Number = 77
# ✅ Train NSE: 0.831, Val NSE: 0.837
#    Train KGE: 0.868, Val KGE: 0.886
#    Train RMSE: 1.794, Val RMSE: 1.607
#    Train PBIAS: -0.026%, Val PBIAS: 2.835%
#    Train FLV: 28.159%, Val FLV: 6.879%
#    Train PTE: 63.2 days, Val PTE: 10.0 days
#    Params: mu=1.384, lambda=63.762, Qs=65.600, qs=10.724
#
# === Station E540651001 ===, Number = 78
# ✅ Train NSE: 0.659, Val NSE: 0.404
#    Train KGE: 0.833, Val KGE: 0.692
#    Train RMSE: 1.025, Val RMSE: 0.977
#    Train PBIAS: -3.251%, Val PBIAS: 6.595%
#    Train FLV: 25.192%, Val FLV: -88.736%
#    Train PTE: 40.3 days, Val PTE: 9.8 days
#    Params: mu=1.019, lambda=136.291, Qs=0.034, qs=0.210
#
# === Station E550572001 ===, Number = 79
# ✅ Train NSE: 0.704, Val NSE: 0.777
#    Train KGE: 0.848, Val KGE: 0.875
#    Train RMSE: 1.666, Val RMSE: 1.101
#    Train PBIAS: -4.393%, Val PBIAS: -2.753%
#    Train FLV: 18.294%, Val FLV: -72.854%
#    Train PTE: 57.8 days, Val PTE: 15.3 days
#    Params: mu=0.976, lambda=96.561, Qs=0.001, qs=0.037
#
# === Station E639701001 ===, Number = 80
# ✅ Train NSE: 0.742, Val NSE: -0.002
#    Train KGE: 0.765, Val KGE: 0.536
#    Train RMSE: 0.274, Val RMSE: 0.324
#    Train PBIAS: 0.152%, Val PBIAS: 31.528%
#    Train FLV: 33.670%, Val FLV: -2.480%
#    Train PTE: 43.1 days, Val PTE: 102.2 days
#    Params: mu=0.815, lambda=26.460, Qs=0.015, qs=0.799
#
# === Station E645651001 ===, Number = 81
# ⚠️ Too many missing values (16.3%)
#
# === Station F352000201 ===, Number = 82
# ⚠️ Too many missing values (43.3%)
#
# === Station F415000101 ===, Number = 83
# ✅ Train NSE: 0.562, Val NSE: 0.581
#    Train KGE: 0.634, Val KGE: 0.627
#    Train RMSE: 2.808, Val RMSE: 3.799
#    Train PBIAS: 1.603%, Val PBIAS: 15.152%
#    Train FLV: -229.583%, Val FLV: -289.645%
#    Train PTE: 108.6 days, Val PTE: 48.5 days
#    Params: mu=1.064, lambda=30.356, Qs=0.001, qs=0.023
#
# === Station F416000201 ===, Number = 84
# ✅ Train NSE: 0.587, Val NSE: 0.640
#    Train KGE: 0.668, Val KGE: 0.691
#    Train RMSE: 3.363, Val RMSE: 4.432
#    Train PBIAS: 0.354%, Val PBIAS: 2.671%
#    Train FLV: -105.104%, Val FLV: -209.661%
#    Train PTE: 133.4 days, Val PTE: 50.3 days
#    Params: mu=1.063, lambda=35.268, Qs=0.004, qs=0.040
#
# === Station F439000101 ===, Number = 85
# ✅ Train NSE: 0.608, Val NSE: 0.699
#    Train KGE: 0.691, Val KGE: 0.792
#    Train RMSE: 11.676, Val RMSE: 12.206
#    Train PBIAS: 0.089%, Val PBIAS: 4.002%
#    Train FLV: -103.358%, Val FLV: -188.672%
#    Train PTE: 72.8 days, Val PTE: 50.2 days
#    Params: mu=1.088, lambda=41.450, Qs=0.275, qs=0.151
#
# === Station F453000101 ===, Number = 86
# ✅ Train NSE: 0.493, Val NSE: 0.266
#    Train KGE: 0.640, Val KGE: 0.243
#    Train RMSE: 1.040, Val RMSE: 1.236
#    Train PBIAS: 0.898%, Val PBIAS: -2.173%
#    Train FLV: 26.120%, Val FLV: 56.897%
#    Train PTE: 93.3 days, Val PTE: 23.3 days
#    Params: mu=1.172, lambda=171.968, Qs=25.200, qs=5.508
#
# === Station F462000101 ===, Number = 87
# ✅ Train NSE: 0.422, Val NSE: 0.480
#    Train KGE: 0.525, Val KGE: 0.544
#    Train RMSE: 0.408, Val RMSE: 0.543
#    Train PBIAS: -1.624%, Val PBIAS: 8.186%
#    Train FLV: -98.383%, Val FLV: -50.879%
#    Train PTE: 82.8 days, Val PTE: 69.8 days
#    Params: mu=1.334, lambda=60.005, Qs=0.098, qs=0.331
#
# === Station F466000101 ===, Number = 88
# ✅ Train NSE: 0.554, Val NSE: 0.621
#    Train KGE: 0.675, Val KGE: 0.684
#    Train RMSE: 0.712, Val RMSE: 0.934
#    Train PBIAS: -3.088%, Val PBIAS: 2.287%
#    Train FLV: -70.236%, Val FLV: -76.843%
#    Train PTE: 72.9 days, Val PTE: 60.0 days
#    Params: mu=1.292, lambda=54.685, Qs=0.125, qs=0.247
#
# === Station F467000101 ===, Number = 89
# ✅ Train NSE: 0.641, Val NSE: 0.702
#    Train KGE: 0.747, Val KGE: 0.814
#    Train RMSE: 1.924, Val RMSE: 2.138
#    Train PBIAS: -2.512%, Val PBIAS: 0.529%
#    Train FLV: -177.187%, Val FLV: -81.030%
#    Train PTE: 20.9 days, Val PTE: 82.7 days
#    Params: mu=1.268, lambda=54.168, Qs=0.340, qs=0.230
#
# === Station F474000102 ===, Number = 90
# ✅ Train NSE: 0.446, Val NSE: 0.545
#    Train KGE: 0.431, Val KGE: 0.476
#    Train RMSE: 2.216, Val RMSE: 3.176
#    Train PBIAS: 22.293%, Val PBIAS: 10.206%
#    Train FLV: -4.683%, Val FLV: -60.871%
#    Train PTE: 124.9 days, Val PTE: 63.2 days
#    Params: mu=1.092, lambda=32.301, Qs=0.001, qs=0.023
#
# === Station G111041010 ===, Number = 91
# ✅ Train NSE: 0.818, Val NSE: 0.784
#    Train KGE: 0.842, Val KGE: 0.699
#    Train RMSE: 0.608, Val RMSE: 0.715
#    Train PBIAS: 0.191%, Val PBIAS: -4.306%
#    Train FLV: -81.891%, Val FLV: -32.076%
#    Train PTE: 36.1 days, Val PTE: 21.8 days
#    Params: mu=1.117, lambda=87.642, Qs=13.483, qs=6.769
#
# === Station G206021010 ===, Number = 92
# ✅ Train NSE: 0.649, Val NSE: 0.728
#    Train KGE: 0.715, Val KGE: 0.756
#    Train RMSE: 1.623, Val RMSE: 1.322
#    Train PBIAS: 0.700%, Val PBIAS: -2.155%
#    Train FLV: -63.012%, Val FLV: -79.520%
#    Train PTE: 109.9 days, Val PTE: 75.8 days
#    Params: mu=1.189, lambda=51.345, Qs=0.810, qs=1.037
#
# === Station G600061010 ===, Number = 93
# ✅ Train NSE: 0.694, Val NSE: -0.361
#    Train KGE: 0.848, Val KGE: 0.579
#    Train RMSE: 0.609, Val RMSE: 0.797
#    Train PBIAS: -1.525%, Val PBIAS: 15.098%
#    Train FLV: -22.055%, Val FLV: -10.043%
#    Train PTE: 141.9 days, Val PTE: 25.7 days
#    Params: mu=0.965, lambda=146.356, Qs=0.001, qs=0.060
#
# === Station H010001001 ===, Number = 94
# ✅ Train NSE: 0.661, Val NSE: 0.705
#    Train KGE: 0.730, Val KGE: 0.802
#    Train RMSE: 3.205, Val RMSE: 3.199
#    Train PBIAS: 0.698%, Val PBIAS: 6.053%
#    Train FLV: -79.921%, Val FLV: -167.713%
#    Train PTE: 26.0 days, Val PTE: 130.2 days
#    Params: mu=1.052, lambda=19.227, Qs=0.008, qs=0.092
#
# === Station H010002001 ===, Number = 95
# ✅ Train NSE: 0.686, Val NSE: 0.759
#    Train KGE: 0.745, Val KGE: 0.815
#    Train RMSE: 5.627, Val RMSE: 5.318
#    Train PBIAS: 1.091%, Val PBIAS: 0.959%
#    Train FLV: -138.424%, Val FLV: -222.663%
#    Train PTE: 28.7 days, Val PTE: 67.3 days
#    Params: mu=1.105, lambda=26.068, Qs=2.683, qs=1.169
#
# === Station H020302002 ===, Number = 96
# ✅ Train NSE: 0.684, Val NSE: 0.791
#    Train KGE: 0.732, Val KGE: 0.847
#    Train RMSE: 1.997, Val RMSE: 1.697
#    Train PBIAS: 2.805%, Val PBIAS: 1.851%
#    Train FLV: -202.777%, Val FLV: -291.886%
#    Train PTE: 43.7 days, Val PTE: 77.3 days
#    Params: mu=1.027, lambda=25.280, Qs=0.001, qs=0.039
#
# === Station H030101001 ===, Number = 97
# ✅ Train NSE: 0.675, Val NSE: 0.741
#    Train KGE: 0.733, Val KGE: 0.723
#    Train RMSE: 1.394, Val RMSE: 1.587
#    Train PBIAS: 2.122%, Val PBIAS: -0.633%
#    Train FLV: 10.166%, Val FLV: -76.824%
#    Train PTE: 62.0 days, Val PTE: 87.0 days
#    Params: mu=1.053, lambda=23.392, Qs=0.001, qs=0.044
#
# === Station H032103001 ===, Number = 98
# ✅ Train NSE: 0.672, Val NSE: 0.732
#    Train KGE: 0.719, Val KGE: 0.787
#    Train RMSE: 4.072, Val RMSE: 4.142
#    Train PBIAS: 3.872%, Val PBIAS: 3.827%
#    Train FLV: -64.170%, Val FLV: -127.164%
#    Train PTE: 49.2 days, Val PTE: 67.7 days
#    Params: mu=1.031, lambda=23.936, Qs=0.001, qs=0.028
#
# === Station H050301001 ===, Number = 99
# ✅ Train NSE: 0.581, Val NSE: 0.733
#    Train KGE: 0.613, Val KGE: 0.678
#    Train RMSE: 1.533, Val RMSE: 1.425
#    Train PBIAS: 9.020%, Val PBIAS: 17.540%
#    Train FLV: 9.819%, Val FLV: -91.600%
#    Train PTE: 117.5 days, Val PTE: 1.7 days
#    Params: mu=1.060, lambda=26.637, Qs=0.001, qs=0.034
#
# === Station H070201001 ===, Number = 100
# ✅ Train NSE: 0.641, Val NSE: 0.776
#    Train KGE: 0.687, Val KGE: 0.783
#    Train RMSE: 1.316, Val RMSE: 1.070
#    Train PBIAS: 3.853%, Val PBIAS: 11.873%
#    Train FLV: -176.723%, Val FLV: -237.556%
#    Train PTE: 119.2 days, Val PTE: 0.8 days
#    Params: mu=1.076, lambda=42.931, Qs=0.001, qs=0.028
#
# === Station H120101001 ===, Number = 101
# ✅ Train NSE: 0.674, Val NSE: 0.732
#    Train KGE: 0.734, Val KGE: 0.790
#    Train RMSE: 10.445, Val RMSE: 11.268
#    Train PBIAS: 2.027%, Val PBIAS: 6.838%
#    Train FLV: -73.575%, Val FLV: -129.109%
#    Train PTE: 77.5 days, Val PTE: 51.0 days
#    Params: mu=1.053, lambda=22.250, Qs=0.290, qs=0.314
#
# === Station H200102001 ===, Number = 102
# ✅ Train NSE: 0.795, Val NSE: 0.792
#    Train KGE: 0.848, Val KGE: 0.810
#    Train RMSE: 1.035, Val RMSE: 1.357
#    Train PBIAS: -0.320%, Val PBIAS: -0.118%
#    Train FLV: 5.466%, Val FLV: -138.839%
#    Train PTE: 95.9 days, Val PTE: 11.3 days
#    Params: mu=1.190, lambda=31.767, Qs=0.388, qs=1.076
#
# === Station H201301001 ===, Number = 103
# ✅ Train NSE: 0.796, Val NSE: 0.833
#    Train KGE: 0.841, Val KGE: 0.843
#    Train RMSE: 0.661, Val RMSE: 0.734
#    Train PBIAS: 0.362%, Val PBIAS: 13.248%
#    Train FLV: 17.138%, Val FLV: -15.407%
#    Train PTE: 42.5 days, Val PTE: 25.8 days
#    Params: mu=1.178, lambda=24.242, Qs=0.467, qs=1.855
#
# === Station H206201001 ===, Number = 104
# ✅ Train NSE: 0.594, Val NSE: 0.653
#    Train KGE: 0.645, Val KGE: 0.699
#    Train RMSE: 2.117, Val RMSE: 1.919
#    Train PBIAS: 6.286%, Val PBIAS: 13.160%
#    Train FLV: -331.729%, Val FLV: -412.242%
#    Train PTE: 95.3 days, Val PTE: 107.7 days
#    Params: mu=1.062, lambda=21.827, Qs=0.001, qs=0.035
#
# === Station H207311001 ===, Number = 105
# ✅ Train NSE: 0.635, Val NSE: 0.751
#    Train KGE: 0.721, Val KGE: 0.863
#    Train RMSE: 0.525, Val RMSE: 0.404
#    Train PBIAS: -0.735%, Val PBIAS: 5.060%
#    Train FLV: -292.886%, Val FLV: -685.168%
#    Train PTE: 73.7 days, Val PTE: 48.5 days
#    Params: mu=1.065, lambda=42.166, Qs=0.001, qs=0.055
#
# === Station H208311001 ===, Number = 106
# ⚠️ Too many missing values (58.7%)
#
# === Station H226000201 ===, Number = 107
# ✅ Train NSE: 0.504, Val NSE: 0.567
#    Train KGE: 0.616, Val KGE: 0.756
#    Train RMSE: 0.148, Val RMSE: 0.127
#    Train PBIAS: -0.616%, Val PBIAS: 6.883%
#    Train FLV: -0.345%, Val FLV: 2.611%
#    Train PTE: 54.9 days, Val PTE: 2.3 days
#    Params: mu=1.810, lambda=88.943, Qs=0.520, qs=1.338
#
# === Station H232201001 ===, Number = 108
# ✅ Train NSE: 0.614, Val NSE: 0.670
#    Train KGE: 0.648, Val KGE: 0.755
#    Train RMSE: 2.354, Val RMSE: 2.171
#    Train PBIAS: 9.554%, Val PBIAS: 14.658%
#    Train FLV: 41.999%, Val FLV: 61.557%
#    Train PTE: 61.5 days, Val PTE: 60.4 days
#    Params: mu=1.070, lambda=20.922, Qs=0.001, qs=0.035
#
# === Station H234202001 ===, Number = 109
# ⚠️ Too many missing values (95.2%)
#
# === Station H247301001 ===, Number = 110
# ✅ Train NSE: 0.567, Val NSE: 0.644
#    Train KGE: 0.634, Val KGE: 0.704
#    Train RMSE: 3.427, Val RMSE: 3.286
#    Train PBIAS: 2.192%, Val PBIAS: 16.485%
#    Train FLV: -43.659%, Val FLV: -254.249%
#    Train PTE: 138.2 days, Val PTE: 51.8 days
#    Params: mu=1.068, lambda=33.644, Qs=0.005, qs=0.049
#
# === Station H248201001 ===, Number = 111
# ✅ Train NSE: 0.684, Val NSE: 0.752
#    Train KGE: 0.729, Val KGE: 0.807
#    Train RMSE: 18.249, Val RMSE: 17.663
#    Train PBIAS: 3.639%, Val PBIAS: 9.872%
#    Train FLV: -145.466%, Val FLV: -459.407%
#    Train PTE: 43.4 days, Val PTE: 52.8 days
#    Params: mu=1.034, lambda=26.822, Qs=0.001, qs=0.011
#
# === Station H303000201 ===, Number = 112
# ⚠️ Too many missing values (15.5%)
#
# === Station H305000101 ===, Number = 113
# ✅ Train NSE: 0.535, Val NSE: 0.539
#    Train KGE: 0.652, Val KGE: 0.553
#    Train RMSE: 0.529, Val RMSE: 0.766
#    Train PBIAS: -2.395%, Val PBIAS: -7.392%
#    Train FLV: -68.699%, Val FLV: -108.915%
#    Train PTE: 60.5 days, Val PTE: 82.2 days
#    Params: mu=1.383, lambda=60.218, Qs=0.242, qs=0.392
#
# === Station H311041010 ===, Number = 114
# ✅ Train NSE: 0.613, Val NSE: 0.727
#    Train KGE: 0.682, Val KGE: 0.759
#    Train RMSE: 1.810, Val RMSE: 1.549
#    Train PBIAS: 2.099%, Val PBIAS: 6.554%
#    Train FLV: -195.309%, Val FLV: -92.359%
#    Train PTE: 110.2 days, Val PTE: 60.6 days
#    Params: mu=1.084, lambda=32.594, Qs=0.001, qs=0.034
#
# === Station H318041010 ===, Number = 115
# ✅ Train NSE: 0.771, Val NSE: 0.632
#    Train KGE: 0.835, Val KGE: 0.780
#    Train RMSE: 2.545, Val RMSE: 2.775
#    Train PBIAS: -0.100%, Val PBIAS: 5.783%
#    Train FLV: -81.937%, Val FLV: -17.722%
#    Train PTE: 98.3 days, Val PTE: 22.2 days
#    Params: mu=1.254, lambda=62.911, Qs=12.326, qs=2.445
#
# === Station H323041010 ===, Number = 116
# ✅ Train NSE: 0.590, Val NSE: 0.657
#    Train KGE: 0.686, Val KGE: 0.683
#    Train RMSE: 0.239, Val RMSE: 0.240
#    Train PBIAS: -2.851%, Val PBIAS: -8.660%
#    Train FLV: -163.289%, Val FLV: -187.609%
#    Train PTE: 106.9 days, Val PTE: 4.8 days
#    Params: mu=1.143, lambda=36.203, Qs=0.001, qs=0.075
#
# === Station H325041010 ===, Number = 117
# ✅ Train NSE: 0.804, Val NSE: 0.709
#    Train KGE: 0.814, Val KGE: 0.856
#    Train RMSE: 0.740, Val RMSE: 0.717
#    Train PBIAS: 0.283%, Val PBIAS: 1.782%
#    Train FLV: -12.020%, Val FLV: -1.033%
#    Train PTE: 83.5 days, Val PTE: 5.3 days
#    Params: mu=1.263, lambda=66.674, Qs=33.800, qs=13.099
#
# === Station H332201001 ===, Number = 118
# ✅ Train NSE: 0.514, Val NSE: 0.497
#    Train KGE: 0.557, Val KGE: 0.467
#    Train RMSE: 1.783, Val RMSE: 2.250
#    Train PBIAS: 8.899%, Val PBIAS: 35.996%
#    Train FLV: -22.697%, Val FLV: -176.617%
#    Train PTE: 152.9 days, Val PTE: 65.7 days
#    Params: mu=1.098, lambda=35.436, Qs=0.001, qs=0.021
#
# === Station H403021010 ===, Number = 119
# ✅ Train NSE: 0.558, Val NSE: 0.571
#    Train KGE: 0.602, Val KGE: 0.611
#    Train RMSE: 1.849, Val RMSE: 1.858
#    Train PBIAS: 9.473%, Val PBIAS: 14.732%
#    Train FLV: -253.166%, Val FLV: -578.815%
#    Train PTE: 77.2 days, Val PTE: 77.5 days
#    Params: mu=1.076, lambda=27.677, Qs=0.001, qs=0.029
#
# === Station H413041010 ===, Number = 120
# ✅ Train NSE: 0.461, Val NSE: 0.469
#    Train KGE: 0.574, Val KGE: 0.498
#    Train RMSE: 0.516, Val RMSE: 0.840
#    Train PBIAS: -1.774%, Val PBIAS: 1.051%
#    Train FLV: -37.745%, Val FLV: -104.138%
#    Train PTE: 134.9 days, Val PTE: 84.3 days
#    Params: mu=1.350, lambda=57.369, Qs=0.197, qs=0.426
#
# === Station H416021010 ===, Number = 121
# ✅ Train NSE: 0.580, Val NSE: 0.585
#    Train KGE: 0.685, Val KGE: 0.774
#    Train RMSE: 3.483, Val RMSE: 3.280
#    Train PBIAS: -1.092%, Val PBIAS: 10.862%
#    Train FLV: -57.424%, Val FLV: -121.826%
#    Train PTE: 127.0 days, Val PTE: 34.2 days
#    Params: mu=1.260, lambda=47.451, Qs=2.194, qs=0.648
#
# === Station H425042010 ===, Number = 122
# ✅ Train NSE: 0.695, Val NSE: 0.557
#    Train KGE: 0.771, Val KGE: 0.773
#    Train RMSE: 1.600, Val RMSE: 1.508
#    Train PBIAS: 0.034%, Val PBIAS: 8.828%
#    Train FLV: -83.331%, Val FLV: -71.066%
#    Train PTE: 82.3 days, Val PTE: 103.2 days
#    Params: mu=1.105, lambda=55.723, Qs=3.402, qs=1.684
#
# === Station H432021010 ===, Number = 123
# ✅ Train NSE: 0.674, Val NSE: 0.607
#    Train KGE: 0.761, Val KGE: 0.793
#    Train RMSE: 6.183, Val RMSE: 5.679
#    Train PBIAS: -0.402%, Val PBIAS: 8.815%
#    Train FLV: -53.961%, Val FLV: -86.163%
#    Train PTE: 81.7 days, Val PTE: 117.7 days
#    Params: mu=1.300, lambda=57.534, Qs=19.062, qs=1.559
#
# === Station H437042010 ===, Number = 124
# ✅ Train NSE: 0.639, Val NSE: 0.606
#    Train KGE: 0.734, Val KGE: 0.800
#    Train RMSE: 1.086, Val RMSE: 0.827
#    Train PBIAS: 0.297%, Val PBIAS: 9.038%
#    Train FLV: -36.436%, Val FLV: -28.002%
#    Train PTE: 29.1 days, Val PTE: 104.2 days
#    Params: mu=1.156, lambda=116.335, Qs=1.110, qs=0.819
#
# === Station H438021010 ===, Number = 125
# ✅ Train NSE: 0.658, Val NSE: 0.510
#    Train KGE: 0.744, Val KGE: 0.749
#    Train RMSE: 7.139, Val RMSE: 6.651
#    Train PBIAS: -0.301%, Val PBIAS: 14.316%
#    Train FLV: -12.167%, Val FLV: -24.904%
#    Train PTE: 81.7 days, Val PTE: 117.7 days
#    Params: mu=1.415, lambda=73.263, Qs=28.964, qs=1.659
#
# === Station H503331001 ===, Number = 126
# ✅ Train NSE: 0.652, Val NSE: 0.644
#    Train KGE: 0.732, Val KGE: 0.779
#    Train RMSE: 0.942, Val RMSE: 0.857
#    Train PBIAS: -1.205%, Val PBIAS: 13.491%
#    Train FLV: 51.347%, Val FLV: -93.243%
#    Train PTE: 69.9 days, Val PTE: 113.3 days
#    Params: mu=1.083, lambda=8.480, Qs=0.352, qs=1.867
#
# === Station H504063010 ===, Number = 127
# ✅ Train NSE: 0.737, Val NSE: 0.589
#    Train KGE: 0.868, Val KGE: 0.840
#    Train RMSE: 0.461, Val RMSE: 0.357
#    Train PBIAS: -2.734%, Val PBIAS: -10.139%
#    Train FLV: -31.275%, Val FLV: -50.013%
#    Train PTE: 47.3 days, Val PTE: 38.5 days
#    Params: mu=0.968, lambda=115.759, Qs=0.001, qs=0.073
#
# === Station H504201001 ===, Number = 128
# ✅ Train NSE: 0.679, Val NSE: 0.695
#    Train KGE: 0.740, Val KGE: 0.815
#    Train RMSE: 1.639, Val RMSE: 1.644
#    Train PBIAS: 2.444%, Val PBIAS: 10.846%
#    Train FLV: 71.268%, Val FLV: 62.090%
#    Train PTE: 77.2 days, Val PTE: 57.8 days
#    Params: mu=1.046, lambda=14.593, Qs=0.001, qs=0.054
#
# === Station H506201001 ===, Number = 129
# ✅ Train NSE: 0.662, Val NSE: 0.738
#    Train KGE: 0.720, Val KGE: 0.800
#    Train RMSE: 7.491, Val RMSE: 7.323
#    Train PBIAS: 2.709%, Val PBIAS: 6.468%
#    Train FLV: -73.428%, Val FLV: -178.635%
#    Train PTE: 100.4 days, Val PTE: 38.3 days
#    Params: mu=1.042, lambda=19.862, Qs=0.001, qs=0.023
#
# === Station H508305001 ===, Number = 130
# ✅ Train NSE: 0.724, Val NSE: 0.761
#    Train KGE: 0.744, Val KGE: 0.730
#    Train RMSE: 3.380, Val RMSE: 3.254
#    Train PBIAS: 6.293%, Val PBIAS: 6.604%
#    Train FLV: -59.791%, Val FLV: -302.915%
#    Train PTE: 136.7 days, Val PTE: 32.0 days
#    Params: mu=1.061, lambda=29.370, Qs=0.001, qs=0.024
#
# === Station H510203001 ===, Number = 131
# ✅ Train NSE: 0.687, Val NSE: 0.804
#    Train KGE: 0.750, Val KGE: 0.775
#    Train RMSE: 4.319, Val RMSE: 4.190
#    Train PBIAS: 0.589%, Val PBIAS: 1.539%
#    Train FLV: -48.850%, Val FLV: -38.454%
#    Train PTE: 100.6 days, Val PTE: 34.7 days
#    Params: mu=1.169, lambda=23.234, Qs=4.127, qs=2.029
#
# === Station H512234001 ===, Number = 132
# ✅ Train NSE: 0.746, Val NSE: 0.762
#    Train KGE: 0.792, Val KGE: 0.748
#    Train RMSE: 5.321, Val RMSE: 6.186
#    Train PBIAS: 2.465%, Val PBIAS: -11.881%
#    Train FLV: -136.489%, Val FLV: -360.995%
#    Train PTE: 107.4 days, Val PTE: 9.0 days
#    Params: mu=1.034, lambda=17.154, Qs=0.001, qs=0.030
#
# === Station H514261001 ===, Number = 133
# ✅ Train NSE: 0.722, Val NSE: 0.711
#    Train KGE: 0.770, Val KGE: 0.660
#    Train RMSE: 0.987, Val RMSE: 1.406
#    Train PBIAS: 2.430%, Val PBIAS: -7.986%
#    Train FLV: -18.657%, Val FLV: -27.100%
#    Train PTE: 86.2 days, Val PTE: 19.3 days
#    Params: mu=1.072, lambda=25.320, Qs=0.003, qs=0.087
#
# === Station H514262001 ===, Number = 134
# ✅ Train NSE: 0.699, Val NSE: 0.666
#    Train KGE: 0.761, Val KGE: 0.640
#    Train RMSE: 1.843, Val RMSE: 2.651
#    Train PBIAS: 1.058%, Val PBIAS: -5.244%
#    Train FLV: -2.371%, Val FLV: 59.091%
#    Train PTE: 144.7 days, Val PTE: 19.7 days
#    Params: mu=1.059, lambda=20.556, Qs=0.002, qs=0.051
#
# === Station H517201001 ===, Number = 135
# ✅ Train NSE: 0.740, Val NSE: 0.801
#    Train KGE: 0.778, Val KGE: 0.840
#    Train RMSE: 15.372, Val RMSE: 15.077
#    Train PBIAS: 2.827%, Val PBIAS: 1.427%
#    Train FLV: -55.906%, Val FLV: -89.648%
#    Train PTE: 110.6 days, Val PTE: 7.0 days
#    Params: mu=1.059, lambda=25.070, Qs=0.414, qs=0.301
#
# === Station H517311001 ===, Number = 136
# ✅ Train NSE: 0.520, Val NSE: 0.608
#    Train KGE: 0.558, Val KGE: 0.568
#    Train RMSE: 1.231, Val RMSE: 1.200
#    Train PBIAS: 9.316%, Val PBIAS: 31.411%
#    Train FLV: -64.217%, Val FLV: -236.840%
#    Train PTE: 105.9 days, Val PTE: 21.5 days
#    Params: mu=1.097, lambda=34.289, Qs=0.001, qs=0.034
#
# === Station H522431001 ===, Number = 137
# ✅ Train NSE: 0.572, Val NSE: 0.403
#    Train KGE: 0.645, Val KGE: 0.559
#    Train RMSE: 0.281, Val RMSE: 0.305
#    Train PBIAS: 0.013%, Val PBIAS: 36.279%
#    Train FLV: -10.218%, Val FLV: 14.365%
#    Train PTE: 122.5 days, Val PTE: 61.2 days
#    Params: mu=0.923, lambda=42.582, Qs=0.185, qs=1.463
#
# === Station H552201001 ===, Number = 138
# ✅ Train NSE: 0.558, Val NSE: 0.611
#    Train KGE: 0.654, Val KGE: 0.644
#    Train RMSE: 1.036, Val RMSE: 1.222
#    Train PBIAS: -0.635%, Val PBIAS: 6.452%
#    Train FLV: -114.854%, Val FLV: -128.049%
#    Train PTE: 77.9 days, Val PTE: 28.8 days
#    Params: mu=1.337, lambda=49.994, Qs=0.743, qs=0.705
#
# === Station H602021010 ===, Number = 139
# ✅ Train NSE: 0.564, Val NSE: 0.568
#    Train KGE: 0.674, Val KGE: 0.731
#    Train RMSE: 1.170, Val RMSE: 1.102
#    Train PBIAS: -4.552%, Val PBIAS: 1.552%
#    Train FLV: -462.877%, Val FLV: -533.541%
#    Train PTE: 114.6 days, Val PTE: 76.5 days
#    Params: mu=1.142, lambda=39.428, Qs=0.007, qs=0.074
#
# === Station H602321001 ===, Number = 140
# ✅ Train NSE: 0.610, Val NSE: 0.707
#    Train KGE: 0.658, Val KGE: 0.734
#    Train RMSE: 0.680, Val RMSE: 0.694
#    Train PBIAS: 4.699%, Val PBIAS: 11.676%
#    Train FLV: -16.141%, Val FLV: -439.145%
#    Train PTE: 80.8 days, Val PTE: 22.0 days
#    Params: mu=1.073, lambda=30.868, Qs=0.001, qs=0.046
#
# === Station H605301001 ===, Number = 141
# ✅ Train NSE: 0.671, Val NSE: 0.710
#    Train KGE: 0.686, Val KGE: 0.701
#    Train RMSE: 0.758, Val RMSE: 0.912
#    Train PBIAS: 10.951%, Val PBIAS: 16.787%
#    Train FLV: -142.031%, Val FLV: 47.138%
#    Train PTE: 141.2 days, Val PTE: 54.8 days
#    Params: mu=1.099, lambda=24.178, Qs=0.001, qs=0.047
#
# === Station H610041010 ===, Number = 142
# ⚠️ Too many missing values (16.0%)
#
# === Station H610201001 ===, Number = 143
# ✅ Train NSE: 0.690, Val NSE: 0.751
#    Train KGE: 0.748, Val KGE: 0.789
#    Train RMSE: 2.670, Val RMSE: 2.826
#    Train PBIAS: 1.997%, Val PBIAS: -4.267%
#    Train FLV: -67.589%, Val FLV: -71.423%
#    Train PTE: 110.3 days, Val PTE: 24.8 days
#    Params: mu=1.050, lambda=19.875, Qs=0.002, qs=0.056
#
# === Station H611061010 ===, Number = 144
# ✅ Train NSE: 0.534, Val NSE: 0.446
#    Train KGE: 0.630, Val KGE: 0.593
#    Train RMSE: 0.296, Val RMSE: 0.338
#    Train PBIAS: -0.008%, Val PBIAS: -0.882%
#    Train FLV: -107.398%, Val FLV: -184.919%
#    Train PTE: 139.5 days, Val PTE: 77.0 days
#    Params: mu=1.331, lambda=68.402, Qs=0.499, qs=1.586
#
# === Station H612201001 ===, Number = 145
# ✅ Train NSE: 0.734, Val NSE: 0.781
#    Train KGE: 0.757, Val KGE: 0.821
#    Train RMSE: 6.024, Val RMSE: 6.041
#    Train PBIAS: 6.240%, Val PBIAS: 11.998%
#    Train FLV: -125.200%, Val FLV: -216.577%
#    Train PTE: 120.4 days, Val PTE: 40.2 days
#    Params: mu=1.056, lambda=23.486, Qs=0.001, qs=0.021
#
# === Station H616201001 ===, Number = 146
# ✅ Train NSE: 0.736, Val NSE: 0.771
#    Train KGE: 0.789, Val KGE: 0.846
#    Train RMSE: 8.346, Val RMSE: 8.757
#    Train PBIAS: 1.442%, Val PBIAS: 8.932%
#    Train FLV: -105.581%, Val FLV: -251.634%
#    Train PTE: 133.7 days, Val PTE: 40.5 days
#    Params: mu=1.062, lambda=20.537, Qs=0.019, qs=0.082
#
# === Station H620101001 ===, Number = 147
# ✅ Train NSE: 0.735, Val NSE: 0.803
#    Train KGE: 0.782, Val KGE: 0.849
#    Train RMSE: 14.466, Val RMSE: 14.776
#    Train PBIAS: 2.071%, Val PBIAS: 5.996%
#    Train FLV: -20.281%, Val FLV: -4.468%
#    Train PTE: 77.1 days, Val PTE: 32.0 days
#    Params: mu=1.042, lambda=28.093, Qs=0.001, qs=0.011
#
# === Station H622101001 ===, Number = 148
# ✅ Train NSE: 0.712, Val NSE: 0.792
#    Train KGE: 0.760, Val KGE: 0.822
#    Train RMSE: 19.029, Val RMSE: 18.712
#    Train PBIAS: 2.408%, Val PBIAS: 11.517%
#    Train FLV: -90.691%, Val FLV: -111.948%
#    Train PTE: 62.3 days, Val PTE: 56.3 days
#    Params: mu=1.038, lambda=27.147, Qs=0.008, qs=0.031
#
# === Station H623021010 ===, Number = 149
# ✅ Train NSE: 0.672, Val NSE: 0.621
#    Train KGE: 0.751, Val KGE: 0.789
#    Train RMSE: 3.674, Val RMSE: 3.297
#    Train PBIAS: 0.230%, Val PBIAS: 9.704%
#    Train FLV: -70.879%, Val FLV: -50.916%
#    Train PTE: 37.6 days, Val PTE: 78.2 days
#    Params: mu=1.337, lambda=75.661, Qs=9.458, qs=1.491
#
# === Station H623302001 ===, Number = 150
# ✅ Train NSE: 0.641, Val NSE: 0.704
#    Train KGE: 0.720, Val KGE: 0.795
#    Train RMSE: 3.463, Val RMSE: 3.326
#    Train PBIAS: -0.877%, Val PBIAS: 8.041%
#    Train FLV: -392.125%, Val FLV: -395.664%
#    Train PTE: 88.5 days, Val PTE: 64.8 days
#    Params: mu=1.068, lambda=19.655, Qs=0.001, qs=0.027
#
# === Station H631302001 ===, Number = 151
# ✅ Train NSE: 0.682, Val NSE: 0.659
#    Train KGE: 0.737, Val KGE: 0.649
#    Train RMSE: 1.761, Val RMSE: 1.851
#    Train PBIAS: -0.618%, Val PBIAS: 33.651%
#    Train FLV: 48.390%, Val FLV: 65.756%
#    Train PTE: 70.4 days, Val PTE: 85.8 days
#    Params: mu=0.920, lambda=27.569, Qs=0.008, qs=0.158
#
# === Station H640203001 ===, Number = 152
# ✅ Train NSE: 0.652, Val NSE: 0.696
#    Train KGE: 0.700, Val KGE: 0.572
#    Train RMSE: 1.392, Val RMSE: 1.594
#    Train PBIAS: -0.025%, Val PBIAS: 39.946%
#    Train FLV: 49.960%, Val FLV: 68.815%
#    Train PTE: 62.8 days, Val PTE: 42.8 days
#    Params: mu=0.888, lambda=26.216, Qs=0.091, qs=0.587
#
# === Station H642301001 ===, Number = 153
# ✅ Train NSE: 0.473, Val NSE: 0.613
#    Train KGE: 0.564, Val KGE: 0.685
#    Train RMSE: 0.939, Val RMSE: 0.968
#    Train PBIAS: -0.333%, Val PBIAS: 22.066%
#    Train FLV: -88.880%, Val FLV: -154.920%
#    Train PTE: 88.8 days, Val PTE: 57.2 days
#    Params: mu=1.082, lambda=52.965, Qs=0.012, qs=0.112
#
# === Station H643201001 ===, Number = 154
# ✅ Train NSE: 0.657, Val NSE: 0.620
#    Train KGE: 0.743, Val KGE: 0.682
#    Train RMSE: 2.840, Val RMSE: 3.222
#    Train PBIAS: -1.290%, Val PBIAS: 29.045%
#    Train FLV: -28.088%, Val FLV: 34.844%
#    Train PTE: 49.1 days, Val PTE: 62.8 days
#    Params: mu=0.979, lambda=44.675, Qs=0.001, qs=0.027
#
# === Station H651301001 ===, Number = 155
# ✅ Train NSE: 0.441, Val NSE: 0.453
#    Train KGE: 0.545, Val KGE: 0.628
#    Train RMSE: 0.232, Val RMSE: 0.228
#    Train PBIAS: -0.440%, Val PBIAS: 19.745%
#    Train FLV: 43.708%, Val FLV: 32.512%
#    Train PTE: 132.0 days, Val PTE: 58.2 days
#    Params: mu=2.006, lambda=74.744, Qs=0.649, qs=1.169
#
# === Station H703301001 ===, Number = 156
# ✅ Train NSE: 0.661, Val NSE: 0.705
#    Train KGE: 0.741, Val KGE: 0.812
#    Train RMSE: 2.061, Val RMSE: 2.088
#    Train PBIAS: -0.743%, Val PBIAS: 1.379%
#    Train FLV: -161.745%, Val FLV: -325.770%
#    Train PTE: 70.4 days, Val PTE: 124.2 days
#    Params: mu=1.187, lambda=34.946, Qs=0.250, qs=0.424
#
# === Station H705311001 ===, Number = 157
# ✅ Train NSE: 0.616, Val NSE: 0.443
#    Train KGE: 0.675, Val KGE: 0.452
#    Train RMSE: 0.243, Val RMSE: 0.236
#    Train PBIAS: 3.113%, Val PBIAS: 50.037%
#    Train FLV: -131.849%, Val FLV: -187.600%
#    Train PTE: 94.5 days, Val PTE: 99.5 days
#    Params: mu=1.115, lambda=32.245, Qs=0.001, qs=0.076
#
# === Station H706101001 ===, Number = 158
# ⚠️ Too many missing values (87.9%)
#
# === Station H716201001 ===, Number = 159
# ✅ Train NSE: 0.709, Val NSE: 0.728
#    Train KGE: 0.761, Val KGE: 0.833
#    Train RMSE: 4.930, Val RMSE: 4.518
#    Train PBIAS: 0.159%, Val PBIAS: 7.557%
#    Train FLV: -21.982%, Val FLV: 1.567%
#    Train PTE: 120.9 days, Val PTE: 76.0 days
#    Params: mu=1.032, lambda=44.685, Qs=154.000, qs=8.349
#
# === Station H740101001 ===, Number = 160
# ✅ Train NSE: 0.727, Val NSE: 0.689
#    Train KGE: 0.790, Val KGE: 0.759
#    Train RMSE: 14.699, Val RMSE: 14.421
#    Train PBIAS: 0.920%, Val PBIAS: 15.093%
#    Train FLV: -122.716%, Val FLV: -294.659%
#    Train PTE: 73.6 days, Val PTE: 119.5 days
#    Params: mu=1.028, lambda=37.506, Qs=0.704, qs=0.297
#
# === Station H741321001 ===, Number = 161
# ✅ Train NSE: 0.551, Val NSE: 0.323
#    Train KGE: 0.665, Val KGE: 0.553
#    Train RMSE: 0.196, Val RMSE: 0.189
#    Train PBIAS: -2.104%, Val PBIAS: 37.843%
#    Train FLV: 38.972%, Val FLV: -6.170%
#    Train PTE: 105.4 days, Val PTE: 84.2 days
#    Params: mu=1.303, lambda=78.567, Qs=0.040, qs=0.260
#
# === Station H742371001 ===, Number = 162
# ⚠️ Too many missing values (42.8%)
#
# === Station H773301001 ===, Number = 163
# ⚠️ Too many missing values (29.0%)
#
# === Station H774201001 ===, Number = 164
# ✅ Train NSE: 0.662, Val NSE: 0.651
#    Train KGE: 0.743, Val KGE: 0.817
#    Train RMSE: 1.616, Val RMSE: 1.482
#    Train PBIAS: -0.414%, Val PBIAS: -0.431%
#    Train FLV: -169.192%, Val FLV: -29.617%
#    Train PTE: 101.7 days, Val PTE: 27.8 days
#    Params: mu=1.352, lambda=67.512, Qs=8.688, qs=3.073
#
# === Station H774202001 ===, Number = 165
# ✅ Train NSE: 0.763, Val NSE: 0.667
#    Train KGE: 0.837, Val KGE: 0.812
#    Train RMSE: 2.093, Val RMSE: 1.974
#    Train PBIAS: 0.274%, Val PBIAS: 1.916%
#    Train FLV: -80.842%, Val FLV: -32.746%
#    Train PTE: 100.4 days, Val PTE: 51.7 days
#    Params: mu=1.256, lambda=67.662, Qs=15.154, qs=3.143
#
# === Station I103101001 ===, Number = 166
# ✅ Train NSE: 0.642, Val NSE: 0.667
#    Train KGE: 0.740, Val KGE: 0.767
#    Train RMSE: 0.980, Val RMSE: 0.986
#    Train PBIAS: -0.888%, Val PBIAS: 0.541%
#    Train FLV: -25.696%, Val FLV: -108.425%
#    Train PTE: 124.6 days, Val PTE: 79.5 days
#    Params: mu=1.493, lambda=58.537, Qs=1.297, qs=0.964
#
# === Station I110301001 ===, Number = 167
# ✅ Train NSE: 0.554, Val NSE: 0.605
#    Train KGE: 0.659, Val KGE: 0.774
#    Train RMSE: 0.895, Val RMSE: 0.757
#    Train PBIAS: -0.543%, Val PBIAS: -0.151%
#    Train FLV: -148.290%, Val FLV: -74.855%
#    Train PTE: 122.1 days, Val PTE: 46.8 days
#    Params: mu=1.582, lambda=87.356, Qs=1.750, qs=1.197
#
# === Station I120301001 ===, Number = 168
# ✅ Train NSE: 0.546, Val NSE: 0.451
#    Train KGE: 0.662, Val KGE: 0.715
#    Train RMSE: 0.666, Val RMSE: 0.684
#    Train PBIAS: -1.174%, Val PBIAS: 8.658%
#    Train FLV: -200.340%, Val FLV: -179.241%
#    Train PTE: 131.2 days, Val PTE: 8.0 days
#    Params: mu=1.640, lambda=73.452, Qs=0.864, qs=0.749
#
# === Station I200101001 ===, Number = 169
# ✅ Train NSE: 0.573, Val NSE: 0.555
#    Train KGE: 0.622, Val KGE: 0.618
#    Train RMSE: 0.486, Val RMSE: 0.473
#    Train PBIAS: 6.992%, Val PBIAS: 20.140%
#    Train FLV: -15.366%, Val FLV: -111.428%
#    Train PTE: 137.8 days, Val PTE: 64.0 days
#    Params: mu=1.108, lambda=33.173, Qs=0.001, qs=0.048
#
# === Station I202101001 ===, Number = 170
# ✅ Train NSE: 0.648, Val NSE: 0.650
#    Train KGE: 0.721, Val KGE: 0.698
#    Train RMSE: 0.988, Val RMSE: 1.002
#    Train PBIAS: 1.351%, Val PBIAS: -1.697%
#    Train FLV: -74.775%, Val FLV: -238.368%
#    Train PTE: 104.6 days, Val PTE: 77.5 days
#    Params: mu=1.051, lambda=46.965, Qs=0.001, qs=0.036
#
# === Station I346301001 ===, Number = 171
# ✅ Train NSE: 0.766, Val NSE: 0.826
#    Train KGE: 0.823, Val KGE: 0.859
#    Train RMSE: 0.858, Val RMSE: 0.713
#    Train PBIAS: -0.142%, Val PBIAS: 3.008%
#    Train FLV: -30.278%, Val FLV: -212.976%
#    Train PTE: 102.4 days, Val PTE: 106.2 days
#    Params: mu=1.152, lambda=29.919, Qs=0.117, qs=0.517
#
# === Station I402201001 ===, Number = 172
# ✅ Train NSE: 0.757, Val NSE: 0.814
#    Train KGE: 0.803, Val KGE: 0.790
#    Train RMSE: 1.001, Val RMSE: 0.894
#    Train PBIAS: 2.367%, Val PBIAS: 17.525%
#    Train FLV: -244.505%, Val FLV: -121.315%
#    Train PTE: 72.5 days, Val PTE: 4.2 days
#    Params: mu=1.117, lambda=25.114, Qs=0.054, qs=0.345
#
# === Station I403201001 ===, Number = 173
# ✅ Train NSE: 0.781, Val NSE: 0.820
#    Train KGE: 0.825, Val KGE: 0.805
#    Train RMSE: 1.407, Val RMSE: 1.299
#    Train PBIAS: 1.684%, Val PBIAS: 14.893%
#    Train FLV: -57.514%, Val FLV: -103.910%
#    Train PTE: 76.8 days, Val PTE: 3.8 days
#    Params: mu=1.121, lambda=33.577, Qs=0.126, qs=0.372
#
# === Station I501361001 ===, Number = 174
# ✅ Train NSE: 0.736, Val NSE: 0.791
#    Train KGE: 0.775, Val KGE: 0.691
#    Train RMSE: 0.400, Val RMSE: 0.447
#    Train PBIAS: 1.803%, Val PBIAS: 10.969%
#    Train FLV: 1.744%, Val FLV: 13.765%
#    Train PTE: 64.0 days, Val PTE: 5.3 days
#    Params: mu=1.335, lambda=27.770, Qs=0.961, qs=2.917
#
# === Station I505301001 ===, Number = 175
# ✅ Train NSE: 0.745, Val NSE: 0.762
#    Train KGE: 0.790, Val KGE: 0.727
#    Train RMSE: 1.331, Val RMSE: 1.374
#    Train PBIAS: 3.547%, Val PBIAS: 21.825%
#    Train FLV: -24.135%, Val FLV: 23.418%
#    Train PTE: 50.7 days, Val PTE: 5.0 days
#    Params: mu=1.103, lambda=19.671, Qs=0.024, qs=0.226
#
# === Station I510101001 ===, Number = 176
# ✅ Train NSE: 0.780, Val NSE: 0.813
#    Train KGE: 0.824, Val KGE: 0.792
#    Train RMSE: 4.387, Val RMSE: 4.067
#    Train PBIAS: 1.506%, Val PBIAS: 18.530%
#    Train FLV: -72.547%, Val FLV: -103.927%
#    Train PTE: 39.0 days, Val PTE: 3.5 days
#    Params: mu=1.137, lambda=22.725, Qs=0.683, qs=0.630
#
# === Station I522101001 ===, Number = 177
# ⚠️ Too many missing values (13.2%)
#
# === Station I524301001 ===, Number = 178
# ✅ Train NSE: 0.839, Val NSE: 0.836
#    Train KGE: 0.861, Val KGE: 0.809
#    Train RMSE: 0.274, Val RMSE: 0.328
#    Train PBIAS: 2.066%, Val PBIAS: 0.772%
#    Train FLV: 9.564%, Val FLV: 10.840%
#    Train PTE: 39.0 days, Val PTE: 38.2 days
#    Params: mu=1.125, lambda=35.690, Qs=0.245, qs=1.443
#
# === Station I532151001 ===, Number = 179
# ✅ Train NSE: 0.755, Val NSE: 0.736
#    Train KGE: 0.805, Val KGE: 0.698
#    Train RMSE: 0.721, Val RMSE: 0.741
#    Train PBIAS: 1.750%, Val PBIAS: 24.406%
#    Train FLV: -81.449%, Val FLV: 52.794%
#    Train PTE: 75.7 days, Val PTE: 74.5 days
#    Params: mu=1.100, lambda=31.011, Qs=0.008, qs=0.124
#
# === Station I535201001 ===, Number = 180
# ✅ Train NSE: 0.748, Val NSE: 0.816
#    Train KGE: 0.784, Val KGE: 0.796
#    Train RMSE: 1.848, Val RMSE: 1.681
#    Train PBIAS: 3.709%, Val PBIAS: 10.534%
#    Train FLV: -106.493%, Val FLV: -121.815%
#    Train PTE: 60.3 days, Val PTE: 4.5 days
#    Params: mu=1.132, lambda=30.126, Qs=0.144, qs=0.393
#
# === Station I696401001 ===, Number = 181
# ✅ Train NSE: 0.652, Val NSE: 0.694
#    Train KGE: 0.740, Val KGE: 0.698
#    Train RMSE: 0.134, Val RMSE: 0.164
#    Train PBIAS: -2.664%, Val PBIAS: 1.388%
#    Train FLV: -226.741%, Val FLV: -367.145%
#    Train PTE: 88.7 days, Val PTE: 11.8 days
#    Params: mu=1.135, lambda=52.170, Qs=0.001, qs=0.083
#
# === Station I722202001 ===, Number = 182
# ✅ Train NSE: 0.782, Val NSE: 0.787
#    Train KGE: 0.821, Val KGE: 0.753
#    Train RMSE: 1.505, Val RMSE: 1.635
#    Train PBIAS: 2.570%, Val PBIAS: 16.936%
#    Train FLV: 27.382%, Val FLV: 13.297%
#    Train PTE: 43.8 days, Val PTE: 4.3 days
#    Params: mu=1.182, lambda=21.130, Qs=0.641, qs=1.201
#
# === Station I903101001 ===, Number = 183
# ✅ Train NSE: 0.764, Val NSE: 0.791
#    Train KGE: 0.804, Val KGE: 0.767
#    Train RMSE: 1.509, Val RMSE: 1.636
#    Train PBIAS: 2.295%, Val PBIAS: -0.185%
#    Train FLV: -79.039%, Val FLV: -65.204%
#    Train PTE: 85.1 days, Val PTE: 11.0 days
#    Params: mu=1.186, lambda=26.262, Qs=0.623, qs=1.109
#
# === Station J001401001 ===, Number = 184
# ✅ Train NSE: 0.654, Val NSE: 0.735
#    Train KGE: 0.730, Val KGE: 0.744
#    Train RMSE: 0.336, Val RMSE: 0.322
#    Train PBIAS: -0.382%, Val PBIAS: 2.953%
#    Train FLV: -116.762%, Val FLV: -23.421%
#    Train PTE: 54.5 days, Val PTE: 53.3 days
#    Params: mu=1.233, lambda=54.764, Qs=0.142, qs=0.763
#
# === Station J014401001 ===, Number = 185
# ✅ Train NSE: 0.727, Val NSE: 0.752
#    Train KGE: 0.801, Val KGE: 0.823
#    Train RMSE: 0.365, Val RMSE: 0.362
#    Train PBIAS: -1.066%, Val PBIAS: 2.828%
#    Train FLV: -77.492%, Val FLV: -2.426%
#    Train PTE: 67.3 days, Val PTE: 53.2 days
#    Params: mu=1.225, lambda=50.763, Qs=0.108, qs=0.545
#
# === Station J032301001 ===, Number = 186
# ✅ Train NSE: 0.647, Val NSE: 0.716
#    Train KGE: 0.678, Val KGE: 0.641
#    Train RMSE: 0.446, Val RMSE: 0.414
#    Train PBIAS: 8.314%, Val PBIAS: 29.989%
#    Train FLV: 74.892%, Val FLV: 74.081%
#    Train PTE: 63.9 days, Val PTE: 15.0 days
#    Params: mu=1.086, lambda=38.210, Qs=0.001, qs=0.056
#
# === Station J061161001 ===, Number = 187
# ✅ Train NSE: 0.669, Val NSE: 0.662
#    Train KGE: 0.737, Val KGE: 0.780
#    Train RMSE: 1.286, Val RMSE: 0.954
#    Train PBIAS: 1.367%, Val PBIAS: 14.768%
#    Train FLV: -29.497%, Val FLV: -106.615%
#    Train PTE: 36.1 days, Val PTE: 60.7 days
#    Params: mu=1.107, lambda=35.292, Qs=0.001, qs=0.031
#
# === Station J100452001 ===, Number = 188
# ✅ Train NSE: 0.605, Val NSE: 0.527
#    Train KGE: 0.642, Val KGE: 0.551
#    Train RMSE: 0.249, Val RMSE: 0.270
#    Train PBIAS: 8.972%, Val PBIAS: 34.929%
# ...
#
# === Station V426401001 ===, Number = 593
# ✅ Train NSE: 0.655, Val NSE: 0.685
#    Train KGE: 0.735, Val KGE: 0.791
#    Train RMSE: 11.800, Val RMSE: 9.682
#    Train PBIAS: -0.947%, Val PBIAS: -2.759%
#    Train FLV: -199.293%, Val FLV: -104.368%
#    Train PTE: 46.1 days, Val PTE: 60.2 days
#    Params: mu=1.123, lambda=35.303, Qs=0.106, qs=0.155
#
# === Station V441401001 ===, Number = 594
# ✅ Train NSE: 0.636, Val NSE: 0.354
#    Train KGE: 0.693, Val KGE: 0.517
#    Train RMSE: 2.074, Val RMSE: 1.673
#    Train PBIAS: 5.981%, Val PBIAS: 38.020%
#    Train FLV: 52.775%, Val FLV: 74.616%
#    Train PTE: 100.3 days, Val PTE: 109.0 days
#    Params: mu=1.101, lambda=35.496, Qs=0.001, qs=0.031
#
# === Station V445501001 ===, Number = 595
# ✅ Train NSE: 0.593, Val NSE: 0.136
#    Train KGE: 0.673, Val KGE: 0.466
#    Train RMSE: 0.800, Val RMSE: 0.658
#    Train PBIAS: 0.454%, Val PBIAS: 37.655%
#    Train FLV: -370.016%, Val FLV: -373.569%
#    Train PTE: 80.5 days, Val PTE: 107.7 days
#    Params: mu=1.110, lambda=48.521, Qs=0.001, qs=0.042
#
# === Station V500403001 ===, Number = 596
# ✅ Train NSE: 0.800, Val NSE: 0.755
#    Train KGE: 0.847, Val KGE: 0.750
#    Train RMSE: 3.637, Val RMSE: 3.982
#    Train PBIAS: -6.311%, Val PBIAS: -12.260%
#    Train FLV: -22.330%, Val FLV: -29.215%
#    Train PTE: 38.4 days, Val PTE: 48.2 days
#    Params: mu=1.197, lambda=8.014, Qs=6.577, qs=12.319
#
# === Station V504661001 ===, Number = 597
# ✅ Train NSE: 0.753, Val NSE: 0.625
#    Train KGE: 0.816, Val KGE: 0.653
#    Train RMSE: 2.815, Val RMSE: 3.655
#    Train PBIAS: -3.640%, Val PBIAS: -11.191%
#    Train FLV: -63.892%, Val FLV: -128.804%
#    Train PTE: 17.6 days, Val PTE: 0.6 days
#    Params: mu=1.152, lambda=18.043, Qs=0.265, qs=0.983
#
# === Station V504881501 ===, Number = 598
# ⚠️ Too many missing values (22.7%)
#
# === Station V542521001 ===, Number = 599
# ⚠️ Too many missing values (63.0%)
#
# === Station V603501001 ===, Number = 600
# ⚠️ Too many missing values (12.1%)
#
# === Station V605201001 ===, Number = 601
# ⚠️ Too many missing values (92.4%)
#
# === Station V711501001 ===, Number = 602
# ⚠️ Too many missing values (13.1%)
#
# === Station V712401001 ===, Number = 603
# ⚠️ Too many missing values (57.7%)
#
# === Station V713501001 ===, Number = 604
# ✅ Train NSE: 0.703, Val NSE: 0.694
#    Train KGE: 0.755, Val KGE: 0.757
#    Train RMSE: 8.899, Val RMSE: 7.911
#    Train PBIAS: 6.532%, Val PBIAS: -3.058%
#    Train FLV: -43.270%, Val FLV: -244.097%
#    Train PTE: 50.6 days, Val PTE: 34.2 days
#    Params: mu=1.115, lambda=47.546, Qs=0.001, qs=0.018
#
# === Station W221503001 ===, Number = 605
# ⚠️ Too many missing values (11.7%)
#
# === Station W231401001 ===, Number = 606
# ✅ Train NSE: 0.214, Val NSE: 0.046
#    Train KGE: 0.237, Val KGE: 0.092
#    Train RMSE: 3.113, Val RMSE: 3.193
#    Train PBIAS: 0.148%, Val PBIAS: -2.570%
#    Train FLV: -27.750%, Val FLV: 56.925%
#    Train PTE: 102.8 days, Val PTE: 125.0 days
#    Params: mu=1.580, lambda=110.854, Qs=2.243, qs=1.461
#
# === Station W233521001 ===, Number = 607
# ✅ Train NSE: 0.281, Val NSE: 0.247
#    Train KGE: 0.333, Val KGE: 0.285
#    Train RMSE: 1.624, Val RMSE: 1.555
#    Train PBIAS: 0.134%, Val PBIAS: -4.236%
#    Train FLV: -50.225%, Val FLV: 3.831%
#    Train PTE: 79.5 days, Val PTE: 161.8 days
#    Params: mu=1.466, lambda=66.149, Qs=1.117, qs=1.982
#
# === Station W240501001 ===, Number = 608
# ✅ Train NSE: 0.486, Val NSE: 0.569
#    Train KGE: 0.562, Val KGE: 0.583
#    Train RMSE: 0.474, Val RMSE: 0.419
#    Train PBIAS: 0.769%, Val PBIAS: 5.521%
#    Train FLV: 27.642%, Val FLV: 33.718%
#    Train PTE: 136.5 days, Val PTE: 62.3 days
#    Params: mu=1.225, lambda=37.835, Qs=0.206, qs=1.631
#
# === Station W271000101 ===, Number = 609
# ⚠️ Too many missing values (18.2%)
#
# === Station W331501001 ===, Number = 610
# ✅ Train NSE: 0.433, Val NSE: 0.426
#    Train KGE: 0.520, Val KGE: 0.442
#    Train RMSE: 0.576, Val RMSE: 0.673
#    Train PBIAS: -0.683%, Val PBIAS: -7.620%
#    Train FLV: 4.733%, Val FLV: 25.507%
#    Train PTE: 105.6 days, Val PTE: 47.7 days
#    Params: mu=1.180, lambda=43.609, Qs=0.004, qs=0.149
#
# === Station X001001002 ===, Number = 611
# ✅ Train NSE: 0.047, Val NSE: 0.008
#    Train KGE: -0.072, Val KGE: -0.181
#    Train RMSE: 4.637, Val RMSE: 4.274
#    Train PBIAS: -2.207%, Val PBIAS: -16.478%
#    Train FLV: 62.101%, Val FLV: -6.634%
#    Train PTE: 119.9 days, Val PTE: 120.8 days
#    Params: mu=1.397, lambda=81.286, Qs=36.062, qs=19.662
#
# === Station X001501001 ===, Number = 612
# ⚠️ Too many missing values (46.2%)
#
# === Station X031001001 ===, Number = 613
# ✅ Train NSE: 0.048, Val NSE: -0.025
#    Train KGE: 0.165, Val KGE: -0.078
#    Train RMSE: 41.854, Val RMSE: 39.705
#    Train PBIAS: -9.858%, Val PBIAS: -26.379%
#    Train FLV: 67.608%, Val FLV: -56.676%
#    Train PTE: 115.6 days, Val PTE: 86.0 days
#    Params: mu=0.947, lambda=58.234, Qs=0.001, qs=0.029
#
# === Station X043401001 ===, Number = 614
# ✅ Train NSE: 0.098, Val NSE: 0.091
#    Train KGE: 0.050, Val KGE: -0.002
#    Train RMSE: 10.789, Val RMSE: 9.247
#    Train PBIAS: -2.021%, Val PBIAS: -6.596%
#    Train FLV: 33.638%, Val FLV: 21.455%
#    Train PTE: 115.2 days, Val PTE: 96.3 days
#    Params: mu=1.110, lambda=103.775, Qs=29.692, qs=5.995
#
# === Station X045401001 ===, Number = 615
# ✅ Train NSE: 0.172, Val NSE: 0.191
#    Train KGE: 0.170, Val KGE: 0.206
#    Train RMSE: 18.016, Val RMSE: 15.477
#    Train PBIAS: 0.144%, Val PBIAS: 3.541%
#    Train FLV: -3.763%, Val FLV: 27.090%
#    Train PTE: 84.9 days, Val PTE: 67.8 days
#    Params: mu=1.725, lambda=111.252, Qs=13.250, qs=1.270
#
# === Station X142000101 ===, Number = 616
# ⚠️ Too many missing values (18.2%)
#
# === Station X211401001 ===, Number = 617
# ✅ Train NSE: 0.632, Val NSE: 0.624
#    Train KGE: 0.715, Val KGE: 0.785
#    Train RMSE: 1.561, Val RMSE: 1.584
#    Train PBIAS: -0.783%, Val PBIAS: -3.973%
#    Train FLV: 27.170%, Val FLV: -43.588%
#    Train PTE: 71.1 days, Val PTE: 22.0 days
#    Params: mu=1.216, lambda=54.745, Qs=0.177, qs=0.464
#
# === Station X230501001 ===, Number = 618
# ✅ Train NSE: 0.689, Val NSE: 0.676
#    Train KGE: 0.744, Val KGE: 0.728
#    Train RMSE: 0.970, Val RMSE: 1.100
#    Train PBIAS: 6.256%, Val PBIAS: 4.803%
#    Train FLV: -33.378%, Val FLV: -48.950%
#    Train PTE: 28.6 days, Val PTE: 115.2 days
#    Params: mu=1.097, lambda=21.072, Qs=0.001, qs=0.067
#
# === Station Y020401001 ===, Number = 619
# ⚠️ Too many missing values (11.1%)
#
# === Station Y024521001 ===, Number = 620
# ⚠️ Too many missing values (27.1%)
#
# === Station Y025404001 ===, Number = 621
# ⚠️ Too many missing values (89.7%)
#
# === Station Y028406001 ===, Number = 622
# ✅ Train NSE: 0.716, Val NSE: 0.701
#    Train KGE: 0.769, Val KGE: 0.771
#    Train RMSE: 10.239, Val RMSE: 11.489
#    Train PBIAS: -9.905%, Val PBIAS: -5.233%
#    Train FLV: 20.874%, Val FLV: -155.705%
#    Train PTE: 5.4 days, Val PTE: 19.5 days
#    Params: mu=1.072, lambda=17.888, Qs=0.003, qs=0.041
#
# === Station Y062402001 ===, Number = 623
# ✅ Train NSE: 0.550, Val NSE: 0.490
#    Train KGE: 0.638, Val KGE: 0.546
#    Train RMSE: 4.047, Val RMSE: 4.602
#    Train PBIAS: -1.831%, Val PBIAS: 12.399%
#    Train FLV: -59.167%, Val FLV: -178.301%
#    Train PTE: 43.4 days, Val PTE: 0.3 days
#    Params: mu=1.201, lambda=25.670, Qs=0.329, qs=0.535
#
# === Station Y065501001 ===, Number = 624
# ⚠️ Too many missing values (11.5%)
#
# === Station Y113501001 ===, Number = 625
# ✅ Train NSE: 0.529, Val NSE: 0.337
#    Train KGE: 0.609, Val KGE: 0.541
#    Train RMSE: 2.012, Val RMSE: 2.515
#    Train PBIAS: 3.406%, Val PBIAS: 24.133%
#    Train FLV: -287.287%, Val FLV: -371.252%
#    Train PTE: 63.5 days, Val PTE: 9.0 days
#    Params: mu=1.101, lambda=21.593, Qs=0.001, qs=0.036
#
# === Station Y122501001 ===, Number = 626
# ✅ Train NSE: 0.473, Val NSE: 0.381
#    Train KGE: 0.523, Val KGE: 0.354
#    Train RMSE: 0.848, Val RMSE: 0.794
#    Train PBIAS: 12.793%, Val PBIAS: 52.215%
#    Train FLV: -96.505%, Val FLV: -162.861%
#    Train PTE: 69.5 days, Val PTE: 9.0 days
#    Params: mu=1.123, lambda=29.909, Qs=0.001, qs=0.047
#
# === Station Y132501001 ===, Number = 627
# ✅ Train NSE: 0.491, Val NSE: 0.524
#    Train KGE: 0.534, Val KGE: 0.571
#    Train RMSE: 0.558, Val RMSE: 0.557
#    Train PBIAS: 10.176%, Val PBIAS: 4.596%
#    Train FLV: -156.385%, Val FLV: -219.374%
#    Train PTE: 75.2 days, Val PTE: 90.8 days
#    Params: mu=1.103, lambda=43.346, Qs=0.001, qs=0.042
#
# === Station Y141502001 ===, Number = 628
# ✅ Train NSE: 0.452, Val NSE: 0.440
#    Train KGE: 0.525, Val KGE: 0.458
#    Train RMSE: 3.298, Val RMSE: 4.683
#    Train PBIAS: 2.752%, Val PBIAS: -1.185%
#    Train FLV: 14.143%, Val FLV: -145.931%
#    Train PTE: 46.1 days, Val PTE: 4.0 days
#    Params: mu=1.099, lambda=32.506, Qs=0.008, qs=0.086
#
# === Station Y152401001 ===, Number = 629
# ✅ Train NSE: 0.568, Val NSE: 0.515
#    Train KGE: 0.646, Val KGE: 0.551
#    Train RMSE: 2.595, Val RMSE: 2.362
#    Train PBIAS: 3.147%, Val PBIAS: 9.308%
#    Train FLV: -193.673%, Val FLV: -143.911%
#    Train PTE: 25.4 days, Val PTE: 7.2 days
#    Params: mu=1.135, lambda=62.880, Qs=0.001, qs=0.022
#
# === Station Y252002001 ===, Number = 630
# ✅ Train NSE: 0.629, Val NSE: 0.698
#    Train KGE: 0.706, Val KGE: 0.838
#    Train RMSE: 3.341, Val RMSE: 2.841
#    Train PBIAS: 1.032%, Val PBIAS: 6.254%
#    Train FLV: -200.051%, Val FLV: -342.987%
#    Train PTE: 42.6 days, Val PTE: 49.0 days
#    Params: mu=1.107, lambda=34.926, Qs=0.001, qs=0.036
#
# === Station Y320002001 ===, Number = 631
# ✅ Train NSE: 0.709, Val NSE: 0.451
#    Train KGE: 0.772, Val KGE: 0.719
#    Train RMSE: 3.438, Val RMSE: 2.220
#    Train PBIAS: 3.097%, Val PBIAS: -1.904%
#    Train FLV: -255.199%, Val FLV: -48.443%
#    Train PTE: 18.5 days, Val PTE: 103.5 days
#    Params: mu=1.130, lambda=38.060, Qs=0.004, qs=0.049
#
# === Station Y400201001 ===, Number = 632
# ⚠️ Too many missing values (44.9%)
#
# === Station Y460402001 ===, Number = 633
# ✅ Train NSE: 0.659, Val NSE: 0.637
#    Train KGE: 0.724, Val KGE: 0.594
#    Train RMSE: 1.814, Val RMSE: 1.532
#    Train PBIAS: 4.301%, Val PBIAS: 20.063%
#    Train FLV: -119.593%, Val FLV: -204.046%
#    Train PTE: 38.2 days, Val PTE: 101.0 days
#    Params: mu=1.122, lambda=49.885, Qs=0.001, qs=0.032
#
# === Station Y461502001 ===, Number = 634
# ✅ Train NSE: 0.702, Val NSE: 0.723
#    Train KGE: 0.764, Val KGE: 0.804
#    Train RMSE: 3.740, Val RMSE: 2.383
#    Train PBIAS: -8.115%, Val PBIAS: -3.493%
#    Train FLV: -29.965%, Val FLV: -402.359%
#    Train PTE: 54.0 days, Val PTE: 72.7 days
#    Params: mu=1.083, lambda=18.587, Qs=0.001, qs=0.042
#
# === Station Y500521001 ===, Number = 635
# ⚠️ Too many missing values (34.5%)
#
# === Station Y503201001 ===, Number = 636
# ✅ Train NSE: 0.671, Val NSE: 0.632
#    Train KGE: 0.746, Val KGE: 0.631
#    Train RMSE: 2.291, Val RMSE: 3.029
#    Train PBIAS: -0.339%, Val PBIAS: 6.419%
#    Train FLV: -251.178%, Val FLV: -461.877%
#    Train PTE: 25.9 days, Val PTE: 0.3 days
#    Params: mu=1.084, lambda=71.016, Qs=0.001, qs=0.021
#
# === Station Y510501001 ===, Number = 637
# ✅ Train NSE: 0.680, Val NSE: 0.639
#    Train KGE: 0.756, Val KGE: 0.758
#    Train RMSE: 2.013, Val RMSE: 1.659
#    Train PBIAS: -1.517%, Val PBIAS: 12.492%
#    Train FLV: -164.494%, Val FLV: -296.526%
#    Train PTE: 19.7 days, Val PTE: 0.7 days
#    Params: mu=1.149, lambda=57.280, Qs=0.020, qs=0.121
#
# === Station Y510661001 ===, Number = 638
# ✅ Train NSE: 0.643, Val NSE: 0.616
#    Train KGE: 0.673, Val KGE: 0.419
#    Train RMSE: 2.032, Val RMSE: 1.616
#    Train PBIAS: 13.005%, Val PBIAS: 48.722%
#    Train FLV: -12.509%, Val FLV: -78.312%
#    Train PTE: 17.3 days, Val PTE: 5.8 days
#    Params: mu=1.104, lambda=52.264, Qs=0.001, qs=0.032
#
# === Station Y521502001 ===, Number = 639
# ✅ Train NSE: 0.705, Val NSE: 0.675
#    Train KGE: 0.747, Val KGE: 0.627
#    Train RMSE: 5.480, Val RMSE: 5.496
#    Train PBIAS: 9.984%, Val PBIAS: 12.809%
#    Train FLV: -8.548%, Val FLV: 27.842%
#    Train PTE: 80.5 days, Val PTE: 89.0 days
#    Params: mu=1.104, lambda=23.582, Qs=0.001, qs=0.026
#
# === Station Y523501001 ===, Number = 640
# ✅ Train NSE: 0.626, Val NSE: 0.637
#    Train KGE: 0.715, Val KGE: 0.634
#    Train RMSE: 1.443, Val RMSE: 1.556
#    Train PBIAS: -6.061%, Val PBIAS: -16.882%
#    Train FLV: 35.523%, Val FLV: -183.473%
#    Train PTE: 37.4 days, Val PTE: 76.0 days
#    Params: mu=1.132, lambda=62.371, Qs=0.001, qs=0.027
#
# === Station Y531201001 ===, Number = 641
# ✅ Train NSE: 0.698, Val NSE: 0.703
#    Train KGE: 0.769, Val KGE: 0.768
#    Train RMSE: 20.790, Val RMSE: 20.675
#    Train PBIAS: -7.468%, Val PBIAS: -0.052%
#    Train FLV: -501.218%, Val FLV: -352.783%
#    Train PTE: 30.0 days, Val PTE: 89.7 days
#    Params: mu=1.083, lambda=41.004, Qs=0.001, qs=0.009
#
# === Station Y532501001 ===, Number = 642
# ✅ Train NSE: 0.547, Val NSE: 0.723
#    Train KGE: 0.598, Val KGE: 0.598
#    Train RMSE: 1.540, Val RMSE: 2.077
#    Train PBIAS: 14.613%, Val PBIAS: 11.441%
#    Train FLV: 15.091%, Val FLV: 19.181%
#    Train PTE: 87.4 days, Val PTE: 50.5 days
#    Params: mu=1.098, lambda=16.274, Qs=0.001, qs=0.070
#
# === Station Y542401001 ===, Number = 643
# ✅ Train NSE: 0.704, Val NSE: 0.752
#    Train KGE: 0.685, Val KGE: 0.484
#    Train RMSE: 1.225, Val RMSE: 0.880
#    Train PBIAS: 19.887%, Val PBIAS: 45.052%
#    Train FLV: -282.609%, Val FLV: nan%
#    Train PTE: 26.5 days, Val PTE: 44.0 days
#    Params: mu=1.130, lambda=40.858, Qs=0.001, qs=0.042
#
# === Station Y543501001 ===, Number = 644
# ✅ Train NSE: 0.457, Val NSE: 0.653
#    Train KGE: 0.410, Val KGE: 0.152
#    Train RMSE: 1.479, Val RMSE: 0.718
#    Train PBIAS: 35.590%, Val PBIAS: 81.218%
#    Train FLV: nan%, Val FLV: nan%
#    Train PTE: 45.3 days, Val PTE: 143.0 days
#    Params: mu=1.123, lambda=31.438, Qs=0.001, qs=0.064
#
# === Station Y550541001 ===, Number = 645
# ⚠️ Too many missing values (30.3%)
#
# === Station Y561501001 ===, Number = 646
# ✅ Train NSE: 0.717, Val NSE: 0.749
#    Train KGE: 0.790, Val KGE: 0.780
#    Train RMSE: 3.647, Val RMSE: 3.945
#    Train PBIAS: -4.448%, Val PBIAS: -7.825%
#    Train FLV: 24.563%, Val FLV: -399.374%
#    Train PTE: 48.7 days, Val PTE: 0.7 days
#    Params: mu=1.232, lambda=12.538, Qs=6.624, qs=5.813
#
# === Station Y604201001 ===, Number = 647
# ⚠️ Too many missing values (10.5%)
#
# === Station Y643401001 ===, Number = 648
# ✅ Train NSE: 0.754, Val NSE: 0.755
#    Train KGE: 0.816, Val KGE: 0.775
#    Train RMSE: 4.809, Val RMSE: 4.422
#    Train PBIAS: -0.697%, Val PBIAS: 6.832%
#    Train FLV: -101.344%, Val FLV: -196.164%
#    Train PTE: 38.1 days, Val PTE: 43.7 days
#    Params: mu=1.233, lambda=60.749, Qs=0.331, qs=0.295
#
# === Station Y661401001 ===, Number = 649
# ✅ Train NSE: 0.563, Val NSE: 0.568
#    Train KGE: 0.633, Val KGE: 0.606
#    Train RMSE: 4.310, Val RMSE: 3.704
#    Train PBIAS: -18.155%, Val PBIAS: -17.949%
#    Train FLV: -93.629%, Val FLV: -162.645%
#    Train PTE: 51.7 days, Val PTE: 0.2 days
#    Params: mu=1.165, lambda=7.328, Qs=4.354, qs=6.741
#
# === Station Y781000101 ===, Number = 650
# ✅ Train NSE: 0.408, Val NSE: 0.539
#    Train KGE: 0.475, Val KGE: 0.611
#    Train RMSE: 3.522, Val RMSE: 3.234
#    Train PBIAS: 5.101%, Val PBIAS: 14.258%
#    Train FLV: -45.852%, Val FLV: 51.671%
#    Train PTE: 139.7 days, Val PTE: 156.2 days
#    Params: mu=1.184, lambda=135.775, Qs=0.001, qs=0.014
#
# === Station Y862000101 ===, Number = 651
# ✅ Train NSE: 0.729, Val NSE: 0.663
#    Train KGE: 0.796, Val KGE: 0.595
#    Train RMSE: 4.193, Val RMSE: 5.930
#    Train PBIAS: -0.520%, Val PBIAS: -16.579%
#    Train FLV: -89.908%, Val FLV: -100.631%
#    Train PTE: 59.6 days, Val PTE: 40.0 days
#    Params: mu=1.273, lambda=56.423, Qs=0.704, qs=0.642
#
# === Station Y881000102 ===, Number = 652
# ⚠️ Too many missing values (44.0%)
#
# === Station Y902000101 ===, Number = 653
# ✅ Train NSE: 0.530, Val NSE: 0.624
#    Train KGE: 0.620, Val KGE: 0.681
#    Train RMSE: 5.651, Val RMSE: 6.201
#    Train PBIAS: -1.451%, Val PBIAS: -0.145%
#    Train FLV: -9.290%, Val FLV: -21.027%
#    Train PTE: 40.7 days, Val PTE: 135.7 days
#    Params: mu=1.214, lambda=58.017, Qs=0.085, qs=0.196
#
# === Station Y960000102 ===, Number = 654
# ✅ Train NSE: 0.514, Val NSE: 0.513
#    Train KGE: 0.594, Val KGE: 0.737
#    Train RMSE: 5.712, Val RMSE: 7.045
#    Train PBIAS: -11.430%, Val PBIAS: -9.880%
#    Train FLV: -301.872%, Val FLV: -174.520%
#    Train PTE: 69.2 days, Val PTE: 37.5 days
#    Params: mu=1.123, lambda=1.530, Qs=296.187, qs=163.800
#
# ✅ Simulation complete for 549 valid basins.

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# ============================================
# 1. EXTRACT DATA TO DATAFRAME
# ============================================
rows = []
seasons = ["DJF", "MAM", "JJA", "SON"]

for station_id, res in results.items():
    # Dynamically unpack parameters (mu, lambda, Qs, qs) using param_names
    param_dict = dict(zip(res["param_names"], res["params"]))

    row = {
        "station_id": station_id,
        **param_dict,
        "RR": res.get("RR", np.nan),
        "NSE_train": res.get("NSE_train", np.nan),
        "NSE_val": res.get("NSE_val", np.nan),
        "NNSE_train": res.get("NNSE_train", np.nan),
        "NNSE_val": res.get("NNSE_val", np.nan),
        "RMSE_train": res.get("RMSE_train", np.nan),
        "RMSE_val": res.get("RMSE_val", np.nan),
        "PBIAS_train": res.get("PBIAS_train", np.nan),
        "PBIAS_val": res.get("PBIAS_val", np.nan),
        "FHV_train": res.get("FHV_train", np.nan),
        "FHV_val": res.get("FHV_val", np.nan),
        "FLV_train": res.get("FLV_train", np.nan),
        "FLV_val": res.get("FLV_val", np.nan),
        "KGE_train": res.get("KGE_train", np.nan),
        "KGE_val": res.get("KGE_val", np.nan),
        "PTE_train": res.get("PTE_train", np.nan),
        "PTE_val": res.get("PTE_val", np.nan),
        "missing_ratio": res.get("missing_ratio", np.nan),
        "missing_count": res.get("missing_count", np.nan),
    }

    # Dynamically add seasonal metrics
    for season in seasons:
        row[f"NSE_{season}_train"]   = res.get(f"NSE_{season}_train", np.nan)
        row[f"NSE_{season}_val"]     = res.get(f"NSE_{season}_val", np.nan)
        row[f"KGE_{season}_train"]   = res.get(f"KGE_{season}_train", np.nan)
        row[f"KGE_{season}_val"]     = res.get(f"KGE_{season}_val", np.nan)
        row[f"RMSE_{season}_train"]  = res.get(f"RMSE_{season}_train", np.nan)
        row[f"RMSE_{season}_val"]    = res.get(f"RMSE_{season}_val", np.nan)
        row[f"PBIAS_{season}_train"] = res.get(f"PBIAS_{season}_train", np.nan)
        row[f"PBIAS_{season}_val"]   = res.get(f"PBIAS_{season}_val", np.nan)

    rows.append(row)

df = pd.DataFrame(rows)

# ============================================
# 2. SAVE RESULTS
# ============================================
# Local save
df.to_csv("dHyMoLAP_Simulation_Data_CAMELS_FR.csv", index=False)
print("✅ Saved locally to dHyMoLAP_Simulation_Data_CAMELS_FR.csv")

# Save to Google Drive (this is the file the loader script reads back)
drive.mount("/content/drive")
df.to_csv("/content/drive/MyDrive/Colab Notebooks/Data/dHyMoLAP_Simulation_Data_CAMELS_FR.csv", index=False)
print("✅ Saved to Google Drive")

# ============================================
# 3. DEFINE METRICS TO REPORT
# ============================================
global_metrics = [
    ("NSE_train",   "NSE Training",     ""),
    ("NSE_val",     "NSE Validation",   ""),
    ("NNSE_train",  "NNSE Training",    ""),
    ("NNSE_val",    "NNSE Validation",  ""),
    ("KGE_train",   "KGE Training",     ""),
    ("KGE_val",     "KGE Validation",   ""),
    ("RMSE_train",  "RMSE Training",    " m³/s"),
    ("RMSE_val",    "RMSE Validation",  " m³/s"),
    ("PTE_train",   "PTE Training",     " days"),
    ("PTE_val",     "PTE Validation",   " days"),
    ("PBIAS_train", "PBIAS Training",   "%"),
    ("PBIAS_val",   "PBIAS Validation", "%"),
    ("FHV_train",   "FHV Training",     "%"),
    ("FHV_val",     "FHV Validation",   "%"),
    ("FLV_train",   "FLV Training",     "%"),
    ("FLV_val",     "FLV Validation",   "%"),
    ("RR",          "Runoff Ratio",     ""),
]

base_vars = ["NSE", "KGE", "RMSE", "PBIAS"]
seasons_metrics = []
for var in base_vars:
    unit = " m³/s" if var == "RMSE" else ("%" if var == "PBIAS" else "")
    for s in seasons:
        for split, label in [("train", "Training"), ("val", "Validation")]:
            col = f"{var}_{s}_{split}"
            seasons_metrics.append((col, f"{var} {s} {label}", unit))

# ============================================
# 4. REPORTING STATISTICS
# ============================================
def print_stats(metrics_list, df, title):
    print(f"\n{'='*60}")
    print(f" {title}")
    print(f"{'='*60}")
    for key, label, unit in metrics_list:
        if key not in df.columns:
            print(f"  ⚠️  '{key}' not found in CSV — skipping.")
            continue
        values = pd.to_numeric(df[key], errors="coerce").to_numpy()
        n_valid   = int(np.sum(~np.isnan(values)))
        n_dropped = int(np.sum( np.isnan(values)))
        if n_valid == 0:
            print(f"  ⚠️  {label}: all NaN — no valid stations.")
            continue
        print(
            f"  {label:<28} | "
            f"Mean: {np.nanmean(values):8.3f}{unit}  "
            f"Median: {np.nanmedian(values):8.3f}{unit}  "
            f"Min: {np.nanmin(values):8.3f}{unit}  "
            f"Max: {np.nanmax(values):8.3f}{unit}  "
            f"P05: {np.nanpercentile(values,  5):8.3f}{unit}  "
            f"P95: {np.nanpercentile(values, 95):8.3f}{unit}  "
            f"(n={n_valid})"
        )
        if n_dropped:
            print(f"    ⚠️  {n_dropped} station(s) excluded (NaN).")

print(f"\n✅ Saved {len(df)} stations to CSV.")
print_stats(global_metrics,  df, "GLOBAL SUMMARY STATISTICS")
print_stats(seasons_metrics, df, "SEASONAL SUMMARY STATISTICS")
# Out:
# ✅ Saved locally to dHyMoLAP_Simulation_Data_CAMELS_FR.csv
# Mounted at /content/drive
# ✅ Saved to Google Drive
#
# ✅ Saved 549 stations to CSV.
#
# ============================================================
#  GLOBAL SUMMARY STATISTICS
# ============================================================
#   NSE Training                 | Mean:    0.637  Median:    0.643  Min:    0.047  Max:    0.877  P05:    0.453  P95:    0.809  (n=549)
#   NSE Validation               | Mean:    0.649  Median:    0.674  Min:   -0.361  Max:    0.900  P05:    0.411  P95:    0.835  (n=549)
#   NNSE Training                | Mean:    0.739  Median:    0.737  Min:    0.512  Max:    0.890  P05:    0.647  P95:    0.840  (n=549)
#   NNSE Validation              | Mean:    0.749  Median:    0.754  Min:    0.423  Max:    0.909  P05:    0.629  P95:    0.858  (n=549)
#   KGE Training                 | Mean:    0.700  Median:    0.706  Min:   -0.072  Max:    0.896  P05:    0.524  P95:    0.850  (n=549)
#   KGE Validation               | Mean:    0.689  Median:    0.715  Min:   -0.181  Max:    0.911  P05:    0.460  P95:    0.853  (n=549)
#   RMSE Training                | Mean:    5.034 m³/s  Median:    1.827 m³/s  Min:    0.088 m³/s  Max:  339.923 m³/s  P05:    0.253 m³/s  P95:   17.737 m³/s  (n=549)
#   RMSE Validation              | Mean:    4.756 m³/s  Median:    1.702 m³/s  Min:    0.074 m³/s  Max:  331.626 m³/s  P05:    0.255 m³/s  P95:   17.046 m³/s  (n=549)
#   PTE Training                 | Mean:   68.847 days  Median:   67.200 days  Min:    4.333 days  Max:  165.133 days  P05:   19.653 days  P95:  128.013 days  (n=549)
#   PTE Validation               | Mean:   56.494 days  Median:   54.333 days  Min:    0.167 days  Max:  203.000 days  P05:    1.567 days  P95:  135.767 days  (n=549)
#   PBIAS Training               | Mean:    2.050%  Median:    0.700%  Min:  -18.155%  Max:   35.590%  P05:   -3.067%  P95:   12.558%  (n=549)
#   PBIAS Validation             | Mean:    9.889%  Median:    7.726%  Min:  -31.469%  Max:   81.218%  P05:   -9.227%  P95:   37.429%  (n=549)
#   FHV Training                 | Mean:  -23.757%  Median:  -23.311%  Min:  -63.273%  Max:   -0.234%  P05:  -39.099%  P95:   -8.572%  (n=549)
#   FHV Validation               | Mean:  -20.159%  Median:  -20.150%  Min:  -73.185%  Max:   23.356%  P05:  -40.975%  P95:    1.226%  (n=549)
#   FLV Training                 | Mean:  -48.727%  Median:  -24.188%  Min: -573.560%  Max:   79.088%  P05: -229.802%  P95:   60.001%  (n=548)
#     ⚠️  1 station(s) excluded (NaN).
#   FLV Validation               | Mean:  -95.921%  Median:  -69.947%  Min: -934.421%  Max:   86.607%  P05: -365.300%  P95:   53.617%  (n=547)
#     ⚠️  2 station(s) excluded (NaN).
#   ⚠️  Runoff Ratio: all NaN — no valid stations.
#
# ============================================================
#  SEASONAL SUMMARY STATISTICS
# ============================================================
#   NSE DJF Training             | Mean:    0.461  Median:    0.597  Min:  -35.487  Max:    0.859  P05:    0.404  P95:    0.778  (n=549)
#   NSE DJF Validation           | Mean:    0.539  Median:    0.677  Min:  -17.525  Max:    0.876  P05:    0.395  P95:    0.817  (n=549)
#   NSE MAM Training             | Mean:    0.610  Median:    0.635  Min:   -0.109  Max:    0.854  P05:    0.334  P95:    0.769  (n=549)
#   NSE MAM Validation           | Mean:    0.623  Median:    0.651  Min:   -0.900  Max:    0.931  P05:    0.294  P95:    0.825  (n=549)
#   NSE JJA Training             | Mean:   -0.420  Median:    0.083  Min:  -33.316  Max:    0.880  P05:   -2.982  P95:    0.703  (n=549)
#   NSE JJA Validation           | Mean:   -0.137  Median:    0.425  Min:  -63.782  Max:    0.917  P05:   -2.220  P95:    0.771  (n=549)
#   NSE SON Training             | Mean:    0.428  Median:    0.540  Min:   -2.953  Max:    0.820  P05:   -0.230  P95:    0.745  (n=549)
#   NSE SON Validation           | Mean:   -0.859  Median:   -0.024  Min:  -34.303  Max:    0.822  P05:   -4.425  P95:    0.711  (n=549)
#   KGE DJF Training             | Mean:    0.637  Median:    0.648  Min:   -1.387  Max:    0.898  P05:    0.446  P95:    0.835  (n=549)
#   KGE DJF Validation           | Mean:    0.678  Median:    0.708  Min:   -0.970  Max:    0.933  P05:    0.444  P95:    0.859  (n=549)
#   KGE MAM Training             | Mean:    0.643  Median:    0.660  Min:   -0.179  Max:    0.921  P05:    0.388  P95:    0.833  (n=549)
#   KGE MAM Validation           | Mean:    0.692  Median:    0.720  Min:   -0.237  Max:    0.949  P05:    0.434  P95:    0.868  (n=549)
#   KGE JJA Training             | Mean:    0.110  Median:    0.331  Min:   -6.115  Max:    0.884  P05:   -1.232  P95:    0.744  (n=549)
#   KGE JJA Validation           | Mean:    0.198  Median:    0.436  Min:  -16.485  Max:    0.900  P05:   -1.104  P95:    0.777  (n=549)
#   KGE SON Training             | Mean:    0.372  Median:    0.484  Min:   -2.053  Max:    0.831  P05:   -0.475  P95:    0.755  (n=549)
#   KGE SON Validation           | Mean:   -0.143  Median:    0.090  Min:   -5.689  Max:    0.790  P05:   -1.809  P95:    0.653  (n=549)
#   RMSE DJF Training            | Mean:    6.462 m³/s  Median:    2.330 m³/s  Min:    0.088 m³/s  Max:  425.227 m³/s  P05:    0.342 m³/s  P95:   22.439 m³/s  (n=549)
#   RMSE DJF Validation          | Mean:    6.230 m³/s  Median:    2.244 m³/s  Min:    0.075 m³/s  Max:  396.786 m³/s  P05:    0.325 m³/s  P95:   22.831 m³/s  (n=549)
#   RMSE MAM Training            | Mean:    5.111 m³/s  Median:    1.751 m³/s  Min:    0.074 m³/s  Max:  402.851 m³/s  P05:    0.254 m³/s  P95:   16.099 m³/s  (n=549)
#   RMSE MAM Validation          | Mean:    4.260 m³/s  Median:    1.448 m³/s  Min:    0.057 m³/s  Max:  302.825 m³/s  P05:    0.191 m³/s  P95:   14.628 m³/s  (n=549)
#   RMSE JJA Training            | Mean:    3.164 m³/s  Median:    1.069 m³/s  Min:    0.041 m³/s  Max:  198.134 m³/s  P05:    0.148 m³/s  P95:   10.922 m³/s  (n=549)
#   RMSE JJA Validation          | Mean:    3.347 m³/s  Median:    1.050 m³/s  Min:    0.044 m³/s  Max:  270.610 m³/s  P05:    0.149 m³/s  P95:   11.779 m³/s  (n=549)
#   RMSE SON Training            | Mean:    4.477 m³/s  Median:    1.664 m³/s  Min:    0.069 m³/s  Max:  273.635 m³/s  P05:    0.222 m³/s  P95:   14.927 m³/s  (n=549)
#   RMSE SON Validation          | Mean:    4.405 m³/s  Median:    1.632 m³/s  Min:    0.073 m³/s  Max:  346.998 m³/s  P05:    0.227 m³/s  P95:   15.936 m³/s  (n=549)
#   PBIAS DJF Training           | Mean:   -8.962%  Median:  -11.441%  Min:  -43.716%  Max:  200.307%  P05:  -23.131%  P95:    5.767%  (n=549)
#   PBIAS DJF Validation         | Mean:   -3.776%  Median:   -6.161%  Min:  -42.469%  Max:  165.278%  P05:  -23.247%  P95:   20.750%  (n=549)
#   PBIAS MAM Training           | Mean:  -16.962%  Median:  -16.094%  Min:  -52.634%  Max:   15.146%  P05:  -33.270%  P95:   -5.578%  (n=549)
#   PBIAS MAM Validation         | Mean:   -6.230%  Median:   -6.639%  Min:  -45.251%  Max:   55.952%  P05:  -28.997%  P95:   14.368%  (n=549)
#   PBIAS JJA Training           | Mean:   66.389%  Median:   47.055%  Min:  -43.802%  Max:  572.785%  P05:   -2.970%  P95:  189.630%  (n=549)
#   PBIAS JJA Validation         | Mean:   57.323%  Median:   36.424%  Min:  -52.006%  Max: 1614.292%  P05:   -9.474%  P95:  183.201%  (n=549)
#   PBIAS SON Training           | Mean:   53.845%  Median:   43.961%  Min:   -6.332%  Max:  286.454%  P05:    6.564%  P95:  143.393%  (n=549)
#   PBIAS SON Validation         | Mean:   89.012%  Median:   66.430%  Min:  -12.332%  Max:  525.703%  P05:    6.226%  P95:  245.104%  (n=549)
