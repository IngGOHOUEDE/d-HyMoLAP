# %% [markdown]
# > **This notebook implements HyMoLAP rainfall–runoff model over CAMELS-GB catchments with less than 10% missing discharge data and stores the resulting calibrated parameters and performance metrics in `HyMoLAP_Simulation_Data_CAMELS_GB.csv`.**
#
# **Author:** Lionel Cedric Gohouede

# %% [markdown]
# ## 1. MOUNT GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import warnings
from numba import njit
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# ## 3. FILTER DATA BY TIME PERIOD (1990-2014)

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/CAMELS_GB/'
start_date, end_date = '1990-01-01', '2014-12-31'

print("Loading, filtering, and aligning CSV files...\n")

# 1. Fast Load & Filter
df_pcp = pd.read_csv(f"{data_dir}pcp_mm.csv", index_col=0).loc[start_date:end_date]
df_pet = pd.read_csv(f"{data_dir}pet_mm.csv", index_col=0).loc[start_date:end_date]
df_q   = pd.read_csv(f"{data_dir}q_cms_obs.csv", index_col=0).loc[start_date:end_date]

# 2. Fast Alignment
common_stations = sorted(list(set(df_pcp.columns) & set(df_pet.columns) & set(df_q.columns)))
df_pcp = df_pcp[common_stations]
df_pet = df_pet[common_stations]
df_q   = df_q[common_stations]

print(f"✅ Data aligned. Total common stations: {len(common_stations)}")

# ============================================
# Memory-Optimized Wrapper Classes
# ============================================
class SimpleArray:
    __slots__ = ['array']  # Prevents massive RAM bloat
    def __init__(self, array):
        self.array = array
    def to_numpy(self):
        return self.array

class StationData:
    __slots__ = ['data']
    def __init__(self, data_dict):
        self.data = data_dict
    def sel(self, dynamic_features=None):
        return SimpleArray(self.data[dynamic_features])

# ============================================
# Ultra-Fast Dictionary Construction
# ============================================
print("Building ds_recent dictionary...\n")

# Convert DataFrames to 2D NumPy matrices once (orders of magnitude faster than column iteration)
pcp_arr = df_pcp.to_numpy()
pet_arr = df_pet.to_numpy()
q_arr   = df_q.to_numpy()
date_arr = pd.to_datetime(df_pcp.index).to_numpy()

# Build the dictionary using fast index slicing
ds_recent = {
    st: StationData({
        'pcp_mm': pcp_arr[:, i],
        'pet_mm': pet_arr[:, i],
        'q_cms_obs': q_arr[:, i],
        'date': date_arr
    })
    for i, st in enumerate(common_stations)
}

print(f"✅ Dictionary built successfully!")

# ============================================
# Validation Test
# ============================================
test_station = common_stations[0]
print(f"\nTesting data access for station: {test_station}")

Q_obs = ds_recent[test_station].sel(dynamic_features="q_cms_obs").to_numpy()
P     = ds_recent[test_station].sel(dynamic_features="pcp_mm").to_numpy()
PET   = ds_recent[test_station].sel(dynamic_features="pet_mm").to_numpy()

print(f"✅ Extraction works correctly!")
print(f"   Q_obs shape: {Q_obs.shape}")
print(f"   Q_obs - min: {np.nanmin(Q_obs):.2f}, max: {np.nanmax(Q_obs):.2f}, mean: {np.nanmean(Q_obs):.2f}")
print(f"   Q_obs Missing: {np.sum(np.isnan(Q_obs))} ({np.sum(np.isnan(Q_obs))/len(Q_obs)*100:.1f}%)")
# Out:
# Loading, filtering, and aligning CSV files...
#
# ✅ Data aligned. Total common stations: 671
# Building ds_recent dictionary...
#
# ✅ Dictionary built successfully!
#
# Testing data access for station: 10002
# ✅ Extraction works correctly!
#    Q_obs shape: (9131,)
#    Q_obs - min: 0.80, max: 94.41, mean: 5.18
#    Q_obs Missing: 0 (0.0%)

# %% [markdown]
# ## 4. MAIN CODE

# %%
import numpy as np
import pandas as pd
from numba import njit
from scipy.optimize import minimize

# ============================================
# 1. COMPILED HYMOLAP MODEL & FAST METRICS
# Defined outside the loop to prevent memory reallocation
# ============================================
@njit
def HyMoLAP_Model(params, Q0, Pn):
    MU, LAMBDA = params
    N = len(Pn)
    Q = np.zeros(N)

    if LAMBDA <= 0.0 or MU <= 0.0:
        return np.full(N, np.nan)

    Q[0] = Q0
    X_curr = 0.0

    mu_lam = MU / LAMBDA
    inv_lam = 1.0 / LAMBDA
    one_m_mu_lam = 1.0 - mu_lam
    pow_term = 2.0 * MU - 1.0

    for t in range(N - 1):
        q_base = max(0.0, Q[t])
        Q[t+1] = max(0.0, Q[t] - mu_lam * (q_base ** pow_term) + inv_lam * X_curr * Pn[t])

        if Pn[t+1] == 0.0:
            X_curr = X_curr * one_m_mu_lam
        else:
            X_curr = X_curr + mu_lam * Pn[t+1]

    return Q

def NSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0 or np.var(valid_obs) == 0.0: return np.nan
    return 1.0 - (np.sum((valid_sim - valid_obs)**2) / np.sum((valid_obs - np.mean(valid_obs))**2))

def RMSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0: return np.nan
    return np.sqrt(np.mean((valid_sim - valid_obs)**2))

def compute_pte(obs, sim, dates):
    """Computes Mean Absolute Annual Peak Timing Error (PTE) in days."""
    df = pd.DataFrame({'obs': obs, 'sim': sim}, index=pd.DatetimeIndex(dates))
    df = df.dropna()

    if df.empty:
        return np.nan

    pte_list = []
    for year, group in df.groupby(df.index.year):
        days_in_year = pd.Timestamp(year, 12, 31).dayofyear
        if len(group) < 0.8 * days_in_year:
            continue

        idx_obs_peak = group['obs'].idxmax()
        idx_sim_peak = group['sim'].idxmax()

        diff_days = abs((idx_sim_peak - idx_obs_peak).days)
        pte_list.append(diff_days)

    return np.mean(pte_list) if pte_list else np.nan

def compute_all_metrics(obs, sim, dates):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    o = obs[mask]
    s = sim[mask]
    L_len = o.size

    if L_len == 0:
        return dict(NSE=np.nan, NNSE=np.nan, RMSE=np.nan,
                    PBIAS=np.nan, FHV=np.nan, FLV=np.nan, KGE=np.nan, PTE=np.nan)

    # 1. Base Metrics
    obs_mean = np.mean(o)
    sim_mean = np.mean(s)
    denom = np.sum((o - obs_mean) ** 2)

    if denom == 0.0:
        nse = np.nan
        nnse = np.nan
    else:
        nse = 1.0 - np.sum((s - o) ** 2) / denom
        nnse = 1.0 / (2.0 - nse) if np.isfinite(nse) else np.nan

    rmse = np.sqrt(np.mean((s - o) ** 2))

    # 2. Water Balance / PBIAS (Yilmaz 2008, Eq A1)
    sum_obs = np.sum(o)
    pbias = 100.0 * np.sum(s - o) / sum_obs if sum_obs != 0.0 else np.nan

    # 3. Flow Duration Curve (FDC) Metrics (FHV, FLV)
    o_sorted = np.sort(o)[::-1]
    s_sorted = np.sort(s)[::-1]

    n_hv = max(1, int(round(0.02 * L_len)))
    sum_obs_hv = np.sum(o_sorted[:n_hv])
    sum_sim_hv = np.sum(s_sorted[:n_hv])
    fhv = 100.0 * (sum_sim_hv - sum_obs_hv) / sum_obs_hv if sum_obs_hv != 0.0 else np.nan

    n_lv = max(1, int(round(0.30 * L_len)))
    epsilon = 1e-6
    o_low = o_sorted[-n_lv:]
    s_low = s_sorted[-n_lv:]

    log_o = np.log(o_low + epsilon)
    log_s = np.log(s_low + epsilon)
    log_o_L = np.log(o_sorted[-1] + epsilon)
    log_s_L = np.log(s_sorted[-1] + epsilon)

    term_o = np.sum(log_o - log_o_L)
    term_s = np.sum(log_s - log_s_L)

    flv = -100.0 * (term_s - term_o) / term_o if term_o != 0.0 else np.nan

    # 4. KGE (Kling-Gupta Efficiency)
    sigma_obs = np.std(o)
    sigma_sim = np.std(s)
    if sigma_obs == 0.0 or sigma_sim == 0.0 or obs_mean == 0.0:
        kge = np.nan
    else:
        r_val = np.corrcoef(o, s)[0, 1]
        alpha = sigma_sim / sigma_obs
        beta = sim_mean / obs_mean
        if not np.isfinite(r_val):
            kge = np.nan
        else:
            kge = 1.0 - np.sqrt((r_val - 1.0) ** 2 + (alpha - 1.0) ** 2 + (beta - 1.0) ** 2)

    # 5. Peak Time Error (Annual)
    pte = compute_pte(obs, sim, dates)

    return dict(NSE=nse, NNSE=nnse, RMSE=rmse, PBIAS=pbias,
                FHV=fhv, FLV=flv, KGE=kge, PTE=pte)

def objective(params, Q0, Pn_train, Q_obs_train):
    Q_sim = HyMoLAP_Model(params, Q0, Pn_train)
    nse = NSE(Q_obs_train, Q_sim)
    return 1.0 - nse if np.isfinite(nse) else 1e9

# ============================================
# 2. CALIBRATION LOOP
# ============================================
b1_ratio = 0.7
max_missing_ratio = 0.1
stations = common_stations
results = {}

param_bounds = [(0.5, 5.0), (1e-3, 200.0)]
initial_guesses = [[1.1, 20.0]]

print(f"\nStarting simulation for {len(stations)} stations...\n")

for i, station_id in enumerate(stations, 1):
    print(f"\n=== Station {station_id} ===, Number={i}")

    Q_obs = ds_recent[station_id].sel(dynamic_features="q_cms_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    # CORRECTED: Extract temporal components using the StationData wrapper
    dates = ds_recent[station_id].sel(dynamic_features="date").to_numpy()
    time_months = pd.DatetimeIndex(dates).month.to_numpy()

    Pn = np.maximum(0.0, P - PET)
    N = len(Q_obs)

    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station skipped (no valid data).")
        continue

    missing_count = np.sum(np.isnan(Q_obs))
    missing_ratio = missing_count / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    total_p = np.nansum(P)
    RR = np.nansum(Q_obs) / total_p if total_p > 0 else np.nan

    b1 = int(N * b1_ratio)
    Q0 = Q_obs[0] if not np.isnan(Q_obs[0]) else np.nanmean(Q_obs[:10])

    Pn_train = Pn[:b1]
    Q_obs_train = Q_obs[:b1]

    best_res = None
    best_val = float("inf")

    for guess in initial_guesses:
        res = minimize(
            objective,
            np.array(guess),
            args=(Q0, Pn_train, Q_obs_train),
            method="Nelder-Mead",
            bounds=param_bounds,
            options={'maxiter': 2500, 'disp': False}
        )
        if res.fun < best_val:
            best_val = res.fun
            best_res = res

    MU, LAMBDA = best_res.x

    # Full-period simulation
    Qsim = HyMoLAP_Model(best_res.x, Q0, Pn)

    # Base Metrics
    m_train = compute_all_metrics(Q_obs_train, Qsim[:b1], dates[:b1])
    m_val   = compute_all_metrics(Q_obs[b1:], Qsim[b1:], dates[b1:])

    print(f"✅ Training NSE: {m_train['NSE']:.3f}, Validation NSE: {m_val['NSE']:.3f}")
    print(f"   Training KGE: {m_train['KGE']:.3f}, Validation KGE: {m_val['KGE']:.3f}")
    print(f"   Training RMSE: {m_train['RMSE']:.3f} m³/s, Validation RMSE: {m_val['RMSE']:.3f} m³/s")
    print(f"   Training PBIAS: {m_train['PBIAS']:.3f}, Validation PBIAS: {m_val['PBIAS']:.3f}")
    print(f"   Params: mu={MU:.3f}, lambda={LAMBDA:.3f}")

    # Build the dictionary entry for the catchment
    station_result = {
        "param_names": ["mu", "lambda"],
        "params": [MU, LAMBDA],
        "NSE_train": m_train["NSE"],     "NSE_val": m_val["NSE"],
        "NNSE_train": m_train["NNSE"],   "NNSE_val": m_val["NNSE"],
        "RMSE_train": m_train["RMSE"],   "RMSE_val": m_val["RMSE"],
        "PBIAS_train": m_train["PBIAS"], "PBIAS_val": m_val["PBIAS"],
        "FHV_train": m_train["FHV"],     "FHV_val": m_val["FHV"],
        "FLV_train": m_train["FLV"],     "FLV_val": m_val["FLV"],
        "KGE_train": m_train["KGE"],     "KGE_val": m_val["KGE"],
        "PTE_train": m_train["PTE"],     "PTE_val": m_val["PTE"],
        "RR": RR,
        "Qsim": Qsim,
        "missing_ratio": missing_ratio,
        "missing_count": missing_count,
    }

    # -----------------------------------------------------------------
    # Extract Seasonal Metrics
    # -----------------------------------------------------------------
    seasons_map = {
        "DJF": [12, 1, 2],
        "MAM": [3, 4, 5],
        "JJA": [6, 7, 8],
        "SON": [9, 10, 11]
    }

    months_train = time_months[:b1]
    months_val = time_months[b1:]

    for season, m_list in seasons_map.items():
        mask_train = np.isin(months_train, m_list)
        mask_val = np.isin(months_val, m_list)

        if np.any(mask_train):
            s_train_metrics = compute_all_metrics(Q_obs_train[mask_train], Qsim[:b1][mask_train], dates[:b1][mask_train])
        else:
            s_train_metrics = {k: np.nan for k in m_train.keys()}

        if np.any(mask_val):
            s_val_metrics = compute_all_metrics(Q_obs[b1:][mask_val], Qsim[b1:][mask_val], dates[b1:][mask_val])
        else:
            s_val_metrics = {k: np.nan for k in m_val.keys()}

        station_result[f"NSE_{season}_train"] = s_train_metrics["NSE"]
        station_result[f"NSE_{season}_val"] = s_val_metrics["NSE"]
        station_result[f"KGE_{season}_train"] = s_train_metrics["KGE"]
        station_result[f"KGE_{season}_val"] = s_val_metrics["KGE"]
        station_result[f"RMSE_{season}_train"] = s_train_metrics["RMSE"]
        station_result[f"RMSE_{season}_val"] = s_val_metrics["RMSE"]
        station_result[f"PBIAS_{season}_train"] = s_train_metrics["PBIAS"]
        station_result[f"PBIAS_{season}_val"] = s_val_metrics["PBIAS"]

    results[station_id] = station_result

print(f"\n✅ Simulation completed for {len(results)} valid catchments.")
# Out:
# Starting simulation for 671 stations...
#
#
# === Station 10002 ===, Number=1
# ✅ Training NSE: 0.660, Validation NSE: 0.607
#    Training KGE: 0.715, Validation KGE: 0.706
#    Training RMSE: 3.042 m³/s, Validation RMSE: 3.862 m³/s
#    Training PBIAS: -22.877, Validation PBIAS: -18.490
#    Params: mu=1.222, lambda=12.641
#
# === Station 10003 ===, Number=2
# ✅ Training NSE: 0.579, Validation NSE: 0.529
#    Training KGE: 0.705, Validation KGE: 0.749
#    Training RMSE: 4.610 m³/s, Validation RMSE: 5.284 m³/s
#    Training PBIAS: -19.577, Validation PBIAS: -5.795
#    Params: mu=1.055, lambda=22.714
#
# === Station 1001 ===, Number=3
# ⚠️ Too many missing values (23.4%)
#
# === Station 101002 ===, Number=4
# ✅ Training NSE: -1.740, Validation NSE: -1.664
#    Training KGE: -0.461, Validation KGE: -0.198
#    Training RMSE: 0.629 m³/s, Validation RMSE: 0.652 m³/s
#    Training PBIAS: 126.704, Validation PBIAS: 90.952
#    Params: mu=5.000, lambda=100.633
#
# === Station 101005 ===, Number=5
# ✅ Training NSE: -4.068, Validation NSE: -2.739
#    Training KGE: -1.444, Validation KGE: -1.063
#    Training RMSE: 0.670 m³/s, Validation RMSE: 0.692 m³/s
#    Training PBIAS: 230.430, Validation PBIAS: 190.204
#    Params: mu=5.000, lambda=106.432
#
# === Station 102001 ===, Number=6
# ✅ Training NSE: -0.346, Validation NSE: -0.293
#    Training KGE: -0.019, Validation KGE: 0.095
#    Training RMSE: 0.768 m³/s, Validation RMSE: 0.796 m³/s
#    Training PBIAS: 80.419, Validation PBIAS: 61.166
#    Params: mu=5.000, lambda=86.460
#
# === Station 106001 ===, Number=7
# ⚠️ Too many missing values (28.0%)
#
# === Station 107001 ===, Number=8
# ⚠️ Too many missing values (38.4%)
#
# === Station 11001 ===, Number=9
# ✅ Training NSE: 0.391, Validation NSE: 0.263
#    Training KGE: 0.508, Validation KGE: 0.505
#    Training RMSE: 15.490 m³/s, Validation RMSE: 17.949 m³/s
#    Training PBIAS: -44.898, Validation PBIAS: -42.208
#    Params: mu=1.047, lambda=8.436
#
# === Station 11003 ===, Number=10
# ✅ Training NSE: 0.382, Validation NSE: 0.185
#    Training KGE: 0.569, Validation KGE: 0.478
#    Training RMSE: 7.164 m³/s, Validation RMSE: 8.659 m³/s
#    Training PBIAS: -23.351, Validation PBIAS: -21.462
#    Params: mu=1.113, lambda=21.875
#
# === Station 11004 ===, Number=11
# ✅ Training NSE: 0.690, Validation NSE: 0.558
#    Training KGE: 0.759, Validation KGE: 0.672
#    Training RMSE: 1.503 m³/s, Validation RMSE: 1.984 m³/s
#    Training PBIAS: -0.370, Validation PBIAS: -0.121
#    Params: mu=1.289, lambda=42.841
#
# === Station 12001 ===, Number=12
# ✅ Training NSE: 0.151, Validation NSE: -0.119
#    Training KGE: 0.407, Validation KGE: 0.347
#    Training RMSE: 35.336 m³/s, Validation RMSE: 40.420 m³/s
#    Training PBIAS: -42.403, Validation PBIAS: -40.665
#    Params: mu=1.060, lambda=8.613
#
# === Station 12002 ===, Number=13
# ✅ Training NSE: 0.214, Validation NSE: -0.064
#    Training KGE: 0.407, Validation KGE: 0.407
#    Training RMSE: 43.912 m³/s, Validation RMSE: 50.298 m³/s
#    Training PBIAS: -48.223, Validation PBIAS: -41.668
#    Params: mu=1.055, lambda=5.751
#
# === Station 12005 ===, Number=14
# ✅ Training NSE: 0.420, Validation NSE: 0.360
#    Training KGE: 0.505, Validation KGE: 0.474
#    Training RMSE: 3.393 m³/s, Validation RMSE: 3.501 m³/s
#    Training PBIAS: -0.181, Validation PBIAS: -2.478
#    Params: mu=1.474, lambda=44.032
#
# === Station 12006 ===, Number=15
# ✅ Training NSE: 0.356, Validation NSE: 0.172
#    Training KGE: 0.473, Validation KGE: 0.339
#    Training RMSE: 3.157 m³/s, Validation RMSE: 3.536 m³/s
#    Training PBIAS: -9.510, Validation PBIAS: -8.452
#    Params: mu=1.387, lambda=34.179
#
# === Station 12007 ===, Number=16
# ✅ Training NSE: 0.191, Validation NSE: 0.077
#    Training KGE: 0.364, Validation KGE: 0.198
#    Training RMSE: 11.601 m³/s, Validation RMSE: 13.553 m³/s
#    Training PBIAS: -24.074, Validation PBIAS: -26.275
#    Params: mu=1.234, lambda=27.971
#
# === Station 12008 ===, Number=17
# ✅ Training NSE: 0.457, Validation NSE: 0.359
#    Training KGE: 0.548, Validation KGE: 0.502
#    Training RMSE: 6.580 m³/s, Validation RMSE: 8.163 m³/s
#    Training PBIAS: -15.351, Validation PBIAS: -14.946
#    Params: mu=1.297, lambda=18.680
#
# === Station 12009 ===, Number=18
# ✅ Training NSE: 0.040, Validation NSE: 0.000
#    Training KGE: 0.029, Validation KGE: 0.005
#    Training RMSE: 2.014 m³/s, Validation RMSE: 2.234 m³/s
#    Training PBIAS: -39.513, Validation PBIAS: -46.326
#    Params: mu=5.000, lambda=92.682
#
# === Station 13001 ===, Number=19
# ✅ Training NSE: 0.623, Validation NSE: 0.532
#    Training KGE: 0.674, Validation KGE: 0.683
#    Training RMSE: 1.658 m³/s, Validation RMSE: 1.982 m³/s
#    Training PBIAS: 8.310, Validation PBIAS: 10.418
#    Params: mu=1.441, lambda=24.764
#
# === Station 13004 ===, Number=20
# ✅ Training NSE: 0.505, Validation NSE: 0.440
#    Training KGE: 0.568, Validation KGE: 0.447
#    Training RMSE: 2.470 m³/s, Validation RMSE: 3.376 m³/s
#    Training PBIAS: 5.811, Validation PBIAS: -2.150
#    Params: mu=1.486, lambda=46.335
#
# === Station 13005 ===, Number=21
# ✅ Training NSE: 0.639, Validation NSE: 0.237
#    Training KGE: 0.611, Validation KGE: 0.576
#    Training RMSE: 1.370 m³/s, Validation RMSE: 2.279 m³/s
#    Training PBIAS: 21.715, Validation PBIAS: 23.027
#    Params: mu=1.434, lambda=26.353
#
# === Station 13007 ===, Number=22
# ✅ Training NSE: 0.394, Validation NSE: 0.326
#    Training KGE: 0.481, Validation KGE: 0.470
#    Training RMSE: 17.892 m³/s, Validation RMSE: 22.455 m³/s
#    Training PBIAS: -39.066, Validation PBIAS: -34.823
#    Params: mu=1.122, lambda=8.804
#
# === Station 13008 ===, Number=23
# ✅ Training NSE: 0.535, Validation NSE: 0.449
#    Training KGE: 0.642, Validation KGE: 0.641
#    Training RMSE: 8.924 m³/s, Validation RMSE: 11.347 m³/s
#    Training PBIAS: -27.021, Validation PBIAS: -24.021
#    Params: mu=1.160, lambda=12.875
#
# === Station 14001 ===, Number=24
# ✅ Training NSE: 0.664, Validation NSE: 0.601
#    Training KGE: 0.751, Validation KGE: 0.732
#    Training RMSE: 2.478 m³/s, Validation RMSE: 2.955 m³/s
#    Training PBIAS: -11.880, Validation PBIAS: -9.761
#    Params: mu=1.219, lambda=17.557
#
# === Station 14002 ===, Number=25
# ✅ Training NSE: 0.622, Validation NSE: 0.320
#    Training KGE: 0.612, Validation KGE: 0.575
#    Training RMSE: 1.126 m³/s, Validation RMSE: 1.829 m³/s
#    Training PBIAS: 17.838, Validation PBIAS: 15.214
#    Params: mu=1.506, lambda=35.042
#
# === Station 14005 ===, Number=26
# ✅ Training NSE: -0.154, Validation NSE: 0.024
#    Training KGE: 0.129, Validation KGE: 0.296
#    Training RMSE: 0.774 m³/s, Validation RMSE: 0.825 m³/s
#    Training PBIAS: 23.458, Validation PBIAS: -1.465
#    Params: mu=5.000, lambda=61.469
#
# === Station 15006 ===, Number=27
# ✅ Training NSE: 0.245, Validation NSE: -0.196
#    Training KGE: 0.464, Validation KGE: 0.374
#    Training RMSE: 135.936 m³/s, Validation RMSE: 164.826 m³/s
#    Training PBIAS: -49.857, Validation PBIAS: -46.696
#    Params: mu=1.009, lambda=5.925
#
# === Station 15007 ===, Number=28
# ✅ Training NSE: 0.612, Validation NSE: 0.430
#    Training KGE: 0.663, Validation KGE: 0.615
#    Training RMSE: 34.749 m³/s, Validation RMSE: 39.351 m³/s
#    Training PBIAS: -30.745, Validation PBIAS: -32.336
#    Params: mu=1.116, lambda=16.537
#
# === Station 15010 ===, Number=29
# ✅ Training NSE: 0.581, Validation NSE: 0.522
#    Training KGE: 0.696, Validation KGE: 0.684
#    Training RMSE: 5.519 m³/s, Validation RMSE: 7.326 m³/s
#    Training PBIAS: -13.393, Validation PBIAS: -10.211
#    Params: mu=1.213, lambda=18.342
#
# === Station 15011 ===, Number=30
# ✅ Training NSE: 0.432, Validation NSE: 0.326
#    Training KGE: 0.552, Validation KGE: 0.511
#    Training RMSE: 13.650 m³/s, Validation RMSE: 13.452 m³/s
#    Training PBIAS: -9.982, Validation PBIAS: -15.964
#    Params: mu=1.323, lambda=30.951
#
# === Station 15012 ===, Number=31
# ✅ Training NSE: 0.381, Validation NSE: 0.180
#    Training KGE: 0.549, Validation KGE: 0.503
#    Training RMSE: 51.820 m³/s, Validation RMSE: 58.880 m³/s
#    Training PBIAS: -40.730, Validation PBIAS: -40.780
#    Params: mu=1.068, lambda=12.695
#
# === Station 15013 ===, Number=32
# ✅ Training NSE: 0.494, Validation NSE: 0.445
#    Training KGE: 0.573, Validation KGE: 0.533
#    Training RMSE: 5.343 m³/s, Validation RMSE: 6.045 m³/s
#    Training PBIAS: 3.653, Validation PBIAS: -2.037
#    Params: mu=1.367, lambda=30.667
#
# === Station 15014 ===, Number=33
# ✅ Training NSE: 0.390, Validation NSE: 0.334
#    Training KGE: 0.467, Validation KGE: 0.450
#    Training RMSE: 3.194 m³/s, Validation RMSE: 3.557 m³/s
#    Training PBIAS: -0.209, Validation PBIAS: 5.488
#    Params: mu=1.498, lambda=36.292
#
# === Station 15016 ===, Number=34
# ✅ Training NSE: 0.726, Validation NSE: 0.597
#    Training KGE: 0.757, Validation KGE: 0.711
#    Training RMSE: 21.121 m³/s, Validation RMSE: 22.591 m³/s
#    Training PBIAS: -21.485, Validation PBIAS: -20.671
#    Params: mu=1.142, lambda=25.003
#
# === Station 15021 ===, Number=35
# ✅ Training NSE: 0.594, Validation NSE: 0.546
#    Training KGE: 0.513, Validation KGE: 0.502
#    Training RMSE: 1.014 m³/s, Validation RMSE: 1.098 m³/s
#    Training PBIAS: 28.435, Validation PBIAS: 32.719
#    Params: mu=1.609, lambda=64.133
#
# === Station 15023 ===, Number=36
# ✅ Training NSE: 0.594, Validation NSE: 0.512
#    Training KGE: 0.683, Validation KGE: 0.689
#    Training RMSE: 5.959 m³/s, Validation RMSE: 6.447 m³/s
#    Training PBIAS: -2.994, Validation PBIAS: -1.700
#    Params: mu=1.298, lambda=22.426
#
# === Station 15024 ===, Number=37
# ✅ Training NSE: 0.562, Validation NSE: 0.526
#    Training KGE: 0.654, Validation KGE: 0.639
#    Training RMSE: 14.232 m³/s, Validation RMSE: 14.064 m³/s
#    Training PBIAS: -4.270, Validation PBIAS: -3.317
#    Params: mu=1.335, lambda=33.724
#
# === Station 15025 ===, Number=38
# ✅ Training NSE: 0.405, Validation NSE: 0.330
#    Training KGE: 0.545, Validation KGE: 0.635
#    Training RMSE: 11.321 m³/s, Validation RMSE: 12.858 m³/s
#    Training PBIAS: -26.677, Validation PBIAS: -13.339
#    Params: mu=1.173, lambda=13.681
#
# === Station 15030 ===, Number=39
# ✅ Training NSE: 0.721, Validation NSE: 0.638
#    Training KGE: 0.784, Validation KGE: 0.799
#    Training RMSE: 2.212 m³/s, Validation RMSE: 2.750 m³/s
#    Training PBIAS: -2.944, Validation PBIAS: 9.840
#    Params: mu=1.223, lambda=19.163
#
# === Station 15039 ===, Number=40
# ✅ Training NSE: 0.246, Validation NSE: 0.157
#    Training KGE: 0.360, Validation KGE: 0.268
#    Training RMSE: 7.413 m³/s, Validation RMSE: 8.368 m³/s
#    Training PBIAS: -17.467, Validation PBIAS: -16.949
#    Params: mu=1.353, lambda=30.734
#
# === Station 16001 ===, Number=41
# ✅ Training NSE: 0.627, Validation NSE: 0.479
#    Training KGE: 0.704, Validation KGE: 0.655
#    Training RMSE: 14.727 m³/s, Validation RMSE: 17.588 m³/s
#    Training PBIAS: -24.483, Validation PBIAS: -25.576
#    Params: mu=1.156, lambda=17.430
#
# === Station 16003 ===, Number=42
# ✅ Training NSE: 0.330, Validation NSE: 0.309
#    Training KGE: 0.366, Validation KGE: 0.321
#    Training RMSE: 6.608 m³/s, Validation RMSE: 7.033 m³/s
#    Training PBIAS: 8.594, Validation PBIAS: 2.644
#    Params: mu=1.498, lambda=59.837
#
# === Station 16004 ===, Number=43
# ✅ Training NSE: 0.640, Validation NSE: 0.504
#    Training KGE: 0.665, Validation KGE: 0.642
#    Training RMSE: 19.031 m³/s, Validation RMSE: 21.921 m³/s
#    Training PBIAS: -30.385, Validation PBIAS: -29.549
#    Params: mu=1.128, lambda=11.726
#
# === Station 17001 ===, Number=44
# ✅ Training NSE: 0.484, Validation NSE: 0.436
#    Training KGE: 0.467, Validation KGE: 0.444
#    Training RMSE: 4.550 m³/s, Validation RMSE: 4.458 m³/s
#    Training PBIAS: 26.962, Validation PBIAS: 28.775
#    Params: mu=1.479, lambda=38.117
#
# === Station 17003 ===, Number=45
# ✅ Training NSE: 0.369, Validation NSE: 0.212
#    Training KGE: 0.351, Validation KGE: 0.299
#    Training RMSE: 1.345 m³/s, Validation RMSE: 1.215 m³/s
#    Training PBIAS: 29.560, Validation PBIAS: 49.480
#    Params: mu=2.002, lambda=73.775
#
# === Station 17004 ===, Number=46
# ✅ Training NSE: 0.730, Validation NSE: 0.659
#    Training KGE: 0.738, Validation KGE: 0.677
#    Training RMSE: 1.273 m³/s, Validation RMSE: 1.574 m³/s
#    Training PBIAS: 10.960, Validation PBIAS: 20.427
#    Params: mu=1.429, lambda=27.496
#
# === Station 17005 ===, Number=47
# ✅ Training NSE: 0.590, Validation NSE: 0.580
#    Training KGE: 0.679, Validation KGE: 0.641
#    Training RMSE: 3.997 m³/s, Validation RMSE: 4.301 m³/s
#    Training PBIAS: -8.309, Validation PBIAS: -6.918
#    Params: mu=1.321, lambda=15.907
#
# === Station 17015 ===, Number=48
# ✅ Training NSE: 0.033, Validation NSE: -0.016
#    Training KGE: 0.197, Validation KGE: 0.119
#    Training RMSE: 1.098 m³/s, Validation RMSE: 1.231 m³/s
#    Training PBIAS: -3.630, Validation PBIAS: -10.486
#    Params: mu=5.000, lambda=107.110
#
# === Station 17018 ===, Number=49
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 ===, Number=50
# ✅ Training NSE: 0.590, Validation NSE: 0.480
#    Training KGE: 0.671, Validation KGE: 0.562
#    Training RMSE: 4.600 m³/s, Validation RMSE: 5.639 m³/s
#    Training PBIAS: -0.329, Validation PBIAS: -2.927
#    Params: mu=1.377, lambda=29.290
#
# === Station 18002 ===, Number=51
# ✅ Training NSE: 0.690, Validation NSE: 0.598
#    Training KGE: 0.731, Validation KGE: 0.553
#    Training RMSE: 3.528 m³/s, Validation RMSE: 4.862 m³/s
#    Training PBIAS: 8.225, Validation PBIAS: -3.703
#    Params: mu=1.370, lambda=26.654
#
# === Station 18003 ===, Number=52
# ✅ Training NSE: 0.781, Validation NSE: 0.624
#    Training KGE: 0.838, Validation KGE: 0.766
#    Training RMSE: 14.819 m³/s, Validation RMSE: 18.131 m³/s
#    Training PBIAS: -10.343, Validation PBIAS: -15.445
#    Params: mu=1.193, lambda=19.133
#
# === Station 18008 ===, Number=53
# ✅ Training NSE: 0.739, Validation NSE: 0.678
#    Training KGE: 0.790, Validation KGE: 0.777
#    Training RMSE: 7.668 m³/s, Validation RMSE: 8.133 m³/s
#    Training PBIAS: 1.675, Validation PBIAS: -0.277
#    Params: mu=1.318, lambda=36.925
#
# === Station 18010 ===, Number=54
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 ===, Number=55
# ✅ Training NSE: 0.689, Validation NSE: 0.541
#    Training KGE: 0.711, Validation KGE: 0.667
#    Training RMSE: 32.054 m³/s, Validation RMSE: 34.809 m³/s
#    Training PBIAS: -24.363, Validation PBIAS: -27.066
#    Params: mu=1.131, lambda=10.272
#
# === Station 18014 ===, Number=56
# ✅ Training NSE: 0.054, Validation NSE: -0.048
#    Training KGE: 0.224, Validation KGE: 0.122
#    Training RMSE: 1.116 m³/s, Validation RMSE: 1.271 m³/s
#    Training PBIAS: -9.057, Validation PBIAS: -27.846
#    Params: mu=5.000, lambda=125.829
#
# === Station 18017 ===, Number=57
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 ===, Number=58
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 ===, Number=59
# ✅ Training NSE: 0.554, Validation NSE: 0.590
#    Training KGE: 0.630, Validation KGE: 0.666
#    Training RMSE: 6.641 m³/s, Validation RMSE: 6.523 m³/s
#    Training PBIAS: -20.483, Validation PBIAS: -17.378
#    Params: mu=1.218, lambda=9.408
#
# === Station 19006 ===, Number=60
# ✅ Training NSE: 0.465, Validation NSE: 0.536
#    Training KGE: 0.497, Validation KGE: 0.603
#    Training RMSE: 1.550 m³/s, Validation RMSE: 1.283 m³/s
#    Training PBIAS: 15.749, Validation PBIAS: 16.398
#    Params: mu=1.613, lambda=35.094
#
# === Station 19010 ===, Number=61
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 ===, Number=62
# ✅ Training NSE: 0.071, Validation NSE: 0.055
#    Training KGE: 0.294, Validation KGE: 0.351
#    Training RMSE: 0.830 m³/s, Validation RMSE: 0.926 m³/s
#    Training PBIAS: 32.860, Validation PBIAS: 14.300
#    Params: mu=5.000, lambda=52.091
#
# === Station 19020 ===, Number=63
# ✅ Training NSE: 0.154, Validation NSE: 0.140
#    Training KGE: 0.225, Validation KGE: 0.164
#    Training RMSE: 1.254 m³/s, Validation RMSE: 1.417 m³/s
#    Training PBIAS: -8.932, Validation PBIAS: -22.100
#    Params: mu=5.000, lambda=78.879
#
# === Station 20002 ===, Number=64
# ✅ Training NSE: -5.308, Validation NSE: -2.072
#    Training KGE: -2.782, Validation KGE: -0.823
#    Training RMSE: 0.663 m³/s, Validation RMSE: 0.655 m³/s
#    Training PBIAS: 368.065, Validation PBIAS: 166.666
#    Params: mu=5.000, lambda=63.738
#
# === Station 20003 ===, Number=65
# ✅ Training NSE: 0.439, Validation NSE: 0.453
#    Training KGE: 0.458, Validation KGE: 0.465
#    Training RMSE: 1.733 m³/s, Validation RMSE: 2.050 m³/s
#    Training PBIAS: 22.462, Validation PBIAS: 4.345
#    Params: mu=1.463, lambda=24.689
#
# === Station 20007 ===, Number=66
# ✅ Training NSE: 0.204, Validation NSE: 0.217
#    Training KGE: 0.245, Validation KGE: 0.399
#    Training RMSE: 1.116 m³/s, Validation RMSE: 1.061 m³/s
#    Training PBIAS: 34.239, Validation PBIAS: 7.757
#    Params: mu=2.313, lambda=43.911
#
# === Station 2001 ===, Number=67
# ✅ Training NSE: 0.403, Validation NSE: 0.357
#    Training KGE: 0.548, Validation KGE: 0.409
#    Training RMSE: 11.888 m³/s, Validation RMSE: 12.294 m³/s
#    Training PBIAS: -27.493, Validation PBIAS: -37.304
#    Params: mu=1.189, lambda=11.146
#
# === Station 2002 ===, Number=68
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 ===, Number=69
# ✅ Training NSE: 0.654, Validation NSE: 0.534
#    Training KGE: 0.711, Validation KGE: 0.716
#    Training RMSE: 10.595 m³/s, Validation RMSE: 13.016 m³/s
#    Training PBIAS: -23.918, Validation PBIAS: -19.253
#    Params: mu=1.142, lambda=11.541
#
# === Station 21006 ===, Number=70
# ✅ Training NSE: 0.542, Validation NSE: 0.398
#    Training KGE: 0.582, Validation KGE: 0.599
#    Training RMSE: 29.420 m³/s, Validation RMSE: 34.861 m³/s
#    Training PBIAS: -37.430, Validation PBIAS: -31.385
#    Params: mu=1.078, lambda=5.932
#
# === Station 21008 ===, Number=71
# ✅ Training NSE: 0.531, Validation NSE: 0.484
#    Training KGE: 0.576, Validation KGE: 0.536
#    Training RMSE: 18.680 m³/s, Validation RMSE: 23.466 m³/s
#    Training PBIAS: -33.569, Validation PBIAS: -32.789
#    Params: mu=1.081, lambda=5.920
#
# === Station 21009 ===, Number=72
# ✅ Training NSE: 0.428, Validation NSE: 0.394
#    Training KGE: 0.469, Validation KGE: 0.499
#    Training RMSE: 68.736 m³/s, Validation RMSE: 76.309 m³/s
#    Training PBIAS: -48.785, Validation PBIAS: -44.898
#    Params: mu=0.992, lambda=2.717
#
# === Station 21011 ===, Number=73
# ✅ Training NSE: 0.722, Validation NSE: 0.609
#    Training KGE: 0.790, Validation KGE: 0.759
#    Training RMSE: 3.900 m³/s, Validation RMSE: 4.687 m³/s
#    Training PBIAS: -1.224, Validation PBIAS: 12.634
#    Params: mu=1.323, lambda=25.469
#
# === Station 21012 ===, Number=74
# ✅ Training NSE: 0.572, Validation NSE: 0.467
#    Training KGE: 0.665, Validation KGE: 0.617
#    Training RMSE: 8.360 m³/s, Validation RMSE: 9.847 m³/s
#    Training PBIAS: -12.345, Validation PBIAS: -9.264
#    Params: mu=1.225, lambda=15.437
#
# === Station 21013 ===, Number=75
# ✅ Training NSE: 0.670, Validation NSE: 0.583
#    Training KGE: 0.730, Validation KGE: 0.694
#    Training RMSE: 2.727 m³/s, Validation RMSE: 3.132 m³/s
#    Training PBIAS: 1.288, Validation PBIAS: 6.830
#    Params: mu=1.279, lambda=19.075
#
# === Station 21015 ===, Number=76
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 ===, Number=77
# ✅ Training NSE: 0.464, Validation NSE: 0.527
#    Training KGE: 0.424, Validation KGE: 0.502
#    Training RMSE: 1.449 m³/s, Validation RMSE: 1.569 m³/s
#    Training PBIAS: 33.927, Validation PBIAS: 26.493
#    Params: mu=1.524, lambda=27.239
#
# === Station 21017 ===, Number=78
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 ===, Number=79
# ✅ Training NSE: 0.706, Validation NSE: 0.600
#    Training KGE: 0.764, Validation KGE: 0.697
#    Training RMSE: 2.010 m³/s, Validation RMSE: 2.448 m³/s
#    Training PBIAS: 3.069, Validation PBIAS: 7.316
#    Params: mu=1.371, lambda=23.028
#
# === Station 21022 ===, Number=80
# ✅ Training NSE: 0.547, Validation NSE: 0.403
#    Training KGE: 0.609, Validation KGE: 0.514
#    Training RMSE: 6.450 m³/s, Validation RMSE: 9.695 m³/s
#    Training PBIAS: -23.884, Validation PBIAS: -22.712
#    Params: mu=1.158, lambda=9.427
#
# === Station 21023 ===, Number=81
# ✅ Training NSE: 0.298, Validation NSE: 0.375
#    Training KGE: 0.076, Validation KGE: 0.319
#    Training RMSE: 2.189 m³/s, Validation RMSE: 2.559 m³/s
#    Training PBIAS: 68.452, Validation PBIAS: 33.361
#    Params: mu=1.428, lambda=24.437
#
# === Station 21024 ===, Number=82
# ✅ Training NSE: 0.494, Validation NSE: 0.434
#    Training KGE: 0.546, Validation KGE: 0.512
#    Training RMSE: 2.626 m³/s, Validation RMSE: 3.067 m³/s
#    Training PBIAS: 10.634, Validation PBIAS: 8.594
#    Params: mu=1.418, lambda=23.135
#
# === Station 21026 ===, Number=83
# ✅ Training NSE: 0.206, Validation NSE: 0.147
#    Training KGE: 0.182, Validation KGE: 0.135
#    Training RMSE: 2.166 m³/s, Validation RMSE: 2.887 m³/s
#    Training PBIAS: 25.975, Validation PBIAS: 8.730
#    Params: mu=2.207, lambda=99.424
#
# === Station 21027 ===, Number=84
# ✅ Training NSE: 0.494, Validation NSE: 0.425
#    Training KGE: 0.508, Validation KGE: 0.510
#    Training RMSE: 2.154 m³/s, Validation RMSE: 2.810 m³/s
#    Training PBIAS: 23.837, Validation PBIAS: 17.381
#    Params: mu=1.373, lambda=20.785
#
# === Station 22001 ===, Number=85
# ✅ Training NSE: 0.590, Validation NSE: 0.497
#    Training KGE: 0.604, Validation KGE: 0.630
#    Training RMSE: 8.252 m³/s, Validation RMSE: 11.376 m³/s
#    Training PBIAS: -29.364, Validation PBIAS: -20.016
#    Params: mu=1.158, lambda=6.722
#
# === Station 22006 ===, Number=86
# ✅ Training NSE: 0.586, Validation NSE: 0.529
#    Training KGE: 0.617, Validation KGE: 0.584
#    Training RMSE: 2.662 m³/s, Validation RMSE: 3.629 m³/s
#    Training PBIAS: 15.857, Validation PBIAS: 10.008
#    Params: mu=1.283, lambda=12.151
#
# === Station 22007 ===, Number=87
# ✅ Training NSE: 0.525, Validation NSE: 0.455
#    Training KGE: 0.601, Validation KGE: 0.531
#    Training RMSE: 4.171 m³/s, Validation RMSE: 5.603 m³/s
#    Training PBIAS: -1.768, Validation PBIAS: -2.379
#    Params: mu=1.258, lambda=10.945
#
# === Station 22009 ===, Number=88
# ✅ Training NSE: 0.578, Validation NSE: 0.469
#    Training KGE: 0.655, Validation KGE: 0.633
#    Training RMSE: 5.486 m³/s, Validation RMSE: 7.586 m³/s
#    Training PBIAS: -18.425, Validation PBIAS: -10.989
#    Params: mu=1.222, lambda=10.155
#
# === Station 23001 ===, Number=89
# ✅ Training NSE: 0.425, Validation NSE: 0.199
#    Training KGE: 0.447, Validation KGE: 0.507
#    Training RMSE: 43.682 m³/s, Validation RMSE: 52.950 m³/s
#    Training PBIAS: -47.012, Validation PBIAS: -36.174
#    Params: mu=1.056, lambda=3.288
#
# === Station 23004 ===, Number=90
# ✅ Training NSE: 0.371, Validation NSE: 0.325
#    Training KGE: 0.436, Validation KGE: 0.445
#    Training RMSE: 21.947 m³/s, Validation RMSE: 22.443 m³/s
#    Training PBIAS: -34.795, Validation PBIAS: -31.168
#    Params: mu=1.149, lambda=7.399
#
# === Station 23006 ===, Number=91
# ✅ Training NSE: 0.348, Validation NSE: 0.321
#    Training KGE: 0.449, Validation KGE: 0.387
#    Training RMSE: 11.973 m³/s, Validation RMSE: 13.105 m³/s
#    Training PBIAS: -23.219, Validation PBIAS: -25.136
#    Params: mu=1.257, lambda=15.867
#
# === Station 23007 ===, Number=92
# ✅ Training NSE: 0.466, Validation NSE: 0.447
#    Training KGE: 0.543, Validation KGE: 0.473
#    Training RMSE: 2.400 m³/s, Validation RMSE: 3.323 m³/s
#    Training PBIAS: 7.069, Validation PBIAS: -4.729
#    Params: mu=1.394, lambda=23.977
#
# === Station 23008 ===, Number=93
# ✅ Training NSE: 0.559, Validation NSE: 0.433
#    Training KGE: 0.637, Validation KGE: 0.591
#    Training RMSE: 6.297 m³/s, Validation RMSE: 8.720 m³/s
#    Training PBIAS: -12.069, Validation PBIAS: -9.495
#    Params: mu=1.234, lambda=9.898
#
# === Station 23011 ===, Number=94
# ✅ Training NSE: -0.007, Validation NSE: -0.002
#    Training KGE: 0.075, Validation KGE: 0.091
#    Training RMSE: 2.856 m³/s, Validation RMSE: 3.112 m³/s
#    Training PBIAS: -48.479, Validation PBIAS: -51.651
#    Params: mu=3.539, lambda=48.197
#
# === Station 23016 ===, Number=95
# ✅ Training NSE: -0.290, Validation NSE: 0.039
#    Training KGE: -0.234, Validation KGE: 0.162
#    Training RMSE: 0.719 m³/s, Validation RMSE: 0.830 m³/s
#    Training PBIAS: 106.888, Validation PBIAS: 64.108
#    Params: mu=5.000, lambda=47.506
#
# === Station 24001 ===, Number=96
# ✅ Training NSE: 0.565, Validation NSE: 0.423
#    Training KGE: 0.590, Validation KGE: 0.606
#    Training RMSE: 10.941 m³/s, Validation RMSE: 14.476 m³/s
#    Training PBIAS: -30.607, Validation PBIAS: -21.656
#    Params: mu=1.151, lambda=6.956
#
# === Station 24003 ===, Number=97
# ✅ Training NSE: 0.429, Validation NSE: 0.351
#    Training KGE: 0.493, Validation KGE: 0.428
#    Training RMSE: 5.187 m³/s, Validation RMSE: 5.769 m³/s
#    Training PBIAS: 6.592, Validation PBIAS: 5.825
#    Params: mu=1.409, lambda=27.794
#
# === Station 24004 ===, Number=98
# ✅ Training NSE: 0.447, Validation NSE: 0.330
#    Training KGE: 0.379, Validation KGE: 0.302
#    Training RMSE: 1.317 m³/s, Validation RMSE: 1.657 m³/s
#    Training PBIAS: 38.055, Validation PBIAS: 38.451
#    Params: mu=1.727, lambda=48.301
#
# === Station 24005 ===, Number=99
# ✅ Training NSE: 0.509, Validation NSE: 0.374
#    Training KGE: 0.520, Validation KGE: 0.410
#    Training RMSE: 1.826 m³/s, Validation RMSE: 2.586 m³/s
#    Training PBIAS: 22.817, Validation PBIAS: 34.218
#    Params: mu=1.427, lambda=20.614
#
# === Station 25001 ===, Number=100
# ✅ Training NSE: 0.456, Validation NSE: 0.398
#    Training KGE: 0.498, Validation KGE: 0.464
#    Training RMSE: 19.676 m³/s, Validation RMSE: 21.253 m³/s
#    Training PBIAS: -36.926, Validation PBIAS: -38.879
#    Params: mu=1.143, lambda=7.184
#
# === Station 25003 ===, Number=101
# ✅ Training NSE: -0.301, Validation NSE: -0.258
#    Training KGE: 0.074, Validation KGE: 0.107
#    Training RMSE: 0.998 m³/s, Validation RMSE: 1.038 m³/s
#    Training PBIAS: 50.650, Validation PBIAS: 35.287
#    Params: mu=5.000, lambda=200.000
#
# === Station 25006 ===, Number=102
# ✅ Training NSE: 0.392, Validation NSE: 0.370
#    Training KGE: 0.425, Validation KGE: 0.400
#    Training RMSE: 3.281 m³/s, Validation RMSE: 3.394 m³/s
#    Training PBIAS: 15.562, Validation PBIAS: 15.810
#    Params: mu=1.518, lambda=31.551
#
# === Station 25012 ===, Number=103
# ✅ Training NSE: 0.054, Validation NSE: -0.012
#    Training KGE: 0.107, Validation KGE: 0.057
#    Training RMSE: 1.532 m³/s, Validation RMSE: 1.498 m³/s
#    Training PBIAS: -19.926, Validation PBIAS: -22.036
#    Params: mu=5.000, lambda=147.485
#
# === Station 25020 ===, Number=104
# ✅ Training NSE: 0.441, Validation NSE: 0.398
#    Training KGE: 0.333, Validation KGE: 0.423
#    Training RMSE: 1.138 m³/s, Validation RMSE: 1.282 m³/s
#    Training PBIAS: 48.182, Validation PBIAS: 38.091
#    Params: mu=1.645, lambda=25.724
#
# === Station 25021 ===, Number=105
# ✅ Training NSE: -0.105, Validation NSE: 0.069
#    Training KGE: 0.108, Validation KGE: 0.308
#    Training RMSE: 0.702 m³/s, Validation RMSE: 0.838 m³/s
#    Training PBIAS: 60.874, Validation PBIAS: 21.763
#    Params: mu=5.000, lambda=51.568
#
# === Station 25029 ===, Number=106
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 ===, Number=107
# ✅ Training NSE: -0.414, Validation NSE: -0.431
#    Training KGE: -0.098, Validation KGE: -0.230
#    Training RMSE: 0.545 m³/s, Validation RMSE: 0.635 m³/s
#    Training PBIAS: 33.606, Validation PBIAS: 6.543
#    Params: mu=5.000, lambda=138.552
#
# === Station 26005 ===, Number=108
# ✅ Training NSE: -2.430, Validation NSE: -0.902
#    Training KGE: -1.691, Validation KGE: -0.545
#    Training RMSE: 0.745 m³/s, Validation RMSE: 0.810 m³/s
#    Training PBIAS: 249.315, Validation PBIAS: 100.598
#    Params: mu=5.000, lambda=95.384
#
# === Station 26006 ===, Number=109
# ✅ Training NSE: -0.233, Validation NSE: -0.175
#    Training KGE: -0.245, Validation KGE: -0.334
#    Training RMSE: 0.718 m³/s, Validation RMSE: 0.891 m³/s
#    Training PBIAS: 59.190, Validation PBIAS: 27.539
#    Params: mu=5.000, lambda=188.486
#
# === Station 26008 ===, Number=110
# ✅ Training NSE: -11.394, Validation NSE: -6.612
#    Training KGE: -1.632, Validation KGE: -0.838
#    Training RMSE: 0.635 m³/s, Validation RMSE: 0.581 m³/s
#    Training PBIAS: 221.315, Validation PBIAS: 131.819
#    Params: mu=5.000, lambda=82.393
#
# === Station 26009 ===, Number=111
# ✅ Training NSE: 0.549, Validation NSE: 0.506
#    Training KGE: 0.547, Validation KGE: 0.584
#    Training RMSE: 1.170 m³/s, Validation RMSE: 1.234 m³/s
#    Training PBIAS: 13.738, Validation PBIAS: 19.294
#    Params: mu=1.200, lambda=97.152
#
# === Station 27001 ===, Number=112
# ✅ Training NSE: 0.721, Validation NSE: 0.641
#    Training KGE: 0.756, Validation KGE: 0.704
#    Training RMSE: 5.751 m³/s, Validation RMSE: 7.857 m³/s
#    Training PBIAS: -17.640, Validation PBIAS: -15.627
#    Params: mu=1.181, lambda=9.549
#
# === Station 27002 ===, Number=113
# ✅ Training NSE: 0.676, Validation NSE: 0.524
#    Training KGE: 0.673, Validation KGE: 0.514
#    Training RMSE: 12.892 m³/s, Validation RMSE: 18.166 m³/s
#    Training PBIAS: -28.186, Validation PBIAS: -41.485
#    Params: mu=1.149, lambda=7.404
#
# === Station 27003 ===, Number=114
# ✅ Training NSE: 0.584, Validation NSE: 0.501
#    Training KGE: 0.542, Validation KGE: 0.544
#    Training RMSE: 24.781 m³/s, Validation RMSE: 28.273 m³/s
#    Training PBIAS: -44.172, Validation PBIAS: -42.359
#    Params: mu=1.042, lambda=4.159
#
# === Station 27006 ===, Number=115
# ✅ Training NSE: 0.625, Validation NSE: 0.584
#    Training KGE: 0.716, Validation KGE: 0.653
#    Training RMSE: 4.132 m³/s, Validation RMSE: 4.223 m³/s
#    Training PBIAS: -5.789, Validation PBIAS: -7.447
#    Params: mu=1.266, lambda=16.569
#
# === Station 27007 ===, Number=116
# ✅ Training NSE: 0.662, Validation NSE: 0.607
#    Training KGE: 0.617, Validation KGE: 0.639
#    Training RMSE: 18.238 m³/s, Validation RMSE: 19.923 m³/s
#    Training PBIAS: -34.922, Validation PBIAS: -31.613
#    Params: mu=1.122, lambda=6.134
#
# === Station 27009 ===, Number=117
# ✅ Training NSE: 0.566, Validation NSE: 0.204
#    Training KGE: 0.540, Validation KGE: 0.491
#    Training RMSE: 40.363 m³/s, Validation RMSE: 55.219 m³/s
#    Training PBIAS: -43.260, Validation PBIAS: -33.403
#    Params: mu=0.995, lambda=3.343
#
# === Station 27021 ===, Number=118
# ✅ Training NSE: 0.606, Validation NSE: 0.518
#    Training KGE: 0.564, Validation KGE: 0.531
#    Training RMSE: 11.845 m³/s, Validation RMSE: 12.478 m³/s
#    Training PBIAS: -41.185, Validation PBIAS: -42.446
#    Params: mu=1.067, lambda=5.356
#
# === Station 27023 ===, Number=119
# ✅ Training NSE: 0.466, Validation NSE: 0.481
#    Training KGE: 0.492, Validation KGE: 0.568
#    Training RMSE: 1.800 m³/s, Validation RMSE: 1.463 m³/s
#    Training PBIAS: 24.739, Validation PBIAS: 21.434
#    Params: mu=1.546, lambda=21.991
#
# === Station 27025 ===, Number=120
# ✅ Training NSE: 0.641, Validation NSE: 0.536
#    Training KGE: 0.710, Validation KGE: 0.628
#    Training RMSE: 3.017 m³/s, Validation RMSE: 3.232 m³/s
#    Training PBIAS: -17.718, Validation PBIAS: -24.884
#    Params: mu=1.227, lambda=11.459
#
# === Station 27026 ===, Number=121
# ✅ Training NSE: 0.549, Validation NSE: 0.509
#    Training KGE: 0.598, Validation KGE: 0.570
#    Training RMSE: 1.981 m³/s, Validation RMSE: 1.917 m³/s
#    Training PBIAS: 13.291, Validation PBIAS: 19.993
#    Params: mu=1.400, lambda=21.196
#
# === Station 27029 ===, Number=122
# ✅ Training NSE: 0.647, Validation NSE: 0.622
#    Training KGE: 0.732, Validation KGE: 0.654
#    Training RMSE: 5.935 m³/s, Validation RMSE: 6.308 m³/s
#    Training PBIAS: -14.173, Validation PBIAS: -15.459
#    Params: mu=1.245, lambda=16.849
#
# === Station 27030 ===, Number=123
# ✅ Training NSE: 0.697, Validation NSE: 0.609
#    Training KGE: 0.764, Validation KGE: 0.641
#    Training RMSE: 2.243 m³/s, Validation RMSE: 2.660 m³/s
#    Training PBIAS: -14.087, Validation PBIAS: -18.988
#    Params: mu=1.229, lambda=13.739
#
# === Station 27032 ===, Number=124
# ✅ Training NSE: -10.418, Validation NSE: -8.254
#    Training KGE: -2.870, Validation KGE: -2.269
#    Training RMSE: 0.822 m³/s, Validation RMSE: 0.789 m³/s
#    Training PBIAS: 367.300, Validation PBIAS: 306.350
#    Params: mu=5.000, lambda=200.000
#
# === Station 27034 ===, Number=125
# ✅ Training NSE: 0.556, Validation NSE: 0.500
#    Training KGE: 0.599, Validation KGE: 0.563
#    Training RMSE: 16.369 m³/s, Validation RMSE: 17.621 m³/s
#    Training PBIAS: -27.817, Validation PBIAS: -28.053
#    Params: mu=1.190, lambda=11.200
#
# === Station 27035 ===, Number=126
# ✅ Training NSE: 0.747, Validation NSE: 0.709
#    Training KGE: 0.810, Validation KGE: 0.714
#    Training RMSE: 4.906 m³/s, Validation RMSE: 5.503 m³/s
#    Training PBIAS: -5.333, Validation PBIAS: -10.262
#    Params: mu=1.235, lambda=14.659
#
# === Station 27038 ===, Number=127
# ✅ Training NSE: -1.994, Validation NSE: -0.715
#    Training KGE: 0.006, Validation KGE: -0.189
#    Training RMSE: 0.400 m³/s, Validation RMSE: 0.514 m³/s
#    Training PBIAS: 50.075, Validation PBIAS: 26.705
#    Params: mu=5.000, lambda=170.562
#
# === Station 27041 ===, Number=128
# ✅ Training NSE: 0.455, Validation NSE: 0.342
#    Training KGE: 0.617, Validation KGE: 0.639
#    Training RMSE: 10.321 m³/s, Validation RMSE: 12.212 m³/s
#    Training PBIAS: -31.349, Validation PBIAS: -17.459
#    Params: mu=0.956, lambda=14.057
#
# === Station 27042 ===, Number=129
# ✅ Training NSE: 0.446, Validation NSE: 0.410
#    Training KGE: 0.434, Validation KGE: 0.454
#    Training RMSE: 0.784 m³/s, Validation RMSE: 0.850 m³/s
#    Training PBIAS: 30.192, Validation PBIAS: 25.173
#    Params: mu=2.054, lambda=63.474
#
# === Station 27043 ===, Number=130
# ✅ Training NSE: 0.527, Validation NSE: 0.513
#    Training KGE: 0.608, Validation KGE: 0.533
#    Training RMSE: 13.303 m³/s, Validation RMSE: 14.227 m³/s
#    Training PBIAS: -21.938, Validation PBIAS: -26.256
#    Params: mu=1.218, lambda=13.214
#
# === Station 27047 ===, Number=131
# ✅ Training NSE: -0.225, Validation NSE: -0.134
#    Training KGE: 0.073, Validation KGE: 0.200
#    Training RMSE: 1.051 m³/s, Validation RMSE: 0.998 m³/s
#    Training PBIAS: 49.609, Validation PBIAS: 35.884
#    Params: mu=5.000, lambda=200.000
#
# === Station 27049 ===, Number=132
# ✅ Training NSE: 0.683, Validation NSE: 0.651
#    Training KGE: 0.765, Validation KGE: 0.781
#    Training RMSE: 2.010 m³/s, Validation RMSE: 2.329 m³/s
#    Training PBIAS: -3.826, Validation PBIAS: -0.993
#    Params: mu=1.250, lambda=23.179
#
# === Station 27051 ===, Number=133
# ✅ Training NSE: -12.962, Validation NSE: -10.743
#    Training KGE: -4.906, Validation KGE: -4.266
#    Training RMSE: 0.727 m³/s, Validation RMSE: 0.736 m³/s
#    Training PBIAS: 573.447, Validation PBIAS: 509.532
#    Params: mu=5.000, lambda=87.541
#
# === Station 27062 ===, Number=134
# ✅ Training NSE: 0.779, Validation NSE: 0.764
#    Training KGE: 0.778, Validation KGE: 0.835
#    Training RMSE: 5.009 m³/s, Validation RMSE: 5.362 m³/s
#    Training PBIAS: -18.790, Validation PBIAS: -11.963
#    Params: mu=1.157, lambda=9.975
#
# === Station 27064 ===, Number=135
# ✅ Training NSE: 0.080, Validation NSE: 0.123
#    Training KGE: 0.118, Validation KGE: 0.158
#    Training RMSE: 0.752 m³/s, Validation RMSE: 0.854 m³/s
#    Training PBIAS: 60.644, Validation PBIAS: 38.665
#    Params: mu=2.615, lambda=39.344
#
# === Station 27065 ===, Number=136
# ✅ Training NSE: 0.560, Validation NSE: 0.548
#    Training KGE: 0.514, Validation KGE: 0.487
#    Training RMSE: 1.800 m³/s, Validation RMSE: 1.814 m³/s
#    Training PBIAS: 27.453, Validation PBIAS: 30.209
#    Params: mu=1.597, lambda=50.739
#
# === Station 27071 ===, Number=137
# ✅ Training NSE: 0.620, Validation NSE: 0.433
#    Training KGE: 0.598, Validation KGE: 0.592
#    Training RMSE: 14.955 m³/s, Validation RMSE: 21.233 m³/s
#    Training PBIAS: -37.361, Validation PBIAS: -32.363
#    Params: mu=1.044, lambda=5.000
#
# === Station 27073 ===, Number=138
# ✅ Training NSE: -9.335, Validation NSE: -6.055
#    Training KGE: -1.236, Validation KGE: -0.828
#    Training RMSE: 0.622 m³/s, Validation RMSE: 0.607 m³/s
#    Training PBIAS: 178.953, Validation PBIAS: 125.157
#    Params: mu=5.000, lambda=88.711
#
# === Station 27077 ===, Number=139
# ✅ Training NSE: -0.089, Validation NSE: -0.194
#    Training KGE: 0.160, Validation KGE: 0.179
#    Training RMSE: 0.778 m³/s, Validation RMSE: 0.726 m³/s
#    Training PBIAS: 20.960, Validation PBIAS: 19.129
#    Params: mu=5.000, lambda=91.942
#
# === Station 27079 ===, Number=140
# ✅ Training NSE: 0.563, Validation NSE: 0.589
#    Training KGE: 0.571, Validation KGE: 0.619
#    Training RMSE: 14.077 m³/s, Validation RMSE: 13.824 m³/s
#    Training PBIAS: -40.351, Validation PBIAS: -34.957
#    Params: mu=1.100, lambda=6.198
#
# === Station 27080 ===, Number=141
# ✅ Training NSE: 0.560, Validation NSE: 0.486
#    Training KGE: 0.568, Validation KGE: 0.570
#    Training RMSE: 12.450 m³/s, Validation RMSE: 13.520 m³/s
#    Training PBIAS: -40.814, Validation PBIAS: -39.293
#    Params: mu=1.103, lambda=6.715
#
# === Station 27084 ===, Number=142
# ✅ Training NSE: 0.080, Validation NSE: 0.055
#    Training KGE: 0.166, Validation KGE: 0.134
#    Training RMSE: 1.387 m³/s, Validation RMSE: 1.362 m³/s
#    Training PBIAS: -18.359, Validation PBIAS: -23.193
#    Params: mu=5.000, lambda=73.543
#
# === Station 27087 ===, Number=143
# ✅ Training NSE: 0.787, Validation NSE: 0.772
#    Training KGE: 0.864, Validation KGE: 0.884
#    Training RMSE: 1.275 m³/s, Validation RMSE: 1.423 m³/s
#    Training PBIAS: -5.070, Validation PBIAS: -1.038
#    Params: mu=1.095, lambda=47.987
#
# === Station 27089 ===, Number=144
# ✅ Training NSE: 0.730, Validation NSE: 0.656
#    Training KGE: 0.701, Validation KGE: 0.681
#    Training RMSE: 11.241 m³/s, Validation RMSE: 13.108 m³/s
#    Training PBIAS: -27.329, Validation PBIAS: -28.002
#    Params: mu=1.139, lambda=7.437
#
# === Station 27090 ===, Number=145
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 ===, Number=146
# ✅ Training NSE: 0.352, Validation NSE: 0.270
#    Training KGE: 0.274, Validation KGE: 0.203
#    Training RMSE: 2.791 m³/s, Validation RMSE: 2.756 m³/s
#    Training PBIAS: 40.159, Validation PBIAS: 50.404
#    Params: mu=1.621, lambda=63.062
#
# === Station 28003 ===, Number=147
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 ===, Number=148
# ✅ Training NSE: 0.611, Validation NSE: 0.607
#    Training KGE: 0.704, Validation KGE: 0.685
#    Training RMSE: 4.574 m³/s, Validation RMSE: 4.234 m³/s
#    Training PBIAS: -22.165, Validation PBIAS: -22.822
#    Params: mu=1.193, lambda=15.652
#
# === Station 28009 ===, Number=149
# ✅ Training NSE: 0.141, Validation NSE: 0.306
#    Training KGE: 0.404, Validation KGE: 0.459
#    Training RMSE: 69.553 m³/s, Validation RMSE: 61.830 m³/s
#    Training PBIAS: -52.760, Validation PBIAS: -50.168
#    Params: mu=0.908, lambda=3.020
#
# === Station 28012 ===, Number=150
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 ===, Number=151
# ✅ Training NSE: 0.599, Validation NSE: 0.580
#    Training KGE: 0.741, Validation KGE: 0.766
#    Training RMSE: 0.895 m³/s, Validation RMSE: 0.932 m³/s
#    Training PBIAS: -8.237, Validation PBIAS: 0.008
#    Params: mu=1.220, lambda=51.181
#
# === Station 28018 ===, Number=152
# ✅ Training NSE: 0.579, Validation NSE: 0.614
#    Training KGE: 0.607, Validation KGE: 0.606
#    Training RMSE: 9.166 m³/s, Validation RMSE: 7.897 m³/s
#    Training PBIAS: -36.218, Validation PBIAS: -37.441
#    Params: mu=1.106, lambda=7.098
#
# === Station 28022 ===, Number=153
# ✅ Training NSE: 0.138, Validation NSE: 0.250
#    Training KGE: 0.420, Validation KGE: 0.492
#    Training RMSE: 72.855 m³/s, Validation RMSE: 63.409 m³/s
#    Training PBIAS: -50.746, Validation PBIAS: -46.203
#    Params: mu=0.892, lambda=3.051
#
# === Station 28023 ===, Number=154
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 ===, Number=155
# ✅ Training NSE: 0.567, Validation NSE: 0.632
#    Training KGE: 0.626, Validation KGE: 0.642
#    Training RMSE: 3.114 m³/s, Validation RMSE: 2.986 m³/s
#    Training PBIAS: -11.496, Validation PBIAS: 2.374
#    Params: mu=1.191, lambda=10.150
#
# === Station 28026 ===, Number=156
# ✅ Training NSE: 0.660, Validation NSE: 0.721
#    Training KGE: 0.723, Validation KGE: 0.700
#    Training RMSE: 2.398 m³/s, Validation RMSE: 2.579 m³/s
#    Training PBIAS: -14.513, Validation PBIAS: -13.112
#    Params: mu=1.212, lambda=10.256
#
# === Station 28031 ===, Number=157
# ✅ Training NSE: 0.559, Validation NSE: 0.582
#    Training KGE: 0.638, Validation KGE: 0.624
#    Training RMSE: 2.822 m³/s, Validation RMSE: 2.582 m³/s
#    Training PBIAS: 0.211, Validation PBIAS: 0.537
#    Params: mu=1.369, lambda=25.019
#
# === Station 28033 ===, Number=158
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 ===, Number=159
# ✅ Training NSE: 0.032, Validation NSE: 0.023
#    Training KGE: -0.046, Validation KGE: -0.106
#    Training RMSE: 1.009 m³/s, Validation RMSE: 1.294 m³/s
#    Training PBIAS: 6.246, Validation PBIAS: 9.244
#    Params: mu=5.000, lambda=121.341
#
# === Station 28040 ===, Number=160
# ✅ Training NSE: 0.077, Validation NSE: 0.001
#    Training KGE: 0.257, Validation KGE: 0.225
#    Training RMSE: 0.879 m³/s, Validation RMSE: 0.781 m³/s
#    Training PBIAS: 4.971, Validation PBIAS: 17.847
#    Params: mu=5.000, lambda=62.272
#
# === Station 28043 ===, Number=161
# ✅ Training NSE: 0.707, Validation NSE: 0.696
#    Training KGE: 0.785, Validation KGE: 0.739
#    Training RMSE: 4.296 m³/s, Validation RMSE: 4.101 m³/s
#    Training PBIAS: -3.818, Validation PBIAS: -8.278
#    Params: mu=1.242, lambda=18.488
#
# === Station 28044 ===, Number=162
# ✅ Training NSE: -18.027, Validation NSE: -10.628
#    Training KGE: -1.472, Validation KGE: -0.978
#    Training RMSE: 0.538 m³/s, Validation RMSE: 0.537 m³/s
#    Training PBIAS: 136.049, Validation PBIAS: 116.605
#    Params: mu=5.000, lambda=84.117
#
# === Station 28046 ===, Number=163
# ✅ Training NSE: 0.717, Validation NSE: 0.664
#    Training KGE: 0.702, Validation KGE: 0.688
#    Training RMSE: 0.779 m³/s, Validation RMSE: 0.772 m³/s
#    Training PBIAS: 11.723, Validation PBIAS: 17.300
#    Params: mu=1.659, lambda=66.469
#
# === Station 28048 ===, Number=164
# ✅ Training NSE: 0.502, Validation NSE: 0.458
#    Training KGE: 0.529, Validation KGE: 0.437
#    Training RMSE: 1.374 m³/s, Validation RMSE: 1.716 m³/s
#    Training PBIAS: 20.606, Validation PBIAS: 16.247
#    Params: mu=1.585, lambda=27.673
#
# === Station 28050 ===, Number=165
# ✅ Training NSE: 0.505, Validation NSE: 0.451
#    Training KGE: 0.532, Validation KGE: 0.435
#    Training RMSE: 0.475 m³/s, Validation RMSE: 0.602 m³/s
#    Training PBIAS: 19.267, Validation PBIAS: 14.961
#    Params: mu=1.988, lambda=50.872
#
# === Station 28052 ===, Number=166
# ✅ Training NSE: 0.593, Validation NSE: 0.582
#    Training KGE: 0.572, Validation KGE: 0.479
#    Training RMSE: 0.807 m³/s, Validation RMSE: 1.031 m³/s
#    Training PBIAS: 24.540, Validation PBIAS: 16.168
#    Params: mu=1.660, lambda=34.759
#
# === Station 28055 ===, Number=167
# ✅ Training NSE: 0.042, Validation NSE: -0.015
#    Training KGE: 0.268, Validation KGE: 0.198
#    Training RMSE: 0.852 m³/s, Validation RMSE: 0.849 m³/s
#    Training PBIAS: 4.870, Validation PBIAS: 6.834
#    Params: mu=5.000, lambda=67.387
#
# === Station 28056 ===, Number=168
# ✅ Training NSE: 0.399, Validation NSE: 0.357
#    Training KGE: 0.322, Validation KGE: 0.228
#    Training RMSE: 0.830 m³/s, Validation RMSE: 0.884 m³/s
#    Training PBIAS: 49.842, Validation PBIAS: 61.902
#    Params: mu=1.924, lambda=33.708
#
# === Station 28060 ===, Number=169
# ✅ Training NSE: -13.887, Validation NSE: -6.879
#    Training KGE: -2.752, Validation KGE: -1.324
#    Training RMSE: 0.634 m³/s, Validation RMSE: 0.616 m³/s
#    Training PBIAS: 337.284, Validation PBIAS: 200.764
#    Params: mu=5.000, lambda=68.429
#
# === Station 28066 ===, Number=170
# ✅ Training NSE: 0.337, Validation NSE: 0.325
#    Training KGE: 0.392, Validation KGE: 0.330
#    Training RMSE: 0.987 m³/s, Validation RMSE: 1.280 m³/s
#    Training PBIAS: 16.896, Validation PBIAS: 16.832
#    Params: mu=1.938, lambda=35.458
#
# === Station 28067 ===, Number=171
# ✅ Training NSE: 0.646, Validation NSE: 0.605
#    Training KGE: 0.639, Validation KGE: 0.579
#    Training RMSE: 11.148 m³/s, Validation RMSE: 12.287 m³/s
#    Training PBIAS: -34.025, Validation PBIAS: -36.582
#    Params: mu=1.080, lambda=7.725
#
# === Station 28072 ===, Number=172
# ✅ Training NSE: -1.878, Validation NSE: -1.196
#    Training KGE: -0.457, Validation KGE: -0.312
#    Training RMSE: 0.554 m³/s, Validation RMSE: 0.583 m³/s
#    Training PBIAS: 127.090, Validation PBIAS: 106.816
#    Params: mu=5.000, lambda=78.951
#
# === Station 28074 ===, Number=173
# ✅ Training NSE: 0.373, Validation NSE: 0.533
#    Training KGE: 0.494, Validation KGE: 0.594
#    Training RMSE: 9.860 m³/s, Validation RMSE: 9.107 m³/s
#    Training PBIAS: -40.262, Validation PBIAS: -32.693
#    Params: mu=1.015, lambda=5.944
#
# === Station 28080 ===, Number=174
# ✅ Training NSE: -0.121, Validation NSE: -0.016
#    Training KGE: -0.083, Validation KGE: -0.233
#    Training RMSE: 10.155 m³/s, Validation RMSE: 11.545 m³/s
#    Training PBIAS: -8.313, Validation PBIAS: 7.110
#    Params: mu=0.805, lambda=200.000
#
# === Station 28081 ===, Number=175
# ✅ Training NSE: 0.256, Validation NSE: 0.280
#    Training KGE: 0.444, Validation KGE: 0.464
#    Training RMSE: 1.600 m³/s, Validation RMSE: 1.712 m³/s
#    Training PBIAS: -19.348, Validation PBIAS: -11.134
#    Params: mu=1.463, lambda=26.942
#
# === Station 28082 ===, Number=176
# ✅ Training NSE: 0.617, Validation NSE: 0.627
#    Training KGE: 0.625, Validation KGE: 0.613
#    Training RMSE: 1.108 m³/s, Validation RMSE: 1.180 m³/s
#    Training PBIAS: 16.230, Validation PBIAS: 15.500
#    Params: mu=1.459, lambda=19.957
#
# === Station 28085 ===, Number=177
# ✅ Training NSE: 0.661, Validation NSE: 0.593
#    Training KGE: 0.668, Validation KGE: 0.587
#    Training RMSE: 9.734 m³/s, Validation RMSE: 10.610 m³/s
#    Training PBIAS: -30.784, Validation PBIAS: -36.825
#    Params: mu=1.088, lambda=9.506
#
# === Station 28091 ===, Number=178
# ✅ Training NSE: 0.628, Validation NSE: 0.633
#    Training KGE: 0.732, Validation KGE: 0.762
#    Training RMSE: 0.812 m³/s, Validation RMSE: 0.761 m³/s
#    Training PBIAS: -3.203, Validation PBIAS: -5.471
#    Params: mu=1.442, lambda=30.989
#
# === Station 28093 ===, Number=179
# ✅ Training NSE: 0.421, Validation NSE: 0.543
#    Training KGE: 0.505, Validation KGE: 0.578
#    Training RMSE: 8.657 m³/s, Validation RMSE: 7.996 m³/s
#    Training PBIAS: -37.423, Validation PBIAS: -32.773
#    Params: mu=1.033, lambda=6.059
#
# === Station 28115 ===, Number=180
# ✅ Training NSE: -0.389, Validation NSE: -0.441
#    Training KGE: 0.170, Validation KGE: 0.122
#    Training RMSE: 0.393 m³/s, Validation RMSE: 0.384 m³/s
#    Training PBIAS: 22.548, Validation PBIAS: 17.329
#    Params: mu=5.000, lambda=148.326
#
# === Station 28116 ===, Number=181
# ⚠️ Too many missing values (28.2%)
#
# === Station 28117 ===, Number=182
# ⚠️ Too many missing values (28.0%)
#
# === Station 29002 ===, Number=183
# ✅ Training NSE: -0.696, Validation NSE: -0.864
#    Training KGE: 0.081, Validation KGE: -0.058
#    Training RMSE: 0.477 m³/s, Validation RMSE: 0.509 m³/s
#    Training PBIAS: 30.179, Validation PBIAS: 17.295
#    Params: mu=5.000, lambda=104.070
#
# === Station 29003 ===, Number=184
# ✅ Training NSE: -1.851, Validation NSE: -1.531
#    Training KGE: -0.130, Validation KGE: -0.029
#    Training RMSE: 0.528 m³/s, Validation RMSE: 0.560 m³/s
#    Training PBIAS: 71.370, Validation PBIAS: 40.804
#    Params: mu=5.000, lambda=85.520
#
# === Station 29005 ===, Number=185
# ✅ Training NSE: 0.089, Validation NSE: 0.151
#    Training KGE: 0.104, Validation KGE: 0.168
#    Training RMSE: 0.807 m³/s, Validation RMSE: 0.998 m³/s
#    Training PBIAS: 60.294, Validation PBIAS: 36.294
#    Params: mu=2.757, lambda=37.916
#
# === Station 29009 ===, Number=186
# ✅ Training NSE: -8.761, Validation NSE: -7.434
#    Training KGE: -2.954, Validation KGE: -2.223
#    Training RMSE: 0.644 m³/s, Validation RMSE: 0.642 m³/s
#    Training PBIAS: 367.910, Validation PBIAS: 292.222
#    Params: mu=5.000, lambda=45.745
#
# === Station 30001 ===, Number=187
# ✅ Training NSE: 0.580, Validation NSE: 0.606
#    Training KGE: 0.657, Validation KGE: 0.645
#    Training RMSE: 1.321 m³/s, Validation RMSE: 1.330 m³/s
#    Training PBIAS: -4.534, Validation PBIAS: -4.078
#    Params: mu=1.237, lambda=29.973
#
# === Station 30004 ===, Number=188
# ✅ Training NSE: -0.239, Validation NSE: -0.120
#    Training KGE: 0.181, Validation KGE: 0.179
#    Training RMSE: 0.569 m³/s, Validation RMSE: 0.623 m³/s
#    Training PBIAS: 40.708, Validation PBIAS: 31.394
#    Params: mu=5.000, lambda=75.780
#
# === Station 30005 ===, Number=189
# ⚠️ Too many missing values (24.0%)
#
# === Station 30011 ===, Number=190
# ✅ Training NSE: -2.549, Validation NSE: -1.805
#    Training KGE: -0.535, Validation KGE: -0.210
#    Training RMSE: 0.590 m³/s, Validation RMSE: 0.589 m³/s
#    Training PBIAS: 126.805, Validation PBIAS: 87.527
#    Params: mu=5.000, lambda=76.569
#
# === Station 30012 ===, Number=191
# ✅ Training NSE: -1.967, Validation NSE: -1.400
#    Training KGE: -1.161, Validation KGE: -0.496
#    Training RMSE: 0.639 m³/s, Validation RMSE: 0.620 m³/s
#    Training PBIAS: 202.073, Validation PBIAS: 129.793
#    Params: mu=5.000, lambda=56.607
#
# ...
#    Training RMSE: 1.301 m³/s, Validation RMSE: 1.459 m³/s
#    Training PBIAS: 332.730, Validation PBIAS: 338.020
#    Params: mu=5.000, lambda=200.000
#
# === Station 80005 ===, Number=612
# ✅ Training NSE: -33.982, Validation NSE: -36.212
#    Training KGE: -5.023, Validation KGE: -5.149
#    Training RMSE: 1.325 m³/s, Validation RMSE: 1.536 m³/s
#    Training PBIAS: 427.151, Validation PBIAS: 406.276
#    Params: mu=5.000, lambda=200.000
#
# === Station 80006 ===, Number=613
# ✅ Training NSE: -0.603, Validation NSE: -0.663
#    Training KGE: 0.267, Validation KGE: 0.285
#    Training RMSE: 1.304 m³/s, Validation RMSE: 1.421 m³/s
#    Training PBIAS: -25.275, Validation PBIAS: -26.948
#    Params: mu=5.000, lambda=200.000
#
# === Station 8004 ===, Number=614
# ✅ Training NSE: 0.147, Validation NSE: -0.036
#    Training KGE: 0.353, Validation KGE: 0.211
#    Training RMSE: 13.315 m³/s, Validation RMSE: 16.013 m³/s
#    Training PBIAS: -26.357, Validation PBIAS: -25.010
#    Params: mu=1.120, lambda=19.500
#
# === Station 8005 ===, Number=615
# ✅ Training NSE: 0.457, Validation NSE: 0.228
#    Training KGE: 0.586, Validation KGE: 0.492
#    Training RMSE: 22.655 m³/s, Validation RMSE: 22.921 m³/s
#    Training PBIAS: -34.639, Validation PBIAS: -40.058
#    Params: mu=1.132, lambda=14.085
#
# === Station 8006 ===, Number=616
# ✅ Training NSE: 0.075, Validation NSE: -0.180
#    Training KGE: 0.440, Validation KGE: 0.294
#    Training RMSE: 53.401 m³/s, Validation RMSE: 59.236 m³/s
#    Training PBIAS: -46.584, Validation PBIAS: -50.216
#    Params: mu=1.036, lambda=7.437
#
# === Station 8009 ===, Number=617
# ✅ Training NSE: 0.378, Validation NSE: 0.254
#    Training KGE: 0.495, Validation KGE: 0.390
#    Training RMSE: 6.390 m³/s, Validation RMSE: 6.778 m³/s
#    Training PBIAS: -20.745, Validation PBIAS: -21.973
#    Params: mu=1.294, lambda=17.091
#
# === Station 8011 ===, Number=618
# ✅ Training NSE: 0.364, Validation NSE: 0.212
#    Training KGE: 0.428, Validation KGE: 0.310
#    Training RMSE: 1.758 m³/s, Validation RMSE: 2.175 m³/s
#    Training PBIAS: 2.591, Validation PBIAS: 0.462
#    Params: mu=1.609, lambda=46.252
#
# === Station 8013 ===, Number=619
# ⚠️ Too many missing values (15.5%)
#
# === Station 81002 ===, Number=620
# ✅ Training NSE: 0.522, Validation NSE: 0.562
#    Training KGE: 0.625, Validation KGE: 0.697
#    Training RMSE: 14.208 m³/s, Validation RMSE: 13.827 m³/s
#    Training PBIAS: -14.629, Validation PBIAS: -11.432
#    Params: mu=1.255, lambda=16.846
#
# === Station 81003 ===, Number=621
# ✅ Training NSE: 0.420, Validation NSE: 0.402
#    Training KGE: 0.496, Validation KGE: 0.491
#    Training RMSE: 7.152 m³/s, Validation RMSE: 8.082 m³/s
#    Training PBIAS: -0.898, Validation PBIAS: -2.272
#    Params: mu=1.361, lambda=22.387
#
# === Station 81004 ===, Number=622
# ✅ Training NSE: 0.757, Validation NSE: 0.749
#    Training KGE: 0.822, Validation KGE: 0.848
#    Training RMSE: 6.163 m³/s, Validation RMSE: 6.831 m³/s
#    Training PBIAS: -6.643, Validation PBIAS: -3.630
#    Params: mu=1.231, lambda=12.522
#
# === Station 81006 ===, Number=623
# ✅ Training NSE: 0.434, Validation NSE: 0.456
#    Training KGE: 0.503, Validation KGE: 0.531
#    Training RMSE: 7.431 m³/s, Validation RMSE: 7.828 m³/s
#    Training PBIAS: 0.629, Validation PBIAS: 1.515
#    Params: mu=1.432, lambda=40.288
#
# === Station 81007 ===, Number=624
# ✅ Training NSE: 0.372, Validation NSE: 0.385
#    Training KGE: 0.392, Validation KGE: 0.423
#    Training RMSE: 3.873 m³/s, Validation RMSE: 4.096 m³/s
#    Training PBIAS: 13.908, Validation PBIAS: 12.148
#    Params: mu=1.622, lambda=59.468
#
# === Station 82001 ===, Number=625
# ✅ Training NSE: 0.592, Validation NSE: 0.657
#    Training KGE: 0.676, Validation KGE: 0.665
#    Training RMSE: 6.418 m³/s, Validation RMSE: 6.492 m³/s
#    Training PBIAS: -1.602, Validation PBIAS: -5.734
#    Params: mu=1.309, lambda=19.249
#
# === Station 82003 ===, Number=626
# ✅ Training NSE: 0.474, Validation NSE: 0.524
#    Training KGE: 0.577, Validation KGE: 0.561
#    Training RMSE: 9.833 m³/s, Validation RMSE: 10.870 m³/s
#    Training PBIAS: -11.800, Validation PBIAS: -16.939
#    Params: mu=1.280, lambda=18.332
#
# === Station 83003 ===, Number=627
# ✅ Training NSE: 0.471, Validation NSE: 0.424
#    Training KGE: 0.566, Validation KGE: 0.558
#    Training RMSE: 5.497 m³/s, Validation RMSE: 5.767 m³/s
#    Training PBIAS: -4.325, Validation PBIAS: -4.981
#    Params: mu=1.391, lambda=23.421
#
# === Station 83004 ===, Number=628
# ✅ Training NSE: 0.481, Validation NSE: 0.467
#    Training KGE: 0.572, Validation KGE: 0.586
#    Training RMSE: 6.100 m³/s, Validation RMSE: 6.239 m³/s
#    Training PBIAS: -5.594, Validation PBIAS: -1.202
#    Params: mu=1.356, lambda=21.088
#
# === Station 83006 ===, Number=629
# ✅ Training NSE: 0.520, Validation NSE: 0.458
#    Training KGE: 0.584, Validation KGE: 0.515
#    Training RMSE: 15.745 m³/s, Validation RMSE: 18.291 m³/s
#    Training PBIAS: -26.097, Validation PBIAS: -31.424
#    Params: mu=1.191, lambda=8.782
#
# === Station 83007 ===, Number=630
# ✅ Training NSE: 0.421, Validation NSE: 0.413
#    Training KGE: 0.388, Validation KGE: 0.419
#    Training RMSE: 2.045 m³/s, Validation RMSE: 1.864 m³/s
#    Training PBIAS: 31.718, Validation PBIAS: 34.371
#    Params: mu=1.793, lambda=52.908
#
# === Station 83009 ===, Number=631
# ✅ Training NSE: 0.409, Validation NSE: 0.448
#    Training KGE: 0.481, Validation KGE: 0.595
#    Training RMSE: 8.002 m³/s, Validation RMSE: 6.551 m³/s
#    Training PBIAS: 3.272, Validation PBIAS: 5.776
#    Params: mu=1.368, lambda=22.618
#
# === Station 83010 ===, Number=632
# ✅ Training NSE: 0.391, Validation NSE: 0.384
#    Training KGE: 0.412, Validation KGE: 0.441
#    Training RMSE: 2.770 m³/s, Validation RMSE: 2.673 m³/s
#    Training PBIAS: 18.346, Validation PBIAS: 18.399
#    Params: mu=1.658, lambda=46.129
#
# === Station 83013 ===, Number=633
# ✅ Training NSE: 0.456, Validation NSE: 0.432
#    Training KGE: 0.547, Validation KGE: 0.650
#    Training RMSE: 7.903 m³/s, Validation RMSE: 6.856 m³/s
#    Training PBIAS: -4.812, Validation PBIAS: 4.502
#    Params: mu=1.312, lambda=15.050
#
# === Station 84001 ===, Number=634
# ✅ Training NSE: 0.677, Validation NSE: 0.648
#    Training KGE: 0.758, Validation KGE: 0.696
#    Training RMSE: 5.889 m³/s, Validation RMSE: 6.429 m³/s
#    Training PBIAS: -13.234, Validation PBIAS: -16.336
#    Params: mu=1.262, lambda=17.119
#
# === Station 84004 ===, Number=635
# ✅ Training NSE: 0.669, Validation NSE: 0.593
#    Training KGE: 0.685, Validation KGE: 0.684
#    Training RMSE: 13.395 m³/s, Validation RMSE: 16.645 m³/s
#    Training PBIAS: -28.458, Validation PBIAS: -26.256
#    Params: mu=1.151, lambda=8.721
#
# === Station 84005 ===, Number=636
# ✅ Training NSE: 0.582, Validation NSE: 0.474
#    Training KGE: 0.574, Validation KGE: 0.546
#    Training RMSE: 34.677 m³/s, Validation RMSE: 41.019 m³/s
#    Training PBIAS: -39.481, Validation PBIAS: -40.759
#    Params: mu=1.079, lambda=4.404
#
# === Station 84008 ===, Number=637
# ✅ Training NSE: 0.384, Validation NSE: 0.390
#    Training KGE: 0.366, Validation KGE: 0.340
#    Training RMSE: 1.983 m³/s, Validation RMSE: 2.315 m³/s
#    Training PBIAS: 27.479, Validation PBIAS: 17.522
#    Params: mu=1.799, lambda=61.182
#
# === Station 84009 ===, Number=638
# ✅ Training NSE: 0.437, Validation NSE: 0.431
#    Training KGE: 0.416, Validation KGE: 0.427
#    Training RMSE: 1.828 m³/s, Validation RMSE: 1.890 m³/s
#    Training PBIAS: 28.234, Validation PBIAS: 17.878
#    Params: mu=1.774, lambda=56.972
#
# === Station 84012 ===, Number=639
# ✅ Training NSE: 0.596, Validation NSE: 0.561
#    Training KGE: 0.685, Validation KGE: 0.716
#    Training RMSE: 6.275 m³/s, Validation RMSE: 5.592 m³/s
#    Training PBIAS: -5.762, Validation PBIAS: 2.872
#    Params: mu=1.316, lambda=19.691
#
# === Station 84013 ===, Number=640
# ✅ Training NSE: 0.522, Validation NSE: 0.440
#    Training KGE: 0.529, Validation KGE: 0.556
#    Training RMSE: 40.690 m³/s, Validation RMSE: 42.340 m³/s
#    Training PBIAS: -43.695, Validation PBIAS: -39.089
#    Params: mu=1.074, lambda=4.088
#
# === Station 84014 ===, Number=641
# ✅ Training NSE: 0.506, Validation NSE: 0.482
#    Training KGE: 0.599, Validation KGE: 0.569
#    Training RMSE: 8.763 m³/s, Validation RMSE: 8.647 m³/s
#    Training PBIAS: -11.846, Validation PBIAS: -14.269
#    Params: mu=1.289, lambda=15.852
#
# === Station 84016 ===, Number=642
# ✅ Training NSE: 0.107, Validation NSE: 0.026
#    Training KGE: 0.256, Validation KGE: 0.297
#    Training RMSE: 1.198 m³/s, Validation RMSE: 1.060 m³/s
#    Training PBIAS: -17.498, Validation PBIAS: -13.633
#    Params: mu=5.000, lambda=75.350
#
# === Station 84017 ===, Number=643
# ✅ Training NSE: 0.693, Validation NSE: 0.693
#    Training KGE: 0.651, Validation KGE: 0.688
#    Training RMSE: 3.130 m³/s, Validation RMSE: 2.844 m³/s
#    Training PBIAS: 17.823, Validation PBIAS: 20.646
#    Params: mu=1.465, lambda=48.921
#
# === Station 84018 ===, Number=644
# ✅ Training NSE: 0.652, Validation NSE: 0.479
#    Training KGE: 0.650, Validation KGE: 0.652
#    Training RMSE: 18.834 m³/s, Validation RMSE: 23.943 m³/s
#    Training PBIAS: -32.160, Validation PBIAS: -26.220
#    Params: mu=1.122, lambda=6.777
#
# === Station 84019 ===, Number=645
# ✅ Training NSE: 0.539, Validation NSE: 0.502
#    Training KGE: 0.604, Validation KGE: 0.573
#    Training RMSE: 2.479 m³/s, Validation RMSE: 2.345 m³/s
#    Training PBIAS: 7.629, Validation PBIAS: 24.625
#    Params: mu=1.457, lambda=24.336
#
# === Station 84020 ===, Number=646
# ✅ Training NSE: -0.073, Validation NSE: -0.052
#    Training KGE: -0.062, Validation KGE: -0.018
#    Training RMSE: 3.352 m³/s, Validation RMSE: 3.047 m³/s
#    Training PBIAS: -61.961, Validation PBIAS: -60.648
#    Params: mu=5.000, lambda=84.730
#
# === Station 84022 ===, Number=647
# ✅ Training NSE: 0.457, Validation NSE: 0.493
#    Training KGE: 0.505, Validation KGE: 0.555
#    Training RMSE: 3.438 m³/s, Validation RMSE: 3.225 m³/s
#    Training PBIAS: 10.005, Validation PBIAS: 11.258
#    Params: mu=1.522, lambda=38.417
#
# === Station 84026 ===, Number=648
# ✅ Training NSE: 0.071, Validation NSE: 0.057
#    Training KGE: 0.063, Validation KGE: 0.140
#    Training RMSE: 1.892 m³/s, Validation RMSE: 1.528 m³/s
#    Training PBIAS: -42.391, Validation PBIAS: -35.051
#    Params: mu=5.000, lambda=120.809
#
# === Station 84030 ===, Number=649
# ✅ Training NSE: 0.483, Validation NSE: 0.473
#    Training KGE: 0.517, Validation KGE: 0.481
#    Training RMSE: 3.673 m³/s, Validation RMSE: 3.857 m³/s
#    Training PBIAS: 14.436, Validation PBIAS: 13.654
#    Params: mu=1.496, lambda=39.045
#
# === Station 85001 ===, Number=650
# ✅ Training NSE: 0.653, Validation NSE: 0.515
#    Training KGE: 0.778, Validation KGE: 0.717
#    Training RMSE: 20.009 m³/s, Validation RMSE: 22.130 m³/s
#    Training PBIAS: -16.884, Validation PBIAS: -20.320
#    Params: mu=1.103, lambda=35.883
#
# === Station 85002 ===, Number=651
# ✅ Training NSE: 0.514, Validation NSE: 0.400
#    Training KGE: 0.603, Validation KGE: 0.401
#    Training RMSE: 8.100 m³/s, Validation RMSE: 11.210 m³/s
#    Training PBIAS: -4.834, Validation PBIAS: -23.719
#    Params: mu=1.329, lambda=22.029
#
# === Station 85003 ===, Number=652
# ✅ Training NSE: -0.085, Validation NSE: -0.184
#    Training KGE: -0.090, Validation KGE: 0.019
#    Training RMSE: 11.150 m³/s, Validation RMSE: 9.181 m³/s
#    Training PBIAS: -69.661, Validation PBIAS: -61.759
#    Params: mu=5.000, lambda=89.660
#
# === Station 85004 ===, Number=653
# ✅ Training NSE: -0.148, Validation NSE: -0.216
#    Training KGE: -0.033, Validation KGE: 0.061
#    Training RMSE: 3.558 m³/s, Validation RMSE: 3.145 m³/s
#    Training PBIAS: -62.626, Validation PBIAS: -57.714
#    Params: mu=5.000, lambda=137.710
#
# === Station 88001 ===, Number=654
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 ===, Number=655
# ✅ Training NSE: -0.067, Validation NSE: -0.080
#    Training KGE: -0.074, Validation KGE: 0.114
#    Training RMSE: 7.711 m³/s, Validation RMSE: 7.415 m³/s
#    Training PBIAS: -67.252, Validation PBIAS: -56.306
#    Params: mu=5.000, lambda=123.074
#
# === Station 89003 ===, Number=656
# ✅ Training NSE: 0.423, Validation NSE: 0.402
#    Training KGE: 0.517, Validation KGE: 0.581
#    Training RMSE: 28.594 m³/s, Validation RMSE: 28.013 m³/s
#    Training PBIAS: -7.516, Validation PBIAS: 12.025
#    Params: mu=1.293, lambda=27.873
#
# === Station 89005 ===, Number=657
# ✅ Training NSE: -0.009, Validation NSE: -0.038
#    Training KGE: -0.083, Validation KGE: -0.014
#    Training RMSE: 9.418 m³/s, Validation RMSE: 8.901 m³/s
#    Training PBIAS: -65.237, Validation PBIAS: -58.100
#    Params: mu=5.000, lambda=102.394
#
# === Station 89007 ===, Number=658
# ✅ Training NSE: -0.044, Validation NSE: -0.076
#    Training KGE: 0.028, Validation KGE: 0.206
#    Training RMSE: 2.470 m³/s, Validation RMSE: 1.906 m³/s
#    Training PBIAS: -46.228, Validation PBIAS: -30.230
#    Params: mu=5.000, lambda=200.000
#
# === Station 90003 ===, Number=659
# ✅ Training NSE: -0.134, Validation NSE: -0.176
#    Training KGE: -0.078, Validation KGE: -0.069
#    Training RMSE: 9.727 m³/s, Validation RMSE: 8.899 m³/s
#    Training PBIAS: -72.460, Validation PBIAS: -72.746
#    Params: mu=5.000, lambda=107.562
#
# === Station 9002 ===, Number=660
# ✅ Training NSE: 0.382, Validation NSE: 0.259
#    Training KGE: 0.448, Validation KGE: 0.377
#    Training RMSE: 15.359 m³/s, Validation RMSE: 20.389 m³/s
#    Training PBIAS: -45.946, Validation PBIAS: -43.181
#    Params: mu=1.106, lambda=7.351
#
# === Station 9003 ===, Number=661
# ✅ Training NSE: 0.522, Validation NSE: 0.339
#    Training KGE: 0.610, Validation KGE: 0.537
#    Training RMSE: 2.901 m³/s, Validation RMSE: 4.052 m³/s
#    Training PBIAS: -0.508, Validation PBIAS: -5.111
#    Params: mu=1.363, lambda=18.997
#
# === Station 9004 ===, Number=662
# ✅ Training NSE: 0.616, Validation NSE: 0.479
#    Training KGE: 0.692, Validation KGE: 0.661
#    Training RMSE: 1.872 m³/s, Validation RMSE: 2.073 m³/s
#    Training PBIAS: 1.493, Validation PBIAS: -5.426
#    Params: mu=1.357, lambda=36.171
#
# === Station 9005 ===, Number=663
# ✅ Training NSE: 0.307, Validation NSE: 0.202
#    Training KGE: 0.333, Validation KGE: 0.247
#    Training RMSE: 1.777 m³/s, Validation RMSE: 2.163 m³/s
#    Training PBIAS: 17.316, Validation PBIAS: 8.459
#    Params: mu=1.788, lambda=48.978
#
# === Station 92001 ===, Number=664
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 ===, Number=665
# ✅ Training NSE: 0.424, Validation NSE: 0.474
#    Training KGE: 0.495, Validation KGE: 0.477
#    Training RMSE: 11.282 m³/s, Validation RMSE: 9.679 m³/s
#    Training PBIAS: 0.664, Validation PBIAS: -3.037
#    Params: mu=1.437, lambda=51.427
#
# === Station 94001 ===, Number=666
# ✅ Training NSE: 0.735, Validation NSE: 0.727
#    Training KGE: 0.826, Validation KGE: 0.736
#    Training RMSE: 12.468 m³/s, Validation RMSE: 11.414 m³/s
#    Training PBIAS: -11.793, Validation PBIAS: -17.073
#    Params: mu=1.202, lambda=43.157
#
# === Station 95001 ===, Number=667
# ✅ Training NSE: 0.703, Validation NSE: 0.697
#    Training KGE: 0.712, Validation KGE: 0.699
#    Training RMSE: 3.388 m³/s, Validation RMSE: 3.185 m³/s
#    Training PBIAS: 4.758, Validation PBIAS: 7.863
#    Params: mu=1.438, lambda=94.867
#
# === Station 96001 ===, Number=668
# ✅ Training NSE: 0.400, Validation NSE: 0.420
#    Training KGE: 0.499, Validation KGE: 0.519
#    Training RMSE: 5.793 m³/s, Validation RMSE: 5.318 m³/s
#    Training PBIAS: -8.228, Validation PBIAS: -7.468
#    Params: mu=1.354, lambda=17.800
#
# === Station 96002 ===, Number=669
# ✅ Training NSE: 0.626, Validation NSE: 0.554
#    Training KGE: 0.714, Validation KGE: 0.547
#    Training RMSE: 11.296 m³/s, Validation RMSE: 11.603 m³/s
#    Training PBIAS: -18.862, Validation PBIAS: -29.049
#    Params: mu=1.210, lambda=14.954
#
# === Station 96004 ===, Number=670
# ✅ Training NSE: 0.254, Validation NSE: 0.262
#    Training KGE: 0.282, Validation KGE: 0.266
#    Training RMSE: 9.345 m³/s, Validation RMSE: 8.722 m³/s
#    Training PBIAS: 0.250, Validation PBIAS: 2.168
#    Params: mu=1.532, lambda=69.660
#
# === Station 97002 ===, Number=671
# ✅ Training NSE: 0.614, Validation NSE: 0.553
#    Training KGE: 0.707, Validation KGE: 0.619
#    Training RMSE: 7.093 m³/s, Validation RMSE: 8.594 m³/s
#    Training PBIAS: -16.899, Validation PBIAS: -15.741
#    Params: mu=1.212, lambda=10.514
#
# ✅ Simulation completed for 623 valid catchments.

# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive

# ============================================
# 1. EXTRACT DATA TO DATAFRAME
# ============================================
rows = []
seasons = ["DJF", "MAM", "JJA", "SON"]

for station_id, res in results.items():
    # Dynamically unpack parameters using param_names
    param_dict = dict(zip(res["param_names"], res["params"]))

    row = {
        "station_id": station_id,
        **param_dict,
        "RR": res.get("RR", np.nan),
        "NSE_train": res.get("NSE_train", np.nan),
        "NSE_val": res.get("NSE_val", np.nan),
        "NNSE_train": res.get("NNSE_train", np.nan),
        "NNSE_val": res.get("NNSE_val", np.nan),
        "RMSE_train": res.get("RMSE_train", np.nan),
        "RMSE_val": res.get("RMSE_val", np.nan),
        "PBIAS_train": res.get("PBIAS_train", np.nan),
        "PBIAS_val": res.get("PBIAS_val", np.nan),
        "FHV_train": res.get("FHV_train", np.nan),
        "FHV_val": res.get("FHV_val", np.nan),
        "FLV_train": res.get("FLV_train", np.nan),
        "FLV_val": res.get("FLV_val", np.nan),
        "KGE_train": res.get("KGE_train", np.nan),
        "KGE_val": res.get("KGE_val", np.nan),
        "PTE_train": res.get("PTE_train", np.nan),
        "PTE_val": res.get("PTE_val", np.nan),
        "missing_ratio": res.get("missing_ratio", np.nan),
        "missing_count": res.get("missing_count", np.nan),
    }

    # Dynamically add seasonal metrics
    for season in seasons:
        row[f"NSE_{season}_train"]   = res.get(f"NSE_{season}_train", np.nan)
        row[f"NSE_{season}_val"]     = res.get(f"NSE_{season}_val", np.nan)
        row[f"KGE_{season}_train"]   = res.get(f"KGE_{season}_train", np.nan)
        row[f"KGE_{season}_val"]     = res.get(f"KGE_{season}_val", np.nan)
        row[f"RMSE_{season}_train"]  = res.get(f"RMSE_{season}_train", np.nan)
        row[f"RMSE_{season}_val"]    = res.get(f"RMSE_{season}_val", np.nan)
        row[f"PBIAS_{season}_train"] = res.get(f"PBIAS_{season}_train", np.nan)
        row[f"PBIAS_{season}_val"]   = res.get(f"PBIAS_{season}_val", np.nan)

    rows.append(row)

df = pd.DataFrame(rows)

# ============================================
# 2. SAVE RESULTS
# ============================================
# Local save
df.to_csv("HyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)
print("✅ Saved locally to HyMoLAP_Simulation_Data_CAMELS_GB.csv")

# Save to Google Drive (this is the file the loader script reads back)
if not os.path.exists('/content/drive/MyDrive'):
    drive.mount("/content/drive")

df.to_csv("/content/drive/MyDrive/Colab Notebooks/Data/HyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)
print("✅ Saved to Google Drive")

# ============================================
# 3. DEFINE METRICS TO REPORT
# ============================================
global_metrics = [
    ("NSE_train",   "NSE Training",     ""),
    ("NSE_val",     "NSE Validation",   ""),
    ("NNSE_train",  "NNSE Training",    ""),
    ("NNSE_val",    "NNSE Validation",  ""),
    ("KGE_train",   "KGE Training",     ""),
    ("KGE_val",     "KGE Validation",   ""),
    ("RMSE_train",  "RMSE Training",    " m³/s"),
    ("RMSE_val",    "RMSE Validation",  " m³/s"),
    ("PBIAS_train", "PBIAS Training",   "%"),
    ("PBIAS_val",   "PBIAS Validation", "%"),
    ("FHV_train",   "FHV Training",     "%"),
    ("FHV_val",     "FHV Validation",   "%"),
    ("FLV_train",   "FLV Training",     "%"),
    ("FLV_val",     "FLV Validation",   "%"),
    ("PTE_train",   "PTE Training",     " days"),
    ("PTE_val",     "PTE Validation",   " days"),
]

season_vars = [("NSE", ""), ("KGE", ""), ("RMSE", " m³/s"), ("PBIAS", "%")]
seasonal_metrics = []
for var, unit in season_vars:
    for s in seasons:
        for split, label in [("train", "Training"), ("val", "Validation")]:
            seasonal_metrics.append((f"{var}_{s}_{split}", f"{var} {s} {label}", unit))

# ============================================
# 4. PRINT STATISTICS
# ============================================
def print_stats(metrics_list, df, title):
    print(f"\n{'='*60}")
    print(f" {title}")
    print(f"{'='*60}")
    for key, label, unit in metrics_list:
        if key not in df.columns:
            print(f"  ⚠️  '{key}' not found in CSV — skipping.")
            continue
        values = pd.to_numeric(df[key], errors="coerce").dropna().to_numpy()
        n_valid   = len(values)
        n_dropped = len(df) - n_valid
        if n_valid == 0:
            print(f"  ⚠️  {label}: all NaN — no valid stations.")
            continue
        print(
            f"  {label:<28} | "
            f"Mean: {values.mean():8.3f}{unit}  "
            f"Median: {np.median(values):8.3f}{unit}  "
            f"Min: {values.min():8.3f}{unit}  "
            f"Max: {values.max():8.3f}{unit}  "
            f"P05: {np.percentile(values,  5):8.3f}{unit}  "
            f"P95: {np.percentile(values, 95):8.3f}{unit}  "
            f"(n={n_valid})"
        )
        if n_dropped:
            print(f"    ⚠️  {n_dropped} station(s) excluded (NaN).")

print(f"\n✅ Saved {len(df)} stations to CSV.")
print_stats(global_metrics,   df, "GLOBAL SUMMARY STATISTICS")
print_stats(seasonal_metrics, df, "SEASONAL SUMMARY STATISTICS")
# Out:
# ✅ Saved locally to HyMoLAP_Simulation_Data_CAMELS_GB.csv
# ✅ Saved to Google Drive
#
# ✅ Saved 623 stations to CSV.
#
# ============================================================
#  GLOBAL SUMMARY STATISTICS
# ============================================================
#   NSE Training                 | Mean:   -2.394  Median:    0.481  Min: -468.261  Max:    0.844  P05:   -4.633  P95:    0.752  (n=623)
#   NSE Validation               | Mean:   -2.570  Median:    0.440  Min: -411.715  Max:    0.861  P05:   -3.591  P95:    0.726  (n=623)
#   NNSE Training                | Mean:    0.597  Median:    0.659  Min:    0.002  Max:    0.865  P05:    0.151  P95:    0.802  (n=623)
#   NNSE Validation              | Mean:    0.585  Median:    0.641  Min:    0.002  Max:    0.878  P05:    0.179  P95:    0.785  (n=623)
#   KGE Training                 | Mean:    0.089  Median:    0.517  Min:  -30.205  Max:    0.879  P05:   -1.628  P95:    0.790  (n=623)
#   KGE Validation               | Mean:    0.088  Median:    0.500  Min:  -38.571  Max:    0.887  P05:   -1.208  P95:    0.765  (n=623)
#   RMSE Training                | Mean:    6.508 m³/s  Median:    2.126 m³/s  Min:    0.342 m³/s  Max:  135.936 m³/s  P05:    0.571 m³/s  P95:   28.250 m³/s  (n=623)
#   RMSE Validation              | Mean:    7.180 m³/s  Median:    2.481 m³/s  Min:    0.344 m³/s  Max:  164.826 m³/s  P05:    0.581 m³/s  P95:   30.071 m³/s  (n=623)
#   PBIAS Training               | Mean:   39.551%  Median:    3.241%  Min:  -72.460%  Max: 3077.980%  P05:  -46.215%  P95:  230.264%  (n=623)
#   PBIAS Validation             | Mean:   34.693%  Median:    2.215%  Min:  -72.746%  Max: 3920.965%  P05:  -44.894%  P95:  199.909%  (n=623)
#   FHV Training                 | Mean:   -9.919%  Median:  -24.074%  Min:  -72.765%  Max: 1358.042%  P05:  -48.248%  P95:   59.146%  (n=623)
#   FHV Validation               | Mean:  -10.183%  Median:  -26.865%  Min:  -78.606%  Max: 1284.975%  P05:  -52.568%  P95:   68.243%  (n=623)
#   FLV Training                 | Mean: -560.035%  Median: -230.127%  Min: -3886.417%  Max:  100.000%  P05: -2050.276%  P95:   43.159%  (n=619)
#     ⚠️  4 station(s) excluded (NaN).
#   FLV Validation               | Mean: -700.803%  Median: -253.853%  Min: -7348.785%  Max:  100.000%  P05: -2464.845%  P95:   31.901%  (n=619)
#     ⚠️  4 station(s) excluded (NaN).
#   PTE Training                 | Mean:   80.440 days  Median:   78.471 days  Min:    1.000 days  Max:  176.765 days  P05:   31.688 days  P95:  133.758 days  (n=623)
#   PTE Validation               | Mean:   88.678 days  Median:   86.000 days  Min:    0.000 days  Max:  224.000 days  P05:   11.729 days  P95:  169.271 days  (n=623)
#
# ============================================================
#  SEASONAL SUMMARY STATISTICS
# ============================================================
#   NSE DJF Training             | Mean:   -1.802  Median:    0.450  Min: -446.726  Max:    0.854  P05:   -2.760  P95:    0.732  (n=623)
#   NSE DJF Validation           | Mean:   -2.474  Median:    0.394  Min: -638.277  Max:    0.924  P05:   -2.699  P95:    0.727  (n=623)
#   NSE MAM Training             | Mean:   -2.988  Median:    0.364  Min: -602.237  Max:    0.854  P05:   -6.713  P95:    0.690  (n=623)
#   NSE MAM Validation           | Mean:   -4.341  Median:    0.207  Min: -1181.720  Max:    0.827  P05:   -8.220  P95:    0.625  (n=623)
#   NSE JJA Training             | Mean:  -13.327  Median:   -0.055  Min: -1102.134  Max:    0.771  P05:  -38.478  P95:    0.625  (n=623)
#   NSE JJA Validation           | Mean:  -10.789  Median:    0.234  Min: -2312.709  Max:    0.823  P05:  -20.335  P95:    0.662  (n=623)
#   NSE SON Training             | Mean:   -9.095  Median:    0.429  Min: -3228.822  Max:    0.866  P05:   -9.746  P95:    0.748  (n=623)
#   NSE SON Validation           | Mean:  -11.679  Median:    0.407  Min: -3612.384  Max:    0.856  P05:  -12.681  P95:    0.730  (n=623)
#   KGE DJF Training             | Mean:    0.266  Median:    0.549  Min:  -18.072  Max:    0.916  P05:   -0.640  P95:    0.797  (n=623)
#   KGE DJF Validation           | Mean:    0.228  Median:    0.505  Min:  -21.039  Max:    0.939  P05:   -0.458  P95:    0.772  (n=623)
#   KGE MAM Training             | Mean:   -0.022  Median:    0.385  Min:  -37.122  Max:    0.892  P05:   -1.916  P95:    0.766  (n=623)
#   KGE MAM Validation           | Mean:   -0.109  Median:    0.346  Min:  -55.739  Max:    0.906  P05:   -1.636  P95:    0.716  (n=623)
#   KGE JJA Training             | Mean:   -1.358  Median:    0.152  Min: -115.829  Max:    0.850  P05:   -5.917  P95:    0.692  (n=623)
#   KGE JJA Validation           | Mean:   -0.706  Median:    0.236  Min:  -80.201  Max:    0.894  P05:   -4.330  P95:    0.696  (n=623)
#   KGE SON Training             | Mean:   -0.201  Median:    0.402  Min:  -43.576  Max:    0.931  P05:   -2.725  P95:    0.766  (n=623)
#   KGE SON Validation           | Mean:   -0.254  Median:    0.399  Min:  -53.225  Max:    0.883  P05:   -3.056  P95:    0.708  (n=623)
#   RMSE DJF Training            | Mean:    8.740 m³/s  Median:    2.757 m³/s  Min:    0.343 m³/s  Max:  153.079 m³/s  P05:    0.598 m³/s  P95:   39.056 m³/s  (n=623)
#   RMSE DJF Validation          | Mean:    9.580 m³/s  Median:    3.295 m³/s  Min:    0.382 m³/s  Max:  226.912 m³/s  P05:    0.618 m³/s  P95:   39.433 m³/s  (n=623)
#   RMSE MAM Training            | Mean:    6.072 m³/s  Median:    1.756 m³/s  Min:    0.269 m³/s  Max:  155.711 m³/s  P05:    0.481 m³/s  P95:   26.363 m³/s  (n=623)
#   RMSE MAM Validation          | Mean:    5.928 m³/s  Median:    1.679 m³/s  Min:    0.240 m³/s  Max:  162.941 m³/s  P05:    0.461 m³/s  P95:   24.565 m³/s  (n=623)
#   RMSE JJA Training            | Mean:    3.370 m³/s  Median:    1.257 m³/s  Min:    0.323 m³/s  Max:   80.424 m³/s  P05:    0.506 m³/s  P95:   13.917 m³/s  (n=623)
#   RMSE JJA Validation          | Mean:    4.994 m³/s  Median:    1.850 m³/s  Min:    0.269 m³/s  Max:  102.592 m³/s  P05:    0.515 m³/s  P95:   21.300 m³/s  (n=623)
#   RMSE SON Training            | Mean:    6.434 m³/s  Median:    2.321 m³/s  Min:    0.334 m³/s  Max:  139.951 m³/s  P05:    0.619 m³/s  P95:   28.338 m³/s  (n=623)
#   RMSE SON Validation          | Mean:    7.037 m³/s  Median:    2.369 m³/s  Min:    0.234 m³/s  Max:  147.242 m³/s  P05:    0.568 m³/s  P95:   30.023 m³/s  (n=623)
#   PBIAS DJF Training           | Mean:   11.152%  Median:   -5.171%  Min:  -70.672%  Max: 1547.555%  P05:  -49.551%  P95:  111.433%  (n=623)
#   PBIAS DJF Validation         | Mean:   11.089%  Median:   -3.943%  Min:  -73.526%  Max: 1916.736%  P05:  -50.047%  P95:   87.479%  (n=623)
#   PBIAS MAM Training           | Mean:   36.784%  Median:   -1.111%  Min:  -80.145%  Max: 3800.609%  P05:  -63.739%  P95:  250.400%  (n=623)
#   PBIAS MAM Validation         | Mean:   39.813%  Median:   -1.493%  Min:  -80.101%  Max: 5654.119%  P05:  -66.134%  P95:  216.913%  (n=623)
#   PBIAS JJA Training           | Mean:  178.685%  Median:   39.564%  Min:  -85.503%  Max: 11652.893%  P05:  -60.633%  P95:  619.304%  (n=623)
#   PBIAS JJA Validation         | Mean:  107.802%  Median:   22.972%  Min:  -82.309%  Max: 8092.885%  P05:  -56.315%  P95:  504.289%  (n=623)
#   PBIAS SON Training           | Mean:   66.008%  Median:   11.807%  Min:  -80.555%  Max: 2877.290%  P05:  -44.887%  P95:  335.549%  (n=623)
#   PBIAS SON Validation         | Mean:   61.428%  Median:    3.868%  Min:  -79.669%  Max: 5378.703%  P05:  -49.317%  P95:  322.556%  (n=623)
