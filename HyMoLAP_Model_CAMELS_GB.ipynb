# %% [markdown]
# > **This notebook implements HyMoLAP rainfall–runoff model over CAMELS-GB catchments with less than 10% missing discharge data and stores the resulting calibrated parameters and performance metrics in `HyMoLAP_Simulation_Data_CAMELS_GB.csv`.**
#
# **Author:** Lionel Cedric Gohouede

# %% [markdown]
# ## 1. MOUNT GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import warnings
from numba import njit
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# ## 3. FILTER DATA BY TIME PERIOD (1990-2014)

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/CAMELS_GB/'
start_date, end_date = '1990-01-01', '2014-12-31'

print("Loading, filtering, and aligning CSV files...\n")

# 1. Fast Load & Filter
df_pcp = pd.read_csv(f"{data_dir}pcp_mm.csv", index_col=0).loc[start_date:end_date]
df_pet = pd.read_csv(f"{data_dir}pet_mm.csv", index_col=0).loc[start_date:end_date]
df_q   = pd.read_csv(f"{data_dir}q_cms_obs.csv", index_col=0).loc[start_date:end_date]

# 2. Fast Alignment
common_stations = sorted(list(set(df_pcp.columns) & set(df_pet.columns) & set(df_q.columns)))
df_pcp = df_pcp[common_stations]
df_pet = df_pet[common_stations]
df_q   = df_q[common_stations]

print(f"✅ Data aligned. Total common stations: {len(common_stations)}")

# ============================================
# Memory-Optimized Wrapper Classes
# ============================================
class SimpleArray:
    __slots__ = ['array']  # Prevents massive RAM bloat
    def __init__(self, array):
        self.array = array
    def to_numpy(self):
        return self.array

class StationData:
    __slots__ = ['data']
    def __init__(self, data_dict):
        self.data = data_dict
    def sel(self, dynamic_features=None):
        return SimpleArray(self.data[dynamic_features])

# ============================================
# Ultra-Fast Dictionary Construction
# ============================================
print("Building ds_recent dictionary...\n")

# Convert DataFrames to 2D NumPy matrices once (orders of magnitude faster than column iteration)
pcp_arr = df_pcp.to_numpy()
pet_arr = df_pet.to_numpy()
q_arr   = df_q.to_numpy()
date_arr = pd.to_datetime(df_pcp.index).to_numpy()

# Build the dictionary using fast index slicing
ds_recent = {
    st: StationData({
        'pcp_mm': pcp_arr[:, i],
        'pet_mm': pet_arr[:, i],
        'q_cms_obs': q_arr[:, i],
        'date': date_arr
    })
    for i, st in enumerate(common_stations)
}

print(f"✅ Dictionary built successfully!")

# ============================================
# Validation Test
# ============================================
test_station = common_stations[0]
print(f"\nTesting data access for station: {test_station}")

Q_obs = ds_recent[test_station].sel(dynamic_features="q_cms_obs").to_numpy()
P     = ds_recent[test_station].sel(dynamic_features="pcp_mm").to_numpy()
PET   = ds_recent[test_station].sel(dynamic_features="pet_mm").to_numpy()

print(f"✅ Extraction works correctly!")
print(f"   Q_obs shape: {Q_obs.shape}")
print(f"   Q_obs - min: {np.nanmin(Q_obs):.2f}, max: {np.nanmax(Q_obs):.2f}, mean: {np.nanmean(Q_obs):.2f}")
print(f"   Q_obs Missing: {np.sum(np.isnan(Q_obs))} ({np.sum(np.isnan(Q_obs))/len(Q_obs)*100:.1f}%)")
# Out:
# Loading, filtering, and aligning CSV files...
#
# ✅ Data aligned. Total common stations: 671
# Building ds_recent dictionary...
#
# ✅ Dictionary built successfully!
#
# Testing data access for station: 10002
# ✅ Extraction works correctly!
#    Q_obs shape: (9131,)
#    Q_obs - min: 0.80, max: 94.41, mean: 5.18
#    Q_obs Missing: 0 (0.0%)

# %% [markdown]
# ## 4. MAIN CODE

# %%
# ============================================
# 1. COMPILED HYMOLAP MODEL & FAST METRICS
# Defined outside the loop to prevent memory reallocation
# ============================================
@njit
def HyMoLAP_Model(params, Q0, Pn):
    MU, LAMBDA = params
    N = len(Pn)
    Q = np.zeros(N)

    # Strict mathematical guards to prevent division by zero or negative exponents
    if LAMBDA <= 0.0 or MU <= 0.0:
        return np.full(N, np.nan)

    Q[0] = Q0
    X_curr = 0.0  # Tracks soil state on the fly (replaces the state_soil array)

    # Precompute constants to save CPU cycles inside the loop
    mu_lam = MU / LAMBDA
    inv_lam = 1.0 / LAMBDA
    one_m_mu_lam = 1.0 - mu_lam
    pow_term = 2.0 * MU - 1.0

    for t in range(N - 1):
        # 1. Compute Flow Q[t+1] using current soil state X[t]
        q_base = max(0.0, Q[t])  # Prevents imaginary numbers if Q[t] dips below 0
        Q[t+1] = max(0.0, Q[t] - mu_lam * (q_base ** pow_term) + inv_lam * X_curr * Pn[t])

        # 2. Update Soil State X for the next iteration (t+1)
        if Pn[t+1] == 0.0:
            X_curr = X_curr * one_m_mu_lam
        else:
            X_curr = X_curr + mu_lam * Pn[t+1]

    return Q

def NSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0 or np.var(valid_obs) == 0.0: return np.nan
    return 1.0 - (np.sum((valid_sim - valid_obs)**2) / np.sum((valid_obs - np.mean(valid_obs))**2))

def RMSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0: return np.nan
    return np.sqrt(np.mean((valid_sim - valid_obs)**2))

def objective(params, Q0, Pn_train, Q_obs_train):
    Q_sim = HyMoLAP_Model(params, Q0, Pn_train)
    nse = NSE(Q_obs_train, Q_sim)
    return 1.0 - nse if np.isfinite(nse) else 1e9

# ============================================
# 2. CALIBRATION LOOP
# ============================================
b1_ratio = 0.7
max_missing_ratio = 0.1
stations = common_stations  # Using the variable from your earlier setup
results = {}

# Bounds prevent Nelder-Mead from testing negative parameters
param_bounds = [(0.5, 10.0), (1e-3, 1000.0)]
initial_guesses = [[1.1, 20.0]]

print(f"\nStarting simulation for {len(stations)} stations...\n")

for i, station_id in enumerate(stations, 1):
    print(f"\n=== Station {station_id} ===, Number={i}")

    # Extract data using the wrapper
    Q_obs = ds_recent[station_id].sel(dynamic_features="q_cms_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    # Calculate net rainfall
    Pn = np.maximum(0.0, P - PET)
    N = len(Q_obs)

    # Data quality checks
    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station skipped (no valid data).")
        continue

    missing_count = np.sum(np.isnan(Q_obs))
    missing_ratio = missing_count / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    # Split data into training and validation sets
    b1 = int(N * b1_ratio)
    Q0 = Q_obs[0] if not np.isnan(Q_obs[0]) else np.nanmean(Q_obs[:10])

    Pn_train = Pn[:b1]
    Q_obs_train = Q_obs[:b1]

    # ============================================
    # MULTI-START Optimization
    # ============================================
    best_res = None
    best_val = float("inf")

    for guess in initial_guesses:
        res = minimize(
            objective,
            np.array(guess),
            args=(Q0, Pn_train, Q_obs_train),
            method="Nelder-Mead",
            bounds=param_bounds,
            options={'maxiter': 2500, 'disp': False}
        )
        if res.fun < best_val:
            best_val = res.fun
            best_res = res

    MU, LAMBDA = best_res.x
    NSE_train = 1.0 - best_res.fun

    # ============================================
    # Validation
    # ============================================
    Qsim = HyMoLAP_Model(best_res.x, Q0, Pn)

    NSE_val    = NSE(Q_obs[b1:], Qsim[b1:])
    RMSE_train = RMSE(Q_obs_train, Qsim[:b1])
    RMSE_val   = RMSE(Q_obs[b1:], Qsim[b1:])

    print(f"✅ Training NSE: {NSE_train:.3f}, Validation NSE: {NSE_val:.3f}")
    print(f"   Training RMSE: {RMSE_train:.3f}, Validation RMSE: {RMSE_val:.3f}")
    print(f"   Params: mu={MU:.3f}, lambda={LAMBDA:.3f}")

    # ============================================
    # Store Results
    # ============================================
    results[station_id] = {
        "params": [MU, LAMBDA],
        "NSE_train": NSE_train,
        "NSE_val": NSE_val,
        "RMSE_train": RMSE_train,
        "RMSE_val": RMSE_val,
        "Qsim": Qsim,
        "missing_ratio": missing_ratio,
        "missing_count": missing_count,
    }

print(f"\n✅ Simulation completed for {len(results)} valid catchments.")
# Out:
# Starting simulation for 671 stations...
#
#
# === Station 10002 ===, Number=1
# ✅ Training NSE: 0.660, Validation NSE: 0.607
#    Training RMSE: 3.042, Validation RMSE: 3.862
#    Params: mu=1.222, lambda=12.641
#
# === Station 10003 ===, Number=2
# ✅ Training NSE: 0.579, Validation NSE: 0.529
#    Training RMSE: 4.610, Validation RMSE: 5.284
#    Params: mu=1.055, lambda=22.714
#
# === Station 1001 ===, Number=3
# ⚠️ Too many missing values (23.4%)
#
# === Station 101002 ===, Number=4
# ✅ Training NSE: -1.092, Validation NSE: -1.180
#    Training RMSE: 0.549, Validation RMSE: 0.590
#    Params: mu=10.000, lambda=150.650
#
# === Station 101005 ===, Number=5
# ✅ Training NSE: -2.594, Validation NSE: -1.980
#    Training RMSE: 0.565, Validation RMSE: 0.618
#    Params: mu=10.000, lambda=136.131
#
# === Station 102001 ===, Number=6
# ✅ Training NSE: -0.148, Validation NSE: -0.069
#    Training RMSE: 0.710, Validation RMSE: 0.724
#    Params: mu=10.000, lambda=114.597
#
# === Station 106001 ===, Number=7
# ⚠️ Too many missing values (28.0%)
#
# === Station 107001 ===, Number=8
# ⚠️ Too many missing values (38.4%)
#
# === Station 11001 ===, Number=9
# ✅ Training NSE: 0.391, Validation NSE: 0.263
#    Training RMSE: 15.490, Validation RMSE: 17.949
#    Params: mu=1.047, lambda=8.436
#
# === Station 11003 ===, Number=10
# ✅ Training NSE: 0.382, Validation NSE: 0.185
#    Training RMSE: 7.164, Validation RMSE: 8.659
#    Params: mu=1.113, lambda=21.875
#
# === Station 11004 ===, Number=11
# ✅ Training NSE: 0.690, Validation NSE: 0.558
#    Training RMSE: 1.503, Validation RMSE: 1.984
#    Params: mu=1.289, lambda=42.841
#
# === Station 12001 ===, Number=12
# ✅ Training NSE: 0.151, Validation NSE: -0.119
#    Training RMSE: 35.336, Validation RMSE: 40.420
#    Params: mu=1.060, lambda=8.613
#
# === Station 12002 ===, Number=13
# ✅ Training NSE: 0.214, Validation NSE: -0.064
#    Training RMSE: 43.912, Validation RMSE: 50.298
#    Params: mu=1.055, lambda=5.751
#
# === Station 12005 ===, Number=14
# ✅ Training NSE: 0.420, Validation NSE: 0.360
#    Training RMSE: 3.393, Validation RMSE: 3.501
#    Params: mu=1.474, lambda=44.032
#
# === Station 12006 ===, Number=15
# ✅ Training NSE: 0.356, Validation NSE: 0.172
#    Training RMSE: 3.157, Validation RMSE: 3.536
#    Params: mu=1.387, lambda=34.179
#
# === Station 12007 ===, Number=16
# ✅ Training NSE: 0.191, Validation NSE: 0.077
#    Training RMSE: 11.601, Validation RMSE: 13.553
#    Params: mu=1.234, lambda=27.971
#
# === Station 12008 ===, Number=17
# ✅ Training NSE: 0.457, Validation NSE: 0.359
#    Training RMSE: 6.580, Validation RMSE: 8.163
#    Params: mu=1.297, lambda=18.680
#
# === Station 12009 ===, Number=18
# ✅ Training NSE: 0.007, Validation NSE: -0.024
#    Training RMSE: 2.049, Validation RMSE: 2.261
#    Params: mu=10.000, lambda=117.681
#
# === Station 13001 ===, Number=19
# ✅ Training NSE: 0.623, Validation NSE: 0.532
#    Training RMSE: 1.658, Validation RMSE: 1.982
#    Params: mu=1.441, lambda=24.764
#
# === Station 13004 ===, Number=20
# ✅ Training NSE: 0.505, Validation NSE: 0.440
#    Training RMSE: 2.470, Validation RMSE: 3.376
#    Params: mu=1.486, lambda=46.335
#
# === Station 13005 ===, Number=21
# ✅ Training NSE: 0.639, Validation NSE: 0.237
#    Training RMSE: 1.370, Validation RMSE: 2.279
#    Params: mu=1.434, lambda=26.353
#
# === Station 13007 ===, Number=22
# ✅ Training NSE: 0.394, Validation NSE: 0.326
#    Training RMSE: 17.892, Validation RMSE: 22.455
#    Params: mu=1.122, lambda=8.804
#
# === Station 13008 ===, Number=23
# ✅ Training NSE: 0.535, Validation NSE: 0.449
#    Training RMSE: 8.924, Validation RMSE: 11.347
#    Params: mu=1.160, lambda=12.875
#
# === Station 14001 ===, Number=24
# ✅ Training NSE: 0.664, Validation NSE: 0.601
#    Training RMSE: 2.478, Validation RMSE: 2.955
#    Params: mu=1.219, lambda=17.557
#
# === Station 14002 ===, Number=25
# ✅ Training NSE: 0.622, Validation NSE: 0.320
#    Training RMSE: 1.126, Validation RMSE: 1.829
#    Params: mu=1.506, lambda=35.042
#
# === Station 14005 ===, Number=26
# ✅ Training NSE: -0.119, Validation NSE: -0.012
#    Training RMSE: 0.762, Validation RMSE: 0.841
#    Params: mu=9.963, lambda=99.117
#
# === Station 15006 ===, Number=27
# ✅ Training NSE: 0.245, Validation NSE: -0.196
#    Training RMSE: 135.936, Validation RMSE: 164.826
#    Params: mu=1.009, lambda=5.925
#
# === Station 15007 ===, Number=28
# ✅ Training NSE: 0.612, Validation NSE: 0.430
#    Training RMSE: 34.749, Validation RMSE: 39.351
#    Params: mu=1.116, lambda=16.537
#
# === Station 15010 ===, Number=29
# ✅ Training NSE: 0.581, Validation NSE: 0.522
#    Training RMSE: 5.519, Validation RMSE: 7.326
#    Params: mu=1.213, lambda=18.342
#
# === Station 15011 ===, Number=30
# ✅ Training NSE: 0.432, Validation NSE: 0.326
#    Training RMSE: 13.650, Validation RMSE: 13.452
#    Params: mu=1.323, lambda=30.951
#
# === Station 15012 ===, Number=31
# ✅ Training NSE: 0.381, Validation NSE: 0.180
#    Training RMSE: 51.820, Validation RMSE: 58.880
#    Params: mu=1.068, lambda=12.695
#
# === Station 15013 ===, Number=32
# ✅ Training NSE: 0.494, Validation NSE: 0.445
#    Training RMSE: 5.343, Validation RMSE: 6.045
#    Params: mu=1.367, lambda=30.667
#
# === Station 15014 ===, Number=33
# ✅ Training NSE: 0.390, Validation NSE: 0.334
#    Training RMSE: 3.194, Validation RMSE: 3.557
#    Params: mu=1.498, lambda=36.292
#
# === Station 15016 ===, Number=34
# ✅ Training NSE: 0.726, Validation NSE: 0.597
#    Training RMSE: 21.121, Validation RMSE: 22.591
#    Params: mu=1.142, lambda=25.003
#
# === Station 15021 ===, Number=35
# ✅ Training NSE: 0.594, Validation NSE: 0.546
#    Training RMSE: 1.014, Validation RMSE: 1.098
#    Params: mu=1.609, lambda=64.133
#
# === Station 15023 ===, Number=36
# ✅ Training NSE: 0.594, Validation NSE: 0.512
#    Training RMSE: 5.959, Validation RMSE: 6.447
#    Params: mu=1.298, lambda=22.426
#
# === Station 15024 ===, Number=37
# ✅ Training NSE: 0.562, Validation NSE: 0.526
#    Training RMSE: 14.232, Validation RMSE: 14.064
#    Params: mu=1.335, lambda=33.724
#
# === Station 15025 ===, Number=38
# ✅ Training NSE: 0.405, Validation NSE: 0.330
#    Training RMSE: 11.321, Validation RMSE: 12.858
#    Params: mu=1.173, lambda=13.681
#
# === Station 15030 ===, Number=39
# ✅ Training NSE: 0.721, Validation NSE: 0.638
#    Training RMSE: 2.212, Validation RMSE: 2.750
#    Params: mu=1.223, lambda=19.163
#
# === Station 15039 ===, Number=40
# ✅ Training NSE: 0.246, Validation NSE: 0.157
#    Training RMSE: 7.413, Validation RMSE: 8.368
#    Params: mu=1.353, lambda=30.734
#
# === Station 16001 ===, Number=41
# ✅ Training NSE: 0.627, Validation NSE: 0.479
#    Training RMSE: 14.727, Validation RMSE: 17.588
#    Params: mu=1.156, lambda=17.430
#
# === Station 16003 ===, Number=42
# ✅ Training NSE: 0.330, Validation NSE: 0.309
#    Training RMSE: 6.608, Validation RMSE: 7.033
#    Params: mu=1.498, lambda=59.837
#
# === Station 16004 ===, Number=43
# ✅ Training NSE: 0.640, Validation NSE: 0.504
#    Training RMSE: 19.031, Validation RMSE: 21.921
#    Params: mu=1.128, lambda=11.726
#
# === Station 17001 ===, Number=44
# ✅ Training NSE: 0.484, Validation NSE: 0.436
#    Training RMSE: 4.550, Validation RMSE: 4.458
#    Params: mu=1.479, lambda=38.117
#
# === Station 17003 ===, Number=45
# ✅ Training NSE: 0.369, Validation NSE: 0.212
#    Training RMSE: 1.345, Validation RMSE: 1.215
#    Params: mu=2.002, lambda=73.775
#
# === Station 17004 ===, Number=46
# ✅ Training NSE: 0.730, Validation NSE: 0.659
#    Training RMSE: 1.273, Validation RMSE: 1.574
#    Params: mu=1.429, lambda=27.496
#
# === Station 17005 ===, Number=47
# ✅ Training NSE: 0.590, Validation NSE: 0.580
#    Training RMSE: 3.997, Validation RMSE: 4.301
#    Params: mu=1.321, lambda=15.907
#
# === Station 17015 ===, Number=48
# ✅ Training NSE: 0.039, Validation NSE: -0.025
#    Training RMSE: 1.094, Validation RMSE: 1.236
#    Params: mu=10.000, lambda=135.172
#
# === Station 17018 ===, Number=49
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 ===, Number=50
# ✅ Training NSE: 0.590, Validation NSE: 0.480
#    Training RMSE: 4.600, Validation RMSE: 5.639
#    Params: mu=1.377, lambda=29.290
#
# === Station 18002 ===, Number=51
# ✅ Training NSE: 0.690, Validation NSE: 0.598
#    Training RMSE: 3.528, Validation RMSE: 4.862
#    Params: mu=1.370, lambda=26.654
#
# === Station 18003 ===, Number=52
# ✅ Training NSE: 0.781, Validation NSE: 0.624
#    Training RMSE: 14.819, Validation RMSE: 18.131
#    Params: mu=1.193, lambda=19.133
#
# === Station 18008 ===, Number=53
# ✅ Training NSE: 0.739, Validation NSE: 0.678
#    Training RMSE: 7.668, Validation RMSE: 8.133
#    Params: mu=1.318, lambda=36.925
#
# === Station 18010 ===, Number=54
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 ===, Number=55
# ✅ Training NSE: 0.689, Validation NSE: 0.541
#    Training RMSE: 32.054, Validation RMSE: 34.809
#    Params: mu=1.131, lambda=10.272
#
# === Station 18014 ===, Number=56
# ✅ Training NSE: 0.039, Validation NSE: -0.042
#    Training RMSE: 1.125, Validation RMSE: 1.267
#    Params: mu=10.000, lambda=151.480
#
# === Station 18017 ===, Number=57
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 ===, Number=58
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 ===, Number=59
# ✅ Training NSE: 0.554, Validation NSE: 0.590
#    Training RMSE: 6.641, Validation RMSE: 6.523
#    Params: mu=1.218, lambda=9.408
#
# === Station 19006 ===, Number=60
# ✅ Training NSE: 0.465, Validation NSE: 0.536
#    Training RMSE: 1.550, Validation RMSE: 1.283
#    Params: mu=1.613, lambda=35.094
#
# === Station 19010 ===, Number=61
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 ===, Number=62
# ✅ Training NSE: 0.085, Validation NSE: 0.077
#    Training RMSE: 0.824, Validation RMSE: 0.915
#    Params: mu=7.061, lambda=66.057
#
# === Station 19020 ===, Number=63
# ✅ Training NSE: 0.133, Validation NSE: 0.114
#    Training RMSE: 1.270, Validation RMSE: 1.438
#    Params: mu=9.759, lambda=94.614
#
# === Station 20002 ===, Number=64
# ✅ Training NSE: -4.023, Validation NSE: -1.639
#    Training RMSE: 0.592, Validation RMSE: 0.607
#    Params: mu=10.000, lambda=86.794
#
# === Station 20003 ===, Number=65
# ✅ Training NSE: 0.439, Validation NSE: 0.453
#    Training RMSE: 1.733, Validation RMSE: 2.050
#    Params: mu=1.463, lambda=24.689
#
# === Station 20007 ===, Number=66
# ✅ Training NSE: 0.204, Validation NSE: 0.217
#    Training RMSE: 1.116, Validation RMSE: 1.061
#    Params: mu=2.313, lambda=43.911
#
# === Station 2001 ===, Number=67
# ✅ Training NSE: 0.403, Validation NSE: 0.357
#    Training RMSE: 11.888, Validation RMSE: 12.294
#    Params: mu=1.189, lambda=11.146
#
# === Station 2002 ===, Number=68
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 ===, Number=69
# ✅ Training NSE: 0.654, Validation NSE: 0.534
#    Training RMSE: 10.595, Validation RMSE: 13.016
#    Params: mu=1.142, lambda=11.541
#
# === Station 21006 ===, Number=70
# ✅ Training NSE: 0.542, Validation NSE: 0.398
#    Training RMSE: 29.420, Validation RMSE: 34.861
#    Params: mu=1.078, lambda=5.932
#
# === Station 21008 ===, Number=71
# ✅ Training NSE: 0.531, Validation NSE: 0.484
#    Training RMSE: 18.680, Validation RMSE: 23.466
#    Params: mu=1.081, lambda=5.920
#
# === Station 21009 ===, Number=72
# ✅ Training NSE: 0.428, Validation NSE: 0.394
#    Training RMSE: 68.736, Validation RMSE: 76.309
#    Params: mu=0.992, lambda=2.717
#
# === Station 21011 ===, Number=73
# ✅ Training NSE: 0.722, Validation NSE: 0.609
#    Training RMSE: 3.900, Validation RMSE: 4.687
#    Params: mu=1.323, lambda=25.469
#
# === Station 21012 ===, Number=74
# ✅ Training NSE: 0.572, Validation NSE: 0.467
#    Training RMSE: 8.360, Validation RMSE: 9.847
#    Params: mu=1.225, lambda=15.437
#
# === Station 21013 ===, Number=75
# ✅ Training NSE: 0.670, Validation NSE: 0.583
#    Training RMSE: 2.727, Validation RMSE: 3.132
#    Params: mu=1.279, lambda=19.075
#
# === Station 21015 ===, Number=76
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 ===, Number=77
# ✅ Training NSE: 0.464, Validation NSE: 0.527
#    Training RMSE: 1.449, Validation RMSE: 1.569
#    Params: mu=1.524, lambda=27.239
#
# === Station 21017 ===, Number=78
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 ===, Number=79
# ✅ Training NSE: 0.706, Validation NSE: 0.600
#    Training RMSE: 2.010, Validation RMSE: 2.448
#    Params: mu=1.371, lambda=23.028
#
# === Station 21022 ===, Number=80
# ✅ Training NSE: 0.547, Validation NSE: 0.403
#    Training RMSE: 6.450, Validation RMSE: 9.695
#    Params: mu=1.158, lambda=9.427
#
# === Station 21023 ===, Number=81
# ✅ Training NSE: 0.298, Validation NSE: 0.375
#    Training RMSE: 2.189, Validation RMSE: 2.559
#    Params: mu=1.428, lambda=24.437
#
# === Station 21024 ===, Number=82
# ✅ Training NSE: 0.494, Validation NSE: 0.434
#    Training RMSE: 2.626, Validation RMSE: 3.067
#    Params: mu=1.418, lambda=23.135
#
# === Station 21026 ===, Number=83
# ✅ Training NSE: 0.206, Validation NSE: 0.147
#    Training RMSE: 2.166, Validation RMSE: 2.887
#    Params: mu=2.207, lambda=99.424
#
# === Station 21027 ===, Number=84
# ✅ Training NSE: 0.494, Validation NSE: 0.425
#    Training RMSE: 2.154, Validation RMSE: 2.810
#    Params: mu=1.373, lambda=20.785
#
# === Station 22001 ===, Number=85
# ✅ Training NSE: 0.590, Validation NSE: 0.497
#    Training RMSE: 8.252, Validation RMSE: 11.376
#    Params: mu=1.158, lambda=6.722
#
# === Station 22006 ===, Number=86
# ✅ Training NSE: 0.586, Validation NSE: 0.529
#    Training RMSE: 2.662, Validation RMSE: 3.629
#    Params: mu=1.283, lambda=12.151
#
# === Station 22007 ===, Number=87
# ✅ Training NSE: 0.525, Validation NSE: 0.455
#    Training RMSE: 4.171, Validation RMSE: 5.603
#    Params: mu=1.258, lambda=10.945
#
# === Station 22009 ===, Number=88
# ✅ Training NSE: 0.578, Validation NSE: 0.469
#    Training RMSE: 5.486, Validation RMSE: 7.586
#    Params: mu=1.222, lambda=10.155
#
# === Station 23001 ===, Number=89
# ✅ Training NSE: 0.425, Validation NSE: 0.199
#    Training RMSE: 43.682, Validation RMSE: 52.950
#    Params: mu=1.056, lambda=3.288
#
# === Station 23004 ===, Number=90
# ✅ Training NSE: 0.371, Validation NSE: 0.325
#    Training RMSE: 21.947, Validation RMSE: 22.443
#    Params: mu=1.149, lambda=7.399
#
# === Station 23006 ===, Number=91
# ✅ Training NSE: 0.348, Validation NSE: 0.321
#    Training RMSE: 11.973, Validation RMSE: 13.105
#    Params: mu=1.257, lambda=15.867
#
# === Station 23007 ===, Number=92
# ✅ Training NSE: 0.466, Validation NSE: 0.447
#    Training RMSE: 2.400, Validation RMSE: 3.323
#    Params: mu=1.394, lambda=23.977
#
# === Station 23008 ===, Number=93
# ✅ Training NSE: 0.559, Validation NSE: 0.433
#    Training RMSE: 6.297, Validation RMSE: 8.720
#    Params: mu=1.234, lambda=9.898
#
# === Station 23011 ===, Number=94
# ✅ Training NSE: -0.007, Validation NSE: -0.002
#    Training RMSE: 2.856, Validation RMSE: 3.112
#    Params: mu=3.539, lambda=48.197
#
# === Station 23016 ===, Number=95
# ✅ Training NSE: -0.144, Validation NSE: 0.068
#    Training RMSE: 0.677, Validation RMSE: 0.817
#    Params: mu=8.531, lambda=65.703
#
# === Station 24001 ===, Number=96
# ✅ Training NSE: 0.565, Validation NSE: 0.423
#    Training RMSE: 10.941, Validation RMSE: 14.476
#    Params: mu=1.151, lambda=6.956
#
# === Station 24003 ===, Number=97
# ✅ Training NSE: 0.429, Validation NSE: 0.351
#    Training RMSE: 5.187, Validation RMSE: 5.769
#    Params: mu=1.409, lambda=27.794
#
# === Station 24004 ===, Number=98
# ✅ Training NSE: 0.447, Validation NSE: 0.330
#    Training RMSE: 1.317, Validation RMSE: 1.657
#    Params: mu=1.727, lambda=48.301
#
# === Station 24005 ===, Number=99
# ✅ Training NSE: 0.509, Validation NSE: 0.374
#    Training RMSE: 1.826, Validation RMSE: 2.586
#    Params: mu=1.427, lambda=20.614
#
# === Station 25001 ===, Number=100
# ✅ Training NSE: 0.456, Validation NSE: 0.398
#    Training RMSE: 19.676, Validation RMSE: 21.253
#    Params: mu=1.143, lambda=7.184
#
# === Station 25003 ===, Number=101
# ✅ Training NSE: -0.066, Validation NSE: -0.089
#    Training RMSE: 0.903, Validation RMSE: 0.966
#    Params: mu=10.000, lambda=352.931
#
# === Station 25006 ===, Number=102
# ✅ Training NSE: 0.392, Validation NSE: 0.370
#    Training RMSE: 3.281, Validation RMSE: 3.394
#    Params: mu=1.518, lambda=31.551
#
# === Station 25012 ===, Number=103
# ✅ Training NSE: 0.013, Validation NSE: -0.062
#    Training RMSE: 1.564, Validation RMSE: 1.534
#    Params: mu=10.000, lambda=219.241
#
# === Station 25020 ===, Number=104
# ✅ Training NSE: 0.441, Validation NSE: 0.398
#    Training RMSE: 1.138, Validation RMSE: 1.282
#    Params: mu=1.645, lambda=25.724
#
# === Station 25021 ===, Number=105
# ✅ Training NSE: -0.038, Validation NSE: 0.069
#    Training RMSE: 0.680, Validation RMSE: 0.838
#    Params: mu=9.179, lambda=66.220
#
# === Station 25029 ===, Number=106
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 ===, Number=107
# ✅ Training NSE: -0.305, Validation NSE: -0.435
#    Training RMSE: 0.524, Validation RMSE: 0.636
#    Params: mu=10.000, lambda=455.862
#
# === Station 26005 ===, Number=108
# ✅ Training NSE: -1.828, Validation NSE: -0.725
#    Training RMSE: 0.677, Validation RMSE: 0.771
#    Params: mu=9.800, lambda=95.229
#
# === Station 26006 ===, Number=109
# ✅ Training NSE: -0.348, Validation NSE: -0.338
#    Training RMSE: 0.751, Validation RMSE: 0.951
#    Params: mu=9.882, lambda=104.905
#
# === Station 26008 ===, Number=110
# ✅ Training NSE: -8.565, Validation NSE: -4.409
#    Training RMSE: 0.558, Validation RMSE: 0.489
#    Params: mu=10.000, lambda=111.667
#
# === Station 26009 ===, Number=111
# ✅ Training NSE: 0.549, Validation NSE: 0.506
#    Training RMSE: 1.170, Validation RMSE: 1.234
#    Params: mu=1.200, lambda=97.152
#
# === Station 27001 ===, Number=112
# ✅ Training NSE: 0.721, Validation NSE: 0.641
#    Training RMSE: 5.751, Validation RMSE: 7.857
#    Params: mu=1.181, lambda=9.549
#
# === Station 27002 ===, Number=113
# ✅ Training NSE: 0.676, Validation NSE: 0.524
#    Training RMSE: 12.892, Validation RMSE: 18.166
#    Params: mu=1.149, lambda=7.404
#
# === Station 27003 ===, Number=114
# ✅ Training NSE: 0.584, Validation NSE: 0.501
#    Training RMSE: 24.781, Validation RMSE: 28.273
#    Params: mu=1.042, lambda=4.159
#
# === Station 27006 ===, Number=115
# ✅ Training NSE: 0.625, Validation NSE: 0.584
#    Training RMSE: 4.132, Validation RMSE: 4.223
#    Params: mu=1.266, lambda=16.569
#
# === Station 27007 ===, Number=116
# ✅ Training NSE: 0.662, Validation NSE: 0.607
#    Training RMSE: 18.238, Validation RMSE: 19.923
#    Params: mu=1.122, lambda=6.134
#
# === Station 27009 ===, Number=117
# ✅ Training NSE: 0.566, Validation NSE: 0.204
#    Training RMSE: 40.363, Validation RMSE: 55.219
#    Params: mu=0.995, lambda=3.343
#
# === Station 27021 ===, Number=118
# ✅ Training NSE: 0.606, Validation NSE: 0.518
#    Training RMSE: 11.845, Validation RMSE: 12.478
#    Params: mu=1.067, lambda=5.356
#
# === Station 27023 ===, Number=119
# ✅ Training NSE: 0.466, Validation NSE: 0.481
#    Training RMSE: 1.800, Validation RMSE: 1.463
#    Params: mu=1.546, lambda=21.991
#
# === Station 27025 ===, Number=120
# ✅ Training NSE: 0.641, Validation NSE: 0.536
#    Training RMSE: 3.017, Validation RMSE: 3.232
#    Params: mu=1.227, lambda=11.459
#
# === Station 27026 ===, Number=121
# ✅ Training NSE: 0.549, Validation NSE: 0.509
#    Training RMSE: 1.981, Validation RMSE: 1.917
#    Params: mu=1.400, lambda=21.196
#
# === Station 27029 ===, Number=122
# ✅ Training NSE: 0.647, Validation NSE: 0.622
#    Training RMSE: 5.935, Validation RMSE: 6.308
#    Params: mu=1.245, lambda=16.849
#
# === Station 27030 ===, Number=123
# ✅ Training NSE: 0.697, Validation NSE: 0.609
#    Training RMSE: 2.243, Validation RMSE: 2.660
#    Params: mu=1.229, lambda=13.739
#
# === Station 27032 ===, Number=124
# ✅ Training NSE: -5.884, Validation NSE: -4.282
#    Training RMSE: 0.639, Validation RMSE: 0.596
#    Params: mu=10.000, lambda=310.521
#
# === Station 27034 ===, Number=125
# ✅ Training NSE: 0.556, Validation NSE: 0.500
#    Training RMSE: 16.369, Validation RMSE: 17.621
#    Params: mu=1.190, lambda=11.200
#
# === Station 27035 ===, Number=126
# ✅ Training NSE: 0.747, Validation NSE: 0.709
#    Training RMSE: 4.906, Validation RMSE: 5.503
#    Params: mu=1.235, lambda=14.659
#
# === Station 27038 ===, Number=127
# ✅ Training NSE: -1.862, Validation NSE: -0.422
#    Training RMSE: 0.391, Validation RMSE: 0.468
#    Params: mu=10.000, lambda=1000.000
#
# === Station 27041 ===, Number=128
# ✅ Training NSE: 0.455, Validation NSE: 0.342
#    Training RMSE: 10.321, Validation RMSE: 12.212
#    Params: mu=0.956, lambda=14.057
#
# === Station 27042 ===, Number=129
# ✅ Training NSE: 0.446, Validation NSE: 0.410
#    Training RMSE: 0.784, Validation RMSE: 0.850
#    Params: mu=2.054, lambda=63.474
#
# === Station 27043 ===, Number=130
# ✅ Training NSE: 0.527, Validation NSE: 0.513
#    Training RMSE: 13.303, Validation RMSE: 14.227
#    Params: mu=1.218, lambda=13.214
#
# === Station 27047 ===, Number=131
# ✅ Training NSE: -0.055, Validation NSE: -0.057
#    Training RMSE: 0.976, Validation RMSE: 0.964
#    Params: mu=10.000, lambda=408.089
#
# === Station 27049 ===, Number=132
# ✅ Training NSE: 0.683, Validation NSE: 0.651
#    Training RMSE: 2.010, Validation RMSE: 2.329
#    Params: mu=1.250, lambda=23.179
#
# === Station 27051 ===, Number=133
# ✅ Training NSE: -9.590, Validation NSE: -7.350
#    Training RMSE: 0.633, Validation RMSE: 0.621
#    Params: mu=10.000, lambda=122.838
#
# === Station 27062 ===, Number=134
# ✅ Training NSE: 0.779, Validation NSE: 0.764
#    Training RMSE: 5.009, Validation RMSE: 5.362
#    Params: mu=1.157, lambda=9.975
#
# === Station 27064 ===, Number=135
# ✅ Training NSE: 0.080, Validation NSE: 0.123
#    Training RMSE: 0.752, Validation RMSE: 0.854
#    Params: mu=2.615, lambda=39.344
#
# === Station 27065 ===, Number=136
# ✅ Training NSE: 0.560, Validation NSE: 0.548
#    Training RMSE: 1.800, Validation RMSE: 1.814
#    Params: mu=1.597, lambda=50.739
#
# === Station 27071 ===, Number=137
# ✅ Training NSE: 0.620, Validation NSE: 0.433
#    Training RMSE: 14.955, Validation RMSE: 21.233
#    Params: mu=1.044, lambda=5.000
#
# === Station 27073 ===, Number=138
# ✅ Training NSE: -6.851, Validation NSE: -5.209
#    Training RMSE: 0.542, Validation RMSE: 0.570
#    Params: mu=10.000, lambda=155.686
#
# === Station 27077 ===, Number=139
# ✅ Training NSE: -0.070, Validation NSE: -0.189
#    Training RMSE: 0.771, Validation RMSE: 0.724
#    Params: mu=10.000, lambda=117.835
#
# === Station 27079 ===, Number=140
# ✅ Training NSE: 0.563, Validation NSE: 0.589
#    Training RMSE: 14.077, Validation RMSE: 13.824
#    Params: mu=1.100, lambda=6.198
#
# === Station 27080 ===, Number=141
# ✅ Training NSE: 0.560, Validation NSE: 0.486
#    Training RMSE: 12.450, Validation RMSE: 13.520
#    Params: mu=1.103, lambda=6.715
#
# === Station 27084 ===, Number=142
# ✅ Training NSE: 0.066, Validation NSE: 0.027
#    Training RMSE: 1.398, Validation RMSE: 1.382
#    Params: mu=8.119, lambda=84.876
#
# === Station 27087 ===, Number=143
# ✅ Training NSE: 0.787, Validation NSE: 0.772
#    Training RMSE: 1.275, Validation RMSE: 1.423
#    Params: mu=1.095, lambda=47.987
#
# === Station 27089 ===, Number=144
# ✅ Training NSE: 0.730, Validation NSE: 0.656
#    Training RMSE: 11.241, Validation RMSE: 13.108
#    Params: mu=1.139, lambda=7.437
#
# === Station 27090 ===, Number=145
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 ===, Number=146
# ✅ Training NSE: 0.352, Validation NSE: 0.270
#    Training RMSE: 2.791, Validation RMSE: 2.756
#    Params: mu=1.621, lambda=63.062
#
# === Station 28003 ===, Number=147
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 ===, Number=148
# ✅ Training NSE: 0.611, Validation NSE: 0.607
#    Training RMSE: 4.574, Validation RMSE: 4.234
#    Params: mu=1.193, lambda=15.652
#
# === Station 28009 ===, Number=149
# ✅ Training NSE: 0.141, Validation NSE: 0.306
#    Training RMSE: 69.553, Validation RMSE: 61.830
#    Params: mu=0.908, lambda=3.020
#
# === Station 28012 ===, Number=150
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 ===, Number=151
# ✅ Training NSE: 0.599, Validation NSE: 0.580
#    Training RMSE: 0.895, Validation RMSE: 0.932
#    Params: mu=1.220, lambda=51.181
#
# === Station 28018 ===, Number=152
# ✅ Training NSE: 0.579, Validation NSE: 0.614
#    Training RMSE: 9.166, Validation RMSE: 7.897
#    Params: mu=1.106, lambda=7.098
#
# === Station 28022 ===, Number=153
# ✅ Training NSE: 0.138, Validation NSE: 0.250
#    Training RMSE: 72.855, Validation RMSE: 63.409
#    Params: mu=0.892, lambda=3.051
#
# === Station 28023 ===, Number=154
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 ===, Number=155
# ✅ Training NSE: 0.567, Validation NSE: 0.632
#    Training RMSE: 3.114, Validation RMSE: 2.986
#    Params: mu=1.191, lambda=10.150
#
# === Station 28026 ===, Number=156
# ✅ Training NSE: 0.660, Validation NSE: 0.721
#    Training RMSE: 2.398, Validation RMSE: 2.579
#    Params: mu=1.212, lambda=10.256
#
# === Station 28031 ===, Number=157
# ✅ Training NSE: 0.559, Validation NSE: 0.582
#    Training RMSE: 2.822, Validation RMSE: 2.582
#    Params: mu=1.369, lambda=25.019
#
# === Station 28033 ===, Number=158
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 ===, Number=159
# ✅ Training NSE: 0.097, Validation NSE: 0.075
#    Training RMSE: 0.975, Validation RMSE: 1.259
#    Params: mu=2.737, lambda=67.116
#
# === Station 28040 ===, Number=160
# ✅ Training NSE: 0.085, Validation NSE: 0.010
#    Training RMSE: 0.876, Validation RMSE: 0.778
#    Params: mu=7.591, lambda=71.170
#
# === Station 28043 ===, Number=161
# ✅ Training NSE: 0.707, Validation NSE: 0.696
#    Training RMSE: 4.296, Validation RMSE: 4.101
#    Params: mu=1.242, lambda=18.488
#
# === Station 28044 ===, Number=162
# ✅ Training NSE: -13.085, Validation NSE: -7.886
#    Training RMSE: 0.463, Validation RMSE: 0.469
#    Params: mu=10.000, lambda=142.912
#
# === Station 28046 ===, Number=163
# ✅ Training NSE: 0.717, Validation NSE: 0.664
#    Training RMSE: 0.779, Validation RMSE: 0.772
#    Params: mu=1.659, lambda=66.469
#
# === Station 28048 ===, Number=164
# ✅ Training NSE: 0.502, Validation NSE: 0.458
#    Training RMSE: 1.374, Validation RMSE: 1.716
#    Params: mu=1.585, lambda=27.673
#
# === Station 28050 ===, Number=165
# ✅ Training NSE: 0.505, Validation NSE: 0.451
#    Training RMSE: 0.475, Validation RMSE: 0.602
#    Params: mu=1.988, lambda=50.872
#
# === Station 28052 ===, Number=166
# ✅ Training NSE: 0.593, Validation NSE: 0.582
#    Training RMSE: 0.807, Validation RMSE: 1.031
#    Params: mu=1.660, lambda=34.759
#
# === Station 28055 ===, Number=167
# ✅ Training NSE: 0.027, Validation NSE: 0.003
#    Training RMSE: 0.859, Validation RMSE: 0.842
#    Params: mu=9.552, lambda=94.132
#
# === Station 28056 ===, Number=168
# ✅ Training NSE: 0.399, Validation NSE: 0.357
#    Training RMSE: 0.830, Validation RMSE: 0.884
#    Params: mu=1.924, lambda=33.708
#
# === Station 28060 ===, Number=169
# ✅ Training NSE: -10.901, Validation NSE: -5.083
#    Training RMSE: 0.566, Validation RMSE: 0.541
#    Params: mu=10.000, lambda=90.784
#
# === Station 28066 ===, Number=170
# ✅ Training NSE: 0.337, Validation NSE: 0.325
#    Training RMSE: 0.987, Validation RMSE: 1.280
#    Params: mu=1.938, lambda=35.458
#
# === Station 28067 ===, Number=171
# ✅ Training NSE: 0.646, Validation NSE: 0.605
#    Training RMSE: 11.148, Validation RMSE: 12.287
#    Params: mu=1.080, lambda=7.725
#
# === Station 28072 ===, Number=172
# ✅ Training NSE: -1.391, Validation NSE: -1.000
#    Training RMSE: 0.505, Validation RMSE: 0.556
#    Params: mu=9.977, lambda=110.242
#
# === Station 28074 ===, Number=173
# ✅ Training NSE: 0.373, Validation NSE: 0.533
#    Training RMSE: 9.860, Validation RMSE: 9.107
#    Params: mu=1.015, lambda=5.944
#
# === Station 28080 ===, Number=174
# ✅ Training NSE: -0.025, Validation NSE: -0.019
#    Training RMSE: 9.709, Validation RMSE: 11.562
#    Params: mu=0.763, lambda=879.870
#
# === Station 28081 ===, Number=175
# ✅ Training NSE: 0.256, Validation NSE: 0.280
#    Training RMSE: 1.600, Validation RMSE: 1.712
#    Params: mu=1.463, lambda=26.942
#
# === Station 28082 ===, Number=176
# ✅ Training NSE: 0.617, Validation NSE: 0.627
#    Training RMSE: 1.108, Validation RMSE: 1.180
#    Params: mu=1.459, lambda=19.957
#
# === Station 28085 ===, Number=177
# ✅ Training NSE: 0.661, Validation NSE: 0.593
#    Training RMSE: 9.734, Validation RMSE: 10.610
#    Params: mu=1.088, lambda=9.506
#
# === Station 28091 ===, Number=178
# ✅ Training NSE: 0.628, Validation NSE: 0.633
#    Training RMSE: 0.812, Validation RMSE: 0.761
#    Params: mu=1.442, lambda=30.989
#
# === Station 28093 ===, Number=179
# ✅ Training NSE: 0.421, Validation NSE: 0.543
#    Training RMSE: 8.657, Validation RMSE: 7.996
#    Params: mu=1.033, lambda=6.059
#
# === Station 28115 ===, Number=180
# ✅ Training NSE: -0.502, Validation NSE: -0.384
#    Training RMSE: 0.409, Validation RMSE: 0.376
#    Params: mu=10.000, lambda=797.685
#
# === Station 28116 ===, Number=181
# ⚠️ Too many missing values (28.2%)
#
# === Station 28117 ===, Number=182
# ⚠️ Too many missing values (28.0%)
#
# === Station 29002 ===, Number=183
# ✅ Training NSE: -0.711, Validation NSE: -0.903
#    Training RMSE: 0.479, Validation RMSE: 0.515
#    Params: mu=10.000, lambda=137.726
#
# === Station 29003 ===, Number=184
# ✅ Training NSE: -1.363, Validation NSE: -1.303
#    Training RMSE: 0.481, Validation RMSE: 0.534
#    Params: mu=10.000, lambda=108.695
#
# === Station 29005 ===, Number=185
# ✅ Training NSE: 0.089, Validation NSE: 0.151
#    Training RMSE: 0.807, Validation RMSE: 0.998
#    Params: mu=2.757, lambda=37.916
#
# === Station 29009 ===, Number=186
# ✅ Training NSE: -6.628, Validation NSE: -6.225
#    Training RMSE: 0.569, Validation RMSE: 0.594
#    Params: mu=10.000, lambda=81.710
#
# === Station 30001 ===, Number=187
# ✅ Training NSE: 0.580, Validation NSE: 0.606
#    Training RMSE: 1.321, Validation RMSE: 1.330
#    Params: mu=1.237, lambda=29.973
#
# === Station 30004 ===, Number=188
# ✅ Training NSE: -0.188, Validation NSE: -0.146
#    Training RMSE: 0.557, Validation RMSE: 0.630
#    Params: mu=8.570, lambda=89.271
#
# === Station 30005 ===, Number=189
# ⚠️ Too many missing values (24.0%)
#
# === Station 30011 ===, Number=190
# ✅ Training NSE: -1.838, Validation NSE: -1.279
#    Training RMSE: 0.528, Validation RMSE: 0.531
#    Params: mu=10.000, lambda=109.394
#
# === Station 30012 ===, Number=191
# ✅ Training NSE: -1.531, Validation NSE: -0.935
#    Training RMSE: 0.590, Validation RMSE: 0.557
#    Params: mu=10.000, lambda=80.232
#
# === Station 30014 ===, Number=192
# ✅ Training NSE: -18.620, Validation NSE: -17.500
#    Training RMSE: 0.620, Validation RMSE: 0.608
#    Params: mu=10.000, lambda=71.222
#
# === Station 30015 ===, Number=193
# ✅ Training NSE: -4.958, Validation NSE: -5.890
#    Training RMSE: 0.533, Validation RMSE: 0.541
#    Params: mu=10.000, lambda=134.859
#
# === Station 3003 ===, Number=194
# ✅ Training NSE: 0.332, Validation NSE: 0.356
#    Training RMSE: 18.709, Validation RMSE: 17.479
#    Params: mu=1.299, lambda=23.887
#
# === Station 31002 ===, Number=195
# ✅ Training NSE: 0.465, Validation NSE: 0.382
#    Training RMSE: 1.376, Validation RMSE: 1.462
#    Params: mu=1.458, lambda=25.623
#
# === Station 31006 ===, Number=196
# ✅ Training NSE: -0.578, Validation NSE: -0.777
#    Training RMSE: 0.501, Validation RMSE: 0.541
#    Params: mu=10.000, lambda=192.884
#
# === Station 31010 ===, Number=197
# ✅ Training NSE: 0.119, Validation NSE: 0.007
#    Training RMSE: 0.686, Validation RMSE: 0.767
#    Params: mu=2.591, lambda=48.458
#
# === Station 31021 ===, Number=198
# ✅ Training NSE: 0.550, Validation NSE: 0.559
#    Training RMSE: 1.734, Validation RMSE: 1.994
#    Params: mu=1.365, lambda=15.358
#
# === Station 31023 ===, Number=199
# ✅ Training NSE: -99.608, Validation NSE: -129.753
#    Training RMSE: 0.655, Validation RMSE: 0.646
#    Params: mu=10.000, lambda=113.005
#
# === Station 31025 ===, Number=200
# ✅ Training NSE: -1.401, Validation NSE: -1.402
#    Training RMSE: 0.605, Validation RMSE: 0.637
#    Params: mu=10.000, lambda=98.666
#
# === Station 32003 ===, Number=201
# ✅ Training NSE: 0.129, Validation NSE: 0.099
#    Training RMSE: 0.901, Validation RMSE: 0.913
#    Params: mu=2.516, lambda=38.594
#
# === Station 32004 ===, Number=202
# ✅ Training NSE: 0.602, Validation NSE: 0.595
#    Training RMSE: 1.176, Validation RMSE: 1.608
#    Params: mu=1.432, lambda=21.708
#
# === Station 32006 ===, Number=203
# ✅ Training NSE: 0.559, Validation NSE: 0.611
#    Training RMSE: 1.229, Validation RMSE: 1.290
#    Params: mu=1.428, lambda=24.678
#
# === Station 32008 ===, Number=204
# ✅ Training NSE: 0.299, Validation NSE: 0.335
#    Training RMSE: 0.778, Validation RMSE: 0.845
#    Params: mu=2.078, lambda=41.541
#
# === Station 33006 ===, Number=205
# ✅ Training NSE: 0.688, Validation NSE: 0.644
#    Training RMSE: 0.792, Validation RMSE: 0.881
#    Params: mu=1.237, lambda=72.320
#
# === Station 33007 ===, Number=206
# ✅ Training NSE: 0.452, Validation NSE: 0.253
#    Training RMSE: 0.481, Validation RMSE: 0.505
#    Params: mu=1.932, lambda=143.729
#
# === Station 33012 ===, Number=207
# ✅ Training NSE: 0.336, Validation NSE: 0.387
#    Training RMSE: 1.213, Validation RMSE: 1.381
#    Params: mu=1.747, lambda=23.357
#
# === Station 33013 ===, Number=208
# ✅ Training NSE: 0.361, Validation NSE: 0.151
#    Training RMSE: 0.712, Validation RMSE: 0.734
#    Params: mu=1.843, lambda=56.650
#
# === Station 33014 ===, Number=209
# ✅ Training NSE: 0.558, Validation NSE: 0.500
#    Training RMSE: 0.713, Validation RMSE: 0.647
#    Params: mu=1.513, lambda=48.864
#
# === Station 33018 ===, Number=210
# ✅ Training NSE: 0.492, Validation NSE: 0.487
#    Training RMSE: 1.066, Validation RMSE: 1.349
#    Params: mu=1.636, lambda=27.343
#
# === Station 33019 ===, Number=211
# ✅ Training NSE: 0.740, Validation NSE: 0.569
#    Training RMSE: 0.851, Validation RMSE: 0.920
#    Params: mu=1.186, lambda=49.961
#
# === Station 33020 ===, Number=212
# ⚠️ Too many missing values (17.1%)
#
# === Station 33021 ===, Number=213
# ✅ Training NSE: 0.516, Validation NSE: 0.465
#    Training RMSE: 0.903, Validation RMSE: 1.065
#    Params: mu=1.364, lambda=55.916
#
# === Station 33022 ===, Number=214
# ✅ Training NSE: 0.553, Validation NSE: 0.514
#    Training RMSE: 1.742, Validation RMSE: 2.083
#    Params: mu=1.106, lambda=30.697
#
# === Station 33023 ===, Number=215
# ✅ Training NSE: -1.147, Validation NSE: -2.608
#    Training RMSE: 0.570, Validation RMSE: 0.579
#    Params: mu=8.834, lambda=61.124
#
# === Station 33024 ===, Number=216
# ✅ Training NSE: 0.390, Validation NSE: 0.338
#    Training RMSE: 0.685, Validation RMSE: 0.666
#    Params: mu=1.842, lambda=58.115
#
# === Station 33026 ===, Number=217
# ✅ Training NSE: 0.501, Validation NSE: 0.538
#    Training RMSE: 13.204, Validation RMSE: 14.788
#    Params: mu=0.950, lambda=5.598
#
# === Station 33028 ===, Number=218
# ✅ Training NSE: 0.532, Validation NSE: 0.526
#    Training RMSE: 0.535, Validation RMSE: 0.558
#    Params: mu=1.818, lambda=48.755
#
# === Station 33029 ===, Number=219
# ✅ Training NSE: -0.509, Validation NSE: -0.654
#    Training RMSE: 0.546, Validation RMSE: 0.546
#    Params: mu=9.966, lambda=84.022
#
# === Station 33031 ===, Number=220
# ✅ Training NSE: 0.056, Validation NSE: 0.208
#    Training RMSE: 0.825, Validation RMSE: 1.038
#    Params: mu=3.976, lambda=36.655
#
# === Station 33032 ===, Number=221
# ✅ Training NSE: -10.575, Validation NSE: -23.837
#    Training RMSE: 0.525, Validation RMSE: 0.567
#    Params: mu=10.000, lambda=102.813
#
# === Station 33033 ===, Number=222
# ✅ Training NSE: 0.027, Validation NSE: 0.106
#    Training RMSE: 0.416, Validation RMSE: 0.426
#    Params: mu=3.025, lambda=157.069
#
# === Station 33034 ===, Number=223
# ✅ Training NSE: 0.758, Validation NSE: 0.637
#    Training RMSE: 1.595, Validation RMSE: 1.557
#    Params: mu=0.994, lambda=36.179
#
# === Station 33035 ===, Number=224
# ✅ Training NSE: 0.539, Validation NSE: 0.380
#    Training RMSE: 9.524, Validation RMSE: 10.243
#    Params: mu=0.838, lambda=15.568
#
# === Station 33039 ===, Number=225
# ✅ Training NSE: 0.544, Validation NSE: 0.529
#    Training RMSE: 9.638, Validation RMSE: 10.686
#    Params: mu=0.963, lambda=7.249
#
# === Station 33053 ===, Number=226
# ⚠️ Too many missing values (16.0%)
#
# === Station 33054 ===, Number=227
# ✅ Training NSE: -1.849, Validation NSE: -2.363
#    Training RMSE: 0.448, Validation RMSE: 0.435
#    Params: mu=10.000, lambda=115.991
#
# === Station 33058 ===, Number=228
# ✅ Training NSE: 0.625, Validation NSE: 0.600
#    Training RMSE: 1.601, Validation RMSE: 2.116
#    Params: mu=1.330, lambda=15.640
#
# === Station 34002 ===, Number=229
# ✅ Training NSE: 0.394, Validation NSE: 0.407
#    Training RMSE: 0.774, Validation RMSE: 0.659
#    Params: mu=1.838, lambda=38.753
#
# === Station 34003 ===, Number=230
# ✅ Training NSE: 0.686, Validation NSE: 0.668
#    Training RMSE: 0.342, Validation RMSE: 0.344
#    Params: mu=1.896, lambda=66.291
#
# === Station 34004 ===, Number=231
# ✅ Training NSE: 0.630, Validation NSE: 0.625
#    Training RMSE: 1.615, Validation RMSE: 1.631
#    Params: mu=1.048, lambda=48.570
#
# === Station 34005 ===, Number=232
# ✅ Training NSE: -1.142, Validation NSE: -0.817
#    Training RMSE: 0.491, Validation RMSE: 0.522
#    Params: mu=10.000, lambda=77.866
#
# === Station 34006 ===, Number=233
# ✅ Training NSE: 0.537, Validation NSE: 0.575
#    Training RMSE: 2.054, Validation RMSE: 1.907
#    Params: mu=1.250, lambda=15.386
#
# === Station 34007 ===, Number=234
# ✅ Training NSE: 0.292, Validation NSE: 0.327
#    Training RMSE: 1.035, Validation RMSE: 1.156
#    Params: mu=1.743, lambda=29.393
#
# === Station 34008 ===, Number=235
# ✅ Training NSE: -8.262, Validation NSE: -8.776
#    Training RMSE: 0.434, Validation RMSE: 0.394
#    Params: mu=10.000, lambda=98.592
#
# === Station 34010 ===, Number=236
# ✅ Training NSE: 0.389, Validation NSE: 0.308
#    Training RMSE: 0.972, Validation RMSE: 0.951
#    Params: mu=1.655, lambda=31.102
#
# === Station 34011 ===, Number=237
# ✅ Training NSE: 0.314, Validation NSE: 0.275
#    Training RMSE: 0.533, Validation RMSE: 0.551
#    Params: mu=2.386, lambda=108.431
#
# === Station 34012 ===, Number=238
# ✅ Training NSE: -4.526, Validation NSE: -9.792
#    Training RMSE: 0.483, Validation RMSE: 0.489
#    Params: mu=10.000, lambda=107.485
#
# === Station 35003 ===, Number=239
# ✅ Training NSE: -0.166, Validation NSE: 0.102
#    Training RMSE: 0.761, Validation RMSE: 1.237
#    Params: mu=9.786, lambda=71.056
#
# === Station 35008 ===, Number=240
# ✅ Training NSE: 0.356, Validation NSE: 0.366
#    Training RMSE: 1.075, Validation RMSE: 1.037
#    Params: mu=1.698, lambda=24.134
#
# === Station 36003 ===, Number=241
# ✅ Training NSE: -1.504, Validation NSE: -1.537
#    Training RMSE: 0.551, Validation RMSE: 0.527
#    Params: mu=10.000, lambda=66.014
#
# === Station 36006 ===, Number=242
# ✅ Training NSE: 0.552, Validation NSE: 0.570
#    Training RMSE: 2.710, Validation RMSE: 2.519
#    Params: mu=1.132, lambda=14.454
#
# === Station 36009 ===, Number=243
# ✅ Training NSE: -2.519, Validation NSE: -2.191
#    Training RMSE: 0.591, Validation RMSE: 0.580
#    Params: mu=10.000, lambda=73.795
#
# === Station 36010 ===, Number=244
# ✅ Training NSE: -1.368, Validation NSE: -1.645
#    Training RMSE: 0.636, Validation RMSE: 0.620
#    Params: mu=10.000, lambda=62.911
#
# === Station 36011 ===, Number=245
# ✅ Training NSE: -0.707, Validation NSE: -0.554
#    Training RMSE: 0.604, Validation RMSE: 0.585
#    Params: mu=10.000, lambda=63.856
#
# === Station 36012 ===, Number=246
# ✅ Training NSE: 0.031, Validation NSE: 0.163
#    Training RMSE: 1.205, Validation RMSE: 0.896
#    Params: mu=2.342, lambda=43.159
#
# === Station 37001 ===, Number=247
# ✅ Training NSE: 0.680, Validation NSE: 0.726
#    Training RMSE: 1.785, Validation RMSE: 1.744
#    Params: mu=1.260, lambda=14.396
#
# === Station 37003 ===, Number=248
# ✅ Training NSE: -0.231, Validation NSE: 0.023
#    Training RMSE: 0.664, Validation RMSE: 0.902
#    Params: mu=9.879, lambda=58.609
#
# === Station 37005 ===, Number=249
# ✅ Training NSE: 0.548, Validation NSE: 0.591
#    Training RMSE: 1.192, Validation RMSE: 1.187
#    Params: mu=1.418, lambda=22.974
#
# === Station 37008 ===, Number=250
# ✅ Training NSE: 0.566, Validation NSE: 0.586
#    Training RMSE: 1.053, Validation RMSE: 1.107
#    Params: mu=1.464, lambda=24.573
#
# === Station 37009 ===, Number=251
# ✅ Training NSE: -0.186, Validation NSE: -0.209
#    Training RMSE: 0.566, Validation RMSE: 0.575
#    Params: mu=9.556, lambda=64.093
#
# === Station 37010 ===, Number=252
# ✅ Training NSE: 0.495, Validation NSE: 0.548
#    Training RMSE: 1.336, Validation RMSE: 1.530
#    Params: mu=1.374, lambda=21.352
#
# === Station 37011 ===, Number=253
# ✅ Training NSE: -0.028, Validation NSE: 0.093
#    Training RMSE: 0.732, Validation RMSE: 0.754
#    Params: mu=5.581, lambda=49.786
#
# === Station 37018 ===, Number=254
# ✅ Training NSE: -0.423, Validation NSE: -0.259
#    Training RMSE: 0.555, Validation RMSE: 0.618
#    Params: mu=9.968, lambda=89.601
#
# === Station 37019 ===, Number=255
# ✅ Training NSE: -0.421, Validation NSE: -0.350
#    Training RMSE: 0.626, Validation RMSE: 0.656
#    Params: mu=9.354, lambda=88.709
#
# === Station 37020 ===, Number=256
# ✅ Training NSE: 0.416, Validation NSE: 0.468
#    Training RMSE: 0.941, Validation RMSE: 1.271
#    Params: mu=1.728, lambda=27.519
#
# === Station 37031 ===, Number=257
# ✅ Training NSE: -0.097, Validation NSE: 0.044
#    Training RMSE: 0.770, Validation RMSE: 0.982
#    Params: mu=10.000, lambda=79.913
#
# === Station 37033 ===, Number=258
# ✅ Training NSE: -47.662, Validation NSE: -35.138
#    Training RMSE: 0.592, Validation RMSE: 0.651
#    Params: mu=10.000, lambda=74.202
#
# === Station 38001 ===, Number=259
# ✅ Training NSE: 0.526, Validation NSE: 0.616
#    Training RMSE: 4.111, Validation RMSE: 3.528
#    Params: mu=1.146, lambda=9.809
#
# === Station 38003 ===, Number=260
# ✅ Training NSE: -1.168, Validation NSE: -2.341
#    Training RMSE: 0.471, Validation RMSE: 0.433
#    Params: mu=10.000, lambda=215.294
#
# === Station 38004 ===, Number=261
# ✅ Training NSE: 0.170, Validation NSE: 0.169
#    Training RMSE: 0.838, Validation RMSE: 0.838
#    Params: mu=4.063, lambda=40.331
#
# === Station 38007 ===, Number=262
# ✅ Training NSE: -3.144, Validation NSE: -3.133
#    Training RMSE: 0.558, Validation RMSE: 0.566
#    Params: mu=9.642, lambda=82.619
#
# === Station 38012 ===, Number=263
# ✅ Training NSE: -7.885, Validation NSE: -11.925
#    Training RMSE: 0.601, Validation RMSE: 0.635
#    Params: mu=10.000, lambda=81.692
#
# === Station 38014 ===, Number=264
# ✅ Training NSE: -2.284, Validation NSE: -2.912
#    Training RMSE: 0.571, Validation RMSE: 0.587
#    Params: mu=9.767, lambda=97.016
#
# === Station 38017 ===, Number=265
# ✅ Training NSE: -79.815, Validation NSE: -181.603
#    Training RMSE: 0.625, Validation RMSE: 0.637
#    Params: mu=10.000, lambda=75.655
#
# === Station 38018 ===, Number=266
# ✅ Training NSE: 0.615, Validation NSE: 0.602
#    Training RMSE: 0.525, Validation RMSE: 0.466
#    Params: mu=1.556, lambda=104.461
#
# === Station 38021 ===, Number=267
# ✅ Training NSE: -0.737, Validation NSE: -0.693
#    Training RMSE: 0.623, Validation RMSE: 0.631
#    Params: mu=9.677, lambda=83.896
#
# === Station 38026 ===, Number=268
# ✅ Training NSE: -0.456, Validation NSE: -0.317
#    Training RMSE: 0.566, Validation RMSE: 0.625
#    Params: mu=10.000, lambda=69.238
#
# === Station 38029 ===, Number=269
# ✅ Training NSE: -1.567, Validation NSE: -2.354
#    Training RMSE: 0.618, Validation RMSE: 0.625
#    Params: mu=10.000, lambda=68.467
#
# === Station 38030 ===, Number=270
# ✅ Training NSE: 0.006, Validation NSE: 0.070
#    Training RMSE: 0.606, Validation RMSE: 0.604
#    Params: mu=6.071, lambda=55.038
#
# === Station 39001 ===, Number=271
# ✅ Training NSE: 0.521, Validation NSE: 0.299
#    Training RMSE: 49.945, Validation RMSE: 69.140
#    Params: mu=0.845, lambda=7.865
#
# === Station 39002 ===, Number=272
# ✅ Training NSE: 0.599, Validation NSE: 0.012
#    Training RMSE: 20.571, Validation RMSE: 39.074
#    Params: mu=0.877, lambda=8.365
#
# === Station 39004 ===, Number=273
# ✅ Training NSE: -8.342, Validation NSE: -8.321
#    Training RMSE: 0.578, Validation RMSE: 0.604
#    Params: mu=10.000, lambda=171.347
#
# === Station 39005 ===, Number=274
# ✅ Training NSE: -0.508, Validation NSE: -1.105
#    Training RMSE: 0.499, Validation RMSE: 0.504
#    Params: mu=10.000, lambda=164.688
#
# === Station 39006 ===, Number=275
# ✅ Training NSE: 0.844, Validation NSE: 0.861
#    Training RMSE: 1.025, Validation RMSE: 1.266
#    Params: mu=1.139, lambda=51.118
#
# === Station 39007 ===, Number=276
# ✅ Training NSE: 0.670, Validation NSE: 0.677
#    Training RMSE: 1.741, Validation RMSE: 2.058
#    Params: mu=1.274, lambda=19.200
#
# === Station 39008 ===, Number=277
# ✅ Training NSE: 0.715, Validation NSE: 0.392
#    Training RMSE: 8.460, Validation RMSE: 14.155
#    Params: mu=0.940, lambda=14.062
#
# === Station 39010 ===, Number=278
# ✅ Training NSE: 0.784, Validation NSE: 0.625
#    Training RMSE: 1.192, Validation RMSE: 1.316
#    Params: mu=1.014, lambda=91.178
#
# === Station 39011 ===, Number=279
# ✅ Training NSE: 0.703, Validation NSE: 0.713
#    Training RMSE: 1.486, Validation RMSE: 1.856
#    Params: mu=1.386, lambda=28.065
#
# === Station 39012 ===, Number=280
# ✅ Training NSE: 0.371, Validation NSE: 0.372
#    Training RMSE: 0.576, Validation RMSE: 0.639
#    Params: mu=1.978, lambda=82.124
#
# === Station 39014 ===, Number=281
# ✅ Training NSE: -0.883, Validation NSE: -1.772
#    Training RMSE: 0.529, Validation RMSE: 0.484
#    Params: mu=10.000, lambda=146.762
#
# === Station 39015 ===, Number=282
# ✅ Training NSE: -3.143, Validation NSE: -1.687
#    Training RMSE: 0.480, Validation RMSE: 0.521
#    Params: mu=10.000, lambda=144.592
#
# === Station 39016 ===, Number=283
# ✅ Training NSE: 0.751, Validation NSE: 0.517
#    Training RMSE: 3.561, Validation RMSE: 4.726
#    Params: mu=0.952, lambda=40.106
#
# === Station 39017 ===, Number=284
# ✅ Training NSE: -4.139, Validation NSE: -2.543
#    Training RMSE: 0.583, Validation RMSE: 0.636
#    Params: mu=10.000, lambda=67.795
#
# === Station 39019 ===, Number=285
# ✅ Training NSE: 0.575, Validation NSE: 0.606
#    Training RMSE: 0.712, Validation RMSE: 0.829
#    Params: mu=1.339, lambda=213.070
#
# === Station 39020 ===, Number=286
# ✅ Training NSE: 0.476, Validation NSE: 0.581
#    Training RMSE: 0.734, Validation RMSE: 0.830
#    Params: mu=1.684, lambda=154.065
#
# === Station 39021 ===, Number=287
# ✅ Training NSE: 0.678, Validation NSE: 0.648
#    Training RMSE: 2.284, Validation RMSE: 2.944
#    Params: mu=1.061, lambda=28.333
#
# === Station 39022 ===, Number=288
# ✅ Training NSE: 0.631, Validation NSE: 0.664
#    Training RMSE: 1.113, Validation RMSE: 1.200
#    Params: mu=1.402, lambda=33.874
#
# === Station 39023 ===, Number=289
# ✅ Training NSE: 0.278, Validation NSE: -0.047
#    Training RMSE: 0.401, Validation RMSE: 0.336
#    Params: mu=2.521, lambda=1000.000
#
# === Station 39025 ===, Number=290
# ✅ Training NSE: 0.641, Validation NSE: 0.626
#    Training RMSE: 1.264, Validation RMSE: 1.210
#    Params: mu=1.537, lambda=29.980
#
# === Station 39027 ===, Number=291
# ✅ Training NSE: -0.301, Validation NSE: -0.487
#    Training RMSE: 0.640, Validation RMSE: 0.717
#    Params: mu=10.000, lambda=247.056
#
# === Station 39028 ===, Number=292
# ✅ Training NSE: -0.646, Validation NSE: -0.726
#    Training RMSE: 0.575, Validation RMSE: 0.622
#    Params: mu=10.000, lambda=208.726
#
# === Station 39029 ===, Number=293
# ✅ Training NSE: -2.070, Validation NSE: -1.622
#    Training RMSE: 0.413, Validation RMSE: 0.446
#    Params: mu=10.000, lambda=193.712
#
# === Station 39034 ===, Number=294
# ✅ Training NSE: 0.782, Validation NSE: 0.675
#    Training RMSE: 1.811, Validation RMSE: 2.409
#    Params: mu=1.094, lambda=28.761
#
# === Station 39035 ===, Number=295
# ✅ Training NSE: 0.224, Validation NSE: 0.225
#    Training RMSE: 0.836, Validation RMSE: 0.731
#    Params: mu=2.303, lambda=141.044
#
# === Station 39036 ===, Number=296
# ✅ Training NSE: -242.904, Validation NSE: -306.862
#    Training RMSE: 0.609, Validation RMSE: 0.677
#    Params: mu=10.000, lambda=151.466
#
# === Station 39037 ===, Number=297
# ✅ Training NSE: 0.171, Validation NSE: 0.216
#    Training RMSE: 0.901, Validation RMSE: 0.941
#    Params: mu=2.400, lambda=163.010
#
# === Station 39042 ===, Number=298
# ✅ Training NSE: -0.003, Validation NSE: -0.001
#    Training RMSE: 0.769, Validation RMSE: 0.773
#    Params: mu=10.000, lambda=833.274
#
# === Station 39049 ===, Number=299
# ✅ Training NSE: -1.293, Validation NSE: -1.461
#    Training RMSE: 0.565, Validation RMSE: 0.603
#    Params: mu=9.608, lambda=94.893
#
# === Station 39052 ===, Number=300
# ✅ Training NSE: -0.173, Validation NSE: -0.174
#    Training RMSE: 0.623, Validation RMSE: 0.654
#    Params: mu=9.510, lambda=101.059
#
# === Station 39054 ===, Number=301
# ⚠️ Too many missing values (16.3%)
#
# === Station 39056 ===, Number=302
# ✅ Training NSE: -0.508, Validation NSE: -0.635
#    Training RMSE: 0.600, Validation RMSE: 0.657
#    Params: mu=10.000, lambda=138.881
#
# === Station 39061 ===, Number=303
# ✅ Training NSE: -59.627, Validation NSE: -54.803
#    Training RMSE: 0.596, Validation RMSE: 0.673
#    Params: mu=9.831, lambda=101.786
#
# === Station 39065 ===, Number=304
# ✅ Training NSE: -341.371, Validation NSE: -277.723
#    Training RMSE: 0.633, Validation RMSE: 0.632
#    Params: mu=10.000, lambda=106.540
#
# === Station 39069 ===, Number=305
# ✅ Training NSE: 0.677, Validation NSE: 0.645
#    Training RMSE: 2.264, Validation RMSE: 3.091
#    Params: mu=1.356, lambda=17.254
#
# === Station 39072 ===, Number=306
# ✅ Training NSE: 0.454, Validation NSE: 0.073
#    Training RMSE: 39.780, Validation RMSE: 61.177
# ...
#
# === Station 72005 ===, Number=573
# ✅ Training NSE: 0.436, Validation NSE: 0.391
#    Training RMSE: 12.131, Validation RMSE: 13.684
#    Params: mu=1.283, lambda=24.259
#
# === Station 72007 ===, Number=574
# ✅ Training NSE: 0.056, Validation NSE: 0.010
#    Training RMSE: 1.110, Validation RMSE: 1.198
#    Params: mu=10.000, lambda=155.558
#
# === Station 72009 ===, Number=575
# ✅ Training NSE: 0.448, Validation NSE: 0.472
#    Training RMSE: 5.656, Validation RMSE: 5.042
#    Params: mu=1.386, lambda=23.566
#
# === Station 72014 ===, Number=576
# ✅ Training NSE: 0.030, Validation NSE: 0.056
#    Training RMSE: 0.925, Validation RMSE: 1.032
#    Params: mu=10.000, lambda=140.338
#
# === Station 72015 ===, Number=577
# ✅ Training NSE: 0.382, Validation NSE: 0.359
#    Training RMSE: 8.309, Validation RMSE: 9.438
#    Params: mu=1.375, lambda=34.525
#
# === Station 73005 ===, Number=578
# ✅ Training NSE: 0.596, Validation NSE: 0.531
#    Training RMSE: 7.513, Validation RMSE: 9.238
#    Params: mu=1.303, lambda=26.863
#
# === Station 73009 ===, Number=579
# ✅ Training NSE: 0.339, Validation NSE: 0.306
#    Training RMSE: 2.146, Validation RMSE: 2.597
#    Params: mu=2.021, lambda=140.226
#
# === Station 73010 ===, Number=580
# ✅ Training NSE: 0.824, Validation NSE: 0.791
#    Training RMSE: 5.843, Validation RMSE: 7.096
#    Params: mu=1.266, lambda=41.641
#
# === Station 73011 ===, Number=581
# ✅ Training NSE: 0.477, Validation NSE: 0.411
#    Training RMSE: 2.452, Validation RMSE: 3.037
#    Params: mu=1.664, lambda=66.110
#
# === Station 73014 ===, Number=582
# ✅ Training NSE: 0.493, Validation NSE: 0.420
#    Training RMSE: 4.870, Validation RMSE: 5.829
#    Params: mu=1.624, lambda=84.558
#
# === Station 73015 ===, Number=583
# ✅ Training NSE: 0.095, Validation NSE: 0.011
#    Training RMSE: 1.139, Validation RMSE: 1.144
#    Params: mu=3.410, lambda=75.246
#
# === Station 74001 ===, Number=584
# ✅ Training NSE: 0.407, Validation NSE: 0.339
#    Training RMSE: 4.875, Validation RMSE: 6.017
#    Params: mu=1.547, lambda=62.167
#
# === Station 74005 ===, Number=585
# ✅ Training NSE: 0.647, Validation NSE: 0.606
#    Training RMSE: 3.248, Validation RMSE: 3.819
#    Params: mu=1.443, lambda=39.793
#
# === Station 74006 ===, Number=586
# ✅ Training NSE: -0.164, Validation NSE: -0.137
#    Training RMSE: 2.153, Validation RMSE: 2.826
#    Params: mu=10.000, lambda=120.097
#
# === Station 74007 ===, Number=587
# ✅ Training NSE: 0.386, Validation NSE: 0.348
#    Training RMSE: 4.424, Validation RMSE: 5.068
#    Params: mu=1.606, lambda=72.552
#
# === Station 75003 ===, Number=588
# ✅ Training NSE: 0.831, Validation NSE: 0.796
#    Training RMSE: 7.382, Validation RMSE: 9.169
#    Params: mu=1.225, lambda=33.003
#
# === Station 75004 ===, Number=589
# ✅ Training NSE: 0.705, Validation NSE: 0.612
#    Training RMSE: 3.343, Validation RMSE: 4.606
#    Params: mu=1.456, lambda=55.172
#
# === Station 75017 ===, Number=590
# ✅ Training NSE: 0.612, Validation NSE: 0.520
#    Training RMSE: 1.805, Validation RMSE: 2.364
#    Params: mu=1.516, lambda=35.412
#
# === Station 76003 ===, Number=591
# ✅ Training NSE: 0.763, Validation NSE: 0.706
#    Training RMSE: 9.283, Validation RMSE: 12.088
#    Params: mu=1.225, lambda=24.455
#
# === Station 76005 ===, Number=592
# ✅ Training NSE: 0.519, Validation NSE: 0.470
#    Training RMSE: 16.843, Validation RMSE: 18.076
#    Params: mu=1.175, lambda=9.883
#
# === Station 76007 ===, Number=593
# ✅ Training NSE: 0.559, Validation NSE: 0.487
#    Training RMSE: 42.742, Validation RMSE: 48.653
#    Params: mu=1.074, lambda=4.706
#
# === Station 76008 ===, Number=594
# ✅ Training NSE: 0.489, Validation NSE: 0.446
#    Training RMSE: 8.394, Validation RMSE: 10.581
#    Params: mu=1.229, lambda=9.791
#
# === Station 76011 ===, Number=595
# ✅ Training NSE: -74.360, Validation NSE: -78.118
#    Training RMSE: 0.718, Validation RMSE: 0.739
#    Params: mu=10.000, lambda=209.568
#
# === Station 76014 ===, Number=596
# ✅ Training NSE: 0.336, Validation NSE: 0.345
#    Training RMSE: 3.932, Validation RMSE: 3.939
#    Params: mu=1.607, lambda=58.942
#
# === Station 77002 ===, Number=597
# ✅ Training NSE: 0.511, Validation NSE: 0.453
#    Training RMSE: 16.108, Validation RMSE: 18.660
#    Params: mu=1.188, lambda=11.808
#
# === Station 77003 ===, Number=598
# ✅ Training NSE: 0.397, Validation NSE: 0.340
#    Training RMSE: 12.358, Validation RMSE: 14.503
#    Params: mu=1.246, lambda=13.675
#
# === Station 77004 ===, Number=599
# ✅ Training NSE: 0.375, Validation NSE: 0.329
#    Training RMSE: 2.076, Validation RMSE: 2.466
#    Params: mu=1.732, lambda=44.634
#
# === Station 78003 ===, Number=600
# ✅ Training NSE: 0.603, Validation NSE: 0.578
#    Training RMSE: 23.066, Validation RMSE: 26.371
#    Params: mu=1.117, lambda=7.003
#
# === Station 78004 ===, Number=601
# ✅ Training NSE: 0.429, Validation NSE: 0.408
#    Training RMSE: 3.381, Validation RMSE: 3.904
#    Params: mu=1.581, lambda=44.854
#
# === Station 78006 ===, Number=602
# ✅ Training NSE: 0.585, Validation NSE: 0.502
#    Training RMSE: 7.002, Validation RMSE: 8.563
#    Params: mu=1.316, lambda=25.577
#
# === Station 79002 ===, Number=603
# ✅ Training NSE: 0.520, Validation NSE: 0.473
#    Training RMSE: 25.155, Validation RMSE: 27.624
#    Params: mu=1.153, lambda=9.623
#
# === Station 79003 ===, Number=604
# ✅ Training NSE: 0.584, Validation NSE: 0.610
#    Training RMSE: 5.872, Validation RMSE: 5.310
#    Params: mu=1.377, lambda=27.020
#
# === Station 79004 ===, Number=605
# ✅ Training NSE: 0.485, Validation NSE: 0.439
#    Training RMSE: 5.962, Validation RMSE: 6.923
#    Params: mu=1.405, lambda=34.353
#
# === Station 79005 ===, Number=606
# ✅ Training NSE: 0.626, Validation NSE: 0.584
#    Training RMSE: 6.692, Validation RMSE: 7.572
#    Params: mu=1.290, lambda=19.871
#
# === Station 79006 ===, Number=607
# ✅ Training NSE: 0.509, Validation NSE: 0.492
#    Training RMSE: 17.302, Validation RMSE: 17.267
#    Params: mu=1.210, lambda=13.517
#
# === Station 80001 ===, Number=608
# ✅ Training NSE: 0.648, Validation NSE: 0.609
#    Training RMSE: 4.728, Validation RMSE: 5.480
#    Params: mu=1.325, lambda=22.065
#
# === Station 80002 ===, Number=609
# ✅ Training NSE: 0.649, Validation NSE: 0.586
#    Training RMSE: 24.166, Validation RMSE: 28.315
#    Params: mu=1.135, lambda=13.092
#
# === Station 80003 ===, Number=610
# ✅ Training NSE: -0.413, Validation NSE: -0.331
#    Training RMSE: 0.695, Validation RMSE: 0.754
#    Params: mu=10.000, lambda=935.431
#
# === Station 80004 ===, Number=611
# ✅ Training NSE: -3.271, Validation NSE: -2.986
#    Training RMSE: 0.654, Validation RMSE: 0.691
#    Params: mu=10.000, lambda=875.849
#
# === Station 80005 ===, Number=612
# ✅ Training NSE: -7.513, Validation NSE: -6.248
#    Training RMSE: 0.654, Validation RMSE: 0.678
#    Params: mu=10.000, lambda=896.927
#
# === Station 80006 ===, Number=613
# ✅ Training NSE: -0.327, Validation NSE: -0.389
#    Training RMSE: 1.187, Validation RMSE: 1.298
#    Params: mu=10.000, lambda=853.562
#
# === Station 8004 ===, Number=614
# ✅ Training NSE: 0.147, Validation NSE: -0.036
#    Training RMSE: 13.315, Validation RMSE: 16.013
#    Params: mu=1.120, lambda=19.500
#
# === Station 8005 ===, Number=615
# ✅ Training NSE: 0.457, Validation NSE: 0.228
#    Training RMSE: 22.655, Validation RMSE: 22.921
#    Params: mu=1.132, lambda=14.085
#
# === Station 8006 ===, Number=616
# ✅ Training NSE: 0.075, Validation NSE: -0.180
#    Training RMSE: 53.401, Validation RMSE: 59.236
#    Params: mu=1.036, lambda=7.437
#
# === Station 8009 ===, Number=617
# ✅ Training NSE: 0.378, Validation NSE: 0.254
#    Training RMSE: 6.390, Validation RMSE: 6.778
#    Params: mu=1.294, lambda=17.091
#
# === Station 8011 ===, Number=618
# ✅ Training NSE: 0.364, Validation NSE: 0.212
#    Training RMSE: 1.758, Validation RMSE: 2.175
#    Params: mu=1.609, lambda=46.252
#
# === Station 8013 ===, Number=619
# ⚠️ Too many missing values (15.5%)
#
# === Station 81002 ===, Number=620
# ✅ Training NSE: 0.522, Validation NSE: 0.562
#    Training RMSE: 14.208, Validation RMSE: 13.827
#    Params: mu=1.255, lambda=16.846
#
# === Station 81003 ===, Number=621
# ✅ Training NSE: 0.420, Validation NSE: 0.402
#    Training RMSE: 7.152, Validation RMSE: 8.082
#    Params: mu=1.361, lambda=22.387
#
# === Station 81004 ===, Number=622
# ✅ Training NSE: 0.757, Validation NSE: 0.749
#    Training RMSE: 6.163, Validation RMSE: 6.831
#    Params: mu=1.231, lambda=12.522
#
# === Station 81006 ===, Number=623
# ✅ Training NSE: 0.434, Validation NSE: 0.456
#    Training RMSE: 7.431, Validation RMSE: 7.828
#    Params: mu=1.432, lambda=40.288
#
# === Station 81007 ===, Number=624
# ✅ Training NSE: 0.372, Validation NSE: 0.385
#    Training RMSE: 3.873, Validation RMSE: 4.096
#    Params: mu=1.622, lambda=59.468
#
# === Station 82001 ===, Number=625
# ✅ Training NSE: 0.592, Validation NSE: 0.657
#    Training RMSE: 6.418, Validation RMSE: 6.492
#    Params: mu=1.309, lambda=19.249
#
# === Station 82003 ===, Number=626
# ✅ Training NSE: 0.474, Validation NSE: 0.524
#    Training RMSE: 9.833, Validation RMSE: 10.870
#    Params: mu=1.280, lambda=18.332
#
# === Station 83003 ===, Number=627
# ✅ Training NSE: 0.471, Validation NSE: 0.424
#    Training RMSE: 5.497, Validation RMSE: 5.767
#    Params: mu=1.391, lambda=23.421
#
# === Station 83004 ===, Number=628
# ✅ Training NSE: 0.481, Validation NSE: 0.467
#    Training RMSE: 6.100, Validation RMSE: 6.239
#    Params: mu=1.356, lambda=21.088
#
# === Station 83006 ===, Number=629
# ✅ Training NSE: 0.520, Validation NSE: 0.458
#    Training RMSE: 15.745, Validation RMSE: 18.291
#    Params: mu=1.191, lambda=8.782
#
# === Station 83007 ===, Number=630
# ✅ Training NSE: 0.421, Validation NSE: 0.413
#    Training RMSE: 2.045, Validation RMSE: 1.864
#    Params: mu=1.793, lambda=52.908
#
# === Station 83009 ===, Number=631
# ✅ Training NSE: 0.409, Validation NSE: 0.448
#    Training RMSE: 8.002, Validation RMSE: 6.551
#    Params: mu=1.368, lambda=22.618
#
# === Station 83010 ===, Number=632
# ✅ Training NSE: 0.391, Validation NSE: 0.384
#    Training RMSE: 2.770, Validation RMSE: 2.673
#    Params: mu=1.658, lambda=46.129
#
# === Station 83013 ===, Number=633
# ✅ Training NSE: 0.456, Validation NSE: 0.432
#    Training RMSE: 7.903, Validation RMSE: 6.856
#    Params: mu=1.312, lambda=15.050
#
# === Station 84001 ===, Number=634
# ✅ Training NSE: 0.677, Validation NSE: 0.648
#    Training RMSE: 5.889, Validation RMSE: 6.429
#    Params: mu=1.262, lambda=17.119
#
# === Station 84004 ===, Number=635
# ✅ Training NSE: 0.669, Validation NSE: 0.593
#    Training RMSE: 13.395, Validation RMSE: 16.645
#    Params: mu=1.151, lambda=8.721
#
# === Station 84005 ===, Number=636
# ✅ Training NSE: 0.582, Validation NSE: 0.474
#    Training RMSE: 34.677, Validation RMSE: 41.019
#    Params: mu=1.079, lambda=4.404
#
# === Station 84008 ===, Number=637
# ✅ Training NSE: 0.384, Validation NSE: 0.390
#    Training RMSE: 1.983, Validation RMSE: 2.315
#    Params: mu=1.799, lambda=61.182
#
# === Station 84009 ===, Number=638
# ✅ Training NSE: 0.437, Validation NSE: 0.431
#    Training RMSE: 1.828, Validation RMSE: 1.890
#    Params: mu=1.774, lambda=56.972
#
# === Station 84012 ===, Number=639
# ✅ Training NSE: 0.596, Validation NSE: 0.561
#    Training RMSE: 6.275, Validation RMSE: 5.592
#    Params: mu=1.316, lambda=19.691
#
# === Station 84013 ===, Number=640
# ✅ Training NSE: 0.522, Validation NSE: 0.440
#    Training RMSE: 40.690, Validation RMSE: 42.340
#    Params: mu=1.074, lambda=4.088
#
# === Station 84014 ===, Number=641
# ✅ Training NSE: 0.506, Validation NSE: 0.482
#    Training RMSE: 8.763, Validation RMSE: 8.647
#    Params: mu=1.289, lambda=15.852
#
# === Station 84016 ===, Number=642
# ✅ Training NSE: 0.089, Validation NSE: -0.017
#    Training RMSE: 1.210, Validation RMSE: 1.083
#    Params: mu=8.971, lambda=96.335
#
# === Station 84017 ===, Number=643
# ✅ Training NSE: 0.693, Validation NSE: 0.693
#    Training RMSE: 3.130, Validation RMSE: 2.844
#    Params: mu=1.465, lambda=48.921
#
# === Station 84018 ===, Number=644
# ✅ Training NSE: 0.652, Validation NSE: 0.479
#    Training RMSE: 18.834, Validation RMSE: 23.943
#    Params: mu=1.122, lambda=6.777
#
# === Station 84019 ===, Number=645
# ✅ Training NSE: 0.539, Validation NSE: 0.502
#    Training RMSE: 2.479, Validation RMSE: 2.345
#    Params: mu=1.457, lambda=24.336
#
# === Station 84020 ===, Number=646
# ✅ Training NSE: 0.320, Validation NSE: 0.307
#    Training RMSE: 2.669, Validation RMSE: 2.473
#    Params: mu=1.807, lambda=76.302
#
# === Station 84022 ===, Number=647
# ✅ Training NSE: 0.457, Validation NSE: 0.493
#    Training RMSE: 3.438, Validation RMSE: 3.225
#    Params: mu=1.522, lambda=38.417
#
# === Station 84026 ===, Number=648
# ✅ Training NSE: 0.014, Validation NSE: -0.033
#    Training RMSE: 1.948, Validation RMSE: 1.599
#    Params: mu=9.785, lambda=121.795
#
# === Station 84030 ===, Number=649
# ✅ Training NSE: 0.483, Validation NSE: 0.473
#    Training RMSE: 3.673, Validation RMSE: 3.857
#    Params: mu=1.496, lambda=39.045
#
# === Station 85001 ===, Number=650
# ✅ Training NSE: 0.653, Validation NSE: 0.515
#    Training RMSE: 20.009, Validation RMSE: 22.130
#    Params: mu=1.103, lambda=35.883
#
# === Station 85002 ===, Number=651
# ✅ Training NSE: 0.514, Validation NSE: 0.400
#    Training RMSE: 8.100, Validation RMSE: 11.210
#    Params: mu=1.329, lambda=22.029
#
# === Station 85003 ===, Number=652
# ✅ Training NSE: -0.083, Validation NSE: -0.202
#    Training RMSE: 11.141, Validation RMSE: 9.252
#    Params: mu=5.775, lambda=90.549
#
# === Station 85004 ===, Number=653
# ✅ Training NSE: -0.195, Validation NSE: -0.250
#    Training RMSE: 3.630, Validation RMSE: 3.189
#    Params: mu=10.000, lambda=172.569
#
# === Station 88001 ===, Number=654
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 ===, Number=655
# ✅ Training NSE: -0.068, Validation NSE: -0.115
#    Training RMSE: 7.714, Validation RMSE: 7.533
#    Params: mu=8.579, lambda=139.846
#
# === Station 89003 ===, Number=656
# ✅ Training NSE: 0.423, Validation NSE: 0.402
#    Training RMSE: 28.594, Validation RMSE: 28.013
#    Params: mu=1.293, lambda=27.873
#
# === Station 89005 ===, Number=657
# ✅ Training NSE: -0.015, Validation NSE: -0.032
#    Training RMSE: 9.444, Validation RMSE: 8.874
#    Params: mu=5.879, lambda=103.533
#
# === Station 89007 ===, Number=658
# ✅ Training NSE: -0.076, Validation NSE: -0.112
#    Training RMSE: 2.506, Validation RMSE: 1.938
#    Params: mu=10.000, lambda=269.290
#
# === Station 90003 ===, Number=659
# ✅ Training NSE: 0.330, Validation NSE: 0.364
#    Training RMSE: 7.473, Validation RMSE: 6.544
#    Params: mu=1.614, lambda=103.793
#
# === Station 9002 ===, Number=660
# ✅ Training NSE: 0.382, Validation NSE: 0.259
#    Training RMSE: 15.359, Validation RMSE: 20.389
#    Params: mu=1.106, lambda=7.351
#
# === Station 9003 ===, Number=661
# ✅ Training NSE: 0.522, Validation NSE: 0.339
#    Training RMSE: 2.901, Validation RMSE: 4.052
#    Params: mu=1.363, lambda=18.997
#
# === Station 9004 ===, Number=662
# ✅ Training NSE: 0.616, Validation NSE: 0.479
#    Training RMSE: 1.872, Validation RMSE: 2.073
#    Params: mu=1.357, lambda=36.171
#
# === Station 9005 ===, Number=663
# ✅ Training NSE: 0.307, Validation NSE: 0.202
#    Training RMSE: 1.777, Validation RMSE: 2.163
#    Params: mu=1.788, lambda=48.978
#
# === Station 92001 ===, Number=664
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 ===, Number=665
# ✅ Training NSE: 0.424, Validation NSE: 0.474
#    Training RMSE: 11.282, Validation RMSE: 9.679
#    Params: mu=1.437, lambda=51.427
#
# === Station 94001 ===, Number=666
# ✅ Training NSE: 0.735, Validation NSE: 0.727
#    Training RMSE: 12.468, Validation RMSE: 11.414
#    Params: mu=1.202, lambda=43.157
#
# === Station 95001 ===, Number=667
# ✅ Training NSE: 0.703, Validation NSE: 0.697
#    Training RMSE: 3.388, Validation RMSE: 3.185
#    Params: mu=1.438, lambda=94.867
#
# === Station 96001 ===, Number=668
# ✅ Training NSE: 0.400, Validation NSE: 0.420
#    Training RMSE: 5.793, Validation RMSE: 5.318
#    Params: mu=1.354, lambda=17.800
#
# === Station 96002 ===, Number=669
# ✅ Training NSE: 0.626, Validation NSE: 0.554
#    Training RMSE: 11.296, Validation RMSE: 11.603
#    Params: mu=1.210, lambda=14.954
#
# === Station 96004 ===, Number=670
# ✅ Training NSE: 0.254, Validation NSE: 0.262
#    Training RMSE: 9.345, Validation RMSE: 8.722
#    Params: mu=1.532, lambda=69.660
#
# === Station 97002 ===, Number=671
# ✅ Training NSE: 0.614, Validation NSE: 0.553
#    Training RMSE: 7.093, Validation RMSE: 8.594
#    Params: mu=1.212, lambda=10.514
#
# ✅ Simulation completed for 623 valid catchments.

# %%
rows = []

for station_id, res in results.items():
    MU, LAMBDA = res["params"]

    rows.append({
        "station_id": station_id,
        "MU": MU,
        "LAMBDA": LAMBDA,
        "NSE_train": res["NSE_train"],
        "NSE_val": res["NSE_val"],
        "RMSE_train": res["RMSE_train"],
        "RMSE_val": res["RMSE_val"],
        "missing_ratio": res["missing_ratio"],
        "missing_count": res["missing_count"],
    })

df = pd.DataFrame(rows)

# Local save
df.to_csv("HyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)

df.head()

# Save to Google Drive
from google.colab import drive
drive.mount("/content/drive")

df.to_csv(
    "/content/drive/MyDrive/HyMoLAP_Simulation_Data_CAMELS_GB.csv",
    index=False
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nse_values = [res['NSE_val'] for res in results.values()]

if nse_values:
    nse_median = np.median(nse_values)
    nse_mean = np.mean(nse_values)
    nse_min = np.min(nse_values)
    nse_max = np.max(nse_values)
    nse_5th = np.percentile(nse_values, 5)
    nse_95th = np.percentile(nse_values, 95)

    print(f"NSE Validation -> Mean: {nse_mean:.3f}, Median {nse_median:.3f}, Min: {nse_min:.3f}, Max: {nse_max:.3f}, 5th percentile: {nse_5th:.3f}, 95th percentile: {nse_95th:.3f}")
else:
    print("No stations processed (all contain missing values).")
# Out:
# NSE Validation -> Mean: -1.754, Median 0.446, Min: -306.862, Max: 0.861, 5th percentile: -2.686, 95th percentile: 0.726

# %%
rmse_values = [res['RMSE_val'] for res in results.values()]

if rmse_values:
    rmse_median = np.median(rmse_values)
    rmse_mean = np.mean(rmse_values)
    rmse_min = np.min(rmse_values)
    rmse_max = np.max(rmse_values)
    rmse_5th = np.percentile(rmse_values, 5)
    rmse_95th = np.percentile(rmse_values, 95)

    print(
        f"RMSE Validation -> Mean: {rmse_mean:.3f}, Median {rmse_median:.3f}, "
        f"Min: {rmse_min:.3f}, Max: {rmse_max:.3f}, "
        f"5th percentile: {rmse_5th:.3f}, 95th percentile: {rmse_95th:.3f}"
    )
else:
    print("No stations processed (all contain missing values).")
# Out:
# RMSE Validation -> Mean: 7.150, Median 2.448, Min: 0.336, Max: 164.826, 5th percentile: 0.546, 95th percentile: 30.071
