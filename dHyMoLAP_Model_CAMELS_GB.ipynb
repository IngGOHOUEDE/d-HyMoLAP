# %% [markdown]
#  **This notebook imprement d-HyMoLAP (dimensionally consistent reformulation of HyMoLAP rainfall-runoff Model) run over CAMELS-GB dataset catchments with less than 10% of missing data, and stock results (parameters and performance metrics) in dHyMoLAP_Simulation_Data_CAMELS_GB.csv**
#
# **Author:** Lionel Cedric Gohouede

# %% [markdown]
# ## 1. MOUNT GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import warnings
from numba import njit
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# ## 3. FILTER DATA BY TIME PERIOD (1990-2014)

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/CAMELS_GB/'
start_date, end_date = '1990-01-01', '2014-12-31'

print("Loading, filtering, and aligning CSV files...\n")

# 1. Fast Load & Filter
df_pcp = pd.read_csv(f"{data_dir}pcp_mm.csv", index_col=0).loc[start_date:end_date]
df_pet = pd.read_csv(f"{data_dir}pet_mm.csv", index_col=0).loc[start_date:end_date]
df_q   = pd.read_csv(f"{data_dir}q_cms_obs.csv", index_col=0).loc[start_date:end_date]

# 2. Fast Alignment
common_stations = sorted(list(set(df_pcp.columns) & set(df_pet.columns) & set(df_q.columns)))
df_pcp = df_pcp[common_stations]
df_pet = df_pet[common_stations]
df_q   = df_q[common_stations]

print(f"✅ Data aligned. Total common stations: {len(common_stations)}")

# ============================================
# Memory-Optimized Wrapper Classes
# ============================================
class SimpleArray:
    __slots__ = ['array']  # Prevents massive RAM bloat
    def __init__(self, array):
        self.array = array
    def to_numpy(self):
        return self.array

class StationData:
    __slots__ = ['data']
    def __init__(self, data_dict):
        self.data = data_dict
    def sel(self, dynamic_features=None):
        return SimpleArray(self.data[dynamic_features])

# ============================================
# Ultra-Fast Dictionary Construction
# ============================================
print("Building ds_recent dictionary...\n")

# Convert DataFrames to 2D NumPy matrices once (orders of magnitude faster than column iteration)
pcp_arr = df_pcp.to_numpy()
pet_arr = df_pet.to_numpy()
q_arr   = df_q.to_numpy()
date_arr = pd.to_datetime(df_pcp.index).to_numpy()

# Build the dictionary using fast index slicing
ds_recent = {
    st: StationData({
        'pcp_mm': pcp_arr[:, i],
        'pet_mm': pet_arr[:, i],
        'q_cms_obs': q_arr[:, i],
        'date': date_arr
    })
    for i, st in enumerate(common_stations)
}

print(f"✅ Dictionary built successfully!")

# ============================================
# Validation Test
# ============================================
test_station = common_stations[0]
print(f"\nTesting data access for station: {test_station}")

Q_obs = ds_recent[test_station].sel(dynamic_features="q_cms_obs").to_numpy()
P     = ds_recent[test_station].sel(dynamic_features="pcp_mm").to_numpy()
PET   = ds_recent[test_station].sel(dynamic_features="pet_mm").to_numpy()

print(f"✅ Extraction works correctly!")
print(f"   Q_obs shape: {Q_obs.shape}")
print(f"   Q_obs - min: {np.nanmin(Q_obs):.2f}, max: {np.nanmax(Q_obs):.2f}, mean: {np.nanmean(Q_obs):.2f}")
print(f"   Q_obs Missing: {np.sum(np.isnan(Q_obs))} ({np.sum(np.isnan(Q_obs))/len(Q_obs)*100:.1f}%)")
# Out:
# Loading, filtering, and aligning CSV files...
#
# ✅ Data aligned. Total common stations: 671
# Building ds_recent dictionary...
#
# ✅ Dictionary built successfully!
#
# Testing data access for station: 10002
# ✅ Extraction works correctly!
#    Q_obs shape: (9131,)
#    Q_obs - min: 0.80, max: 94.41, mean: 5.18
#    Q_obs Missing: 0 (0.0%)

# %% [markdown]
# ## 4. MAIN CODE

# %%
# ============================================
# 1. COMPILED MODEL & FAST METRICS (OUTSIDE THE LOOP)
# ============================================
@njit
def dHyMoLAP_Model(params, Q0, q):
    mu, lambda_, Qs, qs = params
    N = len(q)
    k = np.zeros(N)
    x = np.zeros(N)

    # Strict mathematical guards
    if Qs <= 0.0 or qs <= 0.0 or lambda_ <= 0.0 or mu <= 0.0:
        return np.full(N, np.nan)

    k[0] = Q0 / Qs

    # Precompute constants to save CPU cycles inside the loop
    mu_lam = mu / lambda_
    one_m_mu_lam = 1.0 - mu_lam
    inv_lam = 1.0 / lambda_
    pow_term = 2.0 * mu - 1.0

    for t in range(N - 1):
        r_next = q[t+1] / qs

        if np.isnan(r_next):
            k[t+1] = k[t]
            x[t+1] = x[t]
            continue

        if r_next > 0.0:
            x[t+1] = x[t] + mu_lam * r_next
        else:
            x[t+1] = one_m_mu_lam * x[t]

        k_base = max(0.0, k[t])
        k[t+1] = max(0.0, k[t] - mu_lam * (k_base ** pow_term) + inv_lam * x[t+1] * r_next)

    return k * Qs

def NSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0 or np.var(valid_obs) == 0.0: return np.nan
    return 1.0 - (np.sum((valid_sim - valid_obs)**2) / np.sum((valid_obs - np.mean(valid_obs))**2))

def RMSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0: return np.nan
    return np.sqrt(np.mean((valid_sim - valid_obs)**2))

def objective(params, Q0, q_train, Q_obs_train):
    Q_sim = dHyMoLAP_Model(params, Q0, q_train)
    nse = NSE(Q_obs_train, Q_sim)
    return 1.0 - nse if np.isfinite(nse) else 1e9

# ============================================
# 2. OPTIMIZED EXECUTION LOOP
# ============================================
all_stations = list(ds_recent.keys())
b1_ratio = 0.7
max_missing_ratio = 0.1
results = {}

# Strict bounds: mu >= 0.5 is required so (2*mu - 1) is not negative.
param_bounds = [(0.5, 5.0), (1e-3, 100.0), (1e-3, 1000.0), (1e-3, 1000.0)]

for i, station_id in enumerate(all_stations, 1):
    print(f"\n=== Station {station_id} ===, Number={i}")

    # Extract data using your wrapper
    Q_obs = ds_recent[station_id].sel(dynamic_features="q_cms_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    q = np.maximum(0.0, P - PET)
    N = len(Q_obs)

    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station skipped (no valid data).")
        continue

    missing_count = np.sum(np.isnan(Q_obs))
    missing_ratio = missing_count / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    b1 = int(N * b1_ratio)
    Q0 = Q_obs[0] if not np.isnan(Q_obs[0]) else np.nanmean(Q_obs[:10])

    q_train = q[:b1]
    Q_obs_train = Q_obs[:b1]

    # Optimization
    initial_guess = np.array([1.1, 20.0, np.nanmean(Q_obs_train), np.nanmean(q_train)])

    res = minimize(
        objective,
        initial_guess,
        args=(Q0, q_train, Q_obs_train),
        method="Nelder-Mead",
        bounds=param_bounds,
        options={'maxiter': 2500, 'disp': False}
    )

    MU, LAMBDA, Qs_best, qs_best = res.x
    NSE_train = 1.0 - res.fun

    # Validation
    Qsim = dHyMoLAP_Model(res.x, Q0, q)
    NSE_val = NSE(Q_obs[b1:], Qsim[b1:])
    RMSE_train = RMSE(Q_obs_train, Qsim[:b1])
    RMSE_val   = RMSE(Q_obs[b1:], Qsim[b1:])

    print(f"✅ Training NSE: {NSE_train:.3f}, Validation NSE: {NSE_val:.3f}")
    print(f"   Training RMSE: {RMSE_train:.3f}, Validation RMSE: {RMSE_val:.3f}")
    print(f"   Params: mu={MU:.3f}, lambda={LAMBDA:.3f}, Qs={Qs_best:.3f}, qs={qs_best:.3f}")

    # Storage
    results[station_id] = {
        "params": res.x.tolist(),
        "NSE_train": NSE_train,
        "NSE_val": NSE_val,
        "RMSE_train": RMSE_train,
        "RMSE_val": RMSE_val,
        "Qsim": Qsim,
        "missing_ratio": missing_ratio,
        "missing_count": missing_count,
    }

print(f"\n✅ Simulation terminée pour {len(results)} bassins valides (≤10% de NaN).")
# Out:
# === Station 10002 ===, Number=1
# ✅ Training NSE: 0.675, Validation NSE: 0.532
#    Training RMSE: 2.974, Validation RMSE: 4.211
#    Params: mu=1.168, lambda=54.839, Qs=0.023, qs=0.064
#
# === Station 10003 ===, Number=2
# ✅ Training NSE: 0.787, Validation NSE: 0.684
#    Training RMSE: 3.276, Validation RMSE: 4.326
#    Params: mu=1.202, lambda=49.149, Qs=0.550, qs=0.348
#
# === Station 1001 ===, Number=3
# ⚠️ Too many missing values (23.4%)
#
# === Station 101002 ===, Number=4
# ✅ Training NSE: 0.726, Validation NSE: 0.699
#    Training RMSE: 0.199, Validation RMSE: 0.219
#    Params: mu=1.286, lambda=41.250, Qs=0.024, qs=0.293
#
# === Station 101005 ===, Number=5
# ✅ Training NSE: 0.736, Validation NSE: 0.743
#    Training RMSE: 0.153, Validation RMSE: 0.181
#    Params: mu=1.218, lambda=34.660, Qs=0.004, qs=0.144
#
# === Station 102001 ===, Number=6
# ✅ Training NSE: 0.633, Validation NSE: 0.666
#    Training RMSE: 0.401, Validation RMSE: 0.405
#    Params: mu=1.146, lambda=25.332, Qs=0.002, qs=0.115
#
# === Station 106001 ===, Number=7
# ⚠️ Too many missing values (28.0%)
#
# === Station 107001 ===, Number=8
# ⚠️ Too many missing values (38.4%)
#
# === Station 11001 ===, Number=9
# ✅ Training NSE: 0.729, Validation NSE: 0.550
#    Training RMSE: 10.333, Validation RMSE: 14.035
#    Params: mu=1.173, lambda=53.866, Qs=0.343, qs=0.165
#
# === Station 11003 ===, Number=10
# ✅ Training NSE: 0.616, Validation NSE: 0.384
#    Training RMSE: 5.643, Validation RMSE: 7.525
#    Params: mu=1.243, lambda=56.300, Qs=0.489, qs=0.303
#
# === Station 11004 ===, Number=11
# ✅ Training NSE: 0.768, Validation NSE: 0.636
#    Training RMSE: 1.298, Validation RMSE: 1.801
#    Params: mu=1.230, lambda=46.307, Qs=0.452, qs=0.612
#
# === Station 12001 ===, Number=12
# ✅ Training NSE: 0.530, Validation NSE: 0.393
#    Training RMSE: 26.284, Validation RMSE: 29.784
#    Params: mu=1.260, lambda=95.858, Qs=0.570, qs=0.135
#
# === Station 12002 ===, Number=13
# ✅ Training NSE: 0.585, Validation NSE: 0.459
#    Training RMSE: 31.908, Validation RMSE: 35.870
#    Params: mu=1.195, lambda=94.846, Qs=0.113, qs=0.050
#
# === Station 12005 ===, Number=14
# ✅ Training NSE: 0.616, Validation NSE: 0.400
#    Training RMSE: 2.759, Validation RMSE: 3.390
#    Params: mu=1.462, lambda=2.104, Qs=37.382, qs=62.380
#
# === Station 12006 ===, Number=15
# ✅ Training NSE: 0.490, Validation NSE: 0.286
#    Training RMSE: 2.808, Validation RMSE: 3.283
#    Params: mu=1.572, lambda=2.223, Qs=33.495, qs=50.727
#
# === Station 12007 ===, Number=16
# ✅ Training NSE: 0.429, Validation NSE: 0.362
#    Training RMSE: 9.744, Validation RMSE: 11.266
#    Params: mu=1.416, lambda=85.730, Qs=0.864, qs=0.344
#
# === Station 12008 ===, Number=17
# ✅ Training NSE: 0.681, Validation NSE: 0.653
#    Training RMSE: 5.040, Validation RMSE: 6.003
#    Params: mu=1.338, lambda=4.008, Qs=25.051, qs=16.745
#
# === Station 12009 ===, Number=18
# ✅ Training NSE: 0.600, Validation NSE: 0.556
#    Training RMSE: 1.301, Validation RMSE: 1.489
#    Params: mu=1.342, lambda=4.460, Qs=3.001, qs=11.011
#
# === Station 13001 ===, Number=19
# ✅ Training NSE: 0.743, Validation NSE: 0.721
#    Training RMSE: 1.370, Validation RMSE: 1.531
#    Params: mu=1.207, lambda=30.874, Qs=0.076, qs=0.241
#
# === Station 13004 ===, Number=20
# ✅ Training NSE: 0.696, Validation NSE: 0.615
#    Training RMSE: 1.937, Validation RMSE: 2.800
#    Params: mu=1.405, lambda=9.176, Qs=4.795, qs=6.384
#
# === Station 13005 ===, Number=21
# ✅ Training NSE: 0.750, Validation NSE: -0.465
#    Training RMSE: 1.140, Validation RMSE: 3.159
#    Params: mu=1.103, lambda=33.840, Qs=0.001, qs=0.027
#
# === Station 13007 ===, Number=22
# ✅ Training NSE: 0.707, Validation NSE: 0.586
#    Training RMSE: 12.427, Validation RMSE: 17.604
#    Params: mu=1.386, lambda=6.135, Qs=47.973, qs=9.379
#
# === Station 13008 ===, Number=23
# ✅ Training NSE: 0.680, Validation NSE: 0.575
#    Training RMSE: 7.401, Validation RMSE: 9.963
#    Params: mu=1.440, lambda=6.028, Qs=42.007, qs=13.340
#
# === Station 14001 ===, Number=24
# ✅ Training NSE: 0.770, Validation NSE: 0.706
#    Training RMSE: 2.052, Validation RMSE: 2.535
#    Params: mu=1.145, lambda=39.593, Qs=0.024, qs=0.089
#
# === Station 14002 ===, Number=25
# ✅ Training NSE: 0.734, Validation NSE: -0.533
#    Training RMSE: 0.945, Validation RMSE: 2.745
#    Params: mu=1.130, lambda=37.094, Qs=0.011, qs=0.101
#
# === Station 14005 ===, Number=26
# ✅ Training NSE: 0.691, Validation NSE: 0.612
#    Training RMSE: 0.401, Validation RMSE: 0.521
#    Params: mu=1.100, lambda=32.219, Qs=0.001, qs=0.049
#
# === Station 15006 ===, Number=27
# ✅ Training NSE: 0.771, Validation NSE: 0.704
#    Training RMSE: 74.799, Validation RMSE: 82.058
#    Params: mu=1.384, lambda=37.080, Qs=65.726, qs=2.073
#
# === Station 15007 ===, Number=28
# ✅ Training NSE: 0.806, Validation NSE: 0.726
#    Training RMSE: 24.572, Validation RMSE: 27.264
#    Params: mu=1.445, lambda=22.896, Qs=48.769, qs=6.176
#
# === Station 15010 ===, Number=29
# ✅ Training NSE: 0.710, Validation NSE: 0.650
#    Training RMSE: 4.593, Validation RMSE: 6.267
#    Params: mu=1.236, lambda=30.050, Qs=0.595, qs=0.546
#
# === Station 15011 ===, Number=30
# ✅ Training NSE: 0.597, Validation NSE: 0.527
#    Training RMSE: 11.501, Validation RMSE: 11.265
#    Params: mu=1.153, lambda=62.476, Qs=0.001, qs=0.019
#
# === Station 15012 ===, Number=31
# ✅ Training NSE: 0.750, Validation NSE: 0.660
#    Training RMSE: 32.939, Validation RMSE: 37.925
#    Params: mu=1.422, lambda=38.591, Qs=30.022, qs=2.303
#
# === Station 15013 ===, Number=32
# ✅ Training NSE: 0.656, Validation NSE: 0.533
#    Training RMSE: 4.402, Validation RMSE: 5.543
#    Params: mu=1.207, lambda=22.262, Qs=0.177, qs=0.480
#
# === Station 15014 ===, Number=33
# ✅ Training NSE: 0.591, Validation NSE: 0.511
#    Training RMSE: 2.614, Validation RMSE: 3.048
#    Params: mu=1.300, lambda=46.843, Qs=0.116, qs=0.244
#
# === Station 15016 ===, Number=34
# ✅ Training NSE: 0.815, Validation NSE: 0.725
#    Training RMSE: 17.350, Validation RMSE: 18.670
#    Params: mu=1.541, lambda=13.499, Qs=93.484, qs=18.608
#
# === Station 15021 ===, Number=35
# ✅ Training NSE: 0.759, Validation NSE: 0.630
#    Training RMSE: 0.781, Validation RMSE: 0.992
#    Params: mu=1.157, lambda=24.705, Qs=0.408, qs=1.253
#
# === Station 15023 ===, Number=36
# ✅ Training NSE: 0.724, Validation NSE: 0.557
#    Training RMSE: 4.913, Validation RMSE: 6.146
#    Params: mu=1.232, lambda=18.856, Qs=0.724, qs=0.964
#
# === Station 15024 ===, Number=37
# ✅ Training NSE: 0.688, Validation NSE: 0.680
#    Training RMSE: 11.996, Validation RMSE: 11.544
#    Params: mu=1.167, lambda=100.000, Qs=0.001, qs=0.015
#
# === Station 15025 ===, Number=38
# ✅ Training NSE: 0.643, Validation NSE: 0.564
#    Training RMSE: 8.774, Validation RMSE: 10.367
#    Params: mu=1.318, lambda=34.422, Qs=1.480, qs=0.604
#
# === Station 15030 ===, Number=39
# ✅ Training NSE: 0.747, Validation NSE: 0.599
#    Training RMSE: 2.107, Validation RMSE: 2.895
#    Params: mu=1.098, lambda=40.049, Qs=0.002, qs=0.030
#
# === Station 15039 ===, Number=40
# ✅ Training NSE: 0.461, Validation NSE: 0.397
#    Training RMSE: 6.271, Validation RMSE: 7.077
#    Params: mu=1.302, lambda=100.000, Qs=0.066, qs=0.096
#
# === Station 16001 ===, Number=41
# ✅ Training NSE: 0.793, Validation NSE: 0.692
#    Training RMSE: 10.977, Validation RMSE: 13.515
#    Params: mu=1.344, lambda=28.798, Qs=6.758, qs=1.859
#
# === Station 16003 ===, Number=42
# ✅ Training NSE: 0.702, Validation NSE: 0.644
#    Training RMSE: 4.408, Validation RMSE: 5.048
#    Params: mu=1.193, lambda=95.860, Qs=0.001, qs=0.016
#
# === Station 16004 ===, Number=43
# ✅ Training NSE: 0.780, Validation NSE: 0.696
#    Training RMSE: 14.895, Validation RMSE: 17.171
#    Params: mu=1.268, lambda=35.595, Qs=3.085, qs=0.880
#
# === Station 17001 ===, Number=44
# ✅ Training NSE: 0.678, Validation NSE: 0.560
#    Training RMSE: 3.594, Validation RMSE: 3.938
#    Params: mu=1.192, lambda=4.292, Qs=4.106, qs=9.475
#
# === Station 17003 ===, Number=45
# ✅ Training NSE: 0.707, Validation NSE: 0.656
#    Training RMSE: 0.917, Validation RMSE: 0.803
#    Params: mu=1.179, lambda=55.703, Qs=0.001, qs=0.031
#
# === Station 17004 ===, Number=46
# ✅ Training NSE: 0.781, Validation NSE: 0.709
#    Training RMSE: 1.145, Validation RMSE: 1.454
#    Params: mu=1.164, lambda=28.248, Qs=0.050, qs=0.227
#
# === Station 17005 ===, Number=47
# ✅ Training NSE: 0.739, Validation NSE: 0.737
#    Training RMSE: 3.191, Validation RMSE: 3.400
#    Params: mu=1.136, lambda=40.556, Qs=0.001, qs=0.017
#
# === Station 17015 ===, Number=48
# ✅ Training NSE: 0.685, Validation NSE: 0.598
#    Training RMSE: 0.626, Validation RMSE: 0.774
#    Params: mu=1.231, lambda=9.478, Qs=0.321, qs=2.641
#
# === Station 17018 ===, Number=49
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 ===, Number=50
# ✅ Training NSE: 0.705, Validation NSE: 0.621
#    Training RMSE: 3.900, Validation RMSE: 4.816
#    Params: mu=1.157, lambda=60.432, Qs=0.002, qs=0.026
#
# === Station 18002 ===, Number=51
# ✅ Training NSE: 0.659, Validation NSE: 0.553
#    Training RMSE: 3.704, Validation RMSE: 5.126
#    Params: mu=1.167, lambda=27.886, Qs=0.063, qs=0.280
#
# === Station 18003 ===, Number=52
# ✅ Training NSE: 0.767, Validation NSE: 0.702
#    Training RMSE: 15.300, Validation RMSE: 16.127
#    Params: mu=1.118, lambda=46.267, Qs=0.005, qs=0.040
#
# === Station 18008 ===, Number=53
# ✅ Training NSE: 0.685, Validation NSE: 0.694
#    Training RMSE: 8.417, Validation RMSE: 7.932
#    Params: mu=1.145, lambda=100.000, Qs=0.001, qs=0.018
#
# === Station 18010 ===, Number=54
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 ===, Number=55
# ✅ Training NSE: 0.694, Validation NSE: 0.730
#    Training RMSE: 31.818, Validation RMSE: 26.686
#    Params: mu=1.113, lambda=67.185, Qs=0.001, qs=0.009
#
# === Station 18014 ===, Number=56
# ✅ Training NSE: 0.729, Validation NSE: 0.616
#    Training RMSE: 0.598, Validation RMSE: 0.769
#    Params: mu=1.261, lambda=15.645, Qs=0.168, qs=1.555
#
# === Station 18017 ===, Number=57
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 ===, Number=58
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 ===, Number=59
# ✅ Training NSE: 0.711, Validation NSE: 0.697
#    Training RMSE: 5.347, Validation RMSE: 5.603
#    Params: mu=1.098, lambda=20.700, Qs=0.001, qs=0.018
#
# === Station 19006 ===, Number=60
# ✅ Training NSE: 0.713, Validation NSE: 0.672
#    Training RMSE: 1.135, Validation RMSE: 1.078
#    Params: mu=1.285, lambda=6.954, Qs=2.169, qs=4.175
#
# === Station 19010 ===, Number=61
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 ===, Number=62
# ✅ Training NSE: 0.720, Validation NSE: 0.614
#    Training RMSE: 0.456, Validation RMSE: 0.592
#    Params: mu=1.114, lambda=16.465, Qs=0.001, qs=0.059
#
# === Station 19020 ===, Number=63
# ✅ Training NSE: 0.676, Validation NSE: 0.604
#    Training RMSE: 0.776, Validation RMSE: 0.961
#    Params: mu=1.137, lambda=21.090, Qs=0.001, qs=0.056
#
# === Station 20002 ===, Number=64
# ✅ Training NSE: 0.615, Validation NSE: 0.502
#    Training RMSE: 0.164, Validation RMSE: 0.264
#    Params: mu=1.133, lambda=25.261, Qs=0.001, qs=0.070
#
# === Station 20003 ===, Number=65
# ✅ Training NSE: 0.686, Validation NSE: 0.581
#    Training RMSE: 1.297, Validation RMSE: 1.794
#    Params: mu=1.116, lambda=26.580, Qs=0.001, qs=0.025
#
# === Station 20007 ===, Number=66
# ✅ Training NSE: 0.637, Validation NSE: 0.453
#    Training RMSE: 0.754, Validation RMSE: 0.886
#    Params: mu=1.108, lambda=19.409, Qs=0.001, qs=0.047
#
# === Station 2001 ===, Number=67
# ✅ Training NSE: 0.577, Validation NSE: 0.545
#    Training RMSE: 10.001, Validation RMSE: 10.337
#    Params: mu=1.133, lambda=61.884, Qs=0.001, qs=0.009
#
# === Station 2002 ===, Number=68
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 ===, Number=69
# ✅ Training NSE: 0.772, Validation NSE: 0.716
#    Training RMSE: 8.598, Validation RMSE: 10.167
#    Params: mu=1.256, lambda=24.589, Qs=2.616, qs=1.026
#
# === Station 21006 ===, Number=70
# ✅ Training NSE: 0.730, Validation NSE: 0.687
#    Training RMSE: 22.587, Validation RMSE: 25.137
#    Params: mu=1.210, lambda=31.946, Qs=1.401, qs=0.396
#
# === Station 21008 ===, Number=71
# ✅ Training NSE: 0.706, Validation NSE: 0.668
#    Training RMSE: 14.793, Validation RMSE: 18.810
#    Params: mu=1.153, lambda=30.614, Qs=0.124, qs=0.113
#
# === Station 21009 ===, Number=72
# ✅ Training NSE: 0.718, Validation NSE: 0.671
#    Training RMSE: 48.284, Validation RMSE: 56.268
#    Params: mu=1.141, lambda=36.127, Qs=0.391, qs=0.105
#
# === Station 21011 ===, Number=73
# ✅ Training NSE: 0.726, Validation NSE: 0.640
#    Training RMSE: 3.867, Validation RMSE: 4.499
#    Params: mu=1.177, lambda=38.247, Qs=0.051, qs=0.185
#
# === Station 21012 ===, Number=74
# ✅ Training NSE: 0.738, Validation NSE: 0.668
#    Training RMSE: 6.542, Validation RMSE: 7.770
#    Params: mu=1.188, lambda=26.184, Qs=0.151, qs=0.255
#
# === Station 21013 ===, Number=75
# ✅ Training NSE: 0.723, Validation NSE: 0.618
#    Training RMSE: 2.498, Validation RMSE: 2.997
#    Params: mu=1.134, lambda=25.991, Qs=0.033, qs=0.152
#
# === Station 21015 ===, Number=76
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 ===, Number=77
# ✅ Training NSE: 0.599, Validation NSE: 0.665
#    Training RMSE: 1.253, Validation RMSE: 1.321
#    Params: mu=1.122, lambda=36.603, Qs=0.001, qs=0.025
#
# === Station 21017 ===, Number=78
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 ===, Number=79
# ✅ Training NSE: 0.745, Validation NSE: 0.623
#    Training RMSE: 1.872, Validation RMSE: 2.377
#    Params: mu=1.189, lambda=25.977, Qs=0.127, qs=0.353
#
# === Station 21022 ===, Number=80
# ✅ Training NSE: 0.642, Validation NSE: 0.545
#    Training RMSE: 5.729, Validation RMSE: 8.458
#    Params: mu=1.102, lambda=37.190, Qs=0.001, qs=0.012
#
# === Station 21023 ===, Number=81
# ✅ Training NSE: 0.405, Validation NSE: 0.340
#    Training RMSE: 2.015, Validation RMSE: 2.629
#    Params: mu=1.059, lambda=12.088, Qs=0.001, qs=0.048
#
# === Station 21024 ===, Number=82
# ✅ Training NSE: 0.660, Validation NSE: 0.645
#    Training RMSE: 2.153, Validation RMSE: 2.430
#    Params: mu=1.130, lambda=33.682, Qs=0.001, qs=0.021
#
# === Station 21026 ===, Number=83
# ✅ Training NSE: 0.613, Validation NSE: 0.483
#    Training RMSE: 1.512, Validation RMSE: 2.248
#    Params: mu=1.239, lambda=3.662, Qs=2.304, qs=12.354
#
# === Station 21027 ===, Number=84
# ✅ Training NSE: 0.591, Validation NSE: 0.507
#    Training RMSE: 1.935, Validation RMSE: 2.603
#    Params: mu=1.106, lambda=26.732, Qs=0.001, qs=0.025
#
# === Station 22001 ===, Number=85
# ✅ Training NSE: 0.693, Validation NSE: 0.552
#    Training RMSE: 7.136, Validation RMSE: 10.738
#    Params: mu=1.166, lambda=10.775, Qs=1.415, qs=0.952
#
# === Station 22006 ===, Number=86
# ✅ Training NSE: 0.641, Validation NSE: 0.576
#    Training RMSE: 2.481, Validation RMSE: 3.445
#    Params: mu=1.066, lambda=11.205, Qs=0.001, qs=0.034
#
# === Station 22007 ===, Number=87
# ✅ Training NSE: 0.678, Validation NSE: 0.608
#    Training RMSE: 3.434, Validation RMSE: 4.754
#    Params: mu=1.083, lambda=14.742, Qs=0.001, qs=0.025
#
# === Station 22009 ===, Number=88
# ✅ Training NSE: 0.674, Validation NSE: 0.531
#    Training RMSE: 4.822, Validation RMSE: 7.131
#    Params: mu=1.225, lambda=6.359, Qs=8.737, qs=4.887
#
# === Station 23001 ===, Number=89
# ✅ Training NSE: 0.719, Validation NSE: 0.646
#    Training RMSE: 30.551, Validation RMSE: 35.206
#    Params: mu=1.160, lambda=32.218, Qs=0.151, qs=0.080
#
# === Station 23004 ===, Number=90
# ✅ Training NSE: 0.706, Validation NSE: 0.648
#    Training RMSE: 15.017, Validation RMSE: 16.212
#    Params: mu=1.154, lambda=33.912, Qs=0.016, qs=0.038
#
# === Station 23006 ===, Number=91
# ✅ Training NSE: 0.713, Validation NSE: 0.703
#    Training RMSE: 7.945, Validation RMSE: 8.675
#    Params: mu=1.157, lambda=64.891, Qs=0.001, qs=0.010
#
# === Station 23007 ===, Number=92
# ✅ Training NSE: 0.623, Validation NSE: 0.623
#    Training RMSE: 2.016, Validation RMSE: 2.745
#    Params: mu=1.107, lambda=29.235, Qs=0.001, qs=0.025
#
# === Station 23008 ===, Number=93
# ✅ Training NSE: 0.668, Validation NSE: 0.587
#    Training RMSE: 5.461, Validation RMSE: 7.442
#    Params: mu=1.106, lambda=24.634, Qs=0.001, qs=0.017
#
# === Station 23011 ===, Number=94
# ✅ Training NSE: 0.652, Validation NSE: 0.579
#    Training RMSE: 1.678, Validation RMSE: 2.017
#    Params: mu=1.167, lambda=42.494, Qs=0.001, qs=0.027
#
# === Station 23016 ===, Number=95
# ✅ Training NSE: 0.780, Validation NSE: 0.756
#    Training RMSE: 0.297, Validation RMSE: 0.418
#    Params: mu=1.111, lambda=13.849, Qs=0.001, qs=0.061
#
# === Station 24001 ===, Number=96
# ✅ Training NSE: 0.710, Validation NSE: 0.642
#    Training RMSE: 8.933, Validation RMSE: 11.409
#    Params: mu=1.120, lambda=35.778, Qs=0.003, qs=0.018
#
# === Station 24003 ===, Number=97
# ✅ Training NSE: 0.687, Validation NSE: 0.612
#    Training RMSE: 3.838, Validation RMSE: 4.462
#    Params: mu=1.181, lambda=18.720, Qs=0.060, qs=0.276
#
# === Station 24004 ===, Number=98
# ✅ Training NSE: 0.724, Validation NSE: 0.635
#    Training RMSE: 0.930, Validation RMSE: 1.223
#    Params: mu=1.191, lambda=31.133, Qs=0.018, qs=0.147
#
# === Station 24005 ===, Number=99
# ✅ Training NSE: 0.694, Validation NSE: 0.661
#    Training RMSE: 1.441, Validation RMSE: 1.902
#    Params: mu=1.110, lambda=24.319, Qs=0.001, qs=0.026
#
# === Station 25001 ===, Number=100
# ✅ Training NSE: 0.693, Validation NSE: 0.643
#    Training RMSE: 14.785, Validation RMSE: 16.371
#    Params: mu=1.161, lambda=41.660, Qs=0.023, qs=0.043
#
# === Station 25003 ===, Number=101
# ✅ Training NSE: 0.571, Validation NSE: 0.544
#    Training RMSE: 0.573, Validation RMSE: 0.625
#    Params: mu=1.257, lambda=100.000, Qs=0.001, qs=0.045
#
# === Station 25006 ===, Number=102
# ✅ Training NSE: 0.680, Validation NSE: 0.456
#    Training RMSE: 2.382, Validation RMSE: 3.154
#    Params: mu=1.242, lambda=4.239, Qs=3.754, qs=7.173
#
# === Station 25012 ===, Number=103
# ✅ Training NSE: 0.649, Validation NSE: 0.679
#    Training RMSE: 0.933, Validation RMSE: 0.843
#    Params: mu=1.231, lambda=100.000, Qs=0.001, qs=0.028
#
# === Station 25020 ===, Number=104
# ✅ Training NSE: 0.649, Validation NSE: 0.684
#    Training RMSE: 0.903, Validation RMSE: 0.929
#    Params: mu=1.120, lambda=33.022, Qs=0.001, qs=0.026
#
# === Station 25021 ===, Number=105
# ✅ Training NSE: 0.648, Validation NSE: 0.633
#    Training RMSE: 0.396, Validation RMSE: 0.526
#    Params: mu=1.120, lambda=27.575, Qs=0.001, qs=0.046
#
# === Station 25029 ===, Number=106
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 ===, Number=107
# ✅ Training NSE: 0.777, Validation NSE: 0.714
#    Training RMSE: 0.217, Validation RMSE: 0.284
#    Params: mu=0.902, lambda=39.648, Qs=0.026, qs=0.628
#
# === Station 26005 ===, Number=108
# ✅ Training NSE: 0.806, Validation NSE: 0.595
#    Training RMSE: 0.177, Validation RMSE: 0.374
#    Params: mu=0.649, lambda=25.271, Qs=0.595, qs=3.887
#
# === Station 26006 ===, Number=109
# ✅ Training NSE: 0.671, Validation NSE: 0.546
#    Training RMSE: 0.371, Validation RMSE: 0.554
#    Params: mu=0.816, lambda=33.266, Qs=0.552, qs=2.328
#
# === Station 26008 ===, Number=110
# ✅ Training NSE: 0.696, Validation NSE: 0.734
#    Training RMSE: 0.100, Validation RMSE: 0.108
#    Params: mu=0.956, lambda=56.872, Qs=0.951, qs=3.872
#
# === Station 26009 ===, Number=111
# ✅ Training NSE: 0.709, Validation NSE: 0.568
#    Training RMSE: 0.941, Validation RMSE: 1.154
#    Params: mu=0.960, lambda=33.915, Qs=0.002, qs=0.100
#
# === Station 27001 ===, Number=112
# ✅ Training NSE: 0.713, Validation NSE: 0.660
#    Training RMSE: 5.823, Validation RMSE: 7.646
#    Params: mu=1.120, lambda=32.877, Qs=0.007, qs=0.040
#
# === Station 27002 ===, Number=113
# ✅ Training NSE: 0.690, Validation NSE: 0.657
#    Training RMSE: 12.611, Validation RMSE: 15.417
#    Params: mu=1.118, lambda=53.329, Qs=0.001, qs=0.009
#
# === Station 27003 ===, Number=114
# ✅ Training NSE: 0.770, Validation NSE: 0.765
#    Training RMSE: 18.439, Validation RMSE: 19.409
#    Params: mu=1.139, lambda=60.977, Qs=0.023, qs=0.026
#
# === Station 27006 ===, Number=115
# ✅ Training NSE: 0.724, Validation NSE: 0.703
#    Training RMSE: 3.545, Validation RMSE: 3.569
#    Params: mu=1.110, lambda=34.831, Qs=0.001, qs=0.019
#
# === Station 27007 ===, Number=116
# ✅ Training NSE: 0.683, Validation NSE: 0.645
#    Training RMSE: 17.678, Validation RMSE: 18.918
#    Params: mu=1.118, lambda=61.547, Qs=0.001, qs=0.007
#
# === Station 27009 ===, Number=117
# ✅ Training NSE: 0.745, Validation NSE: 0.723
#    Training RMSE: 30.925, Validation RMSE: 32.566
#    Params: mu=1.147, lambda=41.822, Qs=0.317, qs=0.102
#
# === Station 27021 ===, Number=118
# ✅ Training NSE: 0.740, Validation NSE: 0.725
#    Training RMSE: 9.626, Validation RMSE: 9.433
#    Params: mu=1.103, lambda=52.692, Qs=0.001, qs=0.007
#
# === Station 27023 ===, Number=119
# ✅ Training NSE: 0.602, Validation NSE: 0.692
#    Training RMSE: 1.555, Validation RMSE: 1.128
#    Params: mu=1.097, lambda=16.688, Qs=0.001, qs=0.038
#
# === Station 27025 ===, Number=120
# ✅ Training NSE: 0.697, Validation NSE: 0.656
#    Training RMSE: 2.770, Validation RMSE: 2.784
#    Params: mu=1.113, lambda=38.476, Qs=0.001, qs=0.014
#
# === Station 27026 ===, Number=121
# ✅ Training NSE: 0.732, Validation NSE: 0.729
#    Training RMSE: 1.526, Validation RMSE: 1.423
#    Params: mu=1.120, lambda=29.087, Qs=0.001, qs=0.022
#
# === Station 27029 ===, Number=122
# ✅ Training NSE: 0.782, Validation NSE: 0.761
#    Training RMSE: 4.667, Validation RMSE: 5.016
#    Params: mu=1.169, lambda=41.439, Qs=0.025, qs=0.084
#
# === Station 27030 ===, Number=123
# ✅ Training NSE: 0.739, Validation NSE: 0.714
#    Training RMSE: 2.081, Validation RMSE: 2.275
#    Params: mu=1.114, lambda=45.172, Qs=0.001, qs=0.014
#
# === Station 27032 ===, Number=124
# ✅ Training NSE: 0.701, Validation NSE: 0.670
#    Training RMSE: 0.133, Validation RMSE: 0.149
#    Params: mu=1.235, lambda=37.771, Qs=0.003, qs=0.222
#
# === Station 27034 ===, Number=125
# ✅ Training NSE: 0.713, Validation NSE: 0.672
#    Training RMSE: 13.150, Validation RMSE: 14.260
#    Params: mu=1.123, lambda=46.764, Qs=0.001, qs=0.011
#
# === Station 27035 ===, Number=126
# ✅ Training NSE: 0.766, Validation NSE: 0.761
#    Training RMSE: 4.717, Validation RMSE: 4.986
#    Params: mu=1.118, lambda=43.544, Qs=0.001, qs=0.016
#
# === Station 27038 ===, Number=127
# ✅ Training NSE: 0.493, Validation NSE: 0.210
#    Training RMSE: 0.165, Validation RMSE: 0.349
#    Params: mu=1.569, lambda=100.000, Qs=1.113, qs=3.149
#
# === Station 27041 ===, Number=128
# ✅ Training NSE: 0.806, Validation NSE: 0.796
#    Training RMSE: 6.157, Validation RMSE: 6.796
#    Params: mu=1.151, lambda=49.566, Qs=0.578, qs=0.246
#
# === Station 27042 ===, Number=129
# ✅ Training NSE: 0.760, Validation NSE: 0.702
#    Training RMSE: 0.516, Validation RMSE: 0.604
#    Params: mu=1.274, lambda=36.341, Qs=0.110, qs=0.439
#
# === Station 27043 ===, Number=130
# ✅ Training NSE: 0.716, Validation NSE: 0.711
#    Training RMSE: 10.304, Validation RMSE: 10.947
#    Params: mu=1.143, lambda=66.218, Qs=0.001, qs=0.010
#
# === Station 27047 ===, Number=131
# ✅ Training NSE: 0.761, Validation NSE: 0.761
#    Training RMSE: 0.464, Validation RMSE: 0.458
#    Params: mu=1.233, lambda=73.780, Qs=0.001, qs=0.049
#
# === Station 27049 ===, Number=132
# ✅ Training NSE: 0.705, Validation NSE: 0.675
#    Training RMSE: 1.938, Validation RMSE: 2.247
#    Params: mu=1.137, lambda=40.593, Qs=0.036, qs=0.137
#
# === Station 27051 ===, Number=133
# ✅ Training NSE: 0.739, Validation NSE: 0.754
#    Training RMSE: 0.099, Validation RMSE: 0.107
#    Params: mu=1.140, lambda=15.359, Qs=0.001, qs=0.136
#
# === Station 27062 ===, Number=134
# ✅ Training NSE: 0.733, Validation NSE: 0.729
#    Training RMSE: 5.508, Validation RMSE: 5.749
#    Params: mu=1.137, lambda=36.623, Qs=0.033, qs=0.086
#
# === Station 27064 ===, Number=135
# ✅ Training NSE: 0.598, Validation NSE: 0.563
#    Training RMSE: 0.497, Validation RMSE: 0.603
#    Params: mu=1.122, lambda=36.737, Qs=0.001, qs=0.033
#
# === Station 27065 ===, Number=136
# ✅ Training NSE: 0.759, Validation NSE: 0.763
#    Training RMSE: 1.334, Validation RMSE: 1.314
#    Params: mu=1.153, lambda=30.172, Qs=0.009, qs=0.123
#
# === Station 27071 ===, Number=137
# ✅ Training NSE: 0.726, Validation NSE: 0.693
#    Training RMSE: 12.696, Validation RMSE: 15.631
#    Params: mu=1.145, lambda=46.295, Qs=0.073, qs=0.065
#
# === Station 27073 ===, Number=138
# ✅ Training NSE: 0.726, Validation NSE: 0.774
#    Training RMSE: 0.101, Validation RMSE: 0.109
#    Params: mu=1.124, lambda=44.411, Qs=0.893, qs=4.551
#
# === Station 27077 ===, Number=139
# ✅ Training NSE: 0.723, Validation NSE: 0.648
#    Training RMSE: 0.392, Validation RMSE: 0.394
#    Params: mu=1.316, lambda=4.989, Qs=1.410, qs=7.717
#
# === Station 27079 ===, Number=140
# ✅ Training NSE: 0.750, Validation NSE: 0.740
#    Training RMSE: 10.647, Validation RMSE: 10.995
#    Params: mu=1.191, lambda=52.747, Qs=0.152, qs=0.101
#
# === Station 27080 ===, Number=141
# ✅ Training NSE: 0.791, Validation NSE: 0.806
#    Training RMSE: 8.590, Validation RMSE: 8.307
#    Params: mu=1.187, lambda=61.763, Qs=0.075, qs=0.063
#
# === Station 27084 ===, Number=142
# ✅ Training NSE: 0.776, Validation NSE: 0.757
#    Training RMSE: 0.684, Validation RMSE: 0.690
#    Params: mu=1.152, lambda=30.613, Qs=0.001, qs=0.040
#
# === Station 27087 ===, Number=143
# ✅ Training NSE: 0.804, Validation NSE: 0.791
#    Training RMSE: 1.221, Validation RMSE: 1.364
#    Params: mu=1.187, lambda=54.270, Qs=1.973, qs=1.272
#
# === Station 27089 ===, Number=144
# ✅ Training NSE: 0.708, Validation NSE: 0.687
#    Training RMSE: 11.691, Validation RMSE: 12.505
#    Params: mu=1.118, lambda=62.478, Qs=0.001, qs=0.009
#
# === Station 27090 ===, Number=145
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 ===, Number=146
# ✅ Training NSE: 0.565, Validation NSE: 0.460
#    Training RMSE: 2.287, Validation RMSE: 2.371
#    Params: mu=1.092, lambda=24.941, Qs=0.001, qs=0.055
#
# === Station 28003 ===, Number=147
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 ===, Number=148
# ✅ Training NSE: 0.775, Validation NSE: 0.758
#    Training RMSE: 3.477, Validation RMSE: 3.324
#    Params: mu=1.290, lambda=32.711, Qs=1.149, qs=0.655
#
# === Station 28009 ===, Number=149
# ✅ Training NSE: 0.783, Validation NSE: 0.807
#    Training RMSE: 34.996, Validation RMSE: 32.635
#    Params: mu=1.165, lambda=45.309, Qs=1.775, qs=0.166
#
# === Station 28012 ===, Number=150
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 ===, Number=151
# ✅ Training NSE: 0.635, Validation NSE: 0.647
#    Training RMSE: 0.854, Validation RMSE: 0.855
#    Params: mu=1.397, lambda=65.846, Qs=1.122, qs=0.819
#
# === Station 28018 ===, Number=152
# ✅ Training NSE: 0.706, Validation NSE: 0.719
#    Training RMSE: 7.662, Validation RMSE: 6.736
#    Params: mu=1.218, lambda=36.361, Qs=0.781, qs=0.346
#
# === Station 28022 ===, Number=153
# ✅ Training NSE: 0.763, Validation NSE: 0.805
#    Training RMSE: 38.174, Validation RMSE: 32.357
#    Params: mu=1.158, lambda=46.306, Qs=1.991, qs=0.173
#
# === Station 28023 ===, Number=154
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 ===, Number=155
# ✅ Training NSE: 0.604, Validation NSE: 0.613
#    Training RMSE: 2.980, Validation RMSE: 3.063
#    Params: mu=1.104, lambda=38.265, Qs=0.001, qs=0.014
#
# === Station 28026 ===, Number=156
# ✅ Training NSE: 0.601, Validation NSE: 0.604
#    Training RMSE: 2.596, Validation RMSE: 3.071
#    Params: mu=1.096, lambda=28.000, Qs=0.002, qs=0.026
#
# === Station 28031 ===, Number=157
# ✅ Training NSE: 0.730, Validation NSE: 0.725
#    Training RMSE: 2.210, Validation RMSE: 2.094
#    Params: mu=1.250, lambda=24.471, Qs=0.295, qs=0.506
#
# === Station 28033 ===, Number=158
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 ===, Number=159
# ✅ Training NSE: 0.764, Validation NSE: 0.718
#    Training RMSE: 0.499, Validation RMSE: 0.695
#    Params: mu=1.216, lambda=71.322, Qs=0.001, qs=0.017
#
# === Station 28040 ===, Number=160
# ✅ Training NSE: 0.724, Validation NSE: 0.716
#    Training RMSE: 0.481, Validation RMSE: 0.417
#    Params: mu=1.141, lambda=26.825, Qs=0.001, qs=0.042
#
# === Station 28043 ===, Number=161
# ✅ Training NSE: 0.742, Validation NSE: 0.724
#    Training RMSE: 4.031, Validation RMSE: 3.911
#    Params: mu=1.143, lambda=25.629, Qs=0.076, qs=0.235
#
# === Station 28044 ===, Number=162
# ✅ Training NSE: 0.731, Validation NSE: 0.527
#    Training RMSE: 0.064, Validation RMSE: 0.108
#    Params: mu=0.982, lambda=93.072, Qs=0.001, qs=0.121
#
# === Station 28046 ===, Number=163
# ✅ Training NSE: 0.850, Validation NSE: 0.813
#    Training RMSE: 0.567, Validation RMSE: 0.576
#    Params: mu=1.333, lambda=36.392, Qs=0.961, qs=1.725
#
# === Station 28048 ===, Number=164
# ✅ Training NSE: 0.671, Validation NSE: 0.631
#    Training RMSE: 1.116, Validation RMSE: 1.415
#    Params: mu=1.125, lambda=32.384, Qs=0.001, qs=0.026
#
# === Station 28050 ===, Number=165
# ✅ Training NSE: 0.658, Validation NSE: 0.642
#    Training RMSE: 0.395, Validation RMSE: 0.486
#    Params: mu=1.300, lambda=71.361, Qs=0.117, qs=0.281
#
# === Station 28052 ===, Number=166
# ✅ Training NSE: 0.685, Validation NSE: 0.656
#    Training RMSE: 0.709, Validation RMSE: 0.936
#    Params: mu=1.145, lambda=36.888, Qs=0.008, qs=0.089
#
# === Station 28055 ===, Number=167
# ✅ Training NSE: 0.760, Validation NSE: 0.705
#    Training RMSE: 0.427, Validation RMSE: 0.458
#    Params: mu=1.140, lambda=32.482, Qs=0.001, qs=0.041
#
# === Station 28056 ===, Number=168
# ✅ Training NSE: 0.637, Validation NSE: 0.655
#    Training RMSE: 0.645, Validation RMSE: 0.648
#    Params: mu=1.110, lambda=25.309, Qs=0.001, qs=0.037
#
# === Station 28060 ===, Number=169
# ✅ Training NSE: 0.516, Validation NSE: 0.458
#    Training RMSE: 0.114, Validation RMSE: 0.162
#    Params: mu=1.245, lambda=50.913, Qs=0.007, qs=0.169
#
# === Station 28066 ===, Number=170
# ✅ Training NSE: 0.702, Validation NSE: 0.696
#    Training RMSE: 0.662, Validation RMSE: 0.859
#    Params: mu=1.189, lambda=67.569, Qs=0.001, qs=0.016
#
# === Station 28067 ===, Number=171
# ✅ Training NSE: 0.747, Validation NSE: 0.721
#    Training RMSE: 9.423, Validation RMSE: 10.330
#    Params: mu=1.167, lambda=37.549, Qs=0.445, qs=0.256
#
# === Station 28072 ===, Number=172
# ✅ Training NSE: 0.548, Validation NSE: 0.523
#    Training RMSE: 0.220, Validation RMSE: 0.272
#    Params: mu=1.234, lambda=51.801, Qs=0.010, qs=0.135
#
# === Station 28074 ===, Number=173
# ✅ Training NSE: 0.695, Validation NSE: 0.711
#    Training RMSE: 6.875, Validation RMSE: 7.171
#    Params: mu=1.114, lambda=48.236, Qs=0.007, qs=0.019
#
# === Station 28080 ===, Number=174
# ✅ Training NSE: 0.659, Validation NSE: 0.666
#    Training RMSE: 5.598, Validation RMSE: 6.624
#    Params: mu=1.482, lambda=97.451, Qs=2.306, qs=0.255
#
# === Station 28081 ===, Number=175
# ✅ Training NSE: 0.694, Validation NSE: 0.723
#    Training RMSE: 1.026, Validation RMSE: 1.062
#    Params: mu=1.312, lambda=100.000, Qs=0.036, qs=0.062
#
# === Station 28082 ===, Number=176
# ✅ Training NSE: 0.640, Validation NSE: 0.627
#    Training RMSE: 1.075, Validation RMSE: 1.180
#    Params: mu=1.119, lambda=39.903, Qs=0.001, qs=0.021
#
# === Station 28085 ===, Number=177
# ✅ Training NSE: 0.802, Validation NSE: 0.785
#    Training RMSE: 7.440, Validation RMSE: 7.707
#    Params: mu=1.178, lambda=35.536, Qs=0.586, qs=0.329
#
# === Station 28091 ===, Number=178
# ✅ Training NSE: 0.674, Validation NSE: 0.661
#    Training RMSE: 0.760, Validation RMSE: 0.731
#    Params: mu=1.262, lambda=61.641, Qs=0.117, qs=0.216
#
# === Station 28093 ===, Number=179
# ✅ Training NSE: 0.660, Validation NSE: 0.676
#    Training RMSE: 6.633, Validation RMSE: 6.729
#    Params: mu=1.096, lambda=41.284, Qs=0.002, qs=0.011
#
# === Station 28115 ===, Number=180
# ✅ Training NSE: 0.681, Validation NSE: 0.651
#    Training RMSE: 0.189, Validation RMSE: 0.189
#    Params: mu=1.755, lambda=100.000, Qs=0.280, qs=0.462
#
# === Station 28116 ===, Number=181
# ⚠️ Too many missing values (28.2%)
#
# === Station 28117 ===, Number=182
# ⚠️ Too many missing values (28.0%)
#
# === Station 29002 ===, Number=183
# ✅ Training NSE: 0.735, Validation NSE: 0.673
#    Training RMSE: 0.188, Validation RMSE: 0.213
#    Params: mu=1.114, lambda=53.080, Qs=4.516, qs=6.800
#
# === Station 29003 ===, Number=184
# ✅ Training NSE: 0.730, Validation NSE: 0.649
#    Training RMSE: 0.162, Validation RMSE: 0.208
#    Params: mu=0.980, lambda=45.780, Qs=0.001, qs=0.117
#
# === Station 29005 ===, Number=185
# ✅ Training NSE: 0.560, Validation NSE: 0.498
#    Training RMSE: 0.561, Validation RMSE: 0.767
#    Params: mu=1.114, lambda=27.032, Qs=0.001, qs=0.039
#
# === Station 29009 ===, Number=186
# ✅ Training NSE: 0.597, Validation NSE: 0.650
#    Training RMSE: 0.131, Validation RMSE: 0.131
#    Params: mu=1.104, lambda=28.038, Qs=0.001, qs=0.084
#
# === Station 30001 ===, Number=187
# ✅ Training NSE: 0.644, Validation NSE: 0.646
#    Training RMSE: 1.216, Validation RMSE: 1.260
#    Params: mu=1.165, lambda=56.788, Qs=0.044, qs=0.124
#
# === Station 30004 ===, Number=188
# ✅ Training NSE: 0.663, Validation NSE: 0.638
#    Training RMSE: 0.297, Validation RMSE: 0.354
#    Params: mu=1.220, lambda=47.079, Qs=0.011, qs=0.119
#
# === Station 30005 ===, Number=189
# ⚠️ Too many missing values (24.0%)
#
# === Station 30011 ===, Number=190
# ✅ Training NSE: 0.668, Validation NSE: 0.645
#    Training RMSE: 0.180, Validation RMSE: 0.210
#    Params: mu=1.088, lambda=49.163, Qs=0.001, qs=0.067
#
# === Station 30012 ===, Number=191
# ✅ Training NSE: 0.575, Validation NSE: 0.557
#    Training RMSE: 0.242, Validation RMSE: 0.267
#    Params: mu=1.144, lambda=33.264, Qs=0.001, qs=0.051
#
# === Station 30014 ===, Number=192
# ✅ Training NSE: 0.487, Validation NSE: 0.455
#    Training RMSE: 0.100, Validation RMSE: 0.104
#    Params: mu=1.215, lambda=50.946, Qs=0.001, qs=0.061
#
# === Station 30015 ===, Number=193
# ✅ Training NSE: 0.714, Validation NSE: 0.686
#    Training RMSE: 0.117, Validation RMSE: 0.116
#    Params: mu=0.984, lambda=47.103, Qs=0.008, qs=0.358
#
# === Station 3003 ===, Number=194
# ✅ Training NSE: 0.601, Validation NSE: 0.603
#    Training RMSE: 14.462, Validation RMSE: 13.730
#    Params: mu=1.131, lambda=33.717, Qs=0.001, qs=0.020
#
# === Station 31002 ===, Number=195
# ✅ Training NSE: 0.517, Validation NSE: 0.482
#    Training RMSE: 1.307, Validation RMSE: 1.338
#    Params: mu=0.873, lambda=50.741, Qs=1000.000, qs=25.552
#
# === Station 31006 ===, Number=196
# ✅ Training NSE: 0.707, Validation NSE: 0.608
#    Training RMSE: 0.216, Validation RMSE: 0.254
#    Params: mu=0.965, lambda=41.855, Qs=0.001, qs=0.102
#
# === Station 31010 ===, Number=197
# ✅ Training NSE: 0.575, Validation NSE: 0.527
#    Training RMSE: 0.477, Validation RMSE: 0.529
#    Params: mu=1.135, lambda=41.751, Qs=0.001, qs=0.034
#
# === Station 31021 ===, Number=198
# ✅ Training NSE: 0.572, Validation NSE: 0.544
#    Training RMSE: 1.692, Validation RMSE: 2.027
#    Params: mu=1.111, lambda=33.621, Qs=0.001, qs=0.020
#
# === Station 31023 ===, Number=199
# ✅ Training NSE: 0.533, Validation NSE: 0.495
#    Training RMSE: 0.045, Validation RMSE: 0.040
#    Params: mu=1.219, lambda=24.151, Qs=0.001, qs=0.145
#
# === Station 31025 ===, Number=200
# ✅ Training NSE: 0.551, Validation NSE: 0.525
#    Training RMSE: 0.262, Validation RMSE: 0.283
#    Params: mu=1.165, lambda=30.414, Qs=0.001, qs=0.052
#
# === Station 32003 ===, Number=201
# ✅ Training NSE: 0.511, Validation NSE: 0.474
#    Training RMSE: 0.675, Validation RMSE: 0.697
#    Params: mu=1.143, lambda=33.441, Qs=0.001, qs=0.031
#
# === Station 32004 ===, Number=202
# ✅ Training NSE: 0.640, Validation NSE: 0.626
#    Training RMSE: 1.119, Validation RMSE: 1.546
#    Params: mu=1.112, lambda=39.306, Qs=0.001, qs=0.022
#
# === Station 32006 ===, Number=203
# ✅ Training NSE: 0.616, Validation NSE: 0.651
#    Training RMSE: 1.147, Validation RMSE: 1.221
#    Params: mu=1.111, lambda=45.520, Qs=0.001, qs=0.021
#
# === Station 32008 ===, Number=204
# ✅ Training NSE: 0.598, Validation NSE: 0.641
#    Training RMSE: 0.589, Validation RMSE: 0.621
#    Params: mu=1.134, lambda=44.490, Qs=0.001, qs=0.028
#
# === Station 33006 ===, Number=205
# ✅ Training NSE: 0.762, Validation NSE: 0.633
#    Training RMSE: 0.692, Validation RMSE: 0.894
#    Params: mu=0.994, lambda=50.154, Qs=104.594, qs=14.603
#
# === Station 33007 ===, Number=206
# ✅ Training NSE: 0.802, Validation NSE: 0.679
#    Training RMSE: 0.289, Validation RMSE: 0.331
#    Params: mu=1.079, lambda=44.821, Qs=86.865, qs=25.822
#
# === Station 33012 ===, Number=207
# ✅ Training NSE: 0.510, Validation NSE: 0.454
#    Training RMSE: 1.042, Validation RMSE: 1.303
#    Params: mu=1.118, lambda=30.107, Qs=0.001, qs=0.028
#
# === Station 33013 ===, Number=208
# ✅ Training NSE: 0.623, Validation NSE: 0.523
#    Training RMSE: 0.547, Validation RMSE: 0.550
#    Params: mu=1.072, lambda=46.077, Qs=0.001, qs=0.037
#
# === Station 33014 ===, Number=209
# ✅ Training NSE: 0.615, Validation NSE: 0.480
#    Training RMSE: 0.665, Validation RMSE: 0.660
#    Params: mu=1.055, lambda=60.007, Qs=0.026, qs=0.201
#
# === Station 33018 ===, Number=210
# ✅ Training NSE: 0.650, Validation NSE: 0.627
#    Training RMSE: 0.886, Validation RMSE: 1.149
#    Params: mu=1.125, lambda=37.222, Qs=0.001, qs=0.024
#
# === Station 33019 ===, Number=211
# ✅ Training NSE: 0.760, Validation NSE: 0.633
#    Training RMSE: 0.819, Validation RMSE: 0.849
#    Params: mu=1.028, lambda=47.045, Qs=0.002, qs=0.053
#
# === Station 33020 ===, Number=212
# ⚠️ Too many missing values (17.1%)
#
# === Station 33021 ===, Number=213
# ✅ Training NSE: 0.664, Validation NSE: 0.502
#    Training RMSE: 0.752, Validation RMSE: 1.028
#    Params: mu=0.920, lambda=42.940, Qs=10.107, qs=4.545
#
# === Station 33022 ===, Number=214
# ✅ Training NSE: 0.657, Validation NSE: 0.622
#    Training RMSE: 1.526, Validation RMSE: 1.837
#    Params: mu=1.207, lambda=54.529, Qs=0.162, qs=0.202
#
# === Station 33023 ===, Number=215
# ✅ Training NSE: 0.591, Validation NSE: 0.407
#    Training RMSE: 0.249, Validation RMSE: 0.235
#    Params: mu=0.818, lambda=40.962, Qs=1.892, qs=3.978
#
# === Station 33024 ===, Number=216
# ✅ Training NSE: 0.578, Validation NSE: 0.445
#    Training RMSE: 0.569, Validation RMSE: 0.610
#    Params: mu=1.028, lambda=46.042, Qs=0.127, qs=0.655
#
# === Station 33026 ===, Number=217
# ✅ Training NSE: 0.695, Validation NSE: 0.698
#    Training RMSE: 10.319, Validation RMSE: 11.951
#    Params: mu=1.068, lambda=36.764, Qs=0.001, qs=0.008
#
# === Station 33028 ===, Number=218
# ✅ Training NSE: 0.597, Validation NSE: 0.546
#    Training RMSE: 0.496, Validation RMSE: 0.546
#    Params: mu=1.376, lambda=56.033, Qs=0.258, qs=0.443
#
# === Station 33029 ===, Number=219
# ✅ Training NSE: 0.762, Validation NSE: 0.704
#    Training RMSE: 0.217, Validation RMSE: 0.231
#    Params: mu=0.946, lambda=40.412, Qs=1.077, qs=2.922
#
# === Station 33031 ===, Number=220
# ✅ Training NSE: 0.519, Validation NSE: 0.479
#    Training RMSE: 0.589, Validation RMSE: 0.843
#    Params: mu=1.109, lambda=19.688, Qs=0.001, qs=0.049
#
# === Station 33032 ===, Number=221
# ✅ Training NSE: 0.761, Validation NSE: 0.700
#    Training RMSE: 0.075, Validation RMSE: 0.062
#    Params: mu=0.917, lambda=39.435, Qs=0.003, qs=0.360
#
# === Station 33033 ===, Number=222
# ✅ Training NSE: 0.641, Validation NSE: 0.508
#    Training RMSE: 0.253, Validation RMSE: 0.316
#    Params: mu=1.256, lambda=52.711, Qs=2.679, qs=4.543
#
# === Station 33034 ===, Number=223
# ✅ Training NSE: 0.763, Validation NSE: 0.640
#    Training RMSE: 1.580, Validation RMSE: 1.550
#    Params: mu=1.008, lambda=40.566, Qs=0.001, qs=0.029
#
# === Station 33035 ===, Number=224
# ✅ Training NSE: 0.711, Validation NSE: 0.634
#    Training RMSE: 7.534, Validation RMSE: 7.866
#    Params: mu=1.025, lambda=49.058, Qs=0.001, qs=0.011
#
# === Station 33039 ===, Number=225
# ✅ Training NSE: 0.705, Validation NSE: 0.700
#    Training RMSE: 7.754, Validation RMSE: 8.523
#    Params: mu=1.069, lambda=41.479, Qs=0.001, qs=0.009
#
# === Station 33053 ===, Number=226
# ⚠️ Too many missing values (16.0%)
#
# === Station 33054 ===, Number=227
# ✅ Training NSE: 0.826, Validation NSE: 0.764
#    Training RMSE: 0.111, Validation RMSE: 0.115
#    Params: mu=1.075, lambda=46.100, Qs=249.715, qs=70.040
#
# === Station 33058 ===, Number=228
# ✅ Training NSE: 0.660, Validation NSE: 0.572
#    Training RMSE: 1.525, Validation RMSE: 2.190
#    Params: mu=1.113, lambda=36.910, Qs=0.001, qs=0.018
#
# === Station 34002 ===, Number=229
# ✅ Training NSE: 0.606, Validation NSE: 0.631
#    Training RMSE: 0.624, Validation RMSE: 0.520
#    Params: mu=1.113, lambda=38.531, Qs=0.001, qs=0.030
#
# === Station 34003 ===, Number=230
# ✅ Training NSE: 0.685, Validation NSE: 0.649
#    Training RMSE: 0.343, Validation RMSE: 0.354
#    Params: mu=1.611, lambda=87.258, Qs=0.612, qs=0.703
#
# === Station 34004 ===, Number=231
# ✅ Training NSE: 0.658, Validation NSE: 0.698
#    Training RMSE: 1.554, Validation RMSE: 1.463
#    Params: mu=1.203, lambda=58.832, Qs=1.939, qs=1.125
#
# === Station 34005 ===, Number=232
# ✅ Training NSE: 0.582, Validation NSE: 0.594
#    Training RMSE: 0.217, Validation RMSE: 0.247
#    Params: mu=1.168, lambda=45.516, Qs=0.004, qs=0.103
#
# === Station 34006 ===, Number=233
# ✅ Training NSE: 0.560, Validation NSE: 0.569
#    Training RMSE: 2.002, Validation RMSE: 1.921
#    Params: mu=1.092, lambda=33.153, Qs=0.001, qs=0.019
#
# === Station 34007 ===, Number=234
# ✅ Training NSE: 0.472, Validation NSE: 0.439
#    Training RMSE: 0.893, Validation RMSE: 1.055
#    Params: mu=1.113, lambda=33.617, Qs=0.001, qs=0.028
#
# === Station 34008 ===, Number=235
# ✅ Training NSE: 0.606, Validation NSE: 0.438
#    Training RMSE: 0.089, Validation RMSE: 0.094
#    Params: mu=1.879, lambda=100.000, Qs=0.276, qs=0.952
#
# === Station 34010 ===, Number=236
# ✅ Training NSE: 0.572, Validation NSE: 0.498
#    Training RMSE: 0.813, Validation RMSE: 0.810
#    Params: mu=1.102, lambda=35.478, Qs=0.001, qs=0.029
#
# === Station 34011 ===, Number=237
# ✅ Training NSE: 0.672, Validation NSE: 0.588
#    Training RMSE: 0.369, Validation RMSE: 0.416
#    Params: mu=1.017, lambda=58.411, Qs=0.001, qs=0.064
#
# === Station 34012 ===, Number=238
# ✅ Training NSE: 0.818, Validation NSE: 0.754
#    Training RMSE: 0.088, Validation RMSE: 0.074
#    Params: mu=0.878, lambda=37.318, Qs=0.005, qs=0.481
#
# === Station 35003 ===, Number=239
# ✅ Training NSE: 0.377, Validation NSE: 0.273
#    Training RMSE: 0.557, Validation RMSE: 1.113
#    Params: mu=1.139, lambda=39.096, Qs=0.001, qs=0.037
#
# === Station 35008 ===, Number=240
# ✅ Training NSE: 0.574, Validation NSE: 0.509
#    Training RMSE: 0.875, Validation RMSE: 0.912
#    Params: mu=1.125, lambda=30.243, Qs=0.001, qs=0.026
#
# === Station 36003 ===, Number=241
# ✅ Training NSE: 0.548, Validation NSE: 0.497
#    Training RMSE: 0.234, Validation RMSE: 0.235
#    Params: mu=1.139, lambda=39.345, Qs=0.001, qs=0.048
#
# === Station 36006 ===, Number=242
# ✅ Training NSE: 0.594, Validation NSE: 0.569
#    Training RMSE: 2.579, Validation RMSE: 2.520
#    Params: mu=1.085, lambda=40.672, Qs=0.001, qs=0.015
#
# === Station 36009 ===, Number=243
# ✅ Training NSE: 0.529, Validation NSE: 0.434
#    Training RMSE: 0.216, Validation RMSE: 0.244
#    Params: mu=1.145, lambda=25.867, Qs=0.001, qs=0.063
#
# === Station 36010 ===, Number=244
# ✅ Training NSE: 0.518, Validation NSE: 0.509
#    Training RMSE: 0.287, Validation RMSE: 0.267
#    Params: mu=1.151, lambda=21.190, Qs=0.001, qs=0.057
#
# === Station 36011 ===, Number=245
# ✅ Training NSE: 0.637, Validation NSE: 0.565
#    Training RMSE: 0.278, Validation RMSE: 0.309
#    Params: mu=1.156, lambda=28.309, Qs=0.001, qs=0.043
#
# === Station 36012 ===, Number=246
# ✅ Training NSE: 0.033, Validation NSE: 0.017
#    Training RMSE: 1.204, Validation RMSE: 0.971
#    Params: mu=2.314, lambda=74.777, Qs=1.010, qs=0.912
#
# === Station 37001 ===, Number=247
# ✅ Training NSE: 0.696, Validation NSE: 0.707
#    Training RMSE: 1.739, Validation RMSE: 1.803
#    Params: mu=1.095, lambda=29.739, Qs=0.001, qs=0.020
#
# === Station 37003 ===, Number=248
# ✅ Training NSE: 0.587, Validation NSE: 0.530
#    Training RMSE: 0.385, Validation RMSE: 0.625
#    Params: mu=1.116, lambda=31.984, Qs=0.001, qs=0.042
#
# === Station 37005 ===, Number=249
# ✅ Training NSE: 0.592, Validation NSE: 0.602
#    Training RMSE: 1.132, Validation RMSE: 1.171
#    Params: mu=1.115, lambda=45.488, Qs=0.001, qs=0.020
#
# === Station 37008 ===, Number=250
# ✅ Training NSE: 0.600, Validation NSE: 0.596
#    Training RMSE: 1.011, Validation RMSE: 1.093
#    Params: mu=1.107, lambda=36.447, Qs=0.001, qs=0.024
#
# === Station 37009 ===, Number=251
# ✅ Training NSE: 0.567, Validation NSE: 0.573
#    Training RMSE: 0.342, Validation RMSE: 0.342
#    Params: mu=1.138, lambda=39.107, Qs=0.001, qs=0.036
#
# === Station 37010 ===, Number=252
# ✅ Training NSE: 0.510, Validation NSE: 0.538
#    Training RMSE: 1.316, Validation RMSE: 1.546
#    Params: mu=1.112, lambda=41.778, Qs=0.001, qs=0.020
#
# === Station 37011 ===, Number=253
# ✅ Training NSE: 0.556, Validation NSE: 0.542
#    Training RMSE: 0.481, Validation RMSE: 0.536
#    Params: mu=1.130, lambda=29.834, Qs=0.001, qs=0.039
#
# === Station 37018 ===, Number=254
# ✅ Training NSE: 0.669, Validation NSE: 0.624
#    Training RMSE: 0.267, Validation RMSE: 0.338
#    Params: mu=1.165, lambda=38.839, Qs=0.001, qs=0.034
#
# === Station 37019 ===, Number=255
# ✅ Training NSE: 0.732, Validation NSE: 0.713
#    Training RMSE: 0.272, Validation RMSE: 0.302
#    Params: mu=1.170, lambda=32.903, Qs=0.001, qs=0.031
#
# === Station 37020 ===, Number=256
# ✅ Training NSE: 0.610, Validation NSE: 0.547
#    Training RMSE: 0.769, Validation RMSE: 1.173
#    Params: mu=1.119, lambda=30.796, Qs=0.001, qs=0.029
#
# === Station 37031 ===, Number=257
# ✅ Training NSE: 0.573, Validation NSE: 0.571
#    Training RMSE: 0.480, Validation RMSE: 0.657
#    Params: mu=1.131, lambda=19.589, Qs=0.001, qs=0.042
#
# === Station 37033 ===, Number=258
# ✅ Training NSE: 0.682, Validation NSE: 0.695
#    Training RMSE: 0.048, Validation RMSE: 0.060
#    Params: mu=1.220, lambda=26.429, Qs=0.001, qs=0.084
#
# === Station 38001 ===, Number=259
# ✅ Training NSE: 0.667, Validation NSE: 0.661
#    Training RMSE: 3.444, Validation RMSE: 3.317
#    Params: mu=1.105, lambda=48.102, Qs=0.001, qs=0.011
#
# === Station 38003 ===, Number=260
# ✅ Training NSE: 0.814, Validation NSE: 0.755
#    Training RMSE: 0.138, Validation RMSE: 0.117
#    Params: mu=0.979, lambda=100.000, Qs=0.001, qs=0.103
#
# === Station 38004 ===, Number=261
# ✅ Training NSE: 0.534, Validation NSE: 0.490
#    Training RMSE: 0.627, Validation RMSE: 0.657
#    Params: mu=1.125, lambda=31.947, Qs=0.001, qs=0.035
#
# === Station 38007 ===, Number=262
# ✅ Training NSE: 0.737, Validation NSE: 0.742
#    Training RMSE: 0.141, Validation RMSE: 0.142
#    Params: mu=1.223, lambda=49.575, Qs=0.001, qs=0.035
#
# === Station 38012 ===, Number=263
# ✅ Training NSE: 0.578, Validation NSE: 0.640
#    Training RMSE: 0.131, Validation RMSE: 0.106
#    Params: mu=1.109, lambda=1.768, Qs=1.650, qs=22.630
#
# === Station 38014 ===, Number=264
# ✅ Training NSE: 0.779, Validation NSE: 0.688
#    Training RMSE: 0.148, Validation RMSE: 0.166
#    Params: mu=1.177, lambda=29.156, Qs=0.001, qs=0.051
#
# === Station 38017 ===, Number=265
# ✅ Training NSE: 0.798, Validation NSE: 0.669
#    Training RMSE: 0.031, Validation RMSE: 0.027
#    Params: mu=0.804, lambda=30.356, Qs=0.002, qs=0.815
#
# === Station 38018 ===, Number=266
# ✅ Training NSE: 0.723, Validation NSE: 0.673
#    Training RMSE: 0.445, Validation RMSE: 0.422
#    Params: mu=1.167, lambda=83.399, Qs=1.162, qs=1.623
#
# === Station 38021 ===, Number=267
# ✅ Training NSE: 0.657, Validation NSE: 0.629
#    Training RMSE: 0.277, Validation RMSE: 0.296
#    Params: mu=1.153, lambda=26.142, Qs=0.001, qs=0.052
#
# === Station 38026 ===, Number=268
# ✅ Training NSE: 0.683, Validation NSE: 0.637
#    Training RMSE: 0.264, Validation RMSE: 0.328
#    Params: mu=1.131, lambda=32.168, Qs=0.001, qs=0.047
#
# === Station 38029 ===, Number=269
# ✅ Training NSE: 0.458, Validation NSE: 0.459
#    Training RMSE: 0.284, Validation RMSE: 0.251
#    Params: mu=1.136, lambda=20.960, Qs=0.001, qs=0.070
#
# === Station 38030 ===, Number=270
# ✅ Training NSE: 0.492, Validation NSE: 0.452
#    Training RMSE: 0.433, Validation RMSE: 0.464
#    Params: mu=1.196, lambda=59.496, Qs=0.008, qs=0.089
#
# === Station 39001 ===, Number=271
# ✅ Training NSE: 0.821, Validation NSE: 0.852
#    Training RMSE: 30.532, Validation RMSE: 31.720
#    Params: mu=1.044, lambda=40.970, Qs=0.001, qs=0.006
#
# === Station 39002 ===, Number=272
# ✅ Training NSE: 0.805, Validation NSE: 0.811
#    Training RMSE: 14.349, Validation RMSE: 17.077
#    Params: mu=1.040, lambda=37.221, Qs=0.001, qs=0.008
#
# === Station 39004 ===, Number=273
# ✅ Training NSE: 0.662, Validation NSE: 0.576
#    Training RMSE: 0.110, Validation RMSE: 0.129
#    Params: mu=0.986, lambda=63.373, Qs=0.001, qs=0.190
#
# === Station 39005 ===, Number=274
# ✅ Training NSE: 0.597, Validation NSE: 0.500
#    Training RMSE: 0.258, Validation RMSE: 0.246
#    Params: mu=1.652, lambda=100.000, Qs=0.142, qs=0.246
#
# === Station 39006 ===, Number=275
# ✅ Training NSE: 0.850, Validation NSE: 0.831
#    Training RMSE: 1.005, Validation RMSE: 1.393
#    Params: mu=1.121, lambda=38.123, Qs=5.793, qs=3.237
#
# === Station 39007 ===, Number=276
# ✅ Training NSE: 0.764, Validation NSE: 0.726
#    Training RMSE: 1.473, Validation RMSE: 1.896
# ...
#    Training RMSE: 0.640, Validation RMSE: 0.625
#    Params: mu=1.132, lambda=20.489, Qs=0.001, qs=0.063
#
# === Station 74001 ===, Number=584
# ✅ Training NSE: 0.737, Validation NSE: 0.716
#    Training RMSE: 3.244, Validation RMSE: 3.941
#    Params: mu=1.190, lambda=100.000, Qs=0.001, qs=0.019
#
# === Station 74005 ===, Number=585
# ✅ Training NSE: 0.705, Validation NSE: 0.728
#    Training RMSE: 2.969, Validation RMSE: 3.175
#    Params: mu=1.157, lambda=83.430, Qs=0.001, qs=0.020
#
# === Station 74006 ===, Number=586
# ✅ Training NSE: 0.707, Validation NSE: 0.702
#    Training RMSE: 1.080, Validation RMSE: 1.448
#    Params: mu=1.202, lambda=92.789, Qs=0.001, qs=0.027
#
# === Station 74007 ===, Number=587
# ✅ Training NSE: 0.696, Validation NSE: 0.703
#    Training RMSE: 3.112, Validation RMSE: 3.424
#    Params: mu=1.192, lambda=99.938, Qs=0.001, qs=0.021
#
# === Station 75003 ===, Number=588
# ✅ Training NSE: 0.777, Validation NSE: 0.775
#    Training RMSE: 8.476, Validation RMSE: 9.629
#    Params: mu=1.104, lambda=66.539, Qs=0.001, qs=0.021
#
# === Station 75004 ===, Number=589
# ✅ Training NSE: 0.730, Validation NSE: 0.735
#    Training RMSE: 3.196, Validation RMSE: 3.806
#    Params: mu=1.150, lambda=89.965, Qs=0.001, qs=0.025
#
# === Station 75017 ===, Number=590
# ✅ Training NSE: 0.792, Validation NSE: 0.746
#    Training RMSE: 1.322, Validation RMSE: 1.720
#    Params: mu=1.192, lambda=24.793, Qs=0.060, qs=0.290
#
# === Station 76003 ===, Number=591
# ✅ Training NSE: 0.806, Validation NSE: 0.759
#    Training RMSE: 8.392, Validation RMSE: 10.947
#    Params: mu=1.259, lambda=21.884, Qs=3.324, qs=2.177
#
# === Station 76005 ===, Number=592
# ✅ Training NSE: 0.739, Validation NSE: 0.697
#    Training RMSE: 12.402, Validation RMSE: 13.658
#    Params: mu=1.129, lambda=50.277, Qs=0.001, qs=0.009
#
# === Station 76007 ===, Number=593
# ✅ Training NSE: 0.758, Validation NSE: 0.729
#    Training RMSE: 31.617, Validation RMSE: 35.322
#    Params: mu=1.159, lambda=47.590, Qs=0.112, qs=0.068
#
# === Station 76008 ===, Number=594
# ✅ Training NSE: 0.664, Validation NSE: 0.599
#    Training RMSE: 6.813, Validation RMSE: 9.005
#    Params: mu=1.105, lambda=21.807, Qs=0.001, qs=0.018
#
# === Station 76011 ===, Number=595
# ✅ Training NSE: 0.657, Validation NSE: 0.577
#    Training RMSE: 0.048, Validation RMSE: 0.054
#    Params: mu=1.181, lambda=14.058, Qs=0.001, qs=0.338
#
# === Station 76014 ===, Number=596
# ✅ Training NSE: 0.758, Validation NSE: 0.690
#    Training RMSE: 2.374, Validation RMSE: 2.709
#    Params: mu=1.164, lambda=47.110, Qs=0.001, qs=0.026
#
# === Station 77002 ===, Number=597
# ✅ Training NSE: 0.723, Validation NSE: 0.689
#    Training RMSE: 12.125, Validation RMSE: 14.060
#    Params: mu=1.123, lambda=44.684, Qs=0.001, qs=0.012
#
# === Station 77003 ===, Number=598
# ✅ Training NSE: 0.682, Validation NSE: 0.647
#    Training RMSE: 8.974, Validation RMSE: 10.603
#    Params: mu=1.142, lambda=47.524, Qs=0.001, qs=0.011
#
# === Station 77004 ===, Number=599
# ✅ Training NSE: 0.719, Validation NSE: 0.673
#    Training RMSE: 1.392, Validation RMSE: 1.721
#    Params: mu=1.221, lambda=3.725, Qs=2.952, qs=8.240
#
# === Station 78003 ===, Number=600
# ✅ Training NSE: 0.730, Validation NSE: 0.721
#    Training RMSE: 19.029, Validation RMSE: 21.448
#    Params: mu=1.114, lambda=56.617, Qs=0.001, qs=0.008
#
# === Station 78004 ===, Number=601
# ✅ Training NSE: 0.671, Validation NSE: 0.612
#    Training RMSE: 2.568, Validation RMSE: 3.161
#    Params: mu=1.280, lambda=4.489, Qs=4.626, qs=10.243
#
# === Station 78006 ===, Number=602
# ✅ Training NSE: 0.715, Validation NSE: 0.608
#    Training RMSE: 5.804, Validation RMSE: 7.605
#    Params: mu=1.376, lambda=5.690, Qs=18.010, qs=13.894
#
# === Station 79002 ===, Number=603
# ✅ Training NSE: 0.721, Validation NSE: 0.710
#    Training RMSE: 19.179, Validation RMSE: 20.489
#    Params: mu=1.146, lambda=100.000, Qs=0.001, qs=0.006
#
# === Station 79003 ===, Number=604
# ✅ Training NSE: 0.682, Validation NSE: 0.645
#    Training RMSE: 5.135, Validation RMSE: 5.070
#    Params: mu=1.151, lambda=59.165, Qs=0.001, qs=0.018
#
# === Station 79004 ===, Number=605
# ✅ Training NSE: 0.695, Validation NSE: 0.594
#    Training RMSE: 4.590, Validation RMSE: 5.890
#    Params: mu=1.370, lambda=3.688, Qs=17.605, qs=21.161
#
# === Station 79005 ===, Number=606
# ✅ Training NSE: 0.707, Validation NSE: 0.600
#    Training RMSE: 5.925, Validation RMSE: 7.426
#    Params: mu=1.389, lambda=2.513, Qs=56.213, qs=40.564
#
# === Station 79006 ===, Number=607
# ✅ Training NSE: 0.717, Validation NSE: 0.702
#    Training RMSE: 13.141, Validation RMSE: 13.217
#    Params: mu=1.152, lambda=83.575, Qs=0.001, qs=0.008
#
# === Station 80001 ===, Number=608
# ✅ Training NSE: 0.729, Validation NSE: 0.616
#    Training RMSE: 4.149, Validation RMSE: 5.431
#    Params: mu=1.354, lambda=2.955, Qs=33.681, qs=28.577
#
# === Station 80002 ===, Number=609
# ✅ Training NSE: 0.721, Validation NSE: 0.704
#    Training RMSE: 21.539, Validation RMSE: 23.922
#    Params: mu=1.115, lambda=86.571, Qs=0.001, qs=0.010
#
# === Station 80003 ===, Number=610
# ✅ Training NSE: 0.702, Validation NSE: 0.663
#    Training RMSE: 0.319, Validation RMSE: 0.380
#    Params: mu=1.266, lambda=99.999, Qs=0.001, qs=0.078
#
# === Station 80004 ===, Number=611
# ✅ Training NSE: 0.695, Validation NSE: 0.597
#    Training RMSE: 0.175, Validation RMSE: 0.220
#    Params: mu=1.286, lambda=91.238, Qs=0.001, qs=0.110
#
# === Station 80005 ===, Number=612
# ✅ Training NSE: 0.685, Validation NSE: 0.640
#    Training RMSE: 0.126, Validation RMSE: 0.151
#    Params: mu=1.301, lambda=100.000, Qs=0.001, qs=0.123
#
# === Station 80006 ===, Number=613
# ✅ Training NSE: 0.718, Validation NSE: 0.751
#    Training RMSE: 0.547, Validation RMSE: 0.550
#    Params: mu=1.174, lambda=100.000, Qs=0.001, qs=0.078
#
# === Station 8004 ===, Number=614
# ✅ Training NSE: 0.447, Validation NSE: 0.273
#    Training RMSE: 10.724, Validation RMSE: 13.421
#    Params: mu=1.272, lambda=100.000, Qs=0.176, qs=0.107
#
# === Station 8005 ===, Number=615
# ✅ Training NSE: 0.607, Validation NSE: 0.561
#    Training RMSE: 19.277, Validation RMSE: 17.277
#    Params: mu=1.228, lambda=76.460, Qs=0.418, qs=0.201
#
# === Station 8006 ===, Number=616
# ✅ Training NSE: 0.587, Validation NSE: 0.445
#    Training RMSE: 35.690, Validation RMSE: 40.624
#    Params: mu=1.286, lambda=87.857, Qs=2.196, qs=0.245
#
# === Station 8009 ===, Number=617
# ✅ Training NSE: 0.494, Validation NSE: 0.383
#    Training RMSE: 5.760, Validation RMSE: 6.165
#    Params: mu=1.301, lambda=44.466, Qs=0.352, qs=0.310
#
# === Station 8011 ===, Number=618
# ✅ Training NSE: 0.531, Validation NSE: 0.311
#    Training RMSE: 1.509, Validation RMSE: 2.034
#    Params: mu=1.257, lambda=80.519, Qs=0.026, qs=0.101
#
# === Station 8013 ===, Number=619
# ⚠️ Too many missing values (15.5%)
#
# === Station 81002 ===, Number=620
# ✅ Training NSE: 0.644, Validation NSE: 0.617
#    Training RMSE: 12.264, Validation RMSE: 12.933
#    Params: mu=1.158, lambda=95.429, Qs=0.001, qs=0.010
#
# === Station 81003 ===, Number=621
# ✅ Training NSE: 0.624, Validation NSE: 0.586
#    Training RMSE: 5.759, Validation RMSE: 6.726
#    Params: mu=1.260, lambda=3.133, Qs=17.314, qs=16.195
#
# === Station 81004 ===, Number=622
# ✅ Training NSE: 0.624, Validation NSE: 0.578
#    Training RMSE: 7.658, Validation RMSE: 8.861
#    Params: mu=1.314, lambda=3.512, Qs=52.282, qs=24.658
#
# === Station 81006 ===, Number=623
# ✅ Training NSE: 0.643, Validation NSE: 0.619
#    Training RMSE: 5.903, Validation RMSE: 6.555
#    Params: mu=1.179, lambda=100.000, Qs=0.001, qs=0.016
#
# === Station 81007 ===, Number=624
# ✅ Training NSE: 0.597, Validation NSE: 0.545
#    Training RMSE: 3.102, Validation RMSE: 3.524
#    Params: mu=1.343, lambda=3.273, Qs=9.820, qs=22.321
#
# === Station 82001 ===, Number=625
# ✅ Training NSE: 0.680, Validation NSE: 0.679
#    Training RMSE: 5.690, Validation RMSE: 6.278
#    Params: mu=1.132, lambda=42.542, Qs=0.001, qs=0.018
#
# === Station 82003 ===, Number=626
# ✅ Training NSE: 0.669, Validation NSE: 0.672
#    Training RMSE: 7.807, Validation RMSE: 9.019
#    Params: mu=1.149, lambda=63.663, Qs=0.001, qs=0.013
#
# === Station 83003 ===, Number=627
# ✅ Training NSE: 0.662, Validation NSE: 0.616
#    Training RMSE: 4.392, Validation RMSE: 4.710
#    Params: mu=1.167, lambda=66.933, Qs=0.001, qs=0.014
#
# === Station 83004 ===, Number=628
# ✅ Training NSE: 0.680, Validation NSE: 0.612
#    Training RMSE: 4.794, Validation RMSE: 5.321
#    Params: mu=1.159, lambda=58.357, Qs=0.001, qs=0.014
#
# === Station 83006 ===, Number=629
# ✅ Training NSE: 0.665, Validation NSE: 0.597
#    Training RMSE: 13.162, Validation RMSE: 15.773
#    Params: mu=1.117, lambda=33.401, Qs=0.001, qs=0.012
#
# === Station 83007 ===, Number=630
# ✅ Training NSE: 0.704, Validation NSE: 0.618
#    Training RMSE: 1.462, Validation RMSE: 1.503
#    Params: mu=1.133, lambda=25.536, Qs=0.001, qs=0.045
#
# === Station 83009 ===, Number=631
# ✅ Training NSE: 0.629, Validation NSE: 0.595
#    Training RMSE: 6.340, Validation RMSE: 5.612
#    Params: mu=1.142, lambda=38.243, Qs=0.001, qs=0.020
#
# === Station 83010 ===, Number=632
# ✅ Training NSE: 0.732, Validation NSE: 0.703
#    Training RMSE: 1.837, Validation RMSE: 1.856
#    Params: mu=1.172, lambda=51.580, Qs=0.001, qs=0.023
#
# === Station 83013 ===, Number=633
# ✅ Training NSE: 0.643, Validation NSE: 0.613
#    Training RMSE: 6.407, Validation RMSE: 5.658
#    Params: mu=1.131, lambda=31.211, Qs=0.001, qs=0.018
#
# === Station 84001 ===, Number=634
# ✅ Training NSE: 0.751, Validation NSE: 0.740
#    Training RMSE: 5.177, Validation RMSE: 5.525
#    Params: mu=1.144, lambda=71.658, Qs=0.001, qs=0.012
#
# === Station 84004 ===, Number=635
# ✅ Training NSE: 0.696, Validation NSE: 0.639
#    Training RMSE: 12.839, Validation RMSE: 15.668
#    Params: mu=1.262, lambda=28.199, Qs=2.349, qs=0.846
#
# === Station 84005 ===, Number=636
# ✅ Training NSE: 0.749, Validation NSE: 0.713
#    Training RMSE: 26.857, Validation RMSE: 30.307
#    Params: mu=1.171, lambda=39.733, Qs=0.186, qs=0.103
#
# === Station 84008 ===, Number=637
# ✅ Training NSE: 0.692, Validation NSE: 0.689
#    Training RMSE: 1.402, Validation RMSE: 1.653
#    Params: mu=1.190, lambda=72.751, Qs=0.001, qs=0.022
#
# === Station 84009 ===, Number=638
# ✅ Training NSE: 0.760, Validation NSE: 0.699
#    Training RMSE: 1.195, Validation RMSE: 1.375
#    Params: mu=1.170, lambda=34.141, Qs=0.003, qs=0.068
#
# === Station 84012 ===, Number=639
# ✅ Training NSE: 0.727, Validation NSE: 0.688
#    Training RMSE: 5.165, Validation RMSE: 4.711
#    Params: mu=1.146, lambda=55.027, Qs=0.001, qs=0.015
#
# === Station 84013 ===, Number=640
# ✅ Training NSE: 0.728, Validation NSE: 0.718
#    Training RMSE: 30.694, Validation RMSE: 30.049
#    Params: mu=1.139, lambda=58.910, Qs=0.010, qs=0.017
#
# === Station 84014 ===, Number=641
# ✅ Training NSE: 0.703, Validation NSE: 0.693
#    Training RMSE: 6.791, Validation RMSE: 6.655
#    Params: mu=1.150, lambda=55.705, Qs=0.001, qs=0.012
#
# === Station 84016 ===, Number=642
# ✅ Training NSE: 0.667, Validation NSE: 0.689
#    Training RMSE: 0.732, Validation RMSE: 0.599
#    Params: mu=1.164, lambda=36.308, Qs=0.001, qs=0.041
#
# === Station 84017 ===, Number=643
# ✅ Training NSE: 0.747, Validation NSE: 0.741
#    Training RMSE: 2.839, Validation RMSE: 2.616
#    Params: mu=1.140, lambda=62.092, Qs=0.001, qs=0.028
#
# === Station 84018 ===, Number=644
# ✅ Training NSE: 0.704, Validation NSE: 0.609
#    Training RMSE: 17.357, Validation RMSE: 20.753
#    Params: mu=1.185, lambda=38.475, Qs=0.289, qs=0.193
#
# === Station 84019 ===, Number=645
# ✅ Training NSE: 0.690, Validation NSE: 0.679
#    Training RMSE: 2.033, Validation RMSE: 1.882
#    Params: mu=1.152, lambda=48.658, Qs=0.001, qs=0.018
#
# === Station 84020 ===, Number=646
# ✅ Training NSE: 0.690, Validation NSE: 0.649
#    Training RMSE: 1.803, Validation RMSE: 1.761
#    Params: mu=1.196, lambda=77.978, Qs=0.001, qs=0.023
#
# === Station 84022 ===, Number=647
# ✅ Training NSE: 0.653, Validation NSE: 0.637
#    Training RMSE: 2.749, Validation RMSE: 2.728
#    Params: mu=1.157, lambda=49.501, Qs=0.001, qs=0.023
#
# === Station 84026 ===, Number=648
# ✅ Training NSE: 0.733, Validation NSE: 0.295
#    Training RMSE: 1.014, Validation RMSE: 1.321
#    Params: mu=1.228, lambda=2.634, Qs=5.768, qs=26.874
#
# === Station 84030 ===, Number=649
# ✅ Training NSE: 0.754, Validation NSE: 0.728
#    Training RMSE: 2.531, Validation RMSE: 2.770
#    Params: mu=1.168, lambda=59.129, Qs=0.001, qs=0.019
#
# === Station 85001 ===, Number=650
# ✅ Training NSE: 0.811, Validation NSE: 0.742
#    Training RMSE: 14.759, Validation RMSE: 16.132
#    Params: mu=1.712, lambda=7.579, Qs=196.113, qs=50.003
#
# === Station 85002 ===, Number=651
# ✅ Training NSE: 0.697, Validation NSE: 0.616
#    Training RMSE: 6.390, Validation RMSE: 8.971
#    Params: mu=1.161, lambda=70.984, Qs=0.001, qs=0.013
#
# === Station 85003 ===, Number=652
# ✅ Training NSE: 0.655, Validation NSE: 0.390
#    Training RMSE: 6.286, Validation RMSE: 6.589
#    Params: mu=1.136, lambda=23.602, Qs=0.001, qs=0.055
#
# === Station 85004 ===, Number=653
# ✅ Training NSE: 0.714, Validation NSE: 0.612
#    Training RMSE: 1.777, Validation RMSE: 1.776
#    Params: mu=1.215, lambda=100.000, Qs=0.001, qs=0.029
#
# === Station 88001 ===, Number=654
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 ===, Number=655
# ✅ Training NSE: 0.621, Validation NSE: 0.500
#    Training RMSE: 4.595, Validation RMSE: 5.045
#    Params: mu=1.205, lambda=100.000, Qs=0.001, qs=0.028
#
# === Station 89003 ===, Number=656
# ✅ Training NSE: 0.648, Validation NSE: 0.558
#    Training RMSE: 22.340, Validation RMSE: 24.069
#    Params: mu=1.156, lambda=73.821, Qs=0.001, qs=0.014
#
# === Station 89005 ===, Number=657
# ✅ Training NSE: 0.518, Validation NSE: 0.359
#    Training RMSE: 6.511, Validation RMSE: 6.997
#    Params: mu=1.183, lambda=9.311, Qs=0.193, qs=1.863
#
# === Station 89007 ===, Number=658
# ✅ Training NSE: 0.569, Validation NSE: 0.455
#    Training RMSE: 1.587, Validation RMSE: 1.357
#    Params: mu=1.228, lambda=100.000, Qs=0.001, qs=0.040
#
# === Station 90003 ===, Number=659
# ✅ Training NSE: 0.683, Validation NSE: 0.680
#    Training RMSE: 5.141, Validation RMSE: 4.639
#    Params: mu=1.195, lambda=99.100, Qs=0.001, qs=0.025
#
# === Station 9002 ===, Number=660
# ✅ Training NSE: 0.669, Validation NSE: 0.450
#    Training RMSE: 11.240, Validation RMSE: 17.566
#    Params: mu=1.161, lambda=43.109, Qs=0.077, qs=0.081
#
# === Station 9003 ===, Number=661
# ✅ Training NSE: 0.681, Validation NSE: 0.432
#    Training RMSE: 2.369, Validation RMSE: 3.756
#    Params: mu=1.115, lambda=28.483, Qs=0.001, qs=0.022
#
# === Station 9004 ===, Number=662
# ✅ Training NSE: 0.716, Validation NSE: 0.540
#    Training RMSE: 1.608, Validation RMSE: 1.948
#    Params: mu=1.199, lambda=41.228, Qs=0.144, qs=0.344
#
# === Station 9005 ===, Number=663
# ✅ Training NSE: 0.524, Validation NSE: 0.321
#    Training RMSE: 1.474, Validation RMSE: 1.994
#    Params: mu=1.166, lambda=59.422, Qs=0.001, qs=0.024
#
# === Station 92001 ===, Number=664
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 ===, Number=665
# ✅ Training NSE: 0.666, Validation NSE: 0.708
#    Training RMSE: 8.593, Validation RMSE: 7.212
#    Params: mu=1.181, lambda=100.000, Qs=0.001, qs=0.018
#
# === Station 94001 ===, Number=666
# ✅ Training NSE: 0.784, Validation NSE: 0.837
#    Training RMSE: 11.265, Validation RMSE: 8.836
#    Params: mu=1.205, lambda=100.000, Qs=0.193, qs=0.258
#
# === Station 95001 ===, Number=667
# ✅ Training NSE: 0.725, Validation NSE: 0.753
#    Training RMSE: 3.259, Validation RMSE: 2.874
#    Params: mu=1.211, lambda=100.000, Qs=0.054, qs=0.239
#
# === Station 96001 ===, Number=668
# ✅ Training NSE: 0.529, Validation NSE: 0.443
#    Training RMSE: 5.134, Validation RMSE: 5.209
#    Params: mu=1.312, lambda=2.650, Qs=24.377, qs=21.391
#
# === Station 96002 ===, Number=669
# ✅ Training NSE: 0.693, Validation NSE: 0.661
#    Training RMSE: 10.243, Validation RMSE: 10.115
#    Params: mu=1.142, lambda=100.000, Qs=0.001, qs=0.009
#
# === Station 96004 ===, Number=670
# ✅ Training NSE: 0.560, Validation NSE: 0.538
#    Training RMSE: 7.180, Validation RMSE: 6.897
#    Params: mu=1.143, lambda=30.871, Qs=0.001, qs=0.040
#
# === Station 97002 ===, Number=671
# ✅ Training NSE: 0.576, Validation NSE: 0.437
#    Training RMSE: 7.440, Validation RMSE: 9.645
#    Params: mu=1.133, lambda=72.105, Qs=0.001, qs=0.010
#
# ✅ Simulation terminée pour 623 bassins valides (≤10% de NaN).

# %% [markdown]
# ## 5. SAVE SUMMARY

# %%
rows = []

for station_id, res in results.items():
    MU, LAMBDA, Qs_best, qs_best = res["params"]

    rows.append({
        "station_id": station_id,
        "MU": MU,
        "LAMBDA": LAMBDA,
        "Qs": Qs_best,
        "qs": qs_best,
        "NSE_train": res["NSE_train"],
        "NSE_val": res["NSE_val"],
        "RMSE_train": res["RMSE_train"],
        "RMSE_val": res["RMSE_val"],
        "missing_ratio": res["missing_ratio"],
        "missing_count": res["missing_count"],
    })

df = pd.DataFrame(rows)

# Local save
df.to_csv("dHyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)

df.head()

# Save to Google Drive
from google.colab import drive
drive.mount("/content/drive")

df.to_csv(
    "/content/drive/MyDrive/dHyMoLAP_Simulation_Data_CAMELS_GB.csv",
    index=False
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nse_values = [res['NSE_val'] for res in results.values()]

if nse_values:
    nse_median = np.median(nse_values)
    nse_mean = np.mean(nse_values)
    nse_min = np.min(nse_values)
    nse_max = np.max(nse_values)
    nse_5th = np.percentile(nse_values, 5)
    nse_95th = np.percentile(nse_values, 95)

    print(f"NSE Validation -> Mean: {nse_mean:.3f}, Median {nse_median:.3f}, Min: {nse_min:.3f}, Max: {nse_max:.3f}, 5th percentile: {nse_5th:.3f}, 95th percentile: {nse_95th:.3f}")
else:
    print("No stations processed (all contain missing values).")
# Out:
# NSE Validation -> Mean: 0.650, Median 0.680, Min: -1.764, Max: 0.893, 5th percentile: 0.432, 95th percentile: 0.806

# %%
rmse_values = [res['RMSE_val'] for res in results.values()]

if rmse_values:
    rmse_median = np.median(rmse_values)
    rmse_mean = np.mean(rmse_values)
    rmse_min = np.min(rmse_values)
    rmse_max = np.max(rmse_values)
    rmse_5th = np.percentile(rmse_values, 5)
    rmse_95th = np.percentile(rmse_values, 95)

    print(
        f"RMSE Validation -> Mean: {rmse_mean:.3f}, Median {rmse_median:.3f}, "
        f"Min: {rmse_min:.3f}, Max: {rmse_max:.3f}, "
        f"5th percentile: {rmse_5th:.3f}, 95th percentile: {rmse_95th:.3f}"
    )
else:
    print("No stations processed (all contain missing values).")
# Out:
# RMSE Validation -> Mean: 5.234, Median 2.017, Min: 0.022, Max: 82.058, 5th percentile: 0.155, 95th percentile: 22.770
