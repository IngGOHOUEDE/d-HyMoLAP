# %% [markdown]
#  **This notebook imprement d-HyMoLAP (dimensionally consistent reformulation of HyMoLAP rainfall-runoff Model) run over CAMELS-GB dataset catchments with less than 10% of missing data, and stock results (parameters and performance metrics) in dHyMoLAP_Simulation_Data_CAMELS_GB.csv**
#
# **Author:** Lionel Cedric Gohouede

# %% [markdown]
# ## 1. MOUNT GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import warnings
from numba import njit
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# ## 3. FILTER DATA BY TIME PERIOD (1990-2014)

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/CAMELS_GB/'
start_date, end_date = '1990-01-01', '2014-12-31'

print("Loading, filtering, and aligning CSV files...\n")

# 1. Fast Load & Filter
df_pcp = pd.read_csv(f"{data_dir}pcp_mm.csv", index_col=0).loc[start_date:end_date]
df_pet = pd.read_csv(f"{data_dir}pet_mm.csv", index_col=0).loc[start_date:end_date]
df_q   = pd.read_csv(f"{data_dir}q_cms_obs.csv", index_col=0).loc[start_date:end_date]

# 2. Fast Alignment
common_stations = sorted(list(set(df_pcp.columns) & set(df_pet.columns) & set(df_q.columns)))
df_pcp = df_pcp[common_stations]
df_pet = df_pet[common_stations]
df_q   = df_q[common_stations]

print(f"✅ Data aligned. Total common stations: {len(common_stations)}")

# ============================================
# Memory-Optimized Wrapper Classes
# ============================================
class SimpleArray:
    __slots__ = ['array']  # Prevents massive RAM bloat
    def __init__(self, array):
        self.array = array
    def to_numpy(self):
        return self.array

class StationData:
    __slots__ = ['data']
    def __init__(self, data_dict):
        self.data = data_dict
    def sel(self, dynamic_features=None):
        return SimpleArray(self.data[dynamic_features])

# ============================================
# Ultra-Fast Dictionary Construction
# ============================================
print("Building ds_recent dictionary...\n")

# Convert DataFrames to 2D NumPy matrices once (orders of magnitude faster than column iteration)
pcp_arr = df_pcp.to_numpy()
pet_arr = df_pet.to_numpy()
q_arr   = df_q.to_numpy()
date_arr = pd.to_datetime(df_pcp.index).to_numpy()

# Build the dictionary using fast index slicing
ds_recent = {
    st: StationData({
        'pcp_mm': pcp_arr[:, i],
        'pet_mm': pet_arr[:, i],
        'q_cms_obs': q_arr[:, i],
        'date': date_arr
    })
    for i, st in enumerate(common_stations)
}

print(f"✅ Dictionary built successfully!")

# ============================================
# Validation Test
# ============================================
test_station = common_stations[0]
print(f"\nTesting data access for station: {test_station}")

Q_obs = ds_recent[test_station].sel(dynamic_features="q_cms_obs").to_numpy()
P     = ds_recent[test_station].sel(dynamic_features="pcp_mm").to_numpy()
PET   = ds_recent[test_station].sel(dynamic_features="pet_mm").to_numpy()

print(f"✅ Extraction works correctly!")
print(f"   Q_obs shape: {Q_obs.shape}")
print(f"   Q_obs - min: {np.nanmin(Q_obs):.2f}, max: {np.nanmax(Q_obs):.2f}, mean: {np.nanmean(Q_obs):.2f}")
print(f"   Q_obs Missing: {np.sum(np.isnan(Q_obs))} ({np.sum(np.isnan(Q_obs))/len(Q_obs)*100:.1f}%)")
# Out:
# Loading, filtering, and aligning CSV files...
#
# ✅ Data aligned. Total common stations: 671
# Building ds_recent dictionary...
#
# ✅ Dictionary built successfully!
#
# Testing data access for station: 10002
# ✅ Extraction works correctly!
#    Q_obs shape: (9131,)
#    Q_obs - min: 0.80, max: 94.41, mean: 5.18
#    Q_obs Missing: 0 (0.0%)

# %% [markdown]
# ## 4. MAIN CODE

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from numba import njit

# ============================================
# 1. COMPILED MODEL & FAST METRICS (OUTSIDE THE LOOP)
# ============================================
@njit
def dHyMoLAP_Model(params, Q0, q):
    mu, lambda_, Qs, qs = params
    N = len(q)
    k = np.zeros(N)
    x = np.zeros(N)

    if Qs <= 0.0 or qs <= 0.0 or lambda_ <= 0.0 or mu <= 0.0:
        return np.full(N, np.nan)

    k[0] = Q0 / Qs

    mu_lam = mu / lambda_
    one_m_mu_lam = 1.0 - mu_lam
    inv_lam = 1.0 / lambda_
    pow_term = 2.0 * mu - 1.0

    for t in range(N - 1):
        r_next = q[t+1] / qs

        if np.isnan(r_next):
            k[t+1] = k[t]
            x[t+1] = x[t]
            continue

        if r_next > 0.0:
            x[t+1] = x[t] + mu_lam * r_next
        else:
            x[t+1] = one_m_mu_lam * x[t]

        k_base = max(0.0, k[t])
        k[t+1] = max(0.0, k[t] - mu_lam * (k_base ** pow_term) + inv_lam * x[t+1] * r_next)

    return k * Qs


def NSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0 or np.var(valid_obs) == 0.0:
        return np.nan
    return 1.0 - (np.sum((valid_sim - valid_obs)**2) / np.sum((valid_obs - np.mean(valid_obs))**2))


def RMSE(obs, sim):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    valid_obs, valid_sim = obs[mask], sim[mask]
    if valid_obs.size == 0:
        return np.nan
    return np.sqrt(np.mean((valid_sim - valid_obs)**2))


def compute_pte(obs, sim, dates):
    """Computes Mean Absolute Annual Peak Timing Error (PTE) in days."""
    df = pd.DataFrame({'obs': obs, 'sim': sim}, index=pd.DatetimeIndex(dates))
    df = df.dropna()

    if df.empty:
        return np.nan

    pte_list = []
    for year, group in df.groupby(df.index.year):
        days_in_year = pd.Timestamp(year, 12, 31).dayofyear
        if len(group) < 0.8 * days_in_year:
            continue

        idx_obs_peak = group['obs'].idxmax()
        idx_sim_peak = group['sim'].idxmax()

        diff_days = abs((idx_sim_peak - idx_obs_peak).days)
        pte_list.append(diff_days)

    return np.mean(pte_list) if pte_list else np.nan


def compute_all_metrics(obs, sim, dates):
    mask = ~np.isnan(obs) & ~np.isnan(sim)
    o = obs[mask]
    s = sim[mask]
    L_len = o.size

    if L_len == 0:
        return dict(NSE=np.nan, NNSE=np.nan, RMSE=np.nan,
                    PBIAS=np.nan, FHV=np.nan, FLV=np.nan, KGE=np.nan, PTE=np.nan)

    # 1. Base Metrics
    obs_mean = np.mean(o)
    sim_mean = np.mean(s)
    denom = np.sum((o - obs_mean) ** 2)

    if denom == 0.0:
        nse = np.nan
        nnse = np.nan
    else:
        nse = 1.0 - np.sum((s - o) ** 2) / denom
        nnse = 1.0 / (2.0 - nse) if np.isfinite(nse) else np.nan

    rmse = np.sqrt(np.mean((s - o) ** 2))

    # 2. Water Balance / PBIAS (Yilmaz 2008, Eq A1)
    sum_obs = np.sum(o)
    pbias = 100.0 * np.sum(s - o) / sum_obs if sum_obs != 0.0 else np.nan

    # 3. Flow Duration Curve (FDC) Metrics (FHV, FLV)
    o_sorted = np.sort(o)[::-1]
    s_sorted = np.sort(s)[::-1]

    n_hv = max(1, int(round(0.02 * L_len)))
    sum_obs_hv = np.sum(o_sorted[:n_hv])
    sum_sim_hv = np.sum(s_sorted[:n_hv])
    fhv = 100.0 * (sum_sim_hv - sum_obs_hv) / sum_obs_hv if sum_obs_hv != 0.0 else np.nan

    n_lv = max(1, int(round(0.30 * L_len)))
    epsilon = 1e-6
    o_low = o_sorted[-n_lv:]
    s_low = s_sorted[-n_lv:]

    log_o = np.log(o_low + epsilon)
    log_s = np.log(s_low + epsilon)
    log_o_L = np.log(o_sorted[-1] + epsilon)
    log_s_L = np.log(s_sorted[-1] + epsilon)

    term_o = np.sum(log_o - log_o_L)
    term_s = np.sum(log_s - log_s_L)

    flv = -100.0 * (term_s - term_o) / term_o if term_o != 0.0 else np.nan

    # 4. KGE (Kling-Gupta Efficiency)
    sigma_obs = np.std(o)
    sigma_sim = np.std(s)
    if sigma_obs == 0.0 or sigma_sim == 0.0 or obs_mean == 0.0:
        kge = np.nan
    else:
        r_val = np.corrcoef(o, s)[0, 1]
        alpha = sigma_sim / sigma_obs
        beta = sim_mean / obs_mean
        if not np.isfinite(r_val):
            kge = np.nan
        else:
            kge = 1.0 - np.sqrt((r_val - 1.0) ** 2 + (alpha - 1.0) ** 2 + (beta - 1.0) ** 2)

    # 5. Peak Time Error (Annual)
    pte = compute_pte(obs, sim, dates)

    return dict(NSE=nse, NNSE=nnse, RMSE=rmse, PBIAS=pbias,
                FHV=fhv, FLV=flv, KGE=kge, PTE=pte)


def objective(params, Q0, q_train, Q_obs_train):
    Q_sim = dHyMoLAP_Model(params, Q0, q_train)
    nse = NSE(Q_obs_train, Q_sim)
    return 1.0 - nse if np.isfinite(nse) else 1e9


# ============================================
# 2. OPTIMIZED EXECUTION LOOP
# ============================================
all_stations = list(ds_recent.keys())
b1_ratio = 0.7
max_missing_ratio = 0.1
results = {}

MU_BOUNDS = (0.5, 5.0)
LAMBDA_BOUNDS = (1e-3, 200.0)

for i, station_id in enumerate(all_stations, 1):
    print(f"\n=== Station {station_id} ===, Number={i}")

    Q_obs = ds_recent[station_id].sel(dynamic_features="q_cms_obs").to_numpy()
    P     = ds_recent[station_id].sel(dynamic_features="pcp_mm").to_numpy()
    PET   = ds_recent[station_id].sel(dynamic_features="pet_mm").to_numpy()

    # Extract temporal components properly via StationData wrapper
    dates = ds_recent[station_id].sel(dynamic_features="date").to_numpy()
    time_months = pd.DatetimeIndex(dates).month.to_numpy()

    q = np.maximum(0.0, P - PET)
    N = len(Q_obs)

    if N == 0 or np.all(np.isnan(Q_obs)):
        print("⚠️ Station skipped (no valid data).")
        continue

    missing_count = np.sum(np.isnan(Q_obs))
    missing_ratio = missing_count / N
    if missing_ratio > max_missing_ratio:
        print(f"⚠️ Too many missing values ({missing_ratio*100:.1f}%)")
        continue

    # Global Runoff Ratio
    total_p = np.nansum(P)
    RR = np.nansum(Q_obs) / total_p if total_p > 0 else np.nan

    b1 = int(N * b1_ratio)
    if not np.isnan(Q_obs[0]):
        Q0 = Q_obs[0]
    elif np.any(~np.isnan(Q_obs[:10])):
        Q0 = np.nanmean(Q_obs[:10])
    elif np.any(~np.isnan(Q_obs)):
        Q0 = np.nanmean(Q_obs)   # fall back to the whole series' mean
    else:
        Q0 = 0.0                 # last-resort, always finite

    q_train = q[:b1]
    Q_obs_train = Q_obs[:b1]

    Qs_max_train = np.nanmax(Q_obs_train) if np.any(~np.isnan(Q_obs_train)) else np.nan
    qs_max_train = np.nanmax(q_train) if np.any(~np.isnan(q_train)) else np.nan

    if not np.isfinite(Qs_max_train) or not np.isfinite(qs_max_train):
        print("⚠️ Station skipped (no finite training values to derive Qs/qs bounds).")
        continue

    Qs_upper = 2.0 * Qs_max_train
    qs_upper = 2.0 * qs_max_train

    param_bounds = [MU_BOUNDS, LAMBDA_BOUNDS, (1e-3, Qs_upper), (1e-3, qs_upper)]

    initial_guess = np.array([
        1.1,
        20.0,
        np.clip(np.nanmean(Q_obs_train), 1e-3, Qs_upper),
        np.clip(np.nanmean(q_train), 1e-3, qs_upper),
    ])

    res = minimize(
        objective,
        initial_guess,
        args=(Q0, q_train, Q_obs_train),
        method="Nelder-Mead",
        bounds=param_bounds,
        options={'maxiter': 2500, 'disp': False}
    )

    MU, LAMBDA, Qs_best, qs_best = res.x

    # Full-period simulation
    Qsim = dHyMoLAP_Model(res.x, Q0, q)

    m_train = compute_all_metrics(Q_obs_train, Qsim[:b1], dates[:b1])
    m_val   = compute_all_metrics(Q_obs[b1:], Qsim[b1:], dates[b1:])

    print(f"✅ Training NSE: {m_train['NSE']:.3f}, Validation NSE: {m_val['NSE']:.3f}")
    print(f"   Training KGE: {m_train['KGE']:.3f}, Validation KGE: {m_val['KGE']:.3f}")
    print(f"   Training RMSE: {m_train['RMSE']:.3f} m³/s, Validation RMSE: {m_val['RMSE']:.3f} m³/s")
    print(f"   Training PBIAS: {m_train['PBIAS']:.3f}, Validation PBIAS: {m_val['PBIAS']:.3f}")
    print(f"   Params: mu={MU:.3f}, lambda={LAMBDA:.3f}, Qs={Qs_best:.3f}, qs={qs_best:.3f}")
    print(f"   Bounds used: Qs=({1e-3}, {Qs_upper:.3f}), qs=({1e-3}, {qs_upper:.3f})")

    station_result = {
        "param_names": ["mu", "lambda", "Qs", "qs"],
        "params": res.x.tolist(),
        "param_bounds": param_bounds,
        "NSE_train": m_train["NSE"],     "NSE_val": m_val["NSE"],
        "NNSE_train": m_train["NNSE"],   "NNSE_val": m_val["NNSE"],
        "RMSE_train": m_train["RMSE"],   "RMSE_val": m_val["RMSE"],
        "PBIAS_train": m_train["PBIAS"], "PBIAS_val": m_val["PBIAS"],
        "FHV_train": m_train["FHV"],     "FHV_val": m_val["FHV"],
        "FLV_train": m_train["FLV"],     "FLV_val": m_val["FLV"],
        "KGE_train": m_train["KGE"],     "KGE_val": m_val["KGE"],
        "PTE_train": m_train["PTE"],     "PTE_val": m_val["PTE"],
        "RR": RR,
        "Qsim": Qsim,
        "missing_ratio": missing_ratio,
        "missing_count": missing_count,
    }

    # -----------------------------------------------------------------
    # Extract Seasonal Metrics
    # -----------------------------------------------------------------
    seasons_map = {
        "DJF": [12, 1, 2],
        "MAM": [3, 4, 5],
        "JJA": [6, 7, 8],
        "SON": [9, 10, 11]
    }

    months_train = time_months[:b1]
    months_val = time_months[b1:]

    for season, m_list in seasons_map.items():
        mask_train = np.isin(months_train, m_list)
        mask_val = np.isin(months_val, m_list)

        if np.any(mask_train):
            s_train_metrics = compute_all_metrics(Q_obs_train[mask_train], Qsim[:b1][mask_train], dates[:b1][mask_train])
        else:
            s_train_metrics = {k: np.nan for k in m_train.keys()}

        if np.any(mask_val):
            s_val_metrics = compute_all_metrics(Q_obs[b1:][mask_val], Qsim[b1:][mask_val], dates[b1:][mask_val])
        else:
            s_val_metrics = {k: np.nan for k in m_val.keys()}

        station_result[f"NSE_{season}_train"] = s_train_metrics["NSE"]
        station_result[f"NSE_{season}_val"] = s_val_metrics["NSE"]
        station_result[f"KGE_{season}_train"] = s_train_metrics["KGE"]
        station_result[f"KGE_{season}_val"] = s_val_metrics["KGE"]
        station_result[f"RMSE_{season}_train"] = s_train_metrics["RMSE"]
        station_result[f"RMSE_{season}_val"] = s_val_metrics["RMSE"]
        station_result[f"PBIAS_{season}_train"] = s_train_metrics["PBIAS"]
        station_result[f"PBIAS_{season}_val"] = s_val_metrics["PBIAS"]

    results[station_id] = station_result

print(f"\n✅ Simulation done for {len(results)} valid catchments (≤10% de NaN).")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Station 13001 ===, Number=19
# ✅ Training NSE: 0.743, Validation NSE: 0.721
#    Training KGE: 0.808, Validation KGE: 0.834
#    Training RMSE: 1.370 m³/s, Validation RMSE: 1.531 m³/s
#    Training PBIAS: -0.805, Validation PBIAS: 7.429
#    Params: mu=1.207, lambda=30.874, Qs=0.076, qs=0.241
#    Bounds used: Qs=(0.001, 102.240), qs=(0.001, 134.120)
#
# === Station 13004 ===, Number=20
# ✅ Training NSE: 0.696, Validation NSE: 0.615
#    Training KGE: 0.779, Validation KGE: 0.687
#    Training RMSE: 1.937 m³/s, Validation RMSE: 2.800 m³/s
#    Training PBIAS: -2.199, Validation PBIAS: -8.107
#    Params: mu=1.405, lambda=9.176, Qs=4.795, qs=6.384
#    Bounds used: Qs=(0.001, 108.700), qs=(0.001, 135.900)
#
# === Station 13005 ===, Number=21
# ✅ Training NSE: 0.750, Validation NSE: -0.465
#    Training KGE: 0.805, Validation KGE: 0.322
#    Training RMSE: 1.140 m³/s, Validation RMSE: 3.159 m³/s
#    Training PBIAS: 1.211, Validation PBIAS: 23.329
#    Params: mu=1.103, lambda=33.840, Qs=0.001, qs=0.027
#    Bounds used: Qs=(0.001, 60.000), qs=(0.001, 116.940)
#
# === Station 13007 ===, Number=22
# ✅ Training NSE: 0.707, Validation NSE: 0.586
#    Training KGE: 0.785, Validation KGE: 0.710
#    Training RMSE: 12.427 m³/s, Validation RMSE: 17.604 m³/s
#    Training PBIAS: -2.038, Validation PBIAS: -1.429
#    Params: mu=1.386, lambda=6.135, Qs=47.973, qs=9.379
#    Bounds used: Qs=(0.001, 754.000), qs=(0.001, 125.300)
#
# === Station 13008 ===, Number=23
# ✅ Training NSE: 0.680, Validation NSE: 0.575
#    Training KGE: 0.763, Validation KGE: 0.724
#    Training RMSE: 7.401 m³/s, Validation RMSE: 9.963 m³/s
#    Training PBIAS: -1.589, Validation PBIAS: -2.812
#    Params: mu=1.440, lambda=6.028, Qs=42.007, qs=13.340
#    Bounds used: Qs=(0.001, 297.600), qs=(0.001, 120.200)
#
# === Station 14001 ===, Number=24
# ✅ Training NSE: 0.770, Validation NSE: 0.706
#    Training KGE: 0.842, Validation KGE: 0.818
#    Training RMSE: 2.052 m³/s, Validation RMSE: 2.535 m³/s
#    Training PBIAS: -2.483, Validation PBIAS: 2.578
#    Params: mu=1.145, lambda=39.593, Qs=0.024, qs=0.089
#    Bounds used: Qs=(0.001, 102.180), qs=(0.001, 142.140)
#
# === Station 14002 ===, Number=25
# ✅ Training NSE: 0.734, Validation NSE: -0.533
#    Training KGE: 0.801, Validation KGE: 0.348
#    Training RMSE: 0.945 m³/s, Validation RMSE: 2.745 m³/s
#    Training PBIAS: -0.599, Validation PBIAS: 16.718
#    Params: mu=1.130, lambda=37.094, Qs=0.011, qs=0.101
#    Bounds used: Qs=(0.001, 50.800), qs=(0.001, 120.140)
#
# === Station 14005 ===, Number=26
# ✅ Training NSE: 0.691, Validation NSE: 0.612
#    Training KGE: 0.752, Validation KGE: 0.733
#    Training RMSE: 0.401 m³/s, Validation RMSE: 0.521 m³/s
#    Training PBIAS: 1.941, Validation PBIAS: 7.641
#    Params: mu=1.100, lambda=32.219, Qs=0.001, qs=0.049
#    Bounds used: Qs=(0.001, 25.560), qs=(0.001, 141.900)
#
# === Station 15006 ===, Number=27
# ✅ Training NSE: 0.771, Validation NSE: 0.704
#    Training KGE: 0.835, Validation KGE: 0.815
#    Training RMSE: 74.799 m³/s, Validation RMSE: 82.058 m³/s
#    Training PBIAS: -0.670, Validation PBIAS: 2.859
#    Params: mu=1.384, lambda=37.080, Qs=65.726, qs=2.073
#    Bounds used: Qs=(0.001, 3930.000), qs=(0.001, 120.640)
#
# === Station 15007 ===, Number=28
# ✅ Training NSE: 0.806, Validation NSE: 0.726
#    Training KGE: 0.872, Validation KGE: 0.847
#    Training RMSE: 24.572 m³/s, Validation RMSE: 27.264 m³/s
#    Training PBIAS: -1.868, Validation PBIAS: -2.429
#    Params: mu=1.445, lambda=22.896, Qs=48.769, qs=6.176
#    Bounds used: Qs=(0.001, 1203.200), qs=(0.001, 172.600)
#
# === Station 15010 ===, Number=29
# ✅ Training NSE: 0.710, Validation NSE: 0.650
#    Training KGE: 0.786, Validation KGE: 0.734
#    Training RMSE: 4.593 m³/s, Validation RMSE: 6.267 m³/s
#    Training PBIAS: -1.294, Validation PBIAS: 0.544
#    Params: mu=1.236, lambda=30.050, Qs=0.595, qs=0.546
#    Bounds used: Qs=(0.001, 191.720), qs=(0.001, 116.580)
#
# === Station 15011 ===, Number=30
# ✅ Training NSE: 0.597, Validation NSE: 0.527
#    Training KGE: 0.700, Validation KGE: 0.687
#    Training RMSE: 11.501 m³/s, Validation RMSE: 11.265 m³/s
#    Training PBIAS: -5.866, Validation PBIAS: -10.450
#    Params: mu=1.153, lambda=62.476, Qs=0.001, qs=0.019
#    Bounds used: Qs=(0.001, 731.400), qs=(0.001, 178.720)
#
# === Station 15012 ===, Number=31
# ✅ Training NSE: 0.750, Validation NSE: 0.660
#    Training KGE: 0.818, Validation KGE: 0.759
#    Training RMSE: 32.939 m³/s, Validation RMSE: 37.925 m³/s
#    Training PBIAS: -0.793, Validation PBIAS: 1.370
#    Params: mu=1.422, lambda=38.591, Qs=30.022, qs=2.303
#    Bounds used: Qs=(0.001, 1370.600), qs=(0.001, 125.000)
#
# === Station 15013 ===, Number=32
# ✅ Training NSE: 0.656, Validation NSE: 0.533
#    Training KGE: 0.746, Validation KGE: 0.680
#    Training RMSE: 4.402 m³/s, Validation RMSE: 5.543 m³/s
#    Training PBIAS: -3.982, Validation PBIAS: -8.088
#    Params: mu=1.207, lambda=22.262, Qs=0.177, qs=0.480
#    Bounds used: Qs=(0.001, 338.600), qs=(0.001, 157.340)
#
# === Station 15014 ===, Number=33
# ✅ Training NSE: 0.591, Validation NSE: 0.511
#    Training KGE: 0.672, Validation KGE: 0.648
#    Training RMSE: 2.614 m³/s, Validation RMSE: 3.048 m³/s
#    Training PBIAS: 0.169, Validation PBIAS: 8.665
#    Params: mu=1.300, lambda=46.843, Qs=0.116, qs=0.244
#    Bounds used: Qs=(0.001, 91.560), qs=(0.001, 120.000)
#
# === Station 15016 ===, Number=34
# ✅ Training NSE: 0.815, Validation NSE: 0.725
#    Training KGE: 0.873, Validation KGE: 0.863
#    Training RMSE: 17.350 m³/s, Validation RMSE: 18.670 m³/s
#    Training PBIAS: -1.041, Validation PBIAS: 1.198
#    Params: mu=1.541, lambda=13.499, Qs=93.484, qs=18.608
#    Bounds used: Qs=(0.001, 723.200), qs=(0.001, 190.880)
#
# === Station 15021 ===, Number=35
# ✅ Training NSE: 0.759, Validation NSE: 0.630
#    Training KGE: 0.810, Validation KGE: 0.789
#    Training RMSE: 0.781 m³/s, Validation RMSE: 0.992 m³/s
#    Training PBIAS: 0.865, Validation PBIAS: 11.811
#    Params: mu=1.157, lambda=24.705, Qs=0.408, qs=1.253
#    Bounds used: Qs=(0.001, 50.700), qs=(0.001, 144.920)
#
# === Station 15023 ===, Number=36
# ✅ Training NSE: 0.724, Validation NSE: 0.557
#    Training KGE: 0.795, Validation KGE: 0.765
#    Training RMSE: 4.913 m³/s, Validation RMSE: 6.146 m³/s
#    Training PBIAS: -1.312, Validation PBIAS: 0.681
#    Params: mu=1.232, lambda=18.856, Qs=0.724, qs=0.964
#    Bounds used: Qs=(0.001, 239.800), qs=(0.001, 172.520)
#
# === Station 15024 ===, Number=37
# ✅ Training NSE: 0.689, Validation NSE: 0.683
#    Training KGE: 0.727, Validation KGE: 0.730
#    Training RMSE: 11.994 m³/s, Validation RMSE: 11.503 m³/s
#    Training PBIAS: 5.548, Validation PBIAS: 10.775
#    Params: mu=1.169, lambda=105.845, Qs=0.001, qs=0.015
#    Bounds used: Qs=(0.001, 489.600), qs=(0.001, 225.060)
#
# === Station 15025 ===, Number=38
# ✅ Training NSE: 0.643, Validation NSE: 0.564
#    Training KGE: 0.719, Validation KGE: 0.696
#    Training RMSE: 8.774 m³/s, Validation RMSE: 10.367 m³/s
#    Training PBIAS: 0.109, Validation PBIAS: 12.200
#    Params: mu=1.318, lambda=34.422, Qs=1.480, qs=0.604
#    Bounds used: Qs=(0.001, 350.000), qs=(0.001, 114.320)
#
# === Station 15030 ===, Number=39
# ✅ Training NSE: 0.747, Validation NSE: 0.599
#    Training KGE: 0.812, Validation KGE: 0.741
#    Training RMSE: 2.107 m³/s, Validation RMSE: 2.895 m³/s
#    Training PBIAS: -0.673, Validation PBIAS: 18.223
#    Params: mu=1.098, lambda=40.049, Qs=0.002, qs=0.030
#    Bounds used: Qs=(0.001, 107.040), qs=(0.001, 110.880)
#
# === Station 15039 ===, Number=40
# ✅ Training NSE: 0.463, Validation NSE: 0.403
#    Training KGE: 0.554, Validation KGE: 0.492
#    Training RMSE: 6.256 m³/s, Validation RMSE: 7.044 m³/s
#    Training PBIAS: -0.849, Validation PBIAS: 3.069
#    Params: mu=1.262, lambda=200.000, Qs=0.007, qs=0.021
#    Bounds used: Qs=(0.001, 247.600), qs=(0.001, 148.860)
#
# === Station 16001 ===, Number=41
# ✅ Training NSE: 0.793, Validation NSE: 0.692
#    Training KGE: 0.848, Validation KGE: 0.791
#    Training RMSE: 10.977 m³/s, Validation RMSE: 13.515 m³/s
#    Training PBIAS: -0.422, Validation PBIAS: -2.042
#    Params: mu=1.344, lambda=28.798, Qs=6.758, qs=1.859
#    Bounds used: Qs=(0.001, 574.200), qs=(0.001, 151.600)
#
# === Station 16003 ===, Number=42
# ✅ Training NSE: 0.702, Validation NSE: 0.644
#    Training KGE: 0.738, Validation KGE: 0.674
#    Training RMSE: 4.408 m³/s, Validation RMSE: 5.048 m³/s
#    Training PBIAS: 6.546, Validation PBIAS: 1.171
#    Params: mu=1.193, lambda=95.860, Qs=0.001, qs=0.016
#    Bounds used: Qs=(0.001, 247.800), qs=(0.001, 230.800)
#
# === Station 16004 ===, Number=43
# ✅ Training NSE: 0.780, Validation NSE: 0.696
#    Training KGE: 0.835, Validation KGE: 0.787
#    Training RMSE: 14.895 m³/s, Validation RMSE: 17.171 m³/s
#    Training PBIAS: -0.051, Validation PBIAS: 0.759
#    Params: mu=1.268, lambda=35.595, Qs=3.085, qs=0.880
#    Bounds used: Qs=(0.001, 700.200), qs=(0.001, 140.620)
#
# === Station 17001 ===, Number=44
# ✅ Training NSE: 0.678, Validation NSE: 0.560
#    Training KGE: 0.758, Validation KGE: 0.731
#    Training RMSE: 3.594 m³/s, Validation RMSE: 3.938 m³/s
#    Training PBIAS: -9.478, Validation PBIAS: -7.717
#    Params: mu=1.192, lambda=4.292, Qs=4.106, qs=9.475
#    Bounds used: Qs=(0.001, 287.200), qs=(0.001, 175.060)
#
# === Station 17003 ===, Number=45
# ✅ Training NSE: 0.707, Validation NSE: 0.656
#    Training KGE: 0.790, Validation KGE: 0.774
#    Training RMSE: 0.917 m³/s, Validation RMSE: 0.803 m³/s
#    Training PBIAS: -3.381, Validation PBIAS: 15.837
#    Params: mu=1.179, lambda=55.703, Qs=0.001, qs=0.031
#    Bounds used: Qs=(0.001, 69.320), qs=(0.001, 168.960)
#
# === Station 17004 ===, Number=46
# ✅ Training NSE: 0.781, Validation NSE: 0.709
#    Training KGE: 0.847, Validation KGE: 0.800
#    Training RMSE: 1.145 m³/s, Validation RMSE: 1.454 m³/s
#    Training PBIAS: -1.931, Validation PBIAS: 11.696
#    Params: mu=1.164, lambda=28.248, Qs=0.050, qs=0.227
#    Bounds used: Qs=(0.001, 53.880), qs=(0.001, 150.100)
#
# === Station 17005 ===, Number=47
# ✅ Training NSE: 0.739, Validation NSE: 0.737
#    Training KGE: 0.807, Validation KGE: 0.775
#    Training RMSE: 3.191 m³/s, Validation RMSE: 3.400 m³/s
#    Training PBIAS: -1.623, Validation PBIAS: 3.973
#    Params: mu=1.136, lambda=40.556, Qs=0.001, qs=0.017
#    Bounds used: Qs=(0.001, 261.600), qs=(0.001, 141.000)
#
# === Station 17015 ===, Number=48
# ✅ Training NSE: 0.685, Validation NSE: 0.598
#    Training KGE: 0.764, Validation KGE: 0.635
#    Training RMSE: 0.626 m³/s, Validation RMSE: 0.774 m³/s
#    Training PBIAS: -2.334, Validation PBIAS: -8.515
#    Params: mu=1.231, lambda=9.478, Qs=0.321, qs=2.641
#    Bounds used: Qs=(0.001, 43.320), qs=(0.001, 141.540)
#
# === Station 17018 ===, Number=49
# ⚠️ Too many missing values (18.6%)
#
# === Station 18001 ===, Number=50
# ✅ Training NSE: 0.705, Validation NSE: 0.621
#    Training KGE: 0.775, Validation KGE: 0.671
#    Training RMSE: 3.900 m³/s, Validation RMSE: 4.816 m³/s
#    Training PBIAS: -0.315, Validation PBIAS: -1.640
#    Params: mu=1.157, lambda=60.432, Qs=0.002, qs=0.026
#    Bounds used: Qs=(0.001, 212.400), qs=(0.001, 154.100)
#
# === Station 18002 ===, Number=51
# ✅ Training NSE: 0.659, Validation NSE: 0.553
#    Training KGE: 0.744, Validation KGE: 0.519
#    Training RMSE: 3.704 m³/s, Validation RMSE: 5.126 m³/s
#    Training PBIAS: -2.159, Validation PBIAS: -14.384
#    Params: mu=1.167, lambda=27.886, Qs=0.063, qs=0.280
#    Bounds used: Qs=(0.001, 163.920), qs=(0.001, 135.180)
#
# === Station 18003 ===, Number=52
# ✅ Training NSE: 0.767, Validation NSE: 0.702
#    Training KGE: 0.830, Validation KGE: 0.821
#    Training RMSE: 15.300 m³/s, Validation RMSE: 16.127 m³/s
#    Training PBIAS: -1.157, Validation PBIAS: -4.881
#    Params: mu=1.118, lambda=46.267, Qs=0.005, qs=0.040
#    Bounds used: Qs=(0.001, 728.400), qs=(0.001, 187.500)
#
# === Station 18008 ===, Number=53
# ✅ Training NSE: 0.685, Validation NSE: 0.698
#    Training KGE: 0.724, Validation KGE: 0.745
#    Training RMSE: 8.415 m³/s, Validation RMSE: 7.880 m³/s
#    Training PBIAS: 4.240, Validation PBIAS: 6.731
#    Params: mu=1.147, lambda=106.404, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 300.000), qs=(0.001, 207.560)
#
# === Station 18010 ===, Number=54
# ⚠️ Too many missing values (12.0%)
#
# === Station 18011 ===, Number=55
# ✅ Training NSE: 0.694, Validation NSE: 0.730
#    Training KGE: 0.743, Validation KGE: 0.811
#    Training RMSE: 31.818 m³/s, Validation RMSE: 26.686 m³/s
#    Training PBIAS: 3.395, Validation PBIAS: 5.073
#    Params: mu=1.113, lambda=67.185, Qs=0.001, qs=0.009
#    Bounds used: Qs=(0.001, 1595.600), qs=(0.001, 165.760)
#
# === Station 18014 ===, Number=56
# ✅ Training NSE: 0.729, Validation NSE: 0.616
#    Training KGE: 0.805, Validation KGE: 0.658
#    Training RMSE: 0.598 m³/s, Validation RMSE: 0.769 m³/s
#    Training PBIAS: -3.427, Validation PBIAS: -17.431
#    Params: mu=1.261, lambda=15.645, Qs=0.168, qs=1.555
#    Bounds used: Qs=(0.001, 35.420), qs=(0.001, 145.740)
#
# === Station 18017 ===, Number=57
# ⚠️ Too many missing values (72.0%)
#
# === Station 18018 ===, Number=58
# ⚠️ Too many missing values (72.0%)
#
# === Station 19001 ===, Number=59
# ✅ Training NSE: 0.711, Validation NSE: 0.697
#    Training KGE: 0.790, Validation KGE: 0.807
#    Training RMSE: 5.347 m³/s, Validation RMSE: 5.603 m³/s
#    Training PBIAS: -8.959, Validation PBIAS: -3.523
#    Params: mu=1.098, lambda=20.700, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 294.400), qs=(0.001, 133.020)
#
# === Station 19006 ===, Number=60
# ✅ Training NSE: 0.713, Validation NSE: 0.672
#    Training KGE: 0.799, Validation KGE: 0.836
#    Training RMSE: 1.135 m³/s, Validation RMSE: 1.078 m³/s
#    Training PBIAS: -5.903, Validation PBIAS: -2.149
#    Params: mu=1.285, lambda=6.954, Qs=2.169, qs=4.175
#    Bounds used: Qs=(0.001, 103.600), qs=(0.001, 127.180)
#
# === Station 19010 ===, Number=61
# ⚠️ Too many missing values (20.0%)
#
# === Station 19017 ===, Number=62
# ✅ Training NSE: 0.720, Validation NSE: 0.614
#    Training KGE: 0.789, Validation KGE: 0.738
#    Training RMSE: 0.456 m³/s, Validation RMSE: 0.592 m³/s
#    Training PBIAS: -1.395, Validation PBIAS: 8.388
#    Params: mu=1.114, lambda=16.465, Qs=0.001, qs=0.059
#    Bounds used: Qs=(0.001, 35.760), qs=(0.001, 127.920)
#
# === Station 19020 ===, Number=63
# ✅ Training NSE: 0.676, Validation NSE: 0.604
#    Training KGE: 0.753, Validation KGE: 0.600
#    Training RMSE: 0.776 m³/s, Validation RMSE: 0.961 m³/s
#    Training PBIAS: -2.006, Validation PBIAS: -7.866
#    Params: mu=1.137, lambda=21.090, Qs=0.001, qs=0.056
#    Bounds used: Qs=(0.001, 52.060), qs=(0.001, 137.760)
#
# === Station 20002 ===, Number=64
# ✅ Training NSE: 0.615, Validation NSE: 0.502
#    Training KGE: 0.654, Validation KGE: 0.611
#    Training RMSE: 0.164 m³/s, Validation RMSE: 0.264 m³/s
#    Training PBIAS: 10.321, Validation PBIAS: -8.403
#    Params: mu=1.133, lambda=25.261, Qs=0.001, qs=0.070
#    Bounds used: Qs=(0.001, 10.360), qs=(0.001, 133.240)
#
# === Station 20003 ===, Number=65
# ✅ Training NSE: 0.686, Validation NSE: 0.581
#    Training KGE: 0.763, Validation KGE: 0.651
#    Training RMSE: 1.297 m³/s, Validation RMSE: 1.794 m³/s
#    Training PBIAS: -1.803, Validation PBIAS: -9.823
#    Params: mu=1.116, lambda=26.580, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 119.960), qs=(0.001, 128.360)
#
# === Station 20007 ===, Number=66
# ✅ Training NSE: 0.637, Validation NSE: 0.453
#    Training KGE: 0.727, Validation KGE: 0.733
#    Training RMSE: 0.754 m³/s, Validation RMSE: 0.886 m³/s
#    Training PBIAS: -7.953, Validation PBIAS: -3.088
#    Params: mu=1.108, lambda=19.409, Qs=0.001, qs=0.047
#    Bounds used: Qs=(0.001, 69.520), qs=(0.001, 151.720)
#
# === Station 2001 ===, Number=67
# ✅ Training NSE: 0.577, Validation NSE: 0.545
#    Training KGE: 0.690, Validation KGE: 0.549
#    Training RMSE: 10.001 m³/s, Validation RMSE: 10.337 m³/s
#    Training PBIAS: -4.697, Validation PBIAS: -16.134
#    Params: mu=1.133, lambda=61.884, Qs=0.001, qs=0.009
#    Bounds used: Qs=(0.001, 375.200), qs=(0.001, 117.420)
#
# === Station 2002 ===, Number=68
# ⚠️ Too many missing values (13.3%)
#
# === Station 21003 ===, Number=69
# ✅ Training NSE: 0.772, Validation NSE: 0.716
#    Training KGE: 0.834, Validation KGE: 0.825
#    Training RMSE: 8.598 m³/s, Validation RMSE: 10.167 m³/s
#    Training PBIAS: -0.864, Validation PBIAS: 3.357
#    Params: mu=1.256, lambda=24.589, Qs=2.616, qs=1.026
#    Bounds used: Qs=(0.001, 468.800), qs=(0.001, 118.580)
#
# === Station 21006 ===, Number=70
# ✅ Training NSE: 0.730, Validation NSE: 0.687
#    Training KGE: 0.799, Validation KGE: 0.795
#    Training RMSE: 22.587 m³/s, Validation RMSE: 25.137 m³/s
#    Training PBIAS: -0.891, Validation PBIAS: 4.802
#    Params: mu=1.210, lambda=31.946, Qs=1.401, qs=0.396
#    Bounds used: Qs=(0.001, 1097.000), qs=(0.001, 134.180)
#
# === Station 21008 ===, Number=71
# ✅ Training NSE: 0.706, Validation NSE: 0.668
#    Training KGE: 0.777, Validation KGE: 0.704
#    Training RMSE: 14.793 m³/s, Validation RMSE: 18.810 m³/s
#    Training PBIAS: -0.642, Validation PBIAS: -2.200
#    Params: mu=1.153, lambda=30.614, Qs=0.124, qs=0.113
#    Bounds used: Qs=(0.001, 967.800), qs=(0.001, 154.120)
#
# === Station 21009 ===, Number=72
# ✅ Training NSE: 0.718, Validation NSE: 0.671
#    Training KGE: 0.790, Validation KGE: 0.786
#    Training RMSE: 48.284 m³/s, Validation RMSE: 56.268 m³/s
#    Training PBIAS: -0.944, Validation PBIAS: 1.622
#    Params: mu=1.141, lambda=36.127, Qs=0.391, qs=0.105
#    Bounds used: Qs=(0.001, 2670.000), qs=(0.001, 130.780)
#
# === Station 21011 ===, Number=73
# ✅ Training NSE: 0.726, Validation NSE: 0.640
#    Training KGE: 0.798, Validation KGE: 0.759
#    Training RMSE: 3.867 m³/s, Validation RMSE: 4.499 m³/s
#    Training PBIAS: -1.168, Validation PBIAS: 16.538
#    Params: mu=1.177, lambda=38.247, Qs=0.051, qs=0.185
#    Bounds used: Qs=(0.001, 196.040), qs=(0.001, 156.020)
#
# === Station 21012 ===, Number=74
# ✅ Training NSE: 0.738, Validation NSE: 0.668
#    Training KGE: 0.800, Validation KGE: 0.768
#    Training RMSE: 6.542 m³/s, Validation RMSE: 7.770 m³/s
#    Training PBIAS: 0.016, Validation PBIAS: 4.547
#    Params: mu=1.188, lambda=26.184, Qs=0.151, qs=0.255
#    Bounds used: Qs=(0.001, 328.400), qs=(0.001, 164.720)
#
# === Station 21013 ===, Number=75
# ✅ Training NSE: 0.723, Validation NSE: 0.618
#    Training KGE: 0.789, Validation KGE: 0.744
#    Training RMSE: 2.498 m³/s, Validation RMSE: 2.997 m³/s
#    Training PBIAS: -0.069, Validation PBIAS: 7.826
#    Params: mu=1.134, lambda=25.991, Qs=0.033, qs=0.152
#    Bounds used: Qs=(0.001, 145.420), qs=(0.001, 145.780)
#
# === Station 21015 ===, Number=76
# ⚠️ Too many missing values (11.0%)
#
# === Station 21016 ===, Number=77
# ✅ Training NSE: 0.599, Validation NSE: 0.665
#    Training KGE: 0.665, Validation KGE: 0.712
#    Training RMSE: 1.253 m³/s, Validation RMSE: 1.321 m³/s
#    Training PBIAS: 4.042, Validation PBIAS: 10.610
#    Params: mu=1.122, lambda=36.603, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 67.620), qs=(0.001, 145.440)
#
# === Station 21017 ===, Number=78
# ⚠️ Too many missing values (15.2%)
#
# === Station 21018 ===, Number=79
# ✅ Training NSE: 0.745, Validation NSE: 0.623
#    Training KGE: 0.818, Validation KGE: 0.746
#    Training RMSE: 1.872 m³/s, Validation RMSE: 2.377 m³/s
#    Training PBIAS: -1.994, Validation PBIAS: 3.893
#    Params: mu=1.189, lambda=25.977, Qs=0.127, qs=0.353
#    Bounds used: Qs=(0.001, 119.320), qs=(0.001, 112.700)
#
# === Station 21022 ===, Number=80
# ✅ Training NSE: 0.642, Validation NSE: 0.545
#    Training KGE: 0.722, Validation KGE: 0.674
#    Training RMSE: 5.729 m³/s, Validation RMSE: 8.458 m³/s
#    Training PBIAS: -0.528, Validation PBIAS: 3.888
#    Params: mu=1.102, lambda=37.190, Qs=0.001, qs=0.012
#    Bounds used: Qs=(0.001, 439.400), qs=(0.001, 143.440)
#
# === Station 21023 ===, Number=81
# ✅ Training NSE: 0.405, Validation NSE: 0.340
#    Training KGE: 0.478, Validation KGE: 0.467
#    Training RMSE: 2.015 m³/s, Validation RMSE: 2.629 m³/s
#    Training PBIAS: 4.369, Validation PBIAS: -3.174
#    Params: mu=1.059, lambda=12.088, Qs=0.001, qs=0.048
#    Bounds used: Qs=(0.001, 143.580), qs=(0.001, 114.120)
#
# === Station 21024 ===, Number=82
# ✅ Training NSE: 0.660, Validation NSE: 0.645
#    Training KGE: 0.738, Validation KGE: 0.729
#    Training RMSE: 2.153 m³/s, Validation RMSE: 2.430 m³/s
#    Training PBIAS: -0.712, Validation PBIAS: 2.475
#    Params: mu=1.130, lambda=33.682, Qs=0.001, qs=0.021
#    Bounds used: Qs=(0.001, 121.100), qs=(0.001, 160.480)
#
# === Station 21026 ===, Number=83
# ✅ Training NSE: 0.613, Validation NSE: 0.483
#    Training KGE: 0.705, Validation KGE: 0.622
#    Training RMSE: 1.512 m³/s, Validation RMSE: 2.248 m³/s
#    Training PBIAS: -10.035, Validation PBIAS: -7.105
#    Params: mu=1.239, lambda=3.662, Qs=2.304, qs=12.354
#    Bounds used: Qs=(0.001, 81.320), qs=(0.001, 161.500)
#
# === Station 21027 ===, Number=84
# ✅ Training NSE: 0.591, Validation NSE: 0.507
#    Training KGE: 0.671, Validation KGE: 0.671
#    Training RMSE: 1.935 m³/s, Validation RMSE: 2.603 m³/s
#    Training PBIAS: 0.861, Validation PBIAS: 6.852
#    Params: mu=1.106, lambda=26.732, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 157.120), qs=(0.001, 129.740)
#
# === Station 22001 ===, Number=85
# ✅ Training NSE: 0.693, Validation NSE: 0.552
#    Training KGE: 0.774, Validation KGE: 0.720
#    Training RMSE: 7.136 m³/s, Validation RMSE: 10.738 m³/s
#    Training PBIAS: -4.688, Validation PBIAS: 5.439
#    Params: mu=1.166, lambda=10.775, Qs=1.415, qs=0.952
#    Bounds used: Qs=(0.001, 560.000), qs=(0.001, 111.240)
#
# === Station 22006 ===, Number=86
# ✅ Training NSE: 0.641, Validation NSE: 0.576
#    Training KGE: 0.724, Validation KGE: 0.688
#    Training RMSE: 2.481 m³/s, Validation RMSE: 3.445 m³/s
#    Training PBIAS: -4.061, Validation PBIAS: -2.024
#    Params: mu=1.066, lambda=11.205, Qs=0.001, qs=0.034
#    Bounds used: Qs=(0.001, 184.400), qs=(0.001, 110.700)
#
# === Station 22007 ===, Number=87
# ✅ Training NSE: 0.678, Validation NSE: 0.608
#    Training KGE: 0.752, Validation KGE: 0.705
#    Training RMSE: 3.434 m³/s, Validation RMSE: 4.754 m³/s
#    Training PBIAS: -0.537, Validation PBIAS: 2.146
#    Params: mu=1.083, lambda=14.742, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 254.000), qs=(0.001, 132.340)
#
# === Station 22009 ===, Number=88
# ✅ Training NSE: 0.674, Validation NSE: 0.531
#    Training KGE: 0.762, Validation KGE: 0.702
#    Training RMSE: 4.822 m³/s, Validation RMSE: 7.131 m³/s
#    Training PBIAS: -5.514, Validation PBIAS: 3.793
#    Params: mu=1.225, lambda=6.359, Qs=8.737, qs=4.887
#    Bounds used: Qs=(0.001, 329.600), qs=(0.001, 124.740)
#
# === Station 23001 ===, Number=89
# ✅ Training NSE: 0.719, Validation NSE: 0.646
#    Training KGE: 0.792, Validation KGE: 0.780
#    Training RMSE: 30.551 m³/s, Validation RMSE: 35.206 m³/s
#    Training PBIAS: -1.816, Validation PBIAS: 3.614
#    Params: mu=1.160, lambda=32.218, Qs=0.151, qs=0.080
#    Bounds used: Qs=(0.001, 1654.000), qs=(0.001, 112.580)
#
# === Station 23004 ===, Number=90
# ✅ Training NSE: 0.706, Validation NSE: 0.648
#    Training KGE: 0.775, Validation KGE: 0.736
#    Training RMSE: 15.017 m³/s, Validation RMSE: 16.212 m³/s
#    Training PBIAS: -0.522, Validation PBIAS: 3.260
#    Params: mu=1.154, lambda=33.912, Qs=0.016, qs=0.038
#    Bounds used: Qs=(0.001, 1030.000), qs=(0.001, 141.800)
#
# === Station 23006 ===, Number=91
# ✅ Training NSE: 0.713, Validation NSE: 0.703
#    Training KGE: 0.775, Validation KGE: 0.732
#    Training RMSE: 7.945 m³/s, Validation RMSE: 8.675 m³/s
#    Training PBIAS: 1.188, Validation PBIAS: 1.630
#    Params: mu=1.157, lambda=64.891, Qs=0.001, qs=0.010
#    Bounds used: Qs=(0.001, 498.000), qs=(0.001, 164.520)
#
# === Station 23007 ===, Number=92
# ✅ Training NSE: 0.623, Validation NSE: 0.623
#    Training KGE: 0.722, Validation KGE: 0.654
#    Training RMSE: 2.016 m³/s, Validation RMSE: 2.745 m³/s
#    Training PBIAS: -6.333, Validation PBIAS: -11.162
#    Params: mu=1.107, lambda=29.235, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 220.000), qs=(0.001, 136.140)
#
# === Station 23008 ===, Number=93
# ✅ Training NSE: 0.668, Validation NSE: 0.587
#    Training KGE: 0.741, Validation KGE: 0.692
#    Training RMSE: 5.461 m³/s, Validation RMSE: 7.442 m³/s
#    Training PBIAS: 0.392, Validation PBIAS: 3.126
#    Params: mu=1.106, lambda=24.634, Qs=0.001, qs=0.017
#    Bounds used: Qs=(0.001, 262.000), qs=(0.001, 104.640)
#
# === Station 23011 ===, Number=94
# ✅ Training NSE: 0.652, Validation NSE: 0.579
#    Training KGE: 0.736, Validation KGE: 0.735
#    Training RMSE: 1.678 m³/s, Validation RMSE: 2.017 m³/s
#    Training PBIAS: -2.335, Validation PBIAS: 10.680
#    Params: mu=1.167, lambda=42.494, Qs=0.001, qs=0.027
#    Bounds used: Qs=(0.001, 82.800), qs=(0.001, 148.600)
#
# === Station 23016 ===, Number=95
# ✅ Training NSE: 0.780, Validation NSE: 0.756
#    Training KGE: 0.834, Validation KGE: 0.820
#    Training RMSE: 0.297 m³/s, Validation RMSE: 0.418 m³/s
#    Training PBIAS: 0.879, Validation PBIAS: 9.081
#    Params: mu=1.111, lambda=13.849, Qs=0.001, qs=0.061
#    Bounds used: Qs=(0.001, 26.000), qs=(0.001, 101.780)
#
# === Station 24001 ===, Number=96
# ✅ Training NSE: 0.710, Validation NSE: 0.642
#    Training KGE: 0.783, Validation KGE: 0.714
#    Training RMSE: 8.933 m³/s, Validation RMSE: 11.409 m³/s
#    Training PBIAS: -1.538, Validation PBIAS: 6.662
#    Params: mu=1.120, lambda=35.778, Qs=0.003, qs=0.018
#    Bounds used: Qs=(0.001, 545.600), qs=(0.001, 117.320)
#
# === Station 24003 ===, Number=97
# ✅ Training NSE: 0.687, Validation NSE: 0.612
#    Training KGE: 0.764, Validation KGE: 0.703
#    Training RMSE: 3.838 m³/s, Validation RMSE: 4.462 m³/s
#    Training PBIAS: -2.418, Validation PBIAS: -2.655
#    Params: mu=1.181, lambda=18.720, Qs=0.060, qs=0.276
#    Bounds used: Qs=(0.001, 272.000), qs=(0.001, 149.680)
#
# === Station 24004 ===, Number=98
# ✅ Training NSE: 0.724, Validation NSE: 0.635
#    Training KGE: 0.787, Validation KGE: 0.712
#    Training RMSE: 0.930 m³/s, Validation RMSE: 1.223 m³/s
#    Training PBIAS: 0.460, Validation PBIAS: 8.675
#    Params: mu=1.191, lambda=31.133, Qs=0.018, qs=0.147
#    Bounds used: Qs=(0.001, 50.600), qs=(0.001, 132.720)
#
# === Station 24005 ===, Number=99
# ✅ Training NSE: 0.694, Validation NSE: 0.661
#    Training KGE: 0.767, Validation KGE: 0.696
#    Training RMSE: 1.441 m³/s, Validation RMSE: 1.902 m³/s
#    Training PBIAS: -0.861, Validation PBIAS: 19.909
#    Params: mu=1.110, lambda=24.319, Qs=0.001, qs=0.026
#    Bounds used: Qs=(0.001, 106.600), qs=(0.001, 113.980)
#
# === Station 25001 ===, Number=100
# ✅ Training NSE: 0.693, Validation NSE: 0.643
#    Training KGE: 0.770, Validation KGE: 0.702
#    Training RMSE: 14.785 m³/s, Validation RMSE: 16.371 m³/s
#    Training PBIAS: -2.089, Validation PBIAS: -6.030
#    Params: mu=1.161, lambda=41.660, Qs=0.023, qs=0.043
#    Bounds used: Qs=(0.001, 830.200), qs=(0.001, 120.940)
#
# === Station 25003 ===, Number=101
# ✅ Training NSE: 0.576, Validation NSE: 0.553
#    Training KGE: 0.590, Validation KGE: 0.573
#    Training RMSE: 0.569 m³/s, Validation RMSE: 0.619 m³/s
#    Training PBIAS: 13.048, Validation PBIAS: 9.098
#    Params: mu=1.289, lambda=165.875, Qs=0.001, qs=0.034
#    Bounds used: Qs=(0.001, 23.200), qs=(0.001, 219.920)
#
# === Station 25006 ===, Number=102
# ✅ Training NSE: 0.680, Validation NSE: 0.456
#    Training KGE: 0.759, Validation KGE: 0.711
#    Training RMSE: 2.382 m³/s, Validation RMSE: 3.154 m³/s
#    Training PBIAS: -7.116, Validation PBIAS: -1.331
#    Params: mu=1.242, lambda=4.239, Qs=3.754, qs=7.173
#    Bounds used: Qs=(0.001, 106.400), qs=(0.001, 116.940)
#
# === Station 25012 ===, Number=103
# ✅ Training NSE: 0.649, Validation NSE: 0.679
#    Training KGE: 0.684, Validation KGE: 0.684
#    Training RMSE: 0.933 m³/s, Validation RMSE: 0.843 m³/s
#    Training PBIAS: 8.430, Validation PBIAS: 10.888
#    Params: mu=1.231, lambda=100.474, Qs=0.001, qs=0.028
#    Bounds used: Qs=(0.001, 57.600), qs=(0.001, 174.580)
#
# === Station 25020 ===, Number=104
# ✅ Training NSE: 0.649, Validation NSE: 0.684
#    Training KGE: 0.686, Validation KGE: 0.765
#    Training RMSE: 0.903 m³/s, Validation RMSE: 0.929 m³/s
#    Training PBIAS: 9.381, Validation PBIAS: 14.682
#    Params: mu=1.120, lambda=33.022, Qs=0.001, qs=0.026
#    Bounds used: Qs=(0.001, 45.400), qs=(0.001, 111.020)
#
# === Station 25021 ===, Number=105
# ✅ Training NSE: 0.648, Validation NSE: 0.633
#    Training KGE: 0.700, Validation KGE: 0.717
#    Training RMSE: 0.396 m³/s, Validation RMSE: 0.526 m³/s
#    Training PBIAS: 6.658, Validation PBIAS: -0.393
#    Params: mu=1.120, lambda=27.575, Qs=0.001, qs=0.046
#    Bounds used: Qs=(0.001, 20.800), qs=(0.001, 112.200)
#
# === Station 25029 ===, Number=106
# ⚠️ Too many missing values (68.0%)
#
# === Station 26003 ===, Number=107
# ✅ Training NSE: 0.777, Validation NSE: 0.714
#    Training KGE: 0.809, Validation KGE: 0.791
#    Training RMSE: 0.217 m³/s, Validation RMSE: 0.284 m³/s
#    Training PBIAS: 1.482, Validation PBIAS: 9.937
#    Params: mu=0.902, lambda=39.648, Qs=0.026, qs=0.628
#    Bounds used: Qs=(0.001, 5.320), qs=(0.001, 115.500)
#
# === Station 26005 ===, Number=108
# ✅ Training NSE: 0.806, Validation NSE: 0.595
#    Training KGE: 0.843, Validation KGE: 0.655
#    Training RMSE: 0.177 m³/s, Validation RMSE: 0.374 m³/s
#    Training PBIAS: 3.770, Validation PBIAS: -1.590
#    Params: mu=0.649, lambda=25.271, Qs=0.595, qs=3.887
#    Bounds used: Qs=(0.001, 7.140), qs=(0.001, 106.860)
#
# === Station 26006 ===, Number=109
# ✅ Training NSE: 0.671, Validation NSE: 0.546
#    Training KGE: 0.712, Validation KGE: 0.626
#    Training RMSE: 0.371 m³/s, Validation RMSE: 0.554 m³/s
#    Training PBIAS: 4.345, Validation PBIAS: 29.132
#    Params: mu=0.816, lambda=33.266, Qs=0.552, qs=2.328
#    Bounds used: Qs=(0.001, 9.160), qs=(0.001, 130.100)
#
# === Station 26008 ===, Number=110
# ✅ Training NSE: 0.696, Validation NSE: 0.734
#    Training KGE: 0.758, Validation KGE: 0.821
#    Training RMSE: 0.100 m³/s, Validation RMSE: 0.108 m³/s
#    Training PBIAS: 0.463, Validation PBIAS: -0.721
#    Params: mu=0.956, lambda=56.872, Qs=0.951, qs=3.872
#    Bounds used: Qs=(0.001, 7.240), qs=(0.001, 164.060)
#
# === Station 26009 ===, Number=111
# ✅ Training NSE: 0.709, Validation NSE: 0.568
#    Training KGE: 0.756, Validation KGE: 0.742
#    Training RMSE: 0.941 m³/s, Validation RMSE: 1.154 m³/s
#    Training PBIAS: 1.454, Validation PBIAS: 18.261
#    Params: mu=0.960, lambda=33.915, Qs=0.002, qs=0.100
#    Bounds used: Qs=(0.001, 17.200), qs=(0.001, 125.260)
#
# === Station 27001 ===, Number=112
# ✅ Training NSE: 0.713, Validation NSE: 0.660
#    Training KGE: 0.787, Validation KGE: 0.690
#    Training RMSE: 5.823 m³/s, Validation RMSE: 7.646 m³/s
#    Training PBIAS: -1.793, Validation PBIAS: -0.071
#    Params: mu=1.120, lambda=32.877, Qs=0.007, qs=0.040
#    Bounds used: Qs=(0.001, 318.000), qs=(0.001, 140.340)
#
# === Station 27002 ===, Number=113
# ✅ Training NSE: 0.690, Validation NSE: 0.657
#    Training KGE: 0.761, Validation KGE: 0.636
#    Training RMSE: 12.611 m³/s, Validation RMSE: 15.417 m³/s
#    Training PBIAS: -0.068, Validation PBIAS: -16.660
#    Params: mu=1.118, lambda=53.329, Qs=0.001, qs=0.009
#    Bounds used: Qs=(0.001, 585.800), qs=(0.001, 128.840)
#
# === Station 27003 ===, Number=114
# ✅ Training NSE: 0.770, Validation NSE: 0.765
#    Training KGE: 0.840, Validation KGE: 0.809
#    Training RMSE: 18.439 m³/s, Validation RMSE: 19.409 m³/s
#    Training PBIAS: -2.267, Validation PBIAS: 1.377
#    Params: mu=1.139, lambda=60.977, Qs=0.023, qs=0.026
#    Bounds used: Qs=(0.001, 637.000), qs=(0.001, 125.980)
#
# === Station 27006 ===, Number=115
# ✅ Training NSE: 0.724, Validation NSE: 0.703
#    Training KGE: 0.799, Validation KGE: 0.741
#    Training RMSE: 3.545 m³/s, Validation RMSE: 3.569 m³/s
#    Training PBIAS: -2.822, Validation PBIAS: -4.789
#    Params: mu=1.110, lambda=34.831, Qs=0.001, qs=0.019
#    Bounds used: Qs=(0.001, 370.000), qs=(0.001, 141.600)
#
# === Station 27007 ===, Number=116
# ✅ Training NSE: 0.683, Validation NSE: 0.645
#    Training KGE: 0.757, Validation KGE: 0.725
#    Training RMSE: 17.678 m³/s, Validation RMSE: 18.918 m³/s
#    Training PBIAS: -0.799, Validation PBIAS: 6.210
#    Params: mu=1.118, lambda=61.547, Qs=0.001, qs=0.007
#    Bounds used: Qs=(0.001, 940.000), qs=(0.001, 133.740)
#
# === Station 27009 ===, Number=117
# ✅ Training NSE: 0.745, Validation NSE: 0.723
#    Training KGE: 0.809, Validation KGE: 0.808
#    Training RMSE: 30.925 m³/s, Validation RMSE: 32.566 m³/s
#    Training PBIAS: -0.413, Validation PBIAS: 3.193
#    Params: mu=1.147, lambda=41.822, Qs=0.317, qs=0.102
#    Bounds used: Qs=(0.001, 1116.400), qs=(0.001, 114.380)
#
# === Station 27021 ===, Number=118
# ✅ Training NSE: 0.740, Validation NSE: 0.725
#    Training KGE: 0.821, Validation KGE: 0.808
#    Training RMSE: 9.626 m³/s, Validation RMSE: 9.433 m³/s
#    Training PBIAS: -4.593, Validation PBIAS: -2.722
#    Params: mu=1.103, lambda=52.692, Qs=0.001, qs=0.007
#    Bounds used: Qs=(0.001, 614.000), qs=(0.001, 122.660)
#
# === Station 27023 ===, Number=119
# ✅ Training NSE: 0.602, Validation NSE: 0.692
#    Training KGE: 0.689, Validation KGE: 0.752
#    Training RMSE: 1.555 m³/s, Validation RMSE: 1.128 m³/s
#    Training PBIAS: -10.936, Validation PBIAS: -14.708
#    Params: mu=1.097, lambda=16.688, Qs=0.001, qs=0.038
#    Bounds used: Qs=(0.001, 216.000), qs=(0.001, 159.620)
#
# === Station 27025 ===, Number=120
# ✅ Training NSE: 0.697, Validation NSE: 0.656
#    Training KGE: 0.786, Validation KGE: 0.737
#    Training RMSE: 2.770 m³/s, Validation RMSE: 2.784 m³/s
#    Training PBIAS: -6.434, Validation PBIAS: -13.831
#    Params: mu=1.113, lambda=38.476, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 176.000), qs=(0.001, 116.940)
#
# === Station 27026 ===, Number=121
# ✅ Training NSE: 0.732, Validation NSE: 0.729
#    Training KGE: 0.804, Validation KGE: 0.805
#    Training RMSE: 1.526 m³/s, Validation RMSE: 1.423 m³/s
#    Training PBIAS: -3.258, Validation PBIAS: 2.774
#    Params: mu=1.120, lambda=29.087, Qs=0.001, qs=0.022
#    Bounds used: Qs=(0.001, 174.400), qs=(0.001, 116.580)
#
# === Station 27029 ===, Number=122
# ✅ Training NSE: 0.782, Validation NSE: 0.761
#    Training KGE: 0.845, Validation KGE: 0.763
#    Training RMSE: 4.667 m³/s, Validation RMSE: 5.016 m³/s
#    Training PBIAS: -1.946, Validation PBIAS: -2.419
#    Params: mu=1.169, lambda=41.439, Qs=0.025, qs=0.084
#    Bounds used: Qs=(0.001, 294.000), qs=(0.001, 126.320)
#
# === Station 27030 ===, Number=123
# ✅ Training NSE: 0.739, Validation NSE: 0.714
#    Training KGE: 0.818, Validation KGE: 0.729
#    Training RMSE: 2.081 m³/s, Validation RMSE: 2.275 m³/s
#    Training PBIAS: -5.623, Validation PBIAS: -9.384
#    Params: mu=1.114, lambda=45.172, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 141.600), qs=(0.001, 138.880)
#
# === Station 27032 ===, Number=124
# ✅ Training NSE: 0.701, Validation NSE: 0.670
#    Training KGE: 0.780, Validation KGE: 0.672
#    Training RMSE: 0.133 m³/s, Validation RMSE: 0.149 m³/s
#    Training PBIAS: -1.626, Validation PBIAS: -8.952
#    Params: mu=1.235, lambda=37.771, Qs=0.003, qs=0.222
#    Bounds used: Qs=(0.001, 6.660), qs=(0.001, 149.120)
#
# === Station 27034 ===, Number=125
# ✅ Training NSE: 0.713, Validation NSE: 0.672
#    Training KGE: 0.792, Validation KGE: 0.744
#    Training RMSE: 13.150 m³/s, Validation RMSE: 14.260 m³/s
#    Training PBIAS: -4.634, Validation PBIAS: -3.150
#    Params: mu=1.123, lambda=46.764, Qs=0.001, qs=0.011
#    Bounds used: Qs=(0.001, 666.000), qs=(0.001, 164.620)
#
# === Station 27035 ===, Number=126
# ✅ Training NSE: 0.766, Validation NSE: 0.761
#    Training KGE: 0.809, Validation KGE: 0.740
#    Training RMSE: 4.717 m³/s, Validation RMSE: 4.986 m³/s
#    Training PBIAS: 3.083, Validation PBIAS: 0.109
#    Params: mu=1.118, lambda=43.544, Qs=0.001, qs=0.016
#    Bounds used: Qs=(0.001, 214.000), qs=(0.001, 145.880)
#
# === Station 27038 ===, Number=127
# ✅ Training NSE: 0.503, Validation NSE: 0.210
#    Training KGE: 0.591, Validation KGE: 0.215
#    Training RMSE: 0.163 m³/s, Validation RMSE: 0.349 m³/s
#    Training PBIAS: -0.142, Validation PBIAS: -7.486
#    Params: mu=1.544, lambda=151.918, Qs=0.684, qs=1.816
#    Bounds used: Qs=(0.001, 8.840), qs=(0.001, 145.900)
#
# === Station 27041 ===, Number=128
# ✅ Training NSE: 0.806, Validation NSE: 0.796
#    Training KGE: 0.862, Validation KGE: 0.882
#    Training RMSE: 6.157 m³/s, Validation RMSE: 6.796 m³/s
#    Training PBIAS: -0.665, Validation PBIAS: 2.106
#    Params: mu=1.151, lambda=49.566, Qs=0.578, qs=0.246
#    Bounds used: Qs=(0.001, 280.000), qs=(0.001, 138.380)
#
# === Station 27042 ===, Number=129
# ✅ Training NSE: 0.760, Validation NSE: 0.702
#    Training KGE: 0.824, Validation KGE: 0.825
#    Training RMSE: 0.516 m³/s, Validation RMSE: 0.604 m³/s
#    Training PBIAS: -0.796, Validation PBIAS: 4.796
#    Params: mu=1.274, lambda=36.341, Qs=0.110, qs=0.439
#    Bounds used: Qs=(0.001, 36.260), qs=(0.001, 168.080)
#
# === Station 27043 ===, Number=130
# ✅ Training NSE: 0.716, Validation NSE: 0.711
#    Training KGE: 0.769, Validation KGE: 0.727
#    Training RMSE: 10.304 m³/s, Validation RMSE: 10.947 m³/s
#    Training PBIAS: 2.823, Validation PBIAS: 2.378
#    Params: mu=1.143, lambda=66.218, Qs=0.001, qs=0.010
#    Bounds used: Qs=(0.001, 573.000), qs=(0.001, 135.380)
#
# === Station 27047 ===, Number=131
# ✅ Training NSE: 0.761, Validation NSE: 0.761
#    Training KGE: 0.747, Validation KGE: 0.720
#    Training RMSE: 0.464 m³/s, Validation RMSE: 0.458 m³/s
#    Training PBIAS: 13.105, Validation PBIAS: 20.906
#    Params: mu=1.233, lambda=73.780, Qs=0.001, qs=0.049
#    Bounds used: Qs=(0.001, 24.400), qs=(0.001, 234.260)
#
# === Station 27049 ===, Number=132
# ✅ Training NSE: 0.705, Validation NSE: 0.675
#    Training KGE: 0.786, Validation KGE: 0.794
#    Training RMSE: 1.938 m³/s, Validation RMSE: 2.247 m³/s
#    Training PBIAS: -1.763, Validation PBIAS: 1.960
#    Params: mu=1.137, lambda=40.593, Qs=0.036, qs=0.137
#    Bounds used: Qs=(0.001, 130.200), qs=(0.001, 158.840)
#
# === Station 27051 ===, Number=133
# ✅ Training NSE: 0.739, Validation NSE: 0.754
#    Training KGE: 0.807, Validation KGE: 0.788
#    Training RMSE: 0.099 m³/s, Validation RMSE: 0.107 m³/s
#    Training PBIAS: -3.713, Validation PBIAS: 3.593
#    Params: mu=1.140, lambda=15.359, Qs=0.001, qs=0.136
#    Bounds used: Qs=(0.001, 7.180), qs=(0.001, 176.260)
#
# === Station 27062 ===, Number=134
# ✅ Training NSE: 0.733, Validation NSE: 0.729
#    Training KGE: 0.798, Validation KGE: 0.800
#    Training RMSE: 5.508 m³/s, Validation RMSE: 5.749 m³/s
#    Training PBIAS: -0.225, Validation PBIAS: 6.137
#    Params: mu=1.137, lambda=36.623, Qs=0.033, qs=0.086
#    Bounds used: Qs=(0.001, 270.800), qs=(0.001, 138.440)
#
# === Station 27064 ===, Number=135
# ✅ Training NSE: 0.598, Validation NSE: 0.563
#    Training KGE: 0.690, Validation KGE: 0.590
#    Training RMSE: 0.497 m³/s, Validation RMSE: 0.603 m³/s
#    Training PBIAS: -3.388, Validation PBIAS: -1.895
#    Params: mu=1.122, lambda=36.737, Qs=0.001, qs=0.033
#    Bounds used: Qs=(0.001, 44.300), qs=(0.001, 121.820)
#
# === Station 27065 ===, Number=136
# ✅ Training NSE: 0.759, Validation NSE: 0.763
#    Training KGE: 0.828, Validation KGE: 0.806
#    Training RMSE: 1.334 m³/s, Validation RMSE: 1.314 m³/s
#    Training PBIAS: -2.937, Validation PBIAS: -1.221
#    Params: mu=1.153, lambda=30.172, Qs=0.009, qs=0.123
#    Bounds used: Qs=(0.001, 84.200), qs=(0.001, 151.340)
#
# === Station 27071 ===, Number=137
# ✅ Training NSE: 0.726, Validation NSE: 0.693
#    Training KGE: 0.795, Validation KGE: 0.724
#    Training RMSE: 12.696 m³/s, Validation RMSE: 15.631 m³/s
#    Training PBIAS: -0.692, Validation PBIAS: -5.043
#    Params: mu=1.145, lambda=46.295, Qs=0.073, qs=0.065
#    Bounds used: Qs=(0.001, 422.000), qs=(0.001, 115.980)
#
# === Station 27073 ===, Number=138
# ✅ Training NSE: 0.726, Validation NSE: 0.774
#    Training KGE: 0.754, Validation KGE: 0.789
#    Training RMSE: 0.101 m³/s, Validation RMSE: 0.109 m³/s
#    Training PBIAS: 2.183, Validation PBIAS: 6.995
#    Params: mu=1.124, lambda=44.411, Qs=0.893, qs=4.551
#    Bounds used: Qs=(0.001, 2.620), qs=(0.001, 121.920)
#
# === Station 27077 ===, Number=139
# ✅ Training NSE: 0.723, Validation NSE: 0.648
#    Training KGE: 0.807, Validation KGE: 0.818
#    Training RMSE: 0.392 m³/s, Validation RMSE: 0.394 m³/s
#    Training PBIAS: -9.269, Validation PBIAS: 0.280
#    Params: mu=1.316, lambda=4.989, Qs=1.410, qs=7.717
#    Bounds used: Qs=(0.001, 27.580), qs=(0.001, 145.900)
#
# === Station 27079 ===, Number=140
# ✅ Training NSE: 0.750, Validation NSE: 0.740
#    Training KGE: 0.826, Validation KGE: 0.798
#    Training RMSE: 10.647 m³/s, Validation RMSE: 10.995 m³/s
#    Training PBIAS: -2.565, Validation PBIAS: 6.686
#    Params: mu=1.191, lambda=52.747, Qs=0.152, qs=0.101
#    Bounds used: Qs=(0.001, 574.800), qs=(0.001, 120.560)
#
# === Station 27080 ===, Number=141
# ✅ Training NSE: 0.791, Validation NSE: 0.806
#    Training KGE: 0.857, Validation KGE: 0.860
#    Training RMSE: 8.590 m³/s, Validation RMSE: 8.307 m³/s
#    Training PBIAS: -2.307, Validation PBIAS: 2.163
#    Params: mu=1.187, lambda=61.763, Qs=0.075, qs=0.063
#    Bounds used: Qs=(0.001, 408.000), qs=(0.001, 135.620)
#
# === Station 27084 ===, Number=142
# ✅ Training NSE: 0.776, Validation NSE: 0.757
#    Training KGE: 0.827, Validation KGE: 0.803
#    Training RMSE: 0.684 m³/s, Validation RMSE: 0.690 m³/s
#    Training PBIAS: 1.514, Validation PBIAS: 5.849
#    Params: mu=1.152, lambda=30.613, Qs=0.001, qs=0.040
#    Bounds used: Qs=(0.001, 55.400), qs=(0.001, 164.820)
#
# === Station 27087 ===, Number=143
# ✅ Training NSE: 0.804, Validation NSE: 0.791
#    Training KGE: 0.841, Validation KGE: 0.880
#    Training RMSE: 1.221 m³/s, Validation RMSE: 1.364 m³/s
#    Training PBIAS: 0.685, Validation PBIAS: 2.115
#    Params: mu=1.187, lambda=54.270, Qs=1.973, qs=1.272
#    Bounds used: Qs=(0.001, 54.960), qs=(0.001, 130.520)
#
# === Station 27089 ===, Number=144
# ✅ Training NSE: 0.708, Validation NSE: 0.687
#    Training KGE: 0.764, Validation KGE: 0.730
#    Training RMSE: 11.691 m³/s, Validation RMSE: 12.505 m³/s
#    Training PBIAS: 2.231, Validation PBIAS: 2.224
#    Params: mu=1.118, lambda=62.478, Qs=0.001, qs=0.009
#    Bounds used: Qs=(0.001, 509.400), qs=(0.001, 126.780)
#
# === Station 27090 ===, Number=145
# ⚠️ Too many missing values (11.8%)
#
# === Station 28001 ===, Number=146
# ✅ Training NSE: 0.565, Validation NSE: 0.460
#    Training KGE: 0.641, Validation KGE: 0.569
#    Training RMSE: 2.287 m³/s, Validation RMSE: 2.371 m³/s
#    Training PBIAS: 1.990, Validation PBIAS: 8.014
#    Params: mu=1.092, lambda=24.941, Qs=0.001, qs=0.055
#    Bounds used: Qs=(0.001, 114.760), qs=(0.001, 142.920)
#
# === Station 28003 ===, Number=147
# ⚠️ Too many missing values (12.3%)
#
# === Station 28008 ===, Number=148
# ✅ Training NSE: 0.775, Validation NSE: 0.758
#    Training KGE: 0.835, Validation KGE: 0.809
#    Training RMSE: 3.477 m³/s, Validation RMSE: 3.324 m³/s
#    Training PBIAS: -0.559, Validation PBIAS: -0.219
#    Params: mu=1.290, lambda=32.711, Qs=1.149, qs=0.655
#    Bounds used: Qs=(0.001, 202.000), qs=(0.001, 116.080)
#
# === Station 28009 ===, Number=149
# ✅ Training NSE: 0.783, Validation NSE: 0.807
#    Training KGE: 0.855, Validation KGE: 0.865
#    Training RMSE: 34.996 m³/s, Validation RMSE: 32.635 m³/s
#    Training PBIAS: -2.229, Validation PBIAS: -0.200
#    Params: mu=1.165, lambda=45.309, Qs=1.775, qs=0.166
#    Bounds used: Qs=(0.001, 1963.400), qs=(0.001, 104.340)
#
# === Station 28012 ===, Number=150
# ⚠️ Too many missing values (11.3%)
#
# === Station 28015 ===, Number=151
# ✅ Training NSE: 0.635, Validation NSE: 0.647
#    Training KGE: 0.729, Validation KGE: 0.733
#    Training RMSE: 0.854 m³/s, Validation RMSE: 0.855 m³/s
#    Training PBIAS: -1.037, Validation PBIAS: 4.566
#    Params: mu=1.397, lambda=65.846, Qs=1.122, qs=0.819
#    Bounds used: Qs=(0.001, 38.400), qs=(0.001, 123.860)
#
# === Station 28018 ===, Number=152
# ✅ Training NSE: 0.706, Validation NSE: 0.719
#    Training KGE: 0.783, Validation KGE: 0.782
#    Training RMSE: 7.662 m³/s, Validation RMSE: 6.736 m³/s
#    Training PBIAS: -1.341, Validation PBIAS: -2.133
#    Params: mu=1.218, lambda=36.361, Qs=0.781, qs=0.346
#    Bounds used: Qs=(0.001, 427.600), qs=(0.001, 117.680)
#
# === Station 28022 ===, Number=153
# ✅ Training NSE: 0.763, Validation NSE: 0.805
#    Training KGE: 0.841, Validation KGE: 0.888
#    Training RMSE: 38.174 m³/s, Validation RMSE: 32.357 m³/s
#    Training PBIAS: -2.332, Validation PBIAS: 1.620
#    Params: mu=1.158, lambda=46.306, Qs=1.991, qs=0.173
#    Bounds used: Qs=(0.001, 2048.000), qs=(0.001, 104.240)
#
# === Station 28023 ===, Number=154
# ⚠️ Too many missing values (16.6%)
#
# === Station 28024 ===, Number=155
# ✅ Training NSE: 0.604, Validation NSE: 0.613
#    Training KGE: 0.655, Validation KGE: 0.590
#    Training RMSE: 2.980 m³/s, Validation RMSE: 3.063 m³/s
#    Training PBIAS: 6.418, Validation PBIAS: 21.613
#    Params: mu=1.104, lambda=38.265, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 82.000), qs=(0.001, 119.120)
#
# === Station 28026 ===, Number=156
# ✅ Training NSE: 0.601, Validation NSE: 0.604
#    Training KGE: 0.708, Validation KGE: 0.662
#    Training RMSE: 2.596 m³/s, Validation RMSE: 3.071 m³/s
#    Training PBIAS: -7.013, Validation PBIAS: -5.144
#    Params: mu=1.096, lambda=28.000, Qs=0.002, qs=0.026
#    Bounds used: Qs=(0.001, 128.000), qs=(0.001, 101.480)
#
# === Station 28031 ===, Number=157
# ✅ Training NSE: 0.730, Validation NSE: 0.725
#    Training KGE: 0.797, Validation KGE: 0.758
#    Training RMSE: 2.210 m³/s, Validation RMSE: 2.094 m³/s
#    Training PBIAS: -0.687, Validation PBIAS: -1.552
#    Params: mu=1.250, lambda=24.471, Qs=0.295, qs=0.506
#    Bounds used: Qs=(0.001, 182.000), qs=(0.001, 122.280)
#
# === Station 28033 ===, Number=158
# ⚠️ Too many missing values (27.2%)
#
# === Station 28039 ===, Number=159
# ✅ Training NSE: 0.764, Validation NSE: 0.718
#    Training KGE: 0.828, Validation KGE: 0.720
#    Training RMSE: 0.499 m³/s, Validation RMSE: 0.695 m³/s
#    Training PBIAS: -1.395, Validation PBIAS: 11.878
#    Params: mu=1.216, lambda=71.322, Qs=0.001, qs=0.017
#    Bounds used: Qs=(0.001, 32.320), qs=(0.001, 141.800)
#
# === Station 28040 ===, Number=160
# ✅ Training NSE: 0.724, Validation NSE: 0.716
#    Training KGE: 0.790, Validation KGE: 0.801
#    Training RMSE: 0.481 m³/s, Validation RMSE: 0.417 m³/s
#    Training PBIAS: -0.019, Validation PBIAS: 5.729
#    Params: mu=1.141, lambda=26.825, Qs=0.001, qs=0.042
#    Bounds used: Qs=(0.001, 30.200), qs=(0.001, 97.060)
#
# === Station 28043 ===, Number=161
# ✅ Training NSE: 0.742, Validation NSE: 0.724
#    Training KGE: 0.815, Validation KGE: 0.757
#    Training RMSE: 4.031 m³/s, Validation RMSE: 3.911 m³/s
#    Training PBIAS: -2.606, Validation PBIAS: -7.777
#    Params: mu=1.143, lambda=25.629, Qs=0.076, qs=0.235
#    Bounds used: Qs=(0.001, 268.000), qs=(0.001, 131.220)
#
# === Station 28044 ===, Number=162
# ✅ Training NSE: 0.728, Validation NSE: 0.531
#    Training KGE: 0.864, Validation KGE: 0.681
#    Training RMSE: 0.064 m³/s, Validation RMSE: 0.108 m³/s
#    Training PBIAS: -3.177, Validation PBIAS: 14.893
#    Params: mu=0.997, lambda=107.459, Qs=0.011, qs=0.356
#    Bounds used: Qs=(0.001, 3.020), qs=(0.001, 144.020)
#
# === Station 28046 ===, Number=163
# ✅ Training NSE: 0.850, Validation NSE: 0.813
#    Training KGE: 0.884, Validation KGE: 0.863
#    Training RMSE: 0.567 m³/s, Validation RMSE: 0.576 m³/s
#    Training PBIAS: 0.326, Validation PBIAS: 4.215
#    Params: mu=1.333, lambda=36.392, Qs=0.961, qs=1.725
#    Bounds used: Qs=(0.001, 27.600), qs=(0.001, 110.540)
#
# === Station 28048 ===, Number=164
# ✅ Training NSE: 0.671, Validation NSE: 0.631
#    Training KGE: 0.759, Validation KGE: 0.623
#    Training RMSE: 1.116 m³/s, Validation RMSE: 1.415 m³/s
#    Training PBIAS: -5.059, Validation PBIAS: -6.634
#    Params: mu=1.125, lambda=32.384, Qs=0.001, qs=0.026
#    Bounds used: Qs=(0.001, 93.400), qs=(0.001, 138.060)
#
# === Station 28050 ===, Number=165
# ✅ Training NSE: 0.658, Validation NSE: 0.642
#    Training KGE: 0.761, Validation KGE: 0.660
#    Training RMSE: 0.395 m³/s, Validation RMSE: 0.486 m³/s
#    Training PBIAS: -2.536, Validation PBIAS: -0.067
#    Params: mu=1.300, lambda=71.361, Qs=0.117, qs=0.281
#    Bounds used: Qs=(0.001, 17.360), qs=(0.001, 112.860)
#
# === Station 28052 ===, Number=166
# ✅ Training NSE: 0.685, Validation NSE: 0.656
#    Training KGE: 0.779, Validation KGE: 0.598
#    Training RMSE: 0.709 m³/s, Validation RMSE: 0.936 m³/s
#    Training PBIAS: -3.645, Validation PBIAS: -11.220
#    Params: mu=1.145, lambda=36.888, Qs=0.008, qs=0.089
#    Bounds used: Qs=(0.001, 34.400), qs=(0.001, 98.900)
#
# === Station 28055 ===, Number=167
# ✅ Training NSE: 0.760, Validation NSE: 0.705
#    Training KGE: 0.820, Validation KGE: 0.751
#    Training RMSE: 0.427 m³/s, Validation RMSE: 0.458 m³/s
#    Training PBIAS: -0.468, Validation PBIAS: 0.632
#    Params: mu=1.140, lambda=32.482, Qs=0.001, qs=0.041
#    Bounds used: Qs=(0.001, 31.800), qs=(0.001, 132.880)
#
# === Station 28056 ===, Number=168
# ✅ Training NSE: 0.637, Validation NSE: 0.655
#    Training KGE: 0.725, Validation KGE: 0.752
# ...
#    Training PBIAS: -4.962, Validation PBIAS: -5.418
#    Params: mu=1.343, lambda=3.273, Qs=9.820, qs=22.321
#    Bounds used: Qs=(0.001, 119.300), qs=(0.001, 148.420)
#
# === Station 82001 ===, Number=625
# ✅ Training NSE: 0.680, Validation NSE: 0.679
#    Training KGE: 0.740, Validation KGE: 0.723
#    Training RMSE: 5.690 m³/s, Validation RMSE: 6.278 m³/s
#    Training PBIAS: 2.425, Validation PBIAS: 1.819
#    Params: mu=1.132, lambda=42.542, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 194.480), qs=(0.001, 109.780)
#
# === Station 82003 ===, Number=626
# ✅ Training NSE: 0.669, Validation NSE: 0.672
#    Training KGE: 0.711, Validation KGE: 0.726
#    Training RMSE: 7.807 m³/s, Validation RMSE: 9.019 m³/s
#    Training PBIAS: 5.123, Validation PBIAS: 6.547
#    Params: mu=1.149, lambda=63.663, Qs=0.001, qs=0.013
#    Bounds used: Qs=(0.001, 297.200), qs=(0.001, 120.620)
#
# === Station 83003 ===, Number=627
# ✅ Training NSE: 0.662, Validation NSE: 0.616
#    Training KGE: 0.718, Validation KGE: 0.720
#    Training RMSE: 4.392 m³/s, Validation RMSE: 4.710 m³/s
#    Training PBIAS: 3.666, Validation PBIAS: 7.536
#    Params: mu=1.167, lambda=66.933, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 243.200), qs=(0.001, 123.400)
#
# === Station 83004 ===, Number=628
# ✅ Training NSE: 0.680, Validation NSE: 0.612
#    Training KGE: 0.732, Validation KGE: 0.711
#    Training RMSE: 4.794 m³/s, Validation RMSE: 5.321 m³/s
#    Training PBIAS: 4.032, Validation PBIAS: 13.771
#    Params: mu=1.159, lambda=58.357, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 241.600), qs=(0.001, 102.800)
#
# === Station 83006 ===, Number=629
# ✅ Training NSE: 0.665, Validation NSE: 0.597
#    Training KGE: 0.751, Validation KGE: 0.692
#    Training RMSE: 13.162 m³/s, Validation RMSE: 15.773 m³/s
#    Training PBIAS: -3.932, Validation PBIAS: -7.830
#    Params: mu=1.117, lambda=33.401, Qs=0.001, qs=0.012
#    Bounds used: Qs=(0.001, 621.200), qs=(0.001, 99.080)
#
# === Station 83007 ===, Number=630
# ✅ Training NSE: 0.704, Validation NSE: 0.618
#    Training KGE: 0.775, Validation KGE: 0.782
#    Training RMSE: 1.462 m³/s, Validation RMSE: 1.503 m³/s
#    Training PBIAS: -0.337, Validation PBIAS: 3.122
#    Params: mu=1.133, lambda=25.536, Qs=0.001, qs=0.045
#    Bounds used: Qs=(0.001, 79.840), qs=(0.001, 164.340)
#
# === Station 83009 ===, Number=631
# ✅ Training NSE: 0.629, Validation NSE: 0.595
#    Training KGE: 0.677, Validation KGE: 0.747
#    Training RMSE: 6.340 m³/s, Validation RMSE: 5.612 m³/s
#    Training PBIAS: 7.092, Validation PBIAS: 11.973
#    Params: mu=1.142, lambda=38.243, Qs=0.001, qs=0.020
#    Bounds used: Qs=(0.001, 468.400), qs=(0.001, 152.980)
#
# === Station 83010 ===, Number=632
# ✅ Training NSE: 0.732, Validation NSE: 0.703
#    Training KGE: 0.771, Validation KGE: 0.787
#    Training RMSE: 1.837 m³/s, Validation RMSE: 1.856 m³/s
#    Training PBIAS: 5.190, Validation PBIAS: 10.663
#    Params: mu=1.172, lambda=51.580, Qs=0.001, qs=0.023
#    Bounds used: Qs=(0.001, 130.800), qs=(0.001, 150.020)
#
# === Station 83013 ===, Number=633
# ✅ Training NSE: 0.643, Validation NSE: 0.613
#    Training KGE: 0.708, Validation KGE: 0.745
#    Training RMSE: 6.407 m³/s, Validation RMSE: 5.658 m³/s
#    Training PBIAS: 3.417, Validation PBIAS: 16.878
#    Params: mu=1.131, lambda=31.211, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 446.800), qs=(0.001, 134.140)
#
# === Station 84001 ===, Number=634
# ✅ Training NSE: 0.751, Validation NSE: 0.740
#    Training KGE: 0.800, Validation KGE: 0.772
#    Training RMSE: 5.177 m³/s, Validation RMSE: 5.525 m³/s
#    Training PBIAS: 1.702, Validation PBIAS: 2.767
#    Params: mu=1.144, lambda=71.658, Qs=0.001, qs=0.012
#    Bounds used: Qs=(0.001, 364.000), qs=(0.001, 164.580)
#
# === Station 84004 ===, Number=635
# ✅ Training NSE: 0.696, Validation NSE: 0.639
#    Training KGE: 0.773, Validation KGE: 0.718
#    Training RMSE: 12.839 m³/s, Validation RMSE: 15.668 m³/s
#    Training PBIAS: -1.041, Validation PBIAS: 0.265
#    Params: mu=1.262, lambda=28.199, Qs=2.349, qs=0.846
#    Bounds used: Qs=(0.001, 598.600), qs=(0.001, 92.860)
#
# === Station 84005 ===, Number=636
# ✅ Training NSE: 0.749, Validation NSE: 0.713
#    Training KGE: 0.811, Validation KGE: 0.769
#    Training RMSE: 26.857 m³/s, Validation RMSE: 30.307 m³/s
#    Training PBIAS: -0.290, Validation PBIAS: -1.500
#    Params: mu=1.171, lambda=39.733, Qs=0.186, qs=0.103
#    Bounds used: Qs=(0.001, 1352.800), qs=(0.001, 96.400)
#
# === Station 84008 ===, Number=637
# ✅ Training NSE: 0.692, Validation NSE: 0.689
#    Training KGE: 0.739, Validation KGE: 0.655
#    Training RMSE: 1.402 m³/s, Validation RMSE: 1.653 m³/s
#    Training PBIAS: 4.835, Validation PBIAS: 2.974
#    Params: mu=1.190, lambda=72.751, Qs=0.001, qs=0.022
#    Bounds used: Qs=(0.001, 72.060), qs=(0.001, 137.760)
#
# === Station 84009 ===, Number=638
# ✅ Training NSE: 0.760, Validation NSE: 0.699
#    Training KGE: 0.825, Validation KGE: 0.747
#    Training RMSE: 1.195 m³/s, Validation RMSE: 1.375 m³/s
#    Training PBIAS: -1.882, Validation PBIAS: -9.097
#    Params: mu=1.170, lambda=34.141, Qs=0.003, qs=0.068
#    Bounds used: Qs=(0.001, 88.780), qs=(0.001, 122.500)
#
# === Station 84012 ===, Number=639
# ✅ Training NSE: 0.727, Validation NSE: 0.688
#    Training KGE: 0.777, Validation KGE: 0.766
#    Training RMSE: 5.165 m³/s, Validation RMSE: 4.711 m³/s
#    Training PBIAS: 2.989, Validation PBIAS: 16.700
#    Params: mu=1.146, lambda=55.027, Qs=0.001, qs=0.015
#    Bounds used: Qs=(0.001, 342.800), qs=(0.001, 179.240)
#
# === Station 84013 ===, Number=640
# ✅ Training NSE: 0.728, Validation NSE: 0.718
#    Training KGE: 0.795, Validation KGE: 0.799
#    Training RMSE: 30.694 m³/s, Validation RMSE: 30.049 m³/s
#    Training PBIAS: -0.336, Validation PBIAS: 11.364
#    Params: mu=1.139, lambda=58.910, Qs=0.010, qs=0.017
#    Bounds used: Qs=(0.001, 1875.400), qs=(0.001, 98.280)
#
# === Station 84014 ===, Number=641
# ✅ Training NSE: 0.703, Validation NSE: 0.693
#    Training KGE: 0.746, Validation KGE: 0.746
#    Training RMSE: 6.791 m³/s, Validation RMSE: 6.655 m³/s
#    Training PBIAS: 5.467, Validation PBIAS: 7.051
#    Params: mu=1.150, lambda=55.705, Qs=0.001, qs=0.012
#    Bounds used: Qs=(0.001, 427.600), qs=(0.001, 151.240)
#
# === Station 84016 ===, Number=642
# ✅ Training NSE: 0.667, Validation NSE: 0.689
#    Training KGE: 0.751, Validation KGE: 0.814
#    Training RMSE: 0.732 m³/s, Validation RMSE: 0.599 m³/s
#    Training PBIAS: -2.743, Validation PBIAS: 9.959
#    Params: mu=1.164, lambda=36.308, Qs=0.001, qs=0.041
#    Bounds used: Qs=(0.001, 74.060), qs=(0.001, 144.700)
#
# === Station 84017 ===, Number=643
# ✅ Training NSE: 0.747, Validation NSE: 0.741
#    Training KGE: 0.779, Validation KGE: 0.820
#    Training RMSE: 2.839 m³/s, Validation RMSE: 2.616 m³/s
#    Training PBIAS: 3.952, Validation PBIAS: 9.826
#    Params: mu=1.140, lambda=62.092, Qs=0.001, qs=0.028
#    Bounds used: Qs=(0.001, 191.600), qs=(0.001, 241.980)
#
# === Station 84018 ===, Number=644
# ✅ Training NSE: 0.704, Validation NSE: 0.609
#    Training KGE: 0.776, Validation KGE: 0.736
#    Training RMSE: 17.357 m³/s, Validation RMSE: 20.753 m³/s
#    Training PBIAS: -0.554, Validation PBIAS: 6.897
#    Params: mu=1.185, lambda=38.475, Qs=0.289, qs=0.193
#    Bounds used: Qs=(0.001, 895.200), qs=(0.001, 94.980)
#
# === Station 84019 ===, Number=645
# ✅ Training NSE: 0.690, Validation NSE: 0.679
#    Training KGE: 0.759, Validation KGE: 0.719
#    Training RMSE: 2.033 m³/s, Validation RMSE: 1.882 m³/s
#    Training PBIAS: 0.521, Validation PBIAS: 21.418
#    Params: mu=1.152, lambda=48.658, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 186.260), qs=(0.001, 106.660)
#
# === Station 84020 ===, Number=646
# ✅ Training NSE: 0.690, Validation NSE: 0.649
#    Training KGE: 0.723, Validation KGE: 0.702
#    Training RMSE: 1.803 m³/s, Validation RMSE: 1.761 m³/s
#    Training PBIAS: 6.890, Validation PBIAS: 20.783
#    Params: mu=1.196, lambda=77.978, Qs=0.001, qs=0.023
#    Bounds used: Qs=(0.001, 114.300), qs=(0.001, 190.300)
#
# === Station 84022 ===, Number=647
# ✅ Training NSE: 0.653, Validation NSE: 0.637
#    Training KGE: 0.729, Validation KGE: 0.775
#    Training RMSE: 2.749 m³/s, Validation RMSE: 2.728 m³/s
#    Training PBIAS: -0.175, Validation PBIAS: 4.806
#    Params: mu=1.157, lambda=49.501, Qs=0.001, qs=0.023
#    Bounds used: Qs=(0.001, 183.480), qs=(0.001, 103.020)
#
# === Station 84026 ===, Number=648
# ✅ Training NSE: 0.733, Validation NSE: 0.295
#    Training KGE: 0.801, Validation KGE: 0.635
#    Training RMSE: 1.014 m³/s, Validation RMSE: 1.321 m³/s
#    Training PBIAS: -11.245, Validation PBIAS: 5.264
#    Params: mu=1.228, lambda=2.634, Qs=5.768, qs=26.874
#    Bounds used: Qs=(0.001, 81.540), qs=(0.001, 193.220)
#
# === Station 84030 ===, Number=649
# ✅ Training NSE: 0.754, Validation NSE: 0.728
#    Training KGE: 0.787, Validation KGE: 0.740
#    Training RMSE: 2.531 m³/s, Validation RMSE: 2.770 m³/s
#    Training PBIAS: 5.371, Validation PBIAS: 8.191
#    Params: mu=1.168, lambda=59.129, Qs=0.001, qs=0.019
#    Bounds used: Qs=(0.001, 151.180), qs=(0.001, 169.580)
#
# === Station 85001 ===, Number=650
# ✅ Training NSE: 0.811, Validation NSE: 0.742
#    Training KGE: 0.847, Validation KGE: 0.846
#    Training RMSE: 14.759 m³/s, Validation RMSE: 16.132 m³/s
#    Training PBIAS: 0.711, Validation PBIAS: -5.616
#    Params: mu=1.712, lambda=7.579, Qs=196.113, qs=50.003
#    Bounds used: Qs=(0.001, 433.400), qs=(0.001, 176.560)
#
# === Station 85002 ===, Number=651
# ✅ Training NSE: 0.697, Validation NSE: 0.616
#    Training KGE: 0.726, Validation KGE: 0.568
#    Training RMSE: 6.390 m³/s, Validation RMSE: 8.971 m³/s
#    Training PBIAS: 7.453, Validation PBIAS: -11.150
#    Params: mu=1.161, lambda=70.984, Qs=0.001, qs=0.013
#    Bounds used: Qs=(0.001, 234.600), qs=(0.001, 155.320)
#
# === Station 85003 ===, Number=652
# ✅ Training NSE: 0.655, Validation NSE: 0.390
#    Training KGE: 0.741, Validation KGE: 0.695
#    Training RMSE: 6.286 m³/s, Validation RMSE: 6.589 m³/s
#    Training PBIAS: -10.450, Validation PBIAS: 9.652
#    Params: mu=1.136, lambda=23.602, Qs=0.001, qs=0.055
#    Bounds used: Qs=(0.001, 247.200), qs=(0.001, 251.520)
#
# === Station 85004 ===, Number=653
# ✅ Training NSE: 0.717, Validation NSE: 0.623
#    Training KGE: 0.753, Validation KGE: 0.682
#    Training RMSE: 1.766 m³/s, Validation RMSE: 1.752 m³/s
#    Training PBIAS: 4.881, Validation PBIAS: 27.558
#    Params: mu=1.230, lambda=133.894, Qs=0.001, qs=0.024
#    Bounds used: Qs=(0.001, 78.480), qs=(0.001, 196.240)
#
# === Station 88001 ===, Number=654
# ⚠️ Too many missing values (23.8%)
#
# === Station 89002 ===, Number=655
# ✅ Training NSE: 0.622, Validation NSE: 0.498
#    Training KGE: 0.641, Validation KGE: 0.479
#    Training RMSE: 4.588 m³/s, Validation RMSE: 5.055 m³/s
#    Training PBIAS: 11.655, Validation PBIAS: 48.253
#    Params: mu=1.213, lambda=119.453, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 255.800), qs=(0.001, 234.620)
#
# === Station 89003 ===, Number=656
# ✅ Training NSE: 0.648, Validation NSE: 0.558
#    Training KGE: 0.682, Validation KGE: 0.553
#    Training RMSE: 22.340 m³/s, Validation RMSE: 24.069 m³/s
#    Training PBIAS: 8.710, Validation PBIAS: 39.611
#    Params: mu=1.156, lambda=73.821, Qs=0.001, qs=0.014
#    Bounds used: Qs=(0.001, 895.600), qs=(0.001, 215.980)
#
# === Station 89005 ===, Number=657
# ✅ Training NSE: 0.518, Validation NSE: 0.359
#    Training KGE: 0.616, Validation KGE: 0.622
#    Training RMSE: 6.511 m³/s, Validation RMSE: 6.997 m³/s
#    Training PBIAS: -10.606, Validation PBIAS: 6.528
#    Params: mu=1.183, lambda=9.311, Qs=0.193, qs=1.863
#    Bounds used: Qs=(0.001, 381.400), qs=(0.001, 223.040)
#
# === Station 89007 ===, Number=658
# ✅ Training NSE: 0.571, Validation NSE: 0.470
#    Training KGE: 0.605, Validation KGE: 0.494
#    Training RMSE: 1.582 m³/s, Validation RMSE: 1.338 m³/s
#    Training PBIAS: 8.985, Validation PBIAS: 46.132
#    Params: mu=1.242, lambda=128.136, Qs=0.001, qs=0.034
#    Bounds used: Qs=(0.001, 96.740), qs=(0.001, 213.120)
#
# === Station 90003 ===, Number=659
# ✅ Training NSE: 0.683, Validation NSE: 0.680
#    Training KGE: 0.734, Validation KGE: 0.757
#    Training RMSE: 5.141 m³/s, Validation RMSE: 4.639 m³/s
#    Training PBIAS: 4.040, Validation PBIAS: 10.089
#    Params: mu=1.195, lambda=99.100, Qs=0.001, qs=0.025
#    Bounds used: Qs=(0.001, 263.800), qs=(0.001, 269.260)
#
# === Station 9002 ===, Number=660
# ✅ Training NSE: 0.669, Validation NSE: 0.450
#    Training KGE: 0.751, Validation KGE: 0.605
#    Training RMSE: 11.240 m³/s, Validation RMSE: 17.566 m³/s
#    Training PBIAS: -1.332, Validation PBIAS: 0.935
#    Params: mu=1.161, lambda=43.109, Qs=0.077, qs=0.081
#    Bounds used: Qs=(0.001, 575.400), qs=(0.001, 134.140)
#
# === Station 9003 ===, Number=661
# ✅ Training NSE: 0.681, Validation NSE: 0.432
#    Training KGE: 0.769, Validation KGE: 0.678
#    Training RMSE: 2.369 m³/s, Validation RMSE: 3.756 m³/s
#    Training PBIAS: -6.654, Validation PBIAS: -3.852
#    Params: mu=1.115, lambda=28.483, Qs=0.001, qs=0.022
#    Bounds used: Qs=(0.001, 160.900), qs=(0.001, 140.980)
#
# === Station 9004 ===, Number=662
# ✅ Training NSE: 0.716, Validation NSE: 0.540
#    Training KGE: 0.797, Validation KGE: 0.740
#    Training RMSE: 1.608 m³/s, Validation RMSE: 1.948 m³/s
#    Training PBIAS: -1.750, Validation PBIAS: -6.688
#    Params: mu=1.199, lambda=41.228, Qs=0.144, qs=0.344
#    Bounds used: Qs=(0.001, 110.660), qs=(0.001, 133.360)
#
# === Station 9005 ===, Number=663
# ✅ Training NSE: 0.524, Validation NSE: 0.321
#    Training KGE: 0.631, Validation KGE: 0.485
#    Training RMSE: 1.474 m³/s, Validation RMSE: 1.994 m³/s
#    Training PBIAS: -4.535, Validation PBIAS: -6.017
#    Params: mu=1.166, lambda=59.422, Qs=0.001, qs=0.024
#    Bounds used: Qs=(0.001, 65.940), qs=(0.001, 148.780)
#
# === Station 92001 ===, Number=664
# ⚠️ Too many missing values (22.3%)
#
# === Station 93001 ===, Number=665
# ✅ Training NSE: 0.666, Validation NSE: 0.709
#    Training KGE: 0.705, Validation KGE: 0.693
#    Training RMSE: 8.593 m³/s, Validation RMSE: 7.198 m³/s
#    Training PBIAS: 6.154, Validation PBIAS: 2.641
#    Params: mu=1.182, lambda=103.674, Qs=0.001, qs=0.018
#    Bounds used: Qs=(0.001, 407.800), qs=(0.001, 222.800)
#
# === Station 94001 ===, Number=666
# ✅ Training NSE: 0.789, Validation NSE: 0.861
#    Training KGE: 0.832, Validation KGE: 0.839
#    Training RMSE: 11.129 m³/s, Validation RMSE: 8.158 m³/s
#    Training PBIAS: 0.657, Validation PBIAS: 3.670
#    Params: mu=1.166, lambda=143.402, Qs=0.017, qs=0.061
#    Bounds used: Qs=(0.001, 359.800), qs=(0.001, 183.400)
#
# === Station 95001 ===, Number=667
# ✅ Training NSE: 0.730, Validation NSE: 0.769
#    Training KGE: 0.793, Validation KGE: 0.813
#    Training RMSE: 3.227 m³/s, Validation RMSE: 2.784 m³/s
#    Training PBIAS: 0.047, Validation PBIAS: 6.954
#    Params: mu=1.170, lambda=143.322, Qs=0.005, qs=0.058
#    Bounds used: Qs=(0.001, 113.440), qs=(0.001, 181.800)
#
# === Station 96001 ===, Number=668
# ✅ Training NSE: 0.529, Validation NSE: 0.443
#    Training KGE: 0.639, Validation KGE: 0.643
#    Training RMSE: 5.134 m³/s, Validation RMSE: 5.209 m³/s
#    Training PBIAS: -7.866, Validation PBIAS: -5.239
#    Params: mu=1.312, lambda=2.650, Qs=24.377, qs=21.391
#    Bounds used: Qs=(0.001, 258.000), qs=(0.001, 122.100)
#
# === Station 96002 ===, Number=669
# ✅ Training NSE: 0.696, Validation NSE: 0.666
#    Training KGE: 0.703, Validation KGE: 0.645
#    Training RMSE: 10.187 m³/s, Validation RMSE: 10.048 m³/s
#    Training PBIAS: 7.540, Validation PBIAS: 5.783
#    Params: mu=1.153, lambda=130.564, Qs=0.001, qs=0.008
#    Bounds used: Qs=(0.001, 627.000), qs=(0.001, 118.800)
#
# === Station 96004 ===, Number=670
# ✅ Training NSE: 0.560, Validation NSE: 0.538
#    Training KGE: 0.671, Validation KGE: 0.569
#    Training RMSE: 7.180 m³/s, Validation RMSE: 6.897 m³/s
#    Training PBIAS: -12.963, Validation PBIAS: -18.062
#    Params: mu=1.143, lambda=30.871, Qs=0.001, qs=0.040
#    Bounds used: Qs=(0.001, 301.800), qs=(0.001, 268.500)
#
# === Station 97002 ===, Number=671
# ✅ Training NSE: 0.576, Validation NSE: 0.437
#    Training KGE: 0.633, Validation KGE: 0.488
#    Training RMSE: 7.440 m³/s, Validation RMSE: 9.645 m³/s
#    Training PBIAS: 3.719, Validation PBIAS: 7.043
#    Params: mu=1.133, lambda=72.105, Qs=0.001, qs=0.010
#    Bounds used: Qs=(0.001, 501.800), qs=(0.001, 114.720)
#
# ✅ Simulation done for 623 valid catchments (≤10% de NaN).

# %% [markdown]
# ## 5. SAVE SUMMARY

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# ============================================
# 1. EXTRACT DATA TO DATAFRAME
# ============================================
rows = []
seasons = ["DJF", "MAM", "JJA", "SON"]

for station_id, res in results.items():
    # Dynamically unpack parameters (mu, lambda, Qs, qs) using param_names
    param_dict = dict(zip(res["param_names"], res["params"]))

    row = {
        "station_id": station_id,
        **param_dict,
        "RR": res.get("RR", np.nan),
        "NSE_train": res.get("NSE_train", np.nan),
        "NSE_val": res.get("NSE_val", np.nan),
        "NNSE_train": res.get("NNSE_train", np.nan),
        "NNSE_val": res.get("NNSE_val", np.nan),
        "RMSE_train": res.get("RMSE_train", np.nan),
        "RMSE_val": res.get("RMSE_val", np.nan),
        "PBIAS_train": res.get("PBIAS_train", np.nan),
        "PBIAS_val": res.get("PBIAS_val", np.nan),
        "FHV_train": res.get("FHV_train", np.nan),
        "FHV_val": res.get("FHV_val", np.nan),
        "FLV_train": res.get("FLV_train", np.nan),
        "FLV_val": res.get("FLV_val", np.nan),
        "KGE_train": res.get("KGE_train", np.nan),
        "KGE_val": res.get("KGE_val", np.nan),
        "PTE_train": res.get("PTE_train", np.nan),
        "PTE_val": res.get("PTE_val", np.nan),
        "missing_ratio": res.get("missing_ratio", np.nan),
        "missing_count": res.get("missing_count", np.nan),
    }

    # Dynamically add seasonal metrics
    for season in seasons:
        row[f"NSE_{season}_train"]   = res.get(f"NSE_{season}_train", np.nan)
        row[f"NSE_{season}_val"]     = res.get(f"NSE_{season}_val", np.nan)
        row[f"KGE_{season}_train"]   = res.get(f"KGE_{season}_train", np.nan)
        row[f"KGE_{season}_val"]     = res.get(f"KGE_{season}_val", np.nan)
        row[f"RMSE_{season}_train"]  = res.get(f"RMSE_{season}_train", np.nan)
        row[f"RMSE_{season}_val"]    = res.get(f"RMSE_{season}_val", np.nan)
        row[f"PBIAS_{season}_train"] = res.get(f"PBIAS_{season}_train", np.nan)
        row[f"PBIAS_{season}_val"]   = res.get(f"PBIAS_{season}_val", np.nan)

    rows.append(row)

df = pd.DataFrame(rows)

# ============================================
# 2. SAVE RESULTS
# ============================================
# Local save
df.to_csv("dHyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)
print("✅ Saved locally to dHyMoLAP_Simulation_Data_CAMELS_GB.csv")

# Save to Google Drive (this is the file the loader script reads back)
drive.mount("/content/drive")
df.to_csv("/content/drive/MyDrive/Colab Notebooks/Data/dHyMoLAP_Simulation_Data_CAMELS_GB.csv", index=False)
print("✅ Saved to Google Drive")

# ============================================
# 3. DEFINE METRICS TO REPORT
# ============================================
global_metrics = [
    ("NSE_train",   "NSE Training",     ""),
    ("NSE_val",     "NSE Validation",   ""),
    ("NNSE_train",  "NNSE Training",    ""),
    ("NNSE_val",    "NNSE Validation",  ""),
    ("KGE_train",   "KGE Training",     ""),
    ("KGE_val",     "KGE Validation",   ""),
    ("RMSE_train",  "RMSE Training",    " m³/s"),
    ("RMSE_val",    "RMSE Validation",  " m³/s"),
    ("PTE_train",   "PTE Training",     " days"),
    ("PTE_val",     "PTE Validation",   " days"),
    ("PBIAS_train", "PBIAS Training",   "%"),
    ("PBIAS_val",   "PBIAS Validation", "%"),
    ("FHV_train",   "FHV Training",     "%"),
    ("FHV_val",     "FHV Validation",   "%"),
    ("FLV_train",   "FLV Training",     "%"),
    ("FLV_val",     "FLV Validation",   "%"),
    ("RR",          "Runoff Ratio",     ""),
]

base_vars = ["NSE", "KGE", "RMSE", "PBIAS"]
seasons_metrics = []
for var in base_vars:
    unit = " m³/s" if var == "RMSE" else ("%" if var == "PBIAS" else "")
    for s in seasons:
        for split, label in [("train", "Training"), ("val", "Validation")]:
            col = f"{var}_{s}_{split}"
            seasons_metrics.append((col, f"{var} {s} {label}", unit))

# ============================================
# 4. REPORTING STATISTICS
# ============================================
def print_stats(metrics_list, df, title):
    print(f"\n{'='*60}")
    print(f" {title}")
    print(f"{'='*60}")
    for key, label, unit in metrics_list:
        if key not in df.columns:
            print(f"  ⚠️  '{key}' not found in CSV — skipping.")
            continue
        values = pd.to_numeric(df[key], errors="coerce").to_numpy()
        n_valid   = int(np.sum(~np.isnan(values)))
        n_dropped = int(np.sum( np.isnan(values)))
        if n_valid == 0:
            print(f"  ⚠️  {label}: all NaN — no valid stations.")
            continue
        print(
            f"  {label:<28} | "
            f"Mean: {np.nanmean(values):8.3f}{unit}  "
            f"Median: {np.nanmedian(values):8.3f}{unit}  "
            f"Min: {np.nanmin(values):8.3f}{unit}  "
            f"Max: {np.nanmax(values):8.3f}{unit}  "
            f"P05: {np.nanpercentile(values,  5):8.3f}{unit}  "
            f"P95: {np.nanpercentile(values, 95):8.3f}{unit}  "
            f"(n={n_valid})"
        )
        if n_dropped:
            print(f"    ⚠️  {n_dropped} station(s) excluded (NaN).")

print(f"\n✅ Saved {len(df)} stations to CSV.")
print_stats(global_metrics,  df, "GLOBAL SUMMARY STATISTICS")
print_stats(seasons_metrics, df, "SEASONAL SUMMARY STATISTICS")
# Out:
# ✅ Saved locally to dHyMoLAP_Simulation_Data_CAMELS_GB.csv
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Saved to Google Drive
#
# ✅ Saved 623 stations to CSV.
#
# ============================================================
#  GLOBAL SUMMARY STATISTICS
# ============================================================
#   NSE Training                 | Mean:    0.703  Median:    0.717  Min:    0.033  Max:    0.922  P05:    0.529  P95:    0.827  (n=623)
#   NSE Validation               | Mean:    0.650  Median:    0.683  Min:   -1.764  Max:    0.906  P05:    0.432  P95:    0.806  (n=623)
#   NNSE Training                | Mean:    0.775  Median:    0.780  Min:    0.508  Max:    0.928  P05:    0.680  P95:    0.852  (n=623)
#   NNSE Validation              | Mean:    0.749  Median:    0.759  Min:    0.266  Max:    0.914  P05:    0.638  P95:    0.837  (n=623)
#   KGE Training                 | Mean:    0.763  Median:    0.782  Min:   -0.060  Max:    0.938  P05:    0.599  P95:    0.867  (n=623)
#   KGE Validation               | Mean:    0.715  Median:    0.741  Min:   -0.547  Max:    0.947  P05:    0.488  P95:    0.863  (n=623)
#   RMSE Training                | Mean:    4.822 m³/s  Median:    1.686 m³/s  Min:    0.017 m³/s  Max:   74.799 m³/s  P05:    0.140 m³/s  P95:   22.259 m³/s  (n=623)
#   RMSE Validation              | Mean:    5.232 m³/s  Median:    2.017 m³/s  Min:    0.022 m³/s  Max:   82.058 m³/s  P05:    0.155 m³/s  P95:   22.770 m³/s  (n=623)
#   PTE Training                 | Mean:   69.930 days  Median:   69.250 days  Min:    0.824 days  Max:  161.353 days  P05:   25.324 days  P95:  121.406 days  (n=623)
#   PTE Validation               | Mean:   72.732 days  Median:   68.714 days  Min:    0.143 days  Max:  230.286 days  P05:    6.286 days  P95:  148.136 days  (n=623)
#   PBIAS Training               | Mean:    0.562%  Median:   -0.132%  Min:  -27.299%  Max:   38.797%  P05:   -7.455%  P95:   10.309%  (n=623)
#   PBIAS Validation             | Mean:    2.754%  Median:    2.006%  Min:  -35.754%  Max:   86.131%  P05:  -11.444%  P95:   19.827%  (n=623)
#   FHV Training                 | Mean:  -20.514%  Median:  -20.278%  Min:  -56.781%  Max:   23.088%  P05:  -36.115%  P95:   -7.709%  (n=623)
#   FHV Validation               | Mean:  -20.752%  Median:  -21.854%  Min:  -70.943%  Max:  111.307%  P05:  -43.602%  P95:    5.212%  (n=623)
#   FLV Training                 | Mean: -144.070%  Median:  -93.594%  Min: -1630.671%  Max:   91.251%  P05: -471.877%  P95:   63.865%  (n=619)
#     ⚠️  4 station(s) excluded (NaN).
#   FLV Validation               | Mean: -173.428%  Median: -109.419%  Min: -3120.935%  Max:   91.100%  P05: -644.350%  P95:   31.100%  (n=619)
#     ⚠️  4 station(s) excluded (NaN).
#   Runoff Ratio                 | Mean:    2.543  Median:    0.881  Min:    0.011  Max:   48.505  P05:    0.098  P95:    9.078  (n=623)
#
# ============================================================
#  SEASONAL SUMMARY STATISTICS
# ============================================================
#   NSE DJF Training             | Mean:    0.662  Median:    0.678  Min:    0.032  Max:    0.900  P05:    0.471  P95:    0.796  (n=623)
#   NSE DJF Validation           | Mean:    0.595  Median:    0.643  Min:   -2.041  Max:    0.915  P05:    0.205  P95:    0.804  (n=623)
#   NSE MAM Training             | Mean:    0.660  Median:    0.677  Min:   -0.067  Max:    0.920  P05:    0.450  P95:    0.794  (n=623)
#   NSE MAM Validation           | Mean:    0.506  Median:    0.555  Min:   -1.073  Max:    0.892  P05:    0.143  P95:    0.716  (n=623)
#   NSE JJA Training             | Mean:    0.153  Median:    0.559  Min:  -16.639  Max:    0.871  P05:   -1.315  P95:    0.737  (n=623)
#   NSE JJA Validation           | Mean:    0.294  Median:    0.628  Min:  -11.945  Max:    0.843  P05:   -1.106  P95:    0.770  (n=623)
#   NSE SON Training             | Mean:    0.654  Median:    0.695  Min:   -1.725  Max:    0.860  P05:    0.396  P95:    0.808  (n=623)
#   NSE SON Validation           | Mean:    0.600  Median:    0.690  Min:   -4.414  Max:    0.859  P05:    0.171  P95:    0.808  (n=623)
#   KGE DJF Training             | Mean:    0.737  Median:    0.760  Min:   -0.050  Max:    0.931  P05:    0.530  P95:    0.857  (n=623)
#   KGE DJF Validation           | Mean:    0.681  Median:    0.717  Min:   -0.624  Max:    0.939  P05:    0.394  P95:    0.867  (n=623)
#   KGE MAM Training             | Mean:    0.705  Median:    0.732  Min:   -0.271  Max:    0.925  P05:    0.468  P95:    0.872  (n=623)
#   KGE MAM Validation           | Mean:    0.631  Median:    0.666  Min:   -0.149  Max:    0.925  P05:    0.314  P95:    0.809  (n=623)
#   KGE JJA Training             | Mean:    0.441  Median:    0.606  Min:   -7.404  Max:    0.934  P05:   -0.400  P95:    0.792  (n=623)
#   KGE JJA Validation           | Mean:    0.472  Median:    0.598  Min:   -3.571  Max:    0.892  P05:   -0.434  P95:    0.779  (n=623)
#   KGE SON Training             | Mean:    0.621  Median:    0.656  Min:   -1.407  Max:    0.908  P05:    0.267  P95:    0.803  (n=623)
#   KGE SON Validation           | Mean:    0.609  Median:    0.661  Min:   -3.684  Max:    0.882  P05:    0.293  P95:    0.803  (n=623)
#   RMSE DJF Training            | Mean:    6.844 m³/s  Median:    2.321 m³/s  Min:    0.018 m³/s  Max:  110.418 m³/s  P05:    0.158 m³/s  P95:   29.344 m³/s  (n=623)
#   RMSE DJF Validation          | Mean:    7.270 m³/s  Median:    2.780 m³/s  Min:    0.021 m³/s  Max:  123.449 m³/s  P05:    0.184 m³/s  P95:   29.371 m³/s  (n=623)
#   RMSE MAM Training            | Mean:    3.977 m³/s  Median:    1.374 m³/s  Min:    0.017 m³/s  Max:   65.823 m³/s  P05:    0.113 m³/s  P95:   18.870 m³/s  (n=623)
#   RMSE MAM Validation          | Mean:    4.080 m³/s  Median:    1.469 m³/s  Min:    0.026 m³/s  Max:   76.677 m³/s  P05:    0.127 m³/s  P95:   17.910 m³/s  (n=623)
#   RMSE JJA Training            | Mean:    2.450 m³/s  Median:    0.941 m³/s  Min:    0.015 m³/s  Max:   31.582 m³/s  P05:    0.091 m³/s  P95:   10.165 m³/s  (n=623)
#   RMSE JJA Validation          | Mean:    3.620 m³/s  Median:    1.447 m³/s  Min:    0.020 m³/s  Max:   49.791 m³/s  P05:    0.109 m³/s  P95:   15.080 m³/s  (n=623)
#   RMSE SON Training            | Mean:    4.829 m³/s  Median:    1.797 m³/s  Min:    0.015 m³/s  Max:   69.947 m³/s  P05:    0.142 m³/s  P95:   22.097 m³/s  (n=623)
#   RMSE SON Validation          | Mean:    5.023 m³/s  Median:    1.854 m³/s  Min:    0.017 m³/s  Max:   67.804 m³/s  P05:    0.126 m³/s  P95:   22.328 m³/s  (n=623)
#   PBIAS DJF Training           | Mean:   -3.311%  Median:   -2.046%  Min:  -28.336%  Max:   26.103%  P05:  -15.951%  P95:    5.768%  (n=623)
#   PBIAS DJF Validation         | Mean:    0.885%  Median:    0.715%  Min:  -41.090%  Max:  105.709%  P05:  -18.835%  P95:   19.674%  (n=623)
#   PBIAS MAM Training           | Mean:   -8.188%  Median:  -11.986%  Min:  -49.880%  Max:   41.751%  P05:  -29.322%  P95:   20.773%  (n=623)
#   PBIAS MAM Validation         | Mean:   -4.398%  Median:   -8.083%  Min:  -55.975%  Max:   69.551%  P05:  -32.079%  P95:   35.018%  (n=623)
#   PBIAS JJA Training           | Mean:   26.593%  Median:   15.948%  Min:  -47.964%  Max:  818.601%  P05:  -16.667%  P95:   96.636%  (n=623)
#   PBIAS JJA Validation         | Mean:   23.242%  Median:   13.600%  Min:  -50.277%  Max:  406.915%  P05:  -14.158%  P95:   99.341%  (n=623)
#   PBIAS SON Training           | Mean:   13.996%  Median:    7.771%  Min:  -38.771%  Max:  239.962%  P05:  -14.554%  P95:   62.935%  (n=623)
#   PBIAS SON Validation         | Mean:    9.191%  Median:    2.630%  Min:  -39.087%  Max:  455.939%  P05:  -17.918%  P95:   54.603%  (n=623)
